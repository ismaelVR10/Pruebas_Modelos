# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Librerias
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split, KFold
from keras.callbacks import EarlyStopping

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import load_model

from keras.initializers import he_uniform

from tensorflow.keras.optimizers import RMSprop

from tensorflow.keras.utils import plot_model

# %%
#Dataset Adulto 01
data = pd.read_csv('/content/gdrive/MyDrive/Proyecto_de_grado/SUSTENTACION3.0/FinalX3/adulto09/my_adult09A2_data.csv')

print(f"El archivo se ha cargado correctamente. Tiene {data.shape[0]} filas y {data.shape[1]} columnas.")
# Out:
# El archivo se ha cargado correctamente. Tiene 29768 filas y 3 columnas.

# %%
train_size = int(len(data) * 0.7)

train_data = data.iloc[:train_size, :] # 70% entrenamiento
test_data = data.iloc[train_size:, :] # 30% prueba

test_data = test_data.reset_index(drop=True)

# %%
#los indices donde hay ingestas
posicionestrain = train_data.loc[train_data.iloc[:, 0] != 0].index
posicionestest = test_data.loc[test_data.iloc[:, 0] != 0].index

df_posiciones_train = pd.DataFrame(posicionestrain)
df_posiciones_test = pd.DataFrame(posicionestest)

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_train = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_train)):
    anterior = df_posiciones_train.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_train.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_train.append(anterior)

ultimo_elemento_train = df_posiciones_train.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_train.extend(ultimo_elemento_train.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_train)
print(len(cumplen_train))
# Out:
# [491, 868, 1366, 1985, 2362, 2861, 3477, 3851, 4345, 4960, 5335, 5831, 6446, 6819, 7314, 7928, 8300, 8792, 9404, 9782, 10273, 10885, 11256, 11750, 12368, 12747, 13249, 13862, 14237, 14731, 15346, 15722, 16215, 16834, 17208, 17702, 18320, 18696, 19188, 19802, 20174, 20674]
# 42

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_test = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_test)):
    anterior = df_posiciones_test.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_test.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_test.append(anterior)

ultimo_elemento_test = df_posiciones_test.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_test.extend(ultimo_elemento_test.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_test)
print(len(cumplen_test))
# Out:
# [453, 828, 1323, 1938, 2318, 2821, 3433, 3809, 4307, 4926, 5302, 5794, 6405, 6780, 7278, 7896, 8268, 8762]
# 18

# %%
# pasar la escala de los carbohidratos de las ingestas a gramos
data.iloc[:,0] = data.iloc[:,0].apply(lambda x: (x*15)/1000)

# Grafica con mayor detalle, el pico del comportamiento de la glucosa despues de la primera ingesta
print('')
print('Grafica de los datos del dataset')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
plt.title('Ingestas, Insulina y Glucosa')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')

print('Caso 1: Primera ingesta o Desayuno del primer dia:')
plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 700])
plt.ylim([-5, 250])
plt.show()
print('')

print('Caso 2: Primera y segunda ingesta del primer dia:')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1200])
plt.ylim([-5, 500])
plt.show()


print('Caso 3: las tres ingestas del primer dia:')

plt.plot(data.index, data.iloc[:,0], color='blue', label='Ingestas')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Ingestas de carbohidratos')
plt.xlabel('t [min]')
plt.ylabel('gramos')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Dosificación de insulina')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
#plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1800])
plt.ylim([-5, 500])
plt.show()
# Out:
# Grafica de los datos del dataset
# Caso 1: Primera ingesta o Desayuno del primer dia:
# Caso 2: Primera y segunda ingesta del primer dia:
# Caso 3: las tres ingestas del primer dia:

# %%
#Preprocesar los datos:
X_train = train_data.iloc[:, 1:3].values
y_train = train_data.iloc[:,2].values

X_test = test_data.iloc[:, 1:3].values
y_test = test_data.iloc[:, 2].values

print('Tamaño de los datos de entrada, de X_train: ',X_train.shape)
print(f'Tiene {X_train.shape[0]} filas y {X_train.shape[1]} columna')
print('La primera ingesta al minuto 300, ingesta: ',X_train[300])
print('La primera ingesta hasta el minuto 327, ingesta: ',X_train[327])

print('La entrada son los valores de la insulina y glucosa \n',X_train)
print('Tamaño de los datos de salia, de y_train',y_train.shape)
print(f'Tiene {y_train.shape[0]} filas y {y_train.shape[-1]} columnas')
print('La salida son los valores de glucosa \n',y_train)
# Out:
# Tamaño de los datos de entrada, de X_train:  (20837, 2)
# Tiene 20837 filas y 2 columna
# La primera ingesta al minuto 300, ingesta:  [ 1.6789 96.148 ]
# La primera ingesta hasta el minuto 327, ingesta:  [ 1.6789 94.07  ]
# La entrada son los valores de la insulina y glucosa
#  [[  1.6789 113.57  ]
#  [  1.6789 113.57  ]
#  [  1.6789 113.57  ]
#  ...
#  [  1.6789 197.18  ]
#  [  1.6789 196.45  ]
#  [  1.6789 195.72  ]]
# Tamaño de los datos de salia, de y_train (20837,)
# Tiene 20837 filas y 20837 columnas
# La salida son los valores de glucosa
#  [113.57 113.57 113.57 ... 197.18 196.45 195.72]

# %%
# Normalizar los datos
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Normalizar y_train
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.reshape(-1, 1))
y_test = sc_y.transform(y_test.reshape(-1, 1))

# %%
# Reorganizar los datos en forma de secuencia
def to_sequences(data,  seq_size_input, seq_size_output):
    X = []
    y = []

    for i in range(len(data)-seq_size_input-seq_size_output+1):
        X.append(data[i:(i+seq_size_input), 0:2])
        y.append(data[(i+seq_size_input):(i+seq_size_input+seq_size_output), 2])

    return np.array(X), np.array(y)

# %%
#CON LOS DATOS NORMALIZADOS
seq_size_input = 15
seq_size_output = 210
X_train, y_train = to_sequences(np.hstack((X_train, y_train)), seq_size_input, seq_size_output)
X_test, y_test = to_sequences(np.hstack((X_test, y_test)), seq_size_input, seq_size_output)
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (20613, 210)
# (20613, 15, 2)
# (8707, 210)
# (8707, 15, 2)

# %%
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
flattened_data = np.reshape(X_train, (X_train.shape[0], -1))

df_X_train = pd.DataFrame(flattened_data)

# %%
flattened_test = np.reshape(X_test, (X_test.shape[0], -1))

df_X_test = pd.DataFrame(flattened_test)

# %%
df_y_train = pd.DataFrame(y_train)
df_y_test = pd.DataFrame(y_test)

# %%
# Filtrar el dataframe para mantener solo las filas especificadas
df_X_train_seleccionado = df_X_train[df_X_train.index.isin(cumplen_train)]
df_y_train_seleccionado = df_y_train[df_y_train.index.isin(cumplen_train)]
df_X_test_seleccionado = df_X_test[df_X_test.index.isin(cumplen_test)]
df_y_test_seleccionado = df_y_test[df_y_test.index.isin(cumplen_test)]

# %%
print('Grafica de los datos del dataset')
#plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')

Numerocurva = 0

plt.plot(df_X_train_seleccionado.iloc[Numerocurva, 1::2],color='green',label='Entrada glucosa') #Para mostrar solo la glucosa
plt.plot(df_X_train_seleccionado.iloc[Numerocurva, ::2],color='orange',label='Entrada insulina') #Para mostrar solo la glucosa
plt.plot(range(seq_size_input*2, seq_size_output + seq_size_input*2),df_y_train_seleccionado.iloc[Numerocurva,:], color='red',label='Salida glucosa')
plt.title('Entradas y salidas, entrenamiento')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')
# Out:
# Grafica de los datos del dataset

# %%
X_train = df_X_train_seleccionado.values
y_train = df_y_train_seleccionado.values
X_test = df_X_test_seleccionado.values
y_test = df_y_test_seleccionado.values

print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 30)
# (17, 210)
# (17, 30)

# %%
print(len(X_test))
# Out:
# 17

# %%
X_train = np.reshape(X_train, (len(X_train), seq_size_input, 2))

X_test = np.reshape(X_test, (len(X_test), seq_size_input, 2))
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 15, 2)
# (17, 210)
# (17, 15, 2)

# %%
kf = KFold(n_splits=5)
kf.get_n_splits(X_train)
KFold(n_splits=5, random_state=None, shuffle=False)


# Crear listas para almacenar los valores del "average loss" de entrenamiento y validación en cada pliegue
train_losses = []
val_losses = []

#Para guardar el mejor modelo
best_loss = float('inf')
best_model_path = ""

for i, (train_index, test_index) in enumerate(kf.split(X_train,y_train)):
  model = Sequential()
  model.add(LSTM(60, activation='tanh', input_shape=(seq_size_input, 2), kernel_initializer=he_uniform()))
  model.add(Dense(seq_size_output, activation='linear', kernel_initializer=he_uniform()))


  model.compile(optimizer=RMSprop(), loss='mse')
  print(model.summary())

  filepath = f"modelo-{i+1}.h5"
  early_stop = EarlyStopping(monitor='val_loss', patience=3)
  checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

  X, y =  X_train[train_index], y_train[train_index]
  X_val, y_val = X_train[test_index], y_train[test_index]


  history = model.fit(X, y, epochs=100, batch_size=32,validation_data=(X_val, y_val),callbacks=[checkpoint, early_stop] )

  mediamse = np.mean( history.history['loss'] )
  stdmse = np.std(  history.history['loss'])
  print('')
  print(f" La media del mse, {i}-fold es : {mediamse}")
  print('')
  print(f" La desviacion estandar del mse, {i}-fold es : {stdmse}")

  # Obtener los valores de "average loss" para el pliegue actual
  fold_train_losses = model.history.history['loss']
  fold_val_losses = model.history.history['val_loss']

  # Almacenar los valores de "average loss" para el pliegue actual
  train_losses.append(fold_train_losses)
  val_losses.append(fold_val_losses)

  if min(fold_val_losses) < best_loss:
        best_loss = min(fold_val_losses)
        best_model_path = filepath

  history.history.keys() # aqui me muestra que esta guardando, con history me guarda todos los valores que calcula durante el proceso de entrenamiento

  # vamos a graficar
  plt.plot(history.history['loss'], label='Perdida') # Grafico esta para ver si estoy sobre entrenando
  plt.plot(history.history['val_loss'], label='Validacion') # Grafico esta para ver si estoy sobre entrenando
  plt.xlabel('epoch')
  plt.ylabel('Mean Square Error')
  plt.legend()
  plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60)                15120
#
#  dense (Dense)               (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 1.9181
# Epoch 1: val_loss improved from inf to 1.83836, saving model to modelo-1.h5
# 1/1 [==============================] - 2s 2s/step - loss: 1.9181 - val_loss: 1.8384
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7519
# Epoch 2: val_loss improved from 1.83836 to 1.73843, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 1.7519 - val_loss: 1.7384
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6544
# Epoch 3: val_loss improved from 1.73843 to 1.65904, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 42ms/step - loss: 1.6544 - val_loss: 1.6590
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5771
# Epoch 4: val_loss improved from 1.65904 to 1.58891, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 1.5771 - val_loss: 1.5889
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5090
# Epoch 5: val_loss improved from 1.58891 to 1.52408, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 56ms/step - loss: 1.5090 - val_loss: 1.5241
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4461
# Epoch 6: val_loss improved from 1.52408 to 1.46309, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 1.4461 - val_loss: 1.4631
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3871
# Epoch 7: val_loss improved from 1.46309 to 1.40534, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 77ms/step - loss: 1.3871 - val_loss: 1.4053
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3313
# Epoch 8: val_loss improved from 1.40534 to 1.35051, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 55ms/step - loss: 1.3313 - val_loss: 1.3505
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2783
# Epoch 9: val_loss improved from 1.35051 to 1.29829, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 53ms/step - loss: 1.2783 - val_loss: 1.2983
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2280
# Epoch 10: val_loss improved from 1.29829 to 1.24838, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 1.2280 - val_loss: 1.2484
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1799
# Epoch 11: val_loss improved from 1.24838 to 1.20061, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 1.1799 - val_loss: 1.2006
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1339
# Epoch 12: val_loss improved from 1.20061 to 1.15491, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 1.1339 - val_loss: 1.1549
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0900
# Epoch 13: val_loss improved from 1.15491 to 1.11133, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 54ms/step - loss: 1.0900 - val_loss: 1.1113
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0481
# Epoch 14: val_loss improved from 1.11133 to 1.06993, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 56ms/step - loss: 1.0481 - val_loss: 1.0699
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0084
# Epoch 15: val_loss improved from 1.06993 to 1.03078, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 50ms/step - loss: 1.0084 - val_loss: 1.0308
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9708
# Epoch 16: val_loss improved from 1.03078 to 0.99387, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 0.9708 - val_loss: 0.9939
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9355
# Epoch 17: val_loss improved from 0.99387 to 0.95912, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 55ms/step - loss: 0.9355 - val_loss: 0.9591
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9021
# Epoch 18: val_loss improved from 0.95912 to 0.92636, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.9021 - val_loss: 0.9264
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8706
# Epoch 19: val_loss improved from 0.92636 to 0.89537, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 83ms/step - loss: 0.8706 - val_loss: 0.8954
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8408
# Epoch 20: val_loss improved from 0.89537 to 0.86592, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 0.8408 - val_loss: 0.8659
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8124
# Epoch 21: val_loss improved from 0.86592 to 0.83777, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 56ms/step - loss: 0.8124 - val_loss: 0.8378
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7852
# Epoch 22: val_loss improved from 0.83777 to 0.81071, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.7852 - val_loss: 0.8107
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7590
# Epoch 23: val_loss improved from 0.81071 to 0.78451, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 0.7590 - val_loss: 0.7845
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7336
# Epoch 24: val_loss improved from 0.78451 to 0.75900, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 0.7336 - val_loss: 0.7590
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7088
# Epoch 25: val_loss improved from 0.75900 to 0.73400, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 0.7088 - val_loss: 0.7340
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6845
# Epoch 26: val_loss improved from 0.73400 to 0.70938, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6845 - val_loss: 0.7094
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6606
# Epoch 27: val_loss improved from 0.70938 to 0.68511, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 0.6606 - val_loss: 0.6851
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6369
# Epoch 28: val_loss improved from 0.68511 to 0.66128, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6369 - val_loss: 0.6613
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6138
# Epoch 29: val_loss improved from 0.66128 to 0.63805, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.6138 - val_loss: 0.6381
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5913
# Epoch 30: val_loss improved from 0.63805 to 0.61550, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5913 - val_loss: 0.6155
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5695
# Epoch 31: val_loss improved from 0.61550 to 0.59389, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 77ms/step - loss: 0.5695 - val_loss: 0.5939
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5485
# Epoch 32: val_loss improved from 0.59389 to 0.57252, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5485 - val_loss: 0.5725
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5284
# Epoch 33: val_loss improved from 0.57252 to 0.55796, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5284 - val_loss: 0.5580
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5116
# Epoch 34: val_loss improved from 0.55796 to 0.54822, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5116 - val_loss: 0.5482
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5104
# Epoch 35: val_loss improved from 0.54822 to 0.54678, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 0.5104 - val_loss: 0.5468
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4960
# Epoch 36: val_loss improved from 0.54678 to 0.51153, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 54ms/step - loss: 0.4960 - val_loss: 0.5115
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4744
# Epoch 37: val_loss improved from 0.51153 to 0.49454, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 77ms/step - loss: 0.4744 - val_loss: 0.4945
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4509
# Epoch 38: val_loss improved from 0.49454 to 0.47576, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4509 - val_loss: 0.4758
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4362
# Epoch 39: val_loss improved from 0.47576 to 0.46411, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4362 - val_loss: 0.4641
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4232
# Epoch 40: val_loss improved from 0.46411 to 0.45081, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.4232 - val_loss: 0.4508
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4113
# Epoch 41: val_loss improved from 0.45081 to 0.43986, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4113 - val_loss: 0.4399
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4001
# Epoch 42: val_loss improved from 0.43986 to 0.42858, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4001 - val_loss: 0.4286
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3896
# Epoch 43: val_loss improved from 0.42858 to 0.41885, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.3896 - val_loss: 0.4188
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3797
# Epoch 44: val_loss improved from 0.41885 to 0.40902, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3797 - val_loss: 0.4090
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3705
# Epoch 45: val_loss improved from 0.40902 to 0.40061, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.3705 - val_loss: 0.4006
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3619
# Epoch 46: val_loss improved from 0.40061 to 0.39187, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3619 - val_loss: 0.3919
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3537
# Epoch 47: val_loss improved from 0.39187 to 0.38483, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3537 - val_loss: 0.3848
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3461
# Epoch 48: val_loss improved from 0.38483 to 0.37656, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3461 - val_loss: 0.3766
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3388
# Epoch 49: val_loss improved from 0.37656 to 0.37163, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.3388 - val_loss: 0.3716
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3321
# Epoch 50: val_loss improved from 0.37163 to 0.36229, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.3321 - val_loss: 0.3623
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3262
# Epoch 51: val_loss did not improve from 0.36229
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3262 - val_loss: 0.3652
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3224
# Epoch 52: val_loss improved from 0.36229 to 0.35547, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 79ms/step - loss: 0.3224 - val_loss: 0.3555
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3269
# Epoch 53: val_loss did not improve from 0.35547
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3269 - val_loss: 0.3617
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3174
# Epoch 54: val_loss improved from 0.35547 to 0.34752, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3174 - val_loss: 0.3475
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3207
# Epoch 55: val_loss improved from 0.34752 to 0.34151, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3207 - val_loss: 0.3415
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3034
# Epoch 56: val_loss improved from 0.34151 to 0.33425, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3034 - val_loss: 0.3342
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2991
# Epoch 57: val_loss improved from 0.33425 to 0.33384, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2991 - val_loss: 0.3338
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2951
# Epoch 58: val_loss improved from 0.33384 to 0.32867, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2951 - val_loss: 0.3287
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2917
# Epoch 59: val_loss did not improve from 0.32867
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2917 - val_loss: 0.3297
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2887
# Epoch 60: val_loss improved from 0.32867 to 0.32203, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2887 - val_loss: 0.3220
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2876
# Epoch 61: val_loss did not improve from 0.32203
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2876 - val_loss: 0.3341
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2886
# Epoch 62: val_loss did not improve from 0.32203
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2886 - val_loss: 0.3270
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3024
# Epoch 63: val_loss improved from 0.32203 to 0.31773, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3024 - val_loss: 0.3177
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2796
# Epoch 64: val_loss improved from 0.31773 to 0.31469, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2796 - val_loss: 0.3147
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2767
# Epoch 65: val_loss did not improve from 0.31469
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2767 - val_loss: 0.3148
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2742
# Epoch 66: val_loss improved from 0.31469 to 0.31057, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2742 - val_loss: 0.3106
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2724
# Epoch 67: val_loss did not improve from 0.31057
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2724 - val_loss: 0.3176
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2729
# Epoch 68: val_loss did not improve from 0.31057
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2729 - val_loss: 0.3107
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2843
# Epoch 69: val_loss improved from 0.31057 to 0.30820, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2843 - val_loss: 0.3082
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2681
# Epoch 70: val_loss improved from 0.30820 to 0.30434, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 50ms/step - loss: 0.2681 - val_loss: 0.3043
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2661
# Epoch 71: val_loss did not improve from 0.30434
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2661 - val_loss: 0.3104
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2662
# Epoch 72: val_loss improved from 0.30434 to 0.30353, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 50ms/step - loss: 0.2662 - val_loss: 0.3035
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2757
# Epoch 73: val_loss did not improve from 0.30353
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2757 - val_loss: 0.3053
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2632
# Epoch 74: val_loss improved from 0.30353 to 0.29829, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 0.2632 - val_loss: 0.2983
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2645
# Epoch 75: val_loss did not improve from 0.29829
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2645 - val_loss: 0.3119
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2660
# Epoch 76: val_loss did not improve from 0.29829
# 1/1 [==============================] - 0s 43ms/step - loss: 0.2660 - val_loss: 0.3053
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2814
# Epoch 77: val_loss improved from 0.29829 to 0.29550, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2814 - val_loss: 0.2955
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2601
# Epoch 78: val_loss did not improve from 0.29550
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2601 - val_loss: 0.2983
# Epoch 79/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2575
# Epoch 79: val_loss improved from 0.29550 to 0.29427, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2575 - val_loss: 0.2943
# Epoch 80/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2561
# Epoch 80: val_loss did not improve from 0.29427
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2561 - val_loss: 0.3012
# Epoch 81/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2567
# Epoch 81: val_loss did not improve from 0.29427
# 1/1 [==============================] - 0s 42ms/step - loss: 0.2567 - val_loss: 0.2944
# Epoch 82/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2671
# Epoch 82: val_loss did not improve from 0.29427
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2671 - val_loss: 0.2950
#
#  La media del mse, 0-fold es : 0.6068194181453891
#
#  La desviacion estandar del mse, 0-fold es : 0.41929170546029837
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 60)                15120
#
#  dense_1 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 1.8577
# Epoch 1: val_loss improved from inf to 1.24740, saving model to modelo-2.h5
# 2/2 [==============================] - 2s 407ms/step - loss: 1.8093 - val_loss: 1.2474
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7070
# Epoch 2: val_loss improved from 1.24740 to 1.17770, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.6617 - val_loss: 1.1777
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5094
# Epoch 3: val_loss improved from 1.17770 to 1.07174, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.5841 - val_loss: 1.0717
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4230
# Epoch 4: val_loss improved from 1.07174 to 0.99993, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 1.4632 - val_loss: 0.9999
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3822
# Epoch 5: val_loss improved from 0.99993 to 0.94377, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 1.3788 - val_loss: 0.9438
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3478
# Epoch 6: val_loss improved from 0.94377 to 0.92142, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.3142 - val_loss: 0.9214
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3248
# Epoch 7: val_loss improved from 0.92142 to 0.89994, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 1.2914 - val_loss: 0.8999
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3029
# Epoch 8: val_loss improved from 0.89994 to 0.87461, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.2684 - val_loss: 0.8746
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2688
# Epoch 9: val_loss improved from 0.87461 to 0.82835, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 1.2396 - val_loss: 0.8283
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2103
# Epoch 10: val_loss improved from 0.82835 to 0.77641, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.1848 - val_loss: 0.7764
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1471
# Epoch 11: val_loss improved from 0.77641 to 0.72529, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 1.1217 - val_loss: 0.7253
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0865
# Epoch 12: val_loss improved from 0.72529 to 0.70668, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.0600 - val_loss: 0.7067
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0642
# Epoch 13: val_loss improved from 0.70668 to 0.65745, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.0391 - val_loss: 0.6574
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0023
# Epoch 14: val_loss improved from 0.65745 to 0.61325, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.9779 - val_loss: 0.6133
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9434
# Epoch 15: val_loss improved from 0.61325 to 0.60336, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 0.9237 - val_loss: 0.6034
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9369
# Epoch 16: val_loss improved from 0.60336 to 0.58953, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.9151 - val_loss: 0.5895
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9228
# Epoch 17: val_loss improved from 0.58953 to 0.54986, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.8989 - val_loss: 0.5499
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8694
# Epoch 18: val_loss improved from 0.54986 to 0.54114, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.8500 - val_loss: 0.5411
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8611
# Epoch 19: val_loss improved from 0.54114 to 0.53002, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.8413 - val_loss: 0.5300
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8488
# Epoch 20: val_loss improved from 0.53002 to 0.51739, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.8287 - val_loss: 0.5174
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8361
# Epoch 21: val_loss improved from 0.51739 to 0.47654, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.8127 - val_loss: 0.4765
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7821
# Epoch 22: val_loss improved from 0.47654 to 0.45023, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 0.7599 - val_loss: 0.4502
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7462
# Epoch 23: val_loss improved from 0.45023 to 0.42916, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.7251 - val_loss: 0.4292
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7180
# Epoch 24: val_loss improved from 0.42916 to 0.41152, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6976 - val_loss: 0.4115
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6942
# Epoch 25: val_loss improved from 0.41152 to 0.39222, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.6741 - val_loss: 0.3922
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6590
# Epoch 26: val_loss did not improve from 0.39222
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6483 - val_loss: 0.4025
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6798
# Epoch 27: val_loss did not improve from 0.39222
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6664 - val_loss: 0.3982
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6820
# Epoch 28: val_loss improved from 0.39222 to 0.37355, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.6622 - val_loss: 0.3735
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6474
# Epoch 29: val_loss improved from 0.37355 to 0.36472, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6304 - val_loss: 0.3647
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6366
# Epoch 30: val_loss improved from 0.36472 to 0.35194, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6181 - val_loss: 0.3519
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6102
# Epoch 31: val_loss did not improve from 0.35194
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6013 - val_loss: 0.3643
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5848
# Epoch 32: val_loss improved from 0.35194 to 0.32984, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6136 - val_loss: 0.3298
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5194
# Epoch 33: val_loss did not improve from 0.32984
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5416 - val_loss: 0.3537
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5484
# Epoch 34: val_loss improved from 0.32984 to 0.30029, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5402 - val_loss: 0.3003
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4890
# Epoch 35: val_loss did not improve from 0.30029
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5064 - val_loss: 0.3410
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5128
# Epoch 36: val_loss did not improve from 0.30029
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5232 - val_loss: 0.3682
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5273
# Epoch 37: val_loss did not improve from 0.30029
# 2/2 [==============================] - 0s 73ms/step - loss: 0.5355 - val_loss: 0.3806
#
#  La media del mse, 1-fold es : 0.9299541421838708
#
#  La desviacion estandar del mse, 1-fold es : 0.34845360392382546
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 60)                15120
#
#  dense_2 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 1.9246
# Epoch 1: val_loss improved from inf to 1.53732, saving model to modelo-3.h5
# 2/2 [==============================] - 2s 399ms/step - loss: 1.8766 - val_loss: 1.5373
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7179
# Epoch 2: val_loss improved from 1.53732 to 1.44816, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 1.6740 - val_loss: 1.4482
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6187
# Epoch 3: val_loss improved from 1.44816 to 1.38238, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 1.5768 - val_loss: 1.3824
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5450
# Epoch 4: val_loss improved from 1.38238 to 1.32829, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 1.5044 - val_loss: 1.3283
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4692
# Epoch 5: val_loss improved from 1.32829 to 1.24468, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.4429 - val_loss: 1.2447
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3193
# Epoch 6: val_loss improved from 1.24468 to 1.14862, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.3443 - val_loss: 1.1486
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2631
# Epoch 7: val_loss improved from 1.14862 to 1.12176, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.2319 - val_loss: 1.1218
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2352
# Epoch 8: val_loss improved from 1.12176 to 1.09535, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.2037 - val_loss: 1.0953
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2056
# Epoch 9: val_loss improved from 1.09535 to 1.07081, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.1752 - val_loss: 1.0708
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1802
# Epoch 10: val_loss improved from 1.07081 to 1.04145, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.1484 - val_loss: 1.0415
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1459
# Epoch 11: val_loss improved from 1.04145 to 1.01422, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.1154 - val_loss: 1.0142
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0213
# Epoch 12: val_loss improved from 1.01422 to 0.92812, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 1.0816 - val_loss: 0.9281
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9981
# Epoch 13: val_loss improved from 0.92812 to 0.91290, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.9756 - val_loss: 0.9129
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9836
# Epoch 14: val_loss improved from 0.91290 to 0.87231, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 0.9612 - val_loss: 0.8723
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8412
# Epoch 15: val_loss improved from 0.87231 to 0.80436, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 0.9102 - val_loss: 0.8044
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7740
# Epoch 16: val_loss improved from 0.80436 to 0.77211, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 0.8184 - val_loss: 0.7721
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7314
# Epoch 17: val_loss improved from 0.77211 to 0.75239, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.7635 - val_loss: 0.7524
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6867
# Epoch 18: val_loss improved from 0.75239 to 0.74611, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 0.7247 - val_loss: 0.7461
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7051
# Epoch 19: val_loss improved from 0.74611 to 0.69376, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6984 - val_loss: 0.6938
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6754
# Epoch 20: val_loss improved from 0.69376 to 0.67413, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6669 - val_loss: 0.6741
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6671
# Epoch 21: val_loss improved from 0.67413 to 0.66437, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6607 - val_loss: 0.6644
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6522
# Epoch 22: val_loss improved from 0.66437 to 0.64327, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6602 - val_loss: 0.6433
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6314
# Epoch 23: val_loss improved from 0.64327 to 0.62978, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6162 - val_loss: 0.6298
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6238
# Epoch 24: val_loss improved from 0.62978 to 0.61782, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6073 - val_loss: 0.6178
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6133
# Epoch 25: val_loss improved from 0.61782 to 0.60706, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 0.5967 - val_loss: 0.6071
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5845
# Epoch 26: val_loss improved from 0.60706 to 0.60360, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.5852 - val_loss: 0.6036
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5653
# Epoch 27: val_loss improved from 0.60360 to 0.60217, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.5547 - val_loss: 0.6022
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5425
# Epoch 28: val_loss improved from 0.60217 to 0.55582, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 131ms/step - loss: 0.5407 - val_loss: 0.5558
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5069
# Epoch 29: val_loss did not improve from 0.55582
# 2/2 [==============================] - 0s 49ms/step - loss: 0.5258 - val_loss: 0.5768
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5064
# Epoch 30: val_loss improved from 0.55582 to 0.52186, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5073 - val_loss: 0.5219
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4964
# Epoch 31: val_loss improved from 0.52186 to 0.51524, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.4839 - val_loss: 0.5152
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4579
# Epoch 32: val_loss did not improve from 0.51524
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4834 - val_loss: 0.5336
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4746
# Epoch 33: val_loss did not improve from 0.51524
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4625 - val_loss: 0.5290
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4613
# Epoch 34: val_loss improved from 0.51524 to 0.48422, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.4534 - val_loss: 0.4842
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4454
# Epoch 35: val_loss did not improve from 0.48422
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4435 - val_loss: 0.5048
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4331
# Epoch 36: val_loss improved from 0.48422 to 0.45659, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.4305 - val_loss: 0.4566
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4207
# Epoch 37: val_loss did not improve from 0.45659
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4155 - val_loss: 0.4579
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4411
# Epoch 38: val_loss did not improve from 0.45659
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4309 - val_loss: 0.4589
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4197
# Epoch 39: val_loss did not improve from 0.45659
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4343 - val_loss: 0.4888
#
#  La media del mse, 2-fold es : 0.8406978448232015
#
#  La desviacion estandar del mse, 2-fold es : 0.3975348357535196
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 60)                15120
#
#  dense_3 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 1.8720
# Epoch 1: val_loss improved from inf to 1.68005, saving model to modelo-4.h5
# 2/2 [==============================] - 2s 382ms/step - loss: 1.8389 - val_loss: 1.6801
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5433
# Epoch 2: val_loss improved from 1.68005 to 1.51491, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.6199 - val_loss: 1.5149
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5006
# Epoch 3: val_loss improved from 1.51491 to 1.44012, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.4752 - val_loss: 1.4401
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4410
# Epoch 4: val_loss improved from 1.44012 to 1.39766, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.4064 - val_loss: 1.3977
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3977
# Epoch 5: val_loss improved from 1.39766 to 1.36458, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.3645 - val_loss: 1.3646
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3645
# Epoch 6: val_loss improved from 1.36458 to 1.33378, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.3312 - val_loss: 1.3338
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3334
# Epoch 7: val_loss improved from 1.33378 to 1.30443, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 1.3003 - val_loss: 1.3044
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3051
# Epoch 8: val_loss improved from 1.30443 to 1.26877, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 1.2709 - val_loss: 1.2688
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2049
# Epoch 9: val_loss improved from 1.26877 to 1.16793, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.2346 - val_loss: 1.1679
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0318
# Epoch 10: val_loss improved from 1.16793 to 1.06895, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 1.1426 - val_loss: 1.0689
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0779
# Epoch 11: val_loss improved from 1.06895 to 1.02696, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 1.0551 - val_loss: 1.0270
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0388
# Epoch 12: val_loss improved from 1.02696 to 0.98456, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 1.0162 - val_loss: 0.9846
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9996
# Epoch 13: val_loss improved from 0.98456 to 0.94102, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.9771 - val_loss: 0.9410
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9592
# Epoch 14: val_loss improved from 0.94102 to 0.93042, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 0.9379 - val_loss: 0.9304
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8757
# Epoch 15: val_loss improved from 0.93042 to 0.83963, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.9207 - val_loss: 0.8396
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8664
# Epoch 16: val_loss improved from 0.83963 to 0.81083, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 0.8452 - val_loss: 0.8108
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8351
# Epoch 17: val_loss improved from 0.81083 to 0.80746, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.8178 - val_loss: 0.8075
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8228
# Epoch 18: val_loss did not improve from 0.80746
# 2/2 [==============================] - 0s 43ms/step - loss: 0.8091 - val_loss: 0.8107
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8266
# Epoch 19: val_loss improved from 0.80746 to 0.77499, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 0.8055 - val_loss: 0.7750
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7914
# Epoch 20: val_loss improved from 0.77499 to 0.77214, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.7740 - val_loss: 0.7721
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6812
# Epoch 21: val_loss improved from 0.77214 to 0.67651, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 0.7632 - val_loss: 0.6765
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7088
# Epoch 22: val_loss improved from 0.67651 to 0.65974, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6899 - val_loss: 0.6597
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6917
# Epoch 23: val_loss improved from 0.65974 to 0.64966, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6727 - val_loss: 0.6497
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6190
# Epoch 24: val_loss improved from 0.64966 to 0.60166, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6591 - val_loss: 0.6017
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6066
# Epoch 25: val_loss improved from 0.60166 to 0.58307, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.6286 - val_loss: 0.5831
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6216
# Epoch 26: val_loss improved from 0.58307 to 0.57196, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6205 - val_loss: 0.5720
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5803
# Epoch 27: val_loss improved from 0.57196 to 0.54877, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5876 - val_loss: 0.5488
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5903
# Epoch 28: val_loss improved from 0.54877 to 0.54197, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.5748 - val_loss: 0.5420
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5622
# Epoch 29: val_loss did not improve from 0.54197
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5590 - val_loss: 0.5564
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5516
# Epoch 30: val_loss improved from 0.54197 to 0.51357, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.5519 - val_loss: 0.5136
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5304
# Epoch 31: val_loss did not improve from 0.51357
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5261 - val_loss: 0.5261
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5208
# Epoch 32: val_loss did not improve from 0.51357
# 2/2 [==============================] - 0s 48ms/step - loss: 0.5169 - val_loss: 0.5432
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5174
# Epoch 33: val_loss improved from 0.51357 to 0.47617, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 0.5173 - val_loss: 0.4762
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4530
# Epoch 34: val_loss improved from 0.47617 to 0.46822, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.4767 - val_loss: 0.4682
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4450
# Epoch 35: val_loss did not improve from 0.46822
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4828 - val_loss: 0.4839
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4744
# Epoch 36: val_loss did not improve from 0.46822
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5035 - val_loss: 0.4925
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5116
# Epoch 37: val_loss improved from 0.46822 to 0.46750, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 0.5061 - val_loss: 0.4675
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4701
# Epoch 38: val_loss improved from 0.46750 to 0.41213, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 0.4667 - val_loss: 0.4121
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3941
# Epoch 39: val_loss did not improve from 0.41213
# 2/2 [==============================] - 0s 50ms/step - loss: 0.3867 - val_loss: 0.4900
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3784
# Epoch 40: val_loss did not improve from 0.41213
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4116 - val_loss: 0.4245
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4057
# Epoch 41: val_loss did not improve from 0.41213
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4133 - val_loss: 0.4857
#
#  La media del mse, 3-fold es : 0.8404394969707583
#
#  La desviacion estandar del mse, 3-fold es : 0.3692584016101032
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 60)                15120
#
#  dense_4 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 1.8766
# Epoch 1: val_loss improved from inf to 2.03540, saving model to modelo-5.h5
# 2/2 [==============================] - 2s 389ms/step - loss: 1.8433 - val_loss: 2.0354
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6615
# Epoch 2: val_loss improved from 2.03540 to 1.90010, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.6364 - val_loss: 1.9001
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5006
# Epoch 3: val_loss improved from 1.90010 to 1.77563, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 1.5098 - val_loss: 1.7756
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4236
# Epoch 4: val_loss improved from 1.77563 to 1.69158, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 1.4005 - val_loss: 1.6916
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2965
# Epoch 5: val_loss improved from 1.69158 to 1.57546, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 1.3246 - val_loss: 1.5755
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2555
# Epoch 6: val_loss improved from 1.57546 to 1.50973, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.2300 - val_loss: 1.5097
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1960
# Epoch 7: val_loss improved from 1.50973 to 1.44394, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 1.1709 - val_loss: 1.4439
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1411
# Epoch 8: val_loss improved from 1.44394 to 1.41957, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 1.1149 - val_loss: 1.4196
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1196
# Epoch 9: val_loss improved from 1.41957 to 1.38557, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.0913 - val_loss: 1.3856
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0566
# Epoch 10: val_loss improved from 1.38557 to 1.26745, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 1.0592 - val_loss: 1.2674
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9093
# Epoch 11: val_loss improved from 1.26745 to 1.14519, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.9661 - val_loss: 1.1452
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8995
# Epoch 12: val_loss improved from 1.14519 to 1.10397, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 0.8798 - val_loss: 1.1040
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7948
# Epoch 13: val_loss improved from 1.10397 to 1.01318, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 0.8430 - val_loss: 1.0132
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7957
# Epoch 14: val_loss improved from 1.01318 to 1.00848, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 0.7850 - val_loss: 1.0085
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7856
# Epoch 15: val_loss improved from 1.00848 to 1.00500, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.7714 - val_loss: 1.0050
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7239
# Epoch 16: val_loss improved from 1.00500 to 0.92027, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.7612 - val_loss: 0.9203
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6688
# Epoch 17: val_loss improved from 0.92027 to 0.86660, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.7070 - val_loss: 0.8666
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6853
# Epoch 18: val_loss improved from 0.86660 to 0.86169, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6793 - val_loss: 0.8617
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6790
# Epoch 19: val_loss improved from 0.86169 to 0.84966, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6631 - val_loss: 0.8497
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6568
# Epoch 20: val_loss did not improve from 0.84966
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6498 - val_loss: 0.8557
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5952
# Epoch 21: val_loss improved from 0.84966 to 0.78505, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6462 - val_loss: 0.7851
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6139
# Epoch 22: val_loss did not improve from 0.78505
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6081 - val_loss: 0.7869
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6063
# Epoch 23: val_loss did not improve from 0.78505
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6012 - val_loss: 0.7938
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6161
# Epoch 24: val_loss improved from 0.78505 to 0.78393, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6006 - val_loss: 0.7839
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5968
# Epoch 25: val_loss improved from 0.78393 to 0.73797, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 0.5905 - val_loss: 0.7380
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5605
# Epoch 26: val_loss improved from 0.73797 to 0.69997, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.5624 - val_loss: 0.7000
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5057
# Epoch 27: val_loss improved from 0.69997 to 0.68454, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5469 - val_loss: 0.6845
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5554
# Epoch 28: val_loss improved from 0.68454 to 0.66140, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.5581 - val_loss: 0.6614
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5178
# Epoch 29: val_loss did not improve from 0.66140
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5177 - val_loss: 0.6641
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5124
# Epoch 30: val_loss did not improve from 0.66140
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5091 - val_loss: 0.6758
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5205
# Epoch 31: val_loss did not improve from 0.66140
# 2/2 [==============================] - 0s 39ms/step - loss: 0.5138 - val_loss: 0.6839
#
#  La media del mse, 4-fold es : 0.8819786406332447
#
#  La desviacion estandar del mse, 4-fold es : 0.35942766359406514

# %%
plot_model(model, to_file='model_architecture.png', show_shapes=True)

# %%
# rellenar de ceros los espacios vacios de la lista con loss y validation

df_train_losses = pd.DataFrame(train_losses)

df_filled_train_losses = df_train_losses.fillna(0)

train_losses_completa = df_filled_train_losses.values.tolist()

df_val_losses = pd.DataFrame(val_losses)

df_filled_val_losses = df_val_losses.fillna(0)

val_losses_completa = df_filled_val_losses.values.tolist()

# %%
# Calcular el promedio de "average loss" para todos los pliegues y épocas
avg_train_losses = np.mean(train_losses_completa, axis=0)
avg_val_losses = np.mean(val_losses_completa, axis=0)

# vamos a graficar
plt.plot(avg_train_losses, label='Perdida entrenamiento') # Grafico esta para ver si estoy sobre entrenando
plt.plot(avg_val_losses, label='Perdida Validacion') # Grafico esta para ver si estoy sobre entrenando
plt.title('avg loss train, avg loss val vs epoch ')
plt.xlabel('epoch')
plt.ylabel('Mean Square Error')
plt.legend()
plt.show()

# %%
# Cargar el mejor modelo
best_model = load_model(best_model_path)

# %%
# Seleccionar una secuencia específica
index = 0
input_sequence = X_test[index]

# Hacer la predicción
y_pred = best_model.predict(np.expand_dims(input_sequence, axis=0))
# usamos el np.expand_dims() para agregar una dimensión adicional al inicio de input_sequence
print(y_pred.shape)
# Out:
# 1/1 [==============================] - 0s 407ms/step
# (1, 210)

# %%
# Desenrollar X_test para convertirlo en un array bidimensional
X_test_flattened = X_test.reshape(-1, X_test.shape[-1])

# Aplicar la transformación inversa utilizando el objeto StandardScaler
X_test_desnormalizado = sc.inverse_transform(X_test_flattened)

# Volver a darle forma a X_test_desnormalizado a su forma original
X_test = X_test_desnormalizado.reshape(X_test.shape)

# Desnormalizar los datos
y_pred = sc_y.inverse_transform(y_pred)

y_test = sc_y.inverse_transform(y_test)

print(y_pred.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (1, 210)
# (17, 210)
# (17, 15, 2)

# %%
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
Curva=0

plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

print('')
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(X_test[Curva,:,0],color='orange', label='Valores actuales y anteriores de insulina')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_test[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 182.833575

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_pred[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 183.25856958389284

# %%
# Media MSE y desviacion estandar MSE de las prediciones con la escala normal
mse = mean_squared_error(y_test[0,:].flatten(), y_pred.flatten())
std = np.sqrt(mse)
mediamse = np.mean(mse)

print('La media MSE:',mediamse)
print('La desviacion standar MSE', std)

# calcular la MAE
mae = mean_absolute_error(y_test[0,:], y_pred[0,:])
print('MAE:', mae)

# calcular la RMSE
rmse = np.sqrt(mean_squared_error(y_test[0,:], y_pred[0,:]))
print('RMSE:', rmse)
# Out:
# La media MSE: 134.48274161357077
# La desviacion standar MSE 11.596669419000042
# MAE: 8.419998511904762
# RMSE: 11.596669419000042
