# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Librerias
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split, KFold
from keras.callbacks import EarlyStopping

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import load_model

from keras.initializers import he_uniform

from tensorflow.keras.optimizers import RMSprop

# %%
#Dataset Adulto 01
data = pd.read_csv('/content/gdrive/MyDrive/Proyecto_de_grado/SUSTENTACION3.0/FinalX3/adulto05/my_adult05A2_data.csv')

print(f"El archivo se ha cargado correctamente. Tiene {data.shape[0]} filas y {data.shape[1]} columnas.")
# Out:
# El archivo se ha cargado correctamente. Tiene 29251 filas y 3 columnas.

# %%
train_size = int(len(data) * 0.7)

train_data = data.iloc[:train_size, :] # 70% entrenamiento
test_data = data.iloc[train_size:, :] # 30% prueba

test_data = test_data.reset_index(drop=True)

# %%
#los indices donde hay ingestas
posicionestrain = train_data.loc[train_data.iloc[:, 0] != 0].index
posicionestest = test_data.loc[test_data.iloc[:, 0] != 0].index

df_posiciones_train = pd.DataFrame(posicionestrain)
df_posiciones_test = pd.DataFrame(posicionestest)

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_train = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_train)):
    anterior = df_posiciones_train.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_train.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_train.append(anterior)

ultimo_elemento_train = df_posiciones_train.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_train.extend(ultimo_elemento_train.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_train)
print(len(cumplen_train))
# Out:
# [490, 866, 1353, 1964, 2333, 2817, 3423, 3793, 4277, 4881, 5251, 5737, 6343, 6720, 7210, 7814, 8183, 8672, 9279, 9648, 10133, 10737, 11104, 11594, 12197, 12564, 13049, 13652, 14022, 14505, 15109, 15475, 15960, 16569, 16936, 17420, 18024, 18391, 18874, 19480, 19848, 20332]
# 42

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_test = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_test)):
    anterior = df_posiciones_test.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_test.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_test.append(anterior)

ultimo_elemento_test = df_posiciones_test.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_test.extend(ultimo_elemento_test.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_test)
print(len(cumplen_test))
# Out:
# [462, 832, 1316, 1922, 2289, 2773, 3377, 3748, 4236, 4844, 5213, 5697, 6301, 6670, 7153, 7758, 8124, 8610]
# 18

# %%
# pasar la escala de los carbohidratos de las ingestas a gramos
data.iloc[:,0] = data.iloc[:,0].apply(lambda x: (x*15)/1000)

# Grafica con mayor detalle, el pico del comportamiento de la glucosa despues de la primera ingesta
print('')
print('Grafica de los datos del dataset')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
plt.title('Ingestas, Insulina y Glucosa')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')

print('Caso 1: Primera ingesta o Desayuno del primer dia:')
plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 700])
plt.ylim([-5, 250])
plt.show()
print('')

print('Caso 2: Primera y segunda ingesta del primer dia:')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1200])
plt.ylim([-5, 500])
plt.show()


print('Caso 3: las tres ingestas del primer dia:')

plt.plot(data.index, data.iloc[:,0], color='blue', label='Ingestas')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Ingestas de carbohidratos')
plt.xlabel('t [min]')
plt.ylabel('gramos')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Dosificación de insulina')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
#plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1800])
plt.ylim([-5, 500])
plt.show()
# Out:
# Grafica de los datos del dataset
# Caso 1: Primera ingesta o Desayuno del primer dia:
# Caso 2: Primera y segunda ingesta del primer dia:
# Caso 3: las tres ingestas del primer dia:

# %%
#Preprocesar los datos:
X_train = train_data.iloc[:, 1:3].values
y_train = train_data.iloc[:,2].values

X_test = test_data.iloc[:, 1:3].values
y_test = test_data.iloc[:, 2].values

print('Tamaño de los datos de entrada, de X_train: ',X_train.shape)
print(f'Tiene {X_train.shape[0]} filas y {X_train.shape[1]} columna')
print('La primera ingesta al minuto 300, ingesta: ',X_train[300])
print('La primera ingesta hasta el minuto 327, ingesta: ',X_train[327])

print('La entrada son los valores de la insulina y glucosa \n',X_train)
print('Tamaño de los datos de salia, de y_train',y_train.shape)
print(f'Tiene {y_train.shape[0]} filas y {y_train.shape[-1]} columnas')
print('La salida son los valores de glucosa \n',y_train)
# Out:
# Tamaño de los datos de entrada, de X_train:  (20475, 2)
# Tiene 20475 filas y 2 columna
# La primera ingesta al minuto 300, ingesta:  [  1.6789 104.83  ]
# La primera ingesta hasta el minuto 327, ingesta:  [  1.6789 102.89  ]
# La entrada son los valores de la insulina y glucosa
#  [[  1.6789 119.65  ]
#  [  1.6789 119.65  ]
#  [  1.6789 119.65  ]
#  ...
#  [  1.6789 297.55  ]
#  [  1.6789 296.82  ]
#  [  1.6789 296.1   ]]
# Tamaño de los datos de salia, de y_train (20475,)
# Tiene 20475 filas y 20475 columnas
# La salida son los valores de glucosa
#  [119.65 119.65 119.65 ... 297.55 296.82 296.1 ]

# %%
# Normalizar los datos
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Normalizar y_train
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.reshape(-1, 1))
y_test = sc_y.transform(y_test.reshape(-1, 1))

# %%
# Reorganizar los datos en forma de secuencia
def to_sequences(data,  seq_size_input, seq_size_output):
    X = []
    y = []

    for i in range(len(data)-seq_size_input-seq_size_output+1):
        X.append(data[i:(i+seq_size_input), 0:2])
        y.append(data[(i+seq_size_input):(i+seq_size_input+seq_size_output), 2])

    return np.array(X), np.array(y)

# %%
#CON LOS DATOS NORMALIZADOS
seq_size_input = 15
seq_size_output = 210
X_train, y_train = to_sequences(np.hstack((X_train, y_train)), seq_size_input, seq_size_output)
X_test, y_test = to_sequences(np.hstack((X_test, y_test)), seq_size_input, seq_size_output)
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (20251, 210)
# (20251, 15, 2)
# (8552, 210)
# (8552, 15, 2)

# %%
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
flattened_data = np.reshape(X_train, (X_train.shape[0], -1))

df_X_train = pd.DataFrame(flattened_data)

# %%
flattened_test = np.reshape(X_test, (X_test.shape[0], -1))

df_X_test = pd.DataFrame(flattened_test)

# %%
df_y_train = pd.DataFrame(y_train)
df_y_test = pd.DataFrame(y_test)

# %%
# Filtrar el dataframe para mantener solo las filas especificadas
df_X_train_seleccionado = df_X_train[df_X_train.index.isin(cumplen_train)]
df_y_train_seleccionado = df_y_train[df_y_train.index.isin(cumplen_train)]
df_X_test_seleccionado = df_X_test[df_X_test.index.isin(cumplen_test)]
df_y_test_seleccionado = df_y_test[df_y_test.index.isin(cumplen_test)]

# %%
print('Grafica de los datos del dataset')
#plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')

Numerocurva = 0

plt.plot(df_X_train_seleccionado.iloc[Numerocurva, 1::2],color='green',label='Entrada glucosa') #Para mostrar solo la glucosa
plt.plot(df_X_train_seleccionado.iloc[Numerocurva, ::2],color='orange',label='Entrada insulina') #Para mostrar solo la glucosa
plt.plot(range(seq_size_input*2, seq_size_output + seq_size_input*2),df_y_train_seleccionado.iloc[Numerocurva,:], color='red',label='Salida glucosa')
plt.title('Entradas y salidas, entrenamiento')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')
# Out:
# Grafica de los datos del dataset

# %%
X_train = df_X_train_seleccionado.values
y_train = df_y_train_seleccionado.values
X_test = df_X_test_seleccionado.values
y_test = df_y_test_seleccionado.values

print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 30)
# (17, 210)
# (17, 30)

# %%
print(len(X_test))
# Out:
# 17

# %%
X_train = np.reshape(X_train, (len(X_train), seq_size_input, 2))

X_test = np.reshape(X_test, (len(X_test), seq_size_input, 2))
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 15, 2)
# (17, 210)
# (17, 15, 2)

# %%
kf = KFold(n_splits=5)
kf.get_n_splits(X_train)
KFold(n_splits=5, random_state=None, shuffle=False)


# Crear listas para almacenar los valores del "average loss" de entrenamiento y validación en cada pliegue
train_losses = []
val_losses = []

#Para guardar el mejor modelo
best_loss = float('inf')
best_model_path = ""

for i, (train_index, test_index) in enumerate(kf.split(X_train,y_train)):
  model = Sequential()
  model.add(LSTM(60, activation='tanh', input_shape=(seq_size_input, 2), kernel_initializer=he_uniform()))
  model.add(Dense(seq_size_output, activation='linear', kernel_initializer=he_uniform()))


  model.compile(optimizer=RMSprop(), loss='mse')
  print(model.summary())

  filepath = f"modelo-{i+1}.h5"
  early_stop = EarlyStopping(monitor='val_loss', patience=3)
  checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

  X, y =  X_train[train_index], y_train[train_index]
  X_val, y_val = X_train[test_index], y_train[test_index]


  history = model.fit(X, y, epochs=100, batch_size=32,validation_data=(X_val, y_val),callbacks=[checkpoint, early_stop] )

  mediamse = np.mean( history.history['loss'] )
  stdmse = np.std(  history.history['loss'])
  print('')
  print(f" La media del mse, {i}-fold es : {mediamse}")
  print('')
  print(f" La desviacion estandar del mse, {i}-fold es : {stdmse}")

  # Obtener los valores de "average loss" para el pliegue actual
  fold_train_losses = model.history.history['loss']
  fold_val_losses = model.history.history['val_loss']

  # Almacenar los valores de "average loss" para el pliegue actual
  train_losses.append(fold_train_losses)
  val_losses.append(fold_val_losses)

  if min(fold_val_losses) < best_loss:
        best_loss = min(fold_val_losses)
        best_model_path = filepath

  history.history.keys() # aqui me muestra que esta guardando, con history me guarda todos los valores que calcula durante el proceso de entrenamiento

  # vamos a graficar
  plt.plot(history.history['loss'], label='Perdida') # Grafico esta para ver si estoy sobre entrenando
  plt.plot(history.history['val_loss'], label='Validacion') # Grafico esta para ver si estoy sobre entrenando
  plt.xlabel('epoch')
  plt.ylabel('Mean Square Error')
  plt.legend()
  plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60)                15120
#
#  dense (Dense)               (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6040
# Epoch 1: val_loss improved from inf to 1.57848, saving model to modelo-1.h5
# 1/1 [==============================] - 2s 2s/step - loss: 1.6040 - val_loss: 1.5785
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4954
# Epoch 2: val_loss improved from 1.57848 to 1.51100, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 39ms/step - loss: 1.4954 - val_loss: 1.5110
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4275
# Epoch 3: val_loss improved from 1.51100 to 1.45710, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 39ms/step - loss: 1.4275 - val_loss: 1.4571
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3741
# Epoch 4: val_loss improved from 1.45710 to 1.41020, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 41ms/step - loss: 1.3741 - val_loss: 1.4102
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3278
# Epoch 5: val_loss improved from 1.41020 to 1.36716, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 41ms/step - loss: 1.3278 - val_loss: 1.3672
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2854
# Epoch 6: val_loss improved from 1.36716 to 1.32646, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 42ms/step - loss: 1.2854 - val_loss: 1.3265
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2456
# Epoch 7: val_loss improved from 1.32646 to 1.28719, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 1.2456 - val_loss: 1.2872
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2073
# Epoch 8: val_loss improved from 1.28719 to 1.24875, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 1.2073 - val_loss: 1.2487
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1701
# Epoch 9: val_loss improved from 1.24875 to 1.21077, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 47ms/step - loss: 1.1701 - val_loss: 1.2108
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1335
# Epoch 10: val_loss improved from 1.21077 to 1.17305, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 1.1335 - val_loss: 1.1730
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0973
# Epoch 11: val_loss improved from 1.17305 to 1.13550, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0973 - val_loss: 1.1355
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0615
# Epoch 12: val_loss improved from 1.13550 to 1.09819, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0615 - val_loss: 1.0982
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0261
# Epoch 13: val_loss improved from 1.09819 to 1.06128, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0261 - val_loss: 1.0613
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9913
# Epoch 14: val_loss improved from 1.06128 to 1.02500, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9913 - val_loss: 1.0250
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9573
# Epoch 15: val_loss improved from 1.02500 to 0.98961, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 38ms/step - loss: 0.9573 - val_loss: 0.9896
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9242
# Epoch 16: val_loss improved from 0.98961 to 0.95531, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 40ms/step - loss: 0.9242 - val_loss: 0.9553
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8923
# Epoch 17: val_loss improved from 0.95531 to 0.92221, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 39ms/step - loss: 0.8923 - val_loss: 0.9222
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8616
# Epoch 18: val_loss improved from 0.92221 to 0.89028, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 0.8616 - val_loss: 0.8903
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8319
# Epoch 19: val_loss improved from 0.89028 to 0.85943, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 0.8319 - val_loss: 0.8594
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8031
# Epoch 20: val_loss improved from 0.85943 to 0.82948, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 42ms/step - loss: 0.8031 - val_loss: 0.8295
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7749
# Epoch 21: val_loss improved from 0.82948 to 0.80026, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 42ms/step - loss: 0.7749 - val_loss: 0.8003
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7473
# Epoch 22: val_loss improved from 0.80026 to 0.77160, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 0.7473 - val_loss: 0.7716
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7200
# Epoch 23: val_loss improved from 0.77160 to 0.74338, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 0.7200 - val_loss: 0.7434
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6931
# Epoch 24: val_loss improved from 0.74338 to 0.71554, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6931 - val_loss: 0.7155
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6664
# Epoch 25: val_loss improved from 0.71554 to 0.68805, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.6664 - val_loss: 0.6881
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6399
# Epoch 26: val_loss improved from 0.68805 to 0.66094, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6399 - val_loss: 0.6609
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6138
# Epoch 27: val_loss improved from 0.66094 to 0.63426, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6138 - val_loss: 0.6343
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5880
# Epoch 28: val_loss improved from 0.63426 to 0.60806, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 0.5880 - val_loss: 0.6081
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5626
# Epoch 29: val_loss improved from 0.60806 to 0.58242, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 0.5626 - val_loss: 0.5824
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5377
# Epoch 30: val_loss improved from 0.58242 to 0.55741, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 0.5377 - val_loss: 0.5574
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5134
# Epoch 31: val_loss improved from 0.55741 to 0.53313, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5134 - val_loss: 0.5331
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4898
# Epoch 32: val_loss improved from 0.53313 to 0.50964, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4898 - val_loss: 0.5096
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4671
# Epoch 33: val_loss improved from 0.50964 to 0.48702, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4671 - val_loss: 0.4870
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4452
# Epoch 34: val_loss improved from 0.48702 to 0.46535, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4452 - val_loss: 0.4653
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4244
# Epoch 35: val_loss improved from 0.46535 to 0.44471, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4244 - val_loss: 0.4447
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4047
# Epoch 36: val_loss improved from 0.44471 to 0.42513, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4047 - val_loss: 0.4251
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3861
# Epoch 37: val_loss improved from 0.42513 to 0.40678, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3861 - val_loss: 0.4068
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3687
# Epoch 38: val_loss improved from 0.40678 to 0.38926, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3687 - val_loss: 0.3893
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3524
# Epoch 39: val_loss improved from 0.38926 to 0.37370, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3524 - val_loss: 0.3737
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3372
# Epoch 40: val_loss improved from 0.37370 to 0.35682, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3372 - val_loss: 0.3568
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3232
# Epoch 41: val_loss improved from 0.35682 to 0.34955, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3232 - val_loss: 0.3496
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3109
# Epoch 42: val_loss improved from 0.34955 to 0.32761, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3109 - val_loss: 0.3276
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3025
# Epoch 43: val_loss did not improve from 0.32761
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3025 - val_loss: 0.3458
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2949
# Epoch 44: val_loss improved from 0.32761 to 0.30541, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2949 - val_loss: 0.3054
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2840
# Epoch 45: val_loss improved from 0.30541 to 0.30479, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 0.2840 - val_loss: 0.3048
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2687
# Epoch 46: val_loss improved from 0.30479 to 0.28664, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 41ms/step - loss: 0.2687 - val_loss: 0.2866
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2591
# Epoch 47: val_loss improved from 0.28664 to 0.28028, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2591 - val_loss: 0.2803
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2507
# Epoch 48: val_loss improved from 0.28028 to 0.27068, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2507 - val_loss: 0.2707
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2430
# Epoch 49: val_loss improved from 0.27068 to 0.26330, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2430 - val_loss: 0.2633
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2357
# Epoch 50: val_loss improved from 0.26330 to 0.25537, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 0.2357 - val_loss: 0.2554
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2288
# Epoch 51: val_loss improved from 0.25537 to 0.24860, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2288 - val_loss: 0.2486
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2224
# Epoch 52: val_loss improved from 0.24860 to 0.24155, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2224 - val_loss: 0.2415
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2163
# Epoch 53: val_loss improved from 0.24155 to 0.23565, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 0.2163 - val_loss: 0.2357
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2106
# Epoch 54: val_loss improved from 0.23565 to 0.22916, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2106 - val_loss: 0.2292
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2052
# Epoch 55: val_loss improved from 0.22916 to 0.22437, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2052 - val_loss: 0.2244
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2002
# Epoch 56: val_loss improved from 0.22437 to 0.21811, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 0.2002 - val_loss: 0.2181
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1955
# Epoch 57: val_loss improved from 0.21811 to 0.21470, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 0.1955 - val_loss: 0.2147
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1911
# Epoch 58: val_loss improved from 0.21470 to 0.20830, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1911 - val_loss: 0.2083
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1869
# Epoch 59: val_loss improved from 0.20830 to 0.20599, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1869 - val_loss: 0.2060
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1829
# Epoch 60: val_loss improved from 0.20599 to 0.19949, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1829 - val_loss: 0.1995
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1790
# Epoch 61: val_loss improved from 0.19949 to 0.19821, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 0.1790 - val_loss: 0.1982
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1753
# Epoch 62: val_loss improved from 0.19821 to 0.19195, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1753 - val_loss: 0.1920
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1716
# Epoch 63: val_loss improved from 0.19195 to 0.19107, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1716 - val_loss: 0.1911
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1681
# Epoch 64: val_loss improved from 0.19107 to 0.18598, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1681 - val_loss: 0.1860
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1647
# Epoch 65: val_loss did not improve from 0.18598
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1647 - val_loss: 0.1863
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1615
# Epoch 66: val_loss improved from 0.18598 to 0.18252, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1615 - val_loss: 0.1825
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1583
# Epoch 67: val_loss did not improve from 0.18252
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1583 - val_loss: 0.1868
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1552
# Epoch 68: val_loss improved from 0.18252 to 0.17855, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 0.1552 - val_loss: 0.1786
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1522
# Epoch 69: val_loss did not improve from 0.17855
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1522 - val_loss: 0.2112
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1503
# Epoch 70: val_loss improved from 0.17855 to 0.16529, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1503 - val_loss: 0.1653
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1532
# Epoch 71: val_loss improved from 0.16529 to 0.16469, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1532 - val_loss: 0.1647
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1461
# Epoch 72: val_loss did not improve from 0.16469
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1461 - val_loss: 0.1758
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1418
# Epoch 73: val_loss did not improve from 0.16469
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1418 - val_loss: 0.2094
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1394
# Epoch 74: val_loss improved from 0.16469 to 0.15266, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1394 - val_loss: 0.1527
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1415
# Epoch 75: val_loss improved from 0.15266 to 0.15078, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1415 - val_loss: 0.1508
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1369
# Epoch 76: val_loss did not improve from 0.15078
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1369 - val_loss: 0.1573
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1328
# Epoch 77: val_loss did not improve from 0.15078
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1328 - val_loss: 0.2587
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1383
# Epoch 78: val_loss did not improve from 0.15078
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1383 - val_loss: 0.1528
#
#  La media del mse, 0-fold es : 0.5260006886644241
#
#  La desviacion estandar del mse, 0-fold es : 0.4081549745376994
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 60)                15120
#
#  dense_1 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 1.8651
# Epoch 1: val_loss improved from inf to 1.30839, saving model to modelo-2.h5
# 2/2 [==============================] - 2s 369ms/step - loss: 1.8223 - val_loss: 1.3084
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7233
# Epoch 2: val_loss improved from 1.30839 to 1.23611, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 1.6824 - val_loss: 1.2361
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5469
# Epoch 3: val_loss improved from 1.23611 to 1.12148, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 1.6094 - val_loss: 1.1215
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4162
# Epoch 4: val_loss improved from 1.12148 to 1.04429, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 1.4916 - val_loss: 1.0443
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4440
# Epoch 5: val_loss improved from 1.04429 to 1.01772, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.4091 - val_loss: 1.0177
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4165
# Epoch 6: val_loss improved from 1.01772 to 0.99512, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 1.3831 - val_loss: 0.9951
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3875
# Epoch 7: val_loss improved from 0.99512 to 0.95288, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 1.3593 - val_loss: 0.9529
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3368
# Epoch 8: val_loss improved from 0.95288 to 0.91451, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 39ms/step - loss: 1.3127 - val_loss: 0.9145
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2944
# Epoch 9: val_loss improved from 0.91451 to 0.89333, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 1.2635 - val_loss: 0.8933
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2677
# Epoch 10: val_loss improved from 0.89333 to 0.84829, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 1.2402 - val_loss: 0.8483
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1965
# Epoch 11: val_loss improved from 0.84829 to 0.79151, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.1868 - val_loss: 0.7915
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1418
# Epoch 12: val_loss improved from 0.79151 to 0.77473, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 1.1166 - val_loss: 0.7747
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1241
# Epoch 13: val_loss improved from 0.77473 to 0.75802, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 39ms/step - loss: 1.0979 - val_loss: 0.7580
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0897
# Epoch 14: val_loss improved from 0.75802 to 0.71309, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.0759 - val_loss: 0.7131
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0258
# Epoch 15: val_loss improved from 0.71309 to 0.66900, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 38ms/step - loss: 1.0083 - val_loss: 0.6690
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9600
# Epoch 16: val_loss improved from 0.66900 to 0.65425, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.9480 - val_loss: 0.6543
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9450
# Epoch 17: val_loss improved from 0.65425 to 0.63962, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.9319 - val_loss: 0.6396
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8408
# Epoch 18: val_loss improved from 0.63962 to 0.57860, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 0.9102 - val_loss: 0.5786
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7930
# Epoch 19: val_loss improved from 0.57860 to 0.55047, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.8182 - val_loss: 0.5505
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7826
# Epoch 20: val_loss improved from 0.55047 to 0.52499, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.7668 - val_loss: 0.5250
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7427
# Epoch 21: val_loss improved from 0.52499 to 0.50351, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 38ms/step - loss: 0.7348 - val_loss: 0.5035
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7283
# Epoch 22: val_loss improved from 0.50351 to 0.49151, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 39ms/step - loss: 0.7232 - val_loss: 0.4915
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7191
# Epoch 23: val_loss improved from 0.49151 to 0.48946, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 39ms/step - loss: 0.7120 - val_loss: 0.4895
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6532
# Epoch 24: val_loss improved from 0.48946 to 0.44743, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 37ms/step - loss: 0.7096 - val_loss: 0.4474
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6437
# Epoch 25: val_loss improved from 0.44743 to 0.43057, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6369 - val_loss: 0.4306
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5988
# Epoch 26: val_loss improved from 0.43057 to 0.40988, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6271 - val_loss: 0.4099
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5958
# Epoch 27: val_loss improved from 0.40988 to 0.39354, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.5821 - val_loss: 0.3935
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5386
# Epoch 28: val_loss did not improve from 0.39354
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5652 - val_loss: 0.4028
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5534
# Epoch 29: val_loss did not improve from 0.39354
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5488 - val_loss: 0.4042
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5309
# Epoch 30: val_loss improved from 0.39354 to 0.34873, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 0.5361 - val_loss: 0.3487
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4865
# Epoch 31: val_loss did not improve from 0.34873
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5043 - val_loss: 0.3521
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4791
# Epoch 32: val_loss did not improve from 0.34873
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4842 - val_loss: 0.3619
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4762
# Epoch 33: val_loss did not improve from 0.34873
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4786 - val_loss: 0.3801
#
#  La media del mse, 1-fold es : 0.9781020473350178
#
#  La desviacion estandar del mse, 1-fold es : 0.3783961282569673
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 60)                15120
#
#  dense_2 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 1.7708
# Epoch 1: val_loss improved from inf to 1.47385, saving model to modelo-3.h5
# 2/2 [==============================] - 2s 474ms/step - loss: 1.7312 - val_loss: 1.4738
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5999
# Epoch 2: val_loss improved from 1.47385 to 1.37586, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 1.5725 - val_loss: 1.3759
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4572
# Epoch 3: val_loss improved from 1.37586 to 1.29501, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 1.4592 - val_loss: 1.2950
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2958
# Epoch 4: val_loss improved from 1.29501 to 1.22296, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 1.3621 - val_loss: 1.2230
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2760
# Epoch 5: val_loss improved from 1.22296 to 1.17188, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 1.2747 - val_loss: 1.1719
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2396
# Epoch 6: val_loss improved from 1.17188 to 1.13200, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.2134 - val_loss: 1.1320
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1824
# Epoch 7: val_loss improved from 1.13200 to 1.08370, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 1.1680 - val_loss: 1.0837
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1275
# Epoch 8: val_loss improved from 1.08370 to 1.03380, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 1.1128 - val_loss: 1.0338
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0692
# Epoch 9: val_loss improved from 1.03380 to 1.01002, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 1.0556 - val_loss: 1.0100
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0563
# Epoch 10: val_loss improved from 1.01002 to 0.98905, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 38ms/step - loss: 1.0381 - val_loss: 0.9891
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0329
# Epoch 11: val_loss improved from 0.98905 to 0.93254, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 1.0182 - val_loss: 0.9325
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9670
# Epoch 12: val_loss improved from 0.93254 to 0.91721, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.9538 - val_loss: 0.9172
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9290
# Epoch 13: val_loss improved from 0.91721 to 0.84817, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 0.9400 - val_loss: 0.8482
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8726
# Epoch 14: val_loss improved from 0.84817 to 0.81627, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.8515 - val_loss: 0.8163
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8347
# Epoch 15: val_loss improved from 0.81627 to 0.78094, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 0.8158 - val_loss: 0.7809
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7361
# Epoch 16: val_loss improved from 0.78094 to 0.73902, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 0.7728 - val_loss: 0.7390
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7055
# Epoch 17: val_loss improved from 0.73902 to 0.70418, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.7063 - val_loss: 0.7042
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6647
# Epoch 18: val_loss improved from 0.70418 to 0.67657, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6857 - val_loss: 0.6766
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6351
# Epoch 19: val_loss improved from 0.67657 to 0.64554, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6379 - val_loss: 0.6455
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5870
# Epoch 20: val_loss improved from 0.64554 to 0.62271, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6210 - val_loss: 0.6227
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5908
# Epoch 21: val_loss improved from 0.62271 to 0.59864, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.5776 - val_loss: 0.5986
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5688
# Epoch 22: val_loss improved from 0.59864 to 0.57864, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5556 - val_loss: 0.5786
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5495
# Epoch 23: val_loss improved from 0.57864 to 0.56318, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 39ms/step - loss: 0.5366 - val_loss: 0.5632
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5275
# Epoch 24: val_loss improved from 0.56318 to 0.55073, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 0.5258 - val_loss: 0.5507
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5271
# Epoch 25: val_loss improved from 0.55073 to 0.53831, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5261 - val_loss: 0.5383
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5148
# Epoch 26: val_loss improved from 0.53831 to 0.49905, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.5156 - val_loss: 0.4990
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4670
# Epoch 27: val_loss improved from 0.49905 to 0.48251, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.4557 - val_loss: 0.4825
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4299
# Epoch 28: val_loss did not improve from 0.48251
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4404 - val_loss: 0.4909
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4407
# Epoch 29: val_loss improved from 0.48251 to 0.45498, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.4302 - val_loss: 0.4550
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4120
# Epoch 30: val_loss improved from 0.45498 to 0.44010, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 0.4033 - val_loss: 0.4401
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3819
# Epoch 31: val_loss did not improve from 0.44010
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3950 - val_loss: 0.4499
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3971
# Epoch 32: val_loss improved from 0.44010 to 0.41544, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 39ms/step - loss: 0.3876 - val_loss: 0.4154
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3582
# Epoch 33: val_loss improved from 0.41544 to 0.39187, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.3618 - val_loss: 0.3919
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3521
# Epoch 34: val_loss improved from 0.39187 to 0.37903, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 0.3530 - val_loss: 0.3790
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3495
# Epoch 35: val_loss improved from 0.37903 to 0.37686, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.3454 - val_loss: 0.3769
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3511
# Epoch 36: val_loss did not improve from 0.37686
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3456 - val_loss: 0.3769
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3535
# Epoch 37: val_loss did not improve from 0.37686
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3471 - val_loss: 0.3800
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3607
# Epoch 38: val_loss did not improve from 0.37686
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3524 - val_loss: 0.3781
#
#  La media del mse, 2-fold es : 0.759090687099256
#
#  La desviacion estandar del mse, 2-fold es : 0.38297206664494293
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 60)                15120
#
#  dense_3 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 1.6685
# Epoch 1: val_loss improved from inf to 1.51596, saving model to modelo-4.h5
# 2/2 [==============================] - 2s 662ms/step - loss: 1.6478 - val_loss: 1.5160
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5136
# Epoch 2: val_loss improved from 1.51596 to 1.46221, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 1.4793 - val_loss: 1.4622
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4472
# Epoch 3: val_loss improved from 1.46221 to 1.37306, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 1.4222 - val_loss: 1.3731
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3673
# Epoch 4: val_loss improved from 1.37306 to 1.29727, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 1.3418 - val_loss: 1.2973
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2067
# Epoch 5: val_loss improved from 1.29727 to 1.18286, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 1.2722 - val_loss: 1.1829
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1311
# Epoch 6: val_loss improved from 1.18286 to 1.08846, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 1.1742 - val_loss: 1.0885
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1182
# Epoch 7: val_loss improved from 1.08846 to 1.03898, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.0948 - val_loss: 1.0390
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0594
# Epoch 8: val_loss improved from 1.03898 to 0.97530, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 1.0498 - val_loss: 0.9753
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0099
# Epoch 9: val_loss improved from 0.97530 to 0.96384, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 39ms/step - loss: 0.9955 - val_loss: 0.9638
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9952
# Epoch 10: val_loss improved from 0.96384 to 0.95308, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 37ms/step - loss: 0.9795 - val_loss: 0.9531
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9824
# Epoch 11: val_loss improved from 0.95308 to 0.94034, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 38ms/step - loss: 0.9659 - val_loss: 0.9403
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9684
# Epoch 12: val_loss improved from 0.94034 to 0.92335, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.9513 - val_loss: 0.9234
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9507
# Epoch 13: val_loss improved from 0.92335 to 0.90691, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 0.9333 - val_loss: 0.9069
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9344
# Epoch 14: val_loss improved from 0.90691 to 0.84097, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 0.9148 - val_loss: 0.8410
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8737
# Epoch 15: val_loss improved from 0.84097 to 0.77442, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.8561 - val_loss: 0.7744
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8116
# Epoch 16: val_loss improved from 0.77442 to 0.76073, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.7981 - val_loss: 0.7607
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7971
# Epoch 17: val_loss improved from 0.76073 to 0.74178, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.7822 - val_loss: 0.7418
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7116
# Epoch 18: val_loss improved from 0.74178 to 0.63063, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.7571 - val_loss: 0.6306
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6662
# Epoch 19: val_loss improved from 0.63063 to 0.62383, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6608 - val_loss: 0.6238
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6576
# Epoch 20: val_loss improved from 0.62383 to 0.61977, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6501 - val_loss: 0.6198
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6175
# Epoch 21: val_loss improved from 0.61977 to 0.54424, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6409 - val_loss: 0.5442
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5832
# Epoch 22: val_loss improved from 0.54424 to 0.51726, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 0.5714 - val_loss: 0.5173
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5508
# Epoch 23: val_loss improved from 0.51726 to 0.51537, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.5478 - val_loss: 0.5154
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5548
# Epoch 24: val_loss improved from 0.51537 to 0.48795, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.5425 - val_loss: 0.4880
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5291
# Epoch 25: val_loss improved from 0.48795 to 0.46399, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.5169 - val_loss: 0.4640
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5069
# Epoch 26: val_loss improved from 0.46399 to 0.44767, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.4945 - val_loss: 0.4477
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4627
# Epoch 27: val_loss improved from 0.44767 to 0.41121, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 0.4775 - val_loss: 0.4112
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4105
# Epoch 28: val_loss improved from 0.41121 to 0.40802, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.4434 - val_loss: 0.4080
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4288
# Epoch 29: val_loss improved from 0.40802 to 0.39593, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.4361 - val_loss: 0.3959
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4234
# Epoch 30: val_loss improved from 0.39593 to 0.38725, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.4163 - val_loss: 0.3873
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4017
# Epoch 31: val_loss improved from 0.38725 to 0.33841, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 0.4026 - val_loss: 0.3384
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3562
# Epoch 32: val_loss improved from 0.33841 to 0.33381, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 0.3538 - val_loss: 0.3338
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3517
# Epoch 33: val_loss did not improve from 0.33381
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3506 - val_loss: 0.3393
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3435
# Epoch 34: val_loss improved from 0.33381 to 0.31092, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 0.3419 - val_loss: 0.3109
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3206
# Epoch 35: val_loss improved from 0.31092 to 0.30431, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 39ms/step - loss: 0.3189 - val_loss: 0.3043
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3127
# Epoch 36: val_loss improved from 0.30431 to 0.30151, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 0.3121 - val_loss: 0.3015
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3101
# Epoch 37: val_loss improved from 0.30151 to 0.29675, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.3100 - val_loss: 0.2967
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3136
# Epoch 38: val_loss improved from 0.29675 to 0.28145, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.3056 - val_loss: 0.2814
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2833
# Epoch 39: val_loss did not improve from 0.28145
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2846 - val_loss: 0.2883
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2815
# Epoch 40: val_loss improved from 0.28145 to 0.27118, saving model to modelo-4.h5
# ...
# Epoch 56/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1784
# Epoch 56: val_loss did not improve from 0.21841
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1852 - val_loss: 0.2578
# Epoch 57/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2050
# Epoch 57: val_loss did not improve from 0.21841
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1993 - val_loss: 0.2405
# Epoch 58/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1866
# Epoch 58: val_loss improved from 0.21841 to 0.21703, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1860 - val_loss: 0.2170
# Epoch 59/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1763
# Epoch 59: val_loss improved from 0.21703 to 0.20806, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1730 - val_loss: 0.2081
# Epoch 60/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1688
# Epoch 60: val_loss did not improve from 0.20806
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1676 - val_loss: 0.2098
# Epoch 61/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1682
# Epoch 61: val_loss improved from 0.20806 to 0.20219, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1674 - val_loss: 0.2022
# Epoch 62/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1599
# Epoch 62: val_loss improved from 0.20219 to 0.19636, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1618 - val_loss: 0.1964
# Epoch 63/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1668
# Epoch 63: val_loss improved from 0.19636 to 0.19219, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1636 - val_loss: 0.1922
# Epoch 64/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1607
# Epoch 64: val_loss improved from 0.19219 to 0.19079, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1591 - val_loss: 0.1908
# Epoch 65/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1557
# Epoch 65: val_loss improved from 0.19079 to 0.18751, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1528 - val_loss: 0.1875
# Epoch 66/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1552
# Epoch 66: val_loss improved from 0.18751 to 0.18680, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1521 - val_loss: 0.1868
# Epoch 67/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1459
# Epoch 67: val_loss did not improve from 0.18680
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1464 - val_loss: 0.1915
# Epoch 68/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1565
# Epoch 68: val_loss improved from 0.18680 to 0.18595, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1535 - val_loss: 0.1860
# Epoch 69/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1408
# Epoch 69: val_loss improved from 0.18595 to 0.18468, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1374 - val_loss: 0.1847
# Epoch 70/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1349
# Epoch 70: val_loss did not improve from 0.18468
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1338 - val_loss: 0.1851
# Epoch 71/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1293
# Epoch 71: val_loss did not improve from 0.18468
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1384 - val_loss: 0.2045
# Epoch 72/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1239
# Epoch 72: val_loss did not improve from 0.18468
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1348 - val_loss: 0.2446
#
#  La media del mse, 3-fold es : 0.4900948436309894
#
#  La desviacion estandar del mse, 3-fold es : 0.3839619796165014
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 60)                15120
#
#  dense_4 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 1.4866
# Epoch 1: val_loss improved from inf to 1.68592, saving model to modelo-5.h5
# 2/2 [==============================] - 2s 372ms/step - loss: 1.5497 - val_loss: 1.6859
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3649
# Epoch 2: val_loss improved from 1.68592 to 1.61644, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 1.3536 - val_loss: 1.6164
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3246
# Epoch 3: val_loss improved from 1.61644 to 1.57887, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 1.2950 - val_loss: 1.5789
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2812
# Epoch 4: val_loss improved from 1.57887 to 1.51162, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.2570 - val_loss: 1.5116
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2237
# Epoch 5: val_loss improved from 1.51162 to 1.48647, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.1990 - val_loss: 1.4865
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1899
# Epoch 6: val_loss improved from 1.48647 to 1.40848, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 1.1734 - val_loss: 1.4085
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0794
# Epoch 7: val_loss improved from 1.40848 to 1.30510, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 1.1079 - val_loss: 1.3051
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0379
# Epoch 8: val_loss improved from 1.30510 to 1.23299, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 1.0249 - val_loss: 1.2330
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9833
# Epoch 9: val_loss improved from 1.23299 to 1.21970, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 0.9686 - val_loss: 1.2197
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9748
# Epoch 10: val_loss improved from 1.21970 to 1.16447, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 0.9528 - val_loss: 1.1645
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9218
# Epoch 11: val_loss improved from 1.16447 to 1.15272, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.9082 - val_loss: 1.1527
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8547
# Epoch 12: val_loss improved from 1.15272 to 1.03952, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.8928 - val_loss: 1.0395
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7859
# Epoch 13: val_loss improved from 1.03952 to 0.96317, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 0.8080 - val_loss: 0.9632
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7617
# Epoch 14: val_loss improved from 0.96317 to 0.95494, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.7547 - val_loss: 0.9549
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7537
# Epoch 15: val_loss improved from 0.95494 to 0.94836, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.7427 - val_loss: 0.9484
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7419
# Epoch 16: val_loss improved from 0.94836 to 0.94623, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.7347 - val_loss: 0.9462
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7391
# Epoch 17: val_loss improved from 0.94623 to 0.93739, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.7306 - val_loss: 0.9374
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6980
# Epoch 18: val_loss improved from 0.93739 to 0.83819, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 0.7193 - val_loss: 0.8382
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6077
# Epoch 19: val_loss improved from 0.83819 to 0.76619, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.6491 - val_loss: 0.7662
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6082
# Epoch 20: val_loss improved from 0.76619 to 0.75731, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6068 - val_loss: 0.7573
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5949
# Epoch 21: val_loss improved from 0.75731 to 0.75571, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.5928 - val_loss: 0.7557
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5812
# Epoch 22: val_loss improved from 0.75571 to 0.69816, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 0.5864 - val_loss: 0.6982
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5655
# Epoch 23: val_loss improved from 0.69816 to 0.68966, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 0.5517 - val_loss: 0.6897
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5536
# Epoch 24: val_loss improved from 0.68966 to 0.68033, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.5396 - val_loss: 0.6803
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5205
# Epoch 25: val_loss improved from 0.68033 to 0.62774, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.5283 - val_loss: 0.6277
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5139
# Epoch 26: val_loss improved from 0.62774 to 0.62161, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 0.5024 - val_loss: 0.6216
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4877
# Epoch 27: val_loss did not improve from 0.62161
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4903 - val_loss: 0.6217
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4864
# Epoch 28: val_loss improved from 0.62161 to 0.62058, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.4846 - val_loss: 0.6206
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4935
# Epoch 29: val_loss improved from 0.62058 to 0.61078, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.4811 - val_loss: 0.6108
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4772
# Epoch 30: val_loss did not improve from 0.61078
# 2/2 [==============================] - 0s 59ms/step - loss: 0.4721 - val_loss: 0.6135
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4622
# Epoch 31: val_loss improved from 0.61078 to 0.52885, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.4706 - val_loss: 0.5289
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4240
# Epoch 32: val_loss improved from 0.52885 to 0.49594, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.4228 - val_loss: 0.4959
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4121
# Epoch 33: val_loss improved from 0.49594 to 0.48267, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 0.4116 - val_loss: 0.4827
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3917
# Epoch 34: val_loss improved from 0.48267 to 0.45584, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 0.3913 - val_loss: 0.4558
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3817
# Epoch 35: val_loss improved from 0.45584 to 0.43745, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.3895 - val_loss: 0.4375
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3952
# Epoch 36: val_loss improved from 0.43745 to 0.39984, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.3973 - val_loss: 0.3998
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3616
# Epoch 37: val_loss improved from 0.39984 to 0.38969, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 0.3516 - val_loss: 0.3897
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3465
# Epoch 38: val_loss improved from 0.38969 to 0.37858, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3451 - val_loss: 0.3786
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3645
# Epoch 39: val_loss improved from 0.37858 to 0.36111, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.3574 - val_loss: 0.3611
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3439
# Epoch 40: val_loss improved from 0.36111 to 0.35932, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.3525 - val_loss: 0.3593
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3750
# Epoch 41: val_loss improved from 0.35932 to 0.31554, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 0.3759 - val_loss: 0.3155
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3188
# Epoch 42: val_loss did not improve from 0.31554
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3173 - val_loss: 0.3180
# Epoch 43/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3117
# Epoch 43: val_loss improved from 0.31554 to 0.30520, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 0.3093 - val_loss: 0.3052
# Epoch 44/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3188
# Epoch 44: val_loss improved from 0.30520 to 0.28323, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 0.3187 - val_loss: 0.2832
# Epoch 45/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2875
# Epoch 45: val_loss did not improve from 0.28323
# 2/2 [==============================] - 0s 55ms/step - loss: 0.2853 - val_loss: 0.3007
# Epoch 46/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2766
# Epoch 46: val_loss did not improve from 0.28323
# 2/2 [==============================] - 0s 43ms/step - loss: 0.2742 - val_loss: 0.2996
# Epoch 47/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2729
# Epoch 47: val_loss did not improve from 0.28323
# 2/2 [==============================] - 0s 46ms/step - loss: 0.2713 - val_loss: 0.2964
#
#  La media del mse, 4-fold es : 0.6531937540845668
#
#  La desviacion estandar del mse, 4-fold es : 0.329455794320181

# %%
# rellenar de ceros los espacios vacios de la lista con loss y validation

df_train_losses = pd.DataFrame(train_losses)

df_filled_train_losses = df_train_losses.fillna(0)

train_losses_completa = df_filled_train_losses.values.tolist()

df_val_losses = pd.DataFrame(val_losses)

df_filled_val_losses = df_val_losses.fillna(0)

val_losses_completa = df_filled_val_losses.values.tolist()

# %%
# Calcular el promedio de "average loss" para todos los pliegues y épocas
avg_train_losses = np.mean(train_losses_completa, axis=0)
avg_val_losses = np.mean(val_losses_completa, axis=0)

# vamos a graficar
plt.plot(avg_train_losses, label='Perdida entrenamiento') # Grafico esta para ver si estoy sobre entrenando
plt.plot(avg_val_losses, label='Perdida Validacion') # Grafico esta para ver si estoy sobre entrenando
plt.title('avg loss train, avg loss val vs epoch ')
plt.xlabel('epoch')
plt.ylabel('Mean Square Error')
plt.legend()
plt.show()

# %%
# Cargar el mejor modelo
best_model = load_model(best_model_path)

# %%
# Seleccionar una secuencia específica
index = 0
input_sequence = X_test[index]

# Hacer la predicción
y_pred = best_model.predict(np.expand_dims(input_sequence, axis=0))
# usamos el np.expand_dims() para agregar una dimensión adicional al inicio de input_sequence
print(y_pred.shape)
# Out:
# 1/1 [==============================] - 0s 396ms/step
# (1, 210)

# %%
# Desenrollar X_test para convertirlo en un array bidimensional
X_test_flattened = X_test.reshape(-1, X_test.shape[-1])

# Aplicar la transformación inversa utilizando el objeto StandardScaler
X_test_desnormalizado = sc.inverse_transform(X_test_flattened)

# Volver a darle forma a X_test_desnormalizado a su forma original
X_test = X_test_desnormalizado.reshape(X_test.shape)

# Desnormalizar los datos
y_pred = sc_y.inverse_transform(y_pred)

y_test = sc_y.inverse_transform(y_test)

print(y_pred.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (1, 210)
# (17, 210)
# (17, 15, 2)

# %%
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
Curva=0

plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

print('')
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(X_test[Curva,:,0],color='orange', label='Valores actuales y anteriores de insulina')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_test[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 342.55552500000005

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_pred[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 350.8499210357666

# %%
# Media MSE y desviacion estandar MSE de las prediciones con la escala normal
mse = mean_squared_error(y_test[0,:].flatten(), y_pred.flatten())
std = np.sqrt(mse)
mediamse = np.mean(mse)

print('La media MSE:',mediamse)
print('La desviacion standar MSE', std)

# calcular la MAE
mae = mean_absolute_error(y_test[0,:], y_pred[0,:])
print('MAE:', mae)

# calcular la RMSE
rmse = np.sqrt(mean_squared_error(y_test[0,:], y_pred[0,:]))
print('RMSE:', rmse)
# Out:
# La media MSE: 214.202183393955
# La desviacion standar MSE 14.635647693011574
# MAE: 10.053181669689362
# RMSE: 14.635647693011574
