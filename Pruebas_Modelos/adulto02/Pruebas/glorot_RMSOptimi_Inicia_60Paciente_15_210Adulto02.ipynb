# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#Librerias
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split, KFold
from keras.callbacks import EarlyStopping

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import load_model

from keras.initializers import glorot_uniform

from tensorflow.keras.optimizers import RMSprop

# %%
#Dataset Adulto 02
data = pd.read_csv('/content/gdrive/MyDrive/Proyecto_de_grado/SUSTENTACION3.0/FinalX3/adulto02/my_adult02A2_data.csv')

print(f"El archivo se ha cargado correctamente. Tiene {data.shape[0]} filas y {data.shape[1]} columnas.")
# Out:
# El archivo se ha cargado correctamente. Tiene 29638 filas y 3 columnas.

# %%
train_size = int(len(data) * 0.7)

train_data = data.iloc[:train_size, :] # 70% entrenamiento
test_data = data.iloc[train_size:, :] # 30% prueba

test_data = test_data.reset_index(drop=True)

# %%
#los indices donde hay ingestas
posicionestrain = train_data.loc[train_data.iloc[:, 0] != 0].index
posicionestest = test_data.loc[test_data.iloc[:, 0] != 0].index

df_posiciones_train = pd.DataFrame(posicionestrain)
df_posiciones_test = pd.DataFrame(posicionestest)

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_train = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_train)):
    anterior = df_posiciones_train.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_train.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_train.append(anterior)

ultimo_elemento_train = df_posiciones_train.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_train.extend(ultimo_elemento_train.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_train)
print(len(cumplen_train))
# Out:
# [494, 862, 1358, 1974, 2353, 2840, 3461, 3846, 4334, 4956, 5324, 5820, 6438, 6815, 7301, 7917, 8283, 8781, 9398, 9781, 10268, 10880, 11255, 11750, 12363, 12742, 13230, 13845, 14212, 14699, 15311, 15686, 16183, 16795, 17162, 17650, 18266, 18653, 19140, 19757, 20125, 20614]
# 42

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_test = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_test)):
    anterior = df_posiciones_test.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_test.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_test.append(anterior)

ultimo_elemento_test = df_posiciones_test.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_test.extend(ultimo_elemento_test.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_test)
print(len(cumplen_test))
# Out:
# [487, 855, 1342, 1956, 2335, 2823, 3439, 3805, 4301, 4916, 5291, 5779, 6398, 6765, 7253, 7868, 8234, 8720]
# 18

# %%
# pasar la escala de los carbohidratos de las ingestas a gramos
data.iloc[:,0] = data.iloc[:,0].apply(lambda x: (x*15)/1000)

# Grafica con mayor detalle, el pico del comportamiento de la glucosa despues de la primera ingesta
print('')
print('Grafica de los datos del dataset')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
plt.title('Ingestas, Insulina y Glucosa')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')

print('Caso 1: Primera ingesta o Desayuno del primer dia:')
plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 700])
plt.ylim([-5, 250])
plt.show()
print('')

print('Caso 2: Primera y segunda ingesta del primer dia:')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1200])
plt.ylim([-5, 500])
plt.show()


print('Caso 3: las tres ingestas del primer dia:')

plt.plot(data.index, data.iloc[:,0], color='blue', label='Ingestas')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Ingestas de carbohidratos')
plt.xlabel('t [min]')
plt.ylabel('gramos')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Dosificación de insulina')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
#plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1800])
plt.ylim([-5, 500])
plt.show()
# Out:
# Grafica de los datos del dataset
# Caso 1: Primera ingesta o Desayuno del primer dia:
# Caso 2: Primera y segunda ingesta del primer dia:
# Caso 3: las tres ingestas del primer dia:

# %%
#Preprocesar los datos:
X_train = train_data.iloc[:, 1:3].values
y_train = train_data.iloc[:,2].values

X_test = test_data.iloc[:, 1:3].values
y_test = test_data.iloc[:, 2].values

print('Tamaño de los datos de entrada, de X_train: ',X_train.shape)
print(f'Tiene {X_train.shape[0]} filas y {X_train.shape[1]} columna')
print('La primera ingesta al minuto 300, ingesta: ',X_train[300])
print('La primera ingesta hasta el minuto 327, ingesta: ',X_train[327])

print('La entrada son los valores de la insulina y glucosa \n',X_train)
print('Tamaño de los datos de salia, de y_train',y_train.shape)
print(f'Tiene {y_train.shape[0]} filas y {y_train.shape[-1]} columnas')
print('La salida son los valores de glucosa \n',y_train)
# Out:
# Tamaño de los datos de entrada, de X_train:  (20746, 2)
# Tiene 20746 filas y 2 columna
# La primera ingesta al minuto 300, ingesta:  [  1.6789 123.44  ]
# La primera ingesta hasta el minuto 327, ingesta:  [  1.6789 123.44  ]
# La entrada son los valores de la insulina y glucosa
#  [[  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  ...
#  [  1.6789 198.03  ]
#  [  1.6789 197.1   ]
#  [  1.6789 196.18  ]]
# Tamaño de los datos de salia, de y_train (20746,)
# Tiene 20746 filas y 20746 columnas
# La salida son los valores de glucosa
#  [123.44 123.44 123.44 ... 198.03 197.1  196.18]

# %%
# Normalizar los datos
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Normalizar y_train
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.reshape(-1, 1))
y_test = sc_y.transform(y_test.reshape(-1, 1))

# %%
# Reorganizar los datos en forma de secuencia
def to_sequences(data,  seq_size_input, seq_size_output):
    X = []
    y = []

    for i in range(len(data)-seq_size_input-seq_size_output+1):
        X.append(data[i:(i+seq_size_input), 0:2])
        y.append(data[(i+seq_size_input):(i+seq_size_input+seq_size_output), 2])

    return np.array(X), np.array(y)

# %%
#CON LOS DATOS NORMALIZADOS
seq_size_input = 15
seq_size_output = 210
X_train, y_train = to_sequences(np.hstack((X_train, y_train)), seq_size_input, seq_size_output)
X_test, y_test = to_sequences(np.hstack((X_test, y_test)), seq_size_input, seq_size_output)
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (20522, 210)
# (20522, 15, 2)
# (8668, 210)
# (8668, 15, 2)

# %%
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
flattened_data = np.reshape(X_train, (X_train.shape[0], -1))

df_X_train = pd.DataFrame(flattened_data)

# %%
flattened_test = np.reshape(X_test, (X_test.shape[0], -1))

df_X_test = pd.DataFrame(flattened_test)

# %%
df_y_train = pd.DataFrame(y_train)
df_y_test = pd.DataFrame(y_test)

# %%
# Filtrar el dataframe para mantener solo las filas especificadas
df_X_train_seleccionado = df_X_train[df_X_train.index.isin(cumplen_train)]
df_y_train_seleccionado = df_y_train[df_y_train.index.isin(cumplen_train)]
df_X_test_seleccionado = df_X_test[df_X_test.index.isin(cumplen_test)]
df_y_test_seleccionado = df_y_test[df_y_test.index.isin(cumplen_test)]

# %%
print('Grafica de los datos del dataset')
#plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')

Numerocurva = 0

plt.plot(df_X_train_seleccionado.iloc[Numerocurva, 1::2],color='green',label='Entrada glucosa') #Para mostrar solo la glucosa
plt.plot(df_X_train_seleccionado.iloc[Numerocurva, ::2],color='orange',label='Entrada insulina') #Para mostrar solo la glucosa
plt.plot(range(seq_size_input*2, seq_size_output + seq_size_input*2),df_y_train_seleccionado.iloc[Numerocurva,:], color='red',label='Salida glucosa')
plt.title('Entradas y salidas, entrenamiento')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')
# Out:
# Grafica de los datos del dataset

# %%
X_train = df_X_train_seleccionado.values
y_train = df_y_train_seleccionado.values
X_test = df_X_test_seleccionado.values
y_test = df_y_test_seleccionado.values

print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 30)
# (17, 210)
# (17, 30)

# %%
print(len(X_test))
# Out:
# 17

# %%
X_train = np.reshape(X_train, (len(X_train), seq_size_input, 2))

X_test = np.reshape(X_test, (len(X_test), seq_size_input, 2))
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 15, 2)
# (17, 210)
# (17, 15, 2)

# %%
kf = KFold(n_splits=5)
kf.get_n_splits(X_train)
KFold(n_splits=5, random_state=None, shuffle=False)


# Crear listas para almacenar los valores del "average loss" de entrenamiento y validación en cada pliegue
train_losses = []
val_losses = []

#Para guardar el mejor modelo
best_loss = float('inf')
best_model_path = ""

for i, (train_index, test_index) in enumerate(kf.split(X_train,y_train)):
  model = Sequential()
  model.add(LSTM(60, activation='tanh', input_shape=(seq_size_input, 2), kernel_initializer=glorot_uniform()))
  model.add(Dense(seq_size_output, activation='linear', kernel_initializer=glorot_uniform()))


  model.compile(optimizer=RMSprop(), loss='mse')
  print(model.summary())

  filepath = f"modelo-{i+1}.h5"
  early_stop = EarlyStopping(monitor='val_loss', patience=3)
  checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

  X, y =  X_train[train_index], y_train[train_index]
  X_val, y_val = X_train[test_index], y_train[test_index]


  history = model.fit(X, y, epochs=100, batch_size=32,validation_data=(X_val, y_val),callbacks=[checkpoint, early_stop] )

  mediamse = np.mean( history.history['loss'] )
  stdmse = np.std(  history.history['loss'])
  print('')
  print(f" La media del mse, {i}-fold es : {mediamse}")
  print('')
  print(f" La desviacion estandar del mse, {i}-fold es : {stdmse}")

  # Obtener los valores de "average loss" para el pliegue actual
  fold_train_losses = model.history.history['loss']
  fold_val_losses = model.history.history['val_loss']

  # Almacenar los valores de "average loss" para el pliegue actual
  train_losses.append(fold_train_losses)
  val_losses.append(fold_val_losses)

  if min(fold_val_losses) < best_loss:
        best_loss = min(fold_val_losses)
        best_model_path = filepath

  history.history.keys() # aqui me muestra que esta guardando, con history me guarda todos los valores que calcula durante el proceso de entrenamiento

  # vamos a graficar
  plt.plot(history.history['loss'], label='Perdida') # Grafico esta para ver si estoy sobre entrenando
  plt.plot(history.history['val_loss'], label='Validacion') # Grafico esta para ver si estoy sobre entrenando
  plt.xlabel('epoch')
  plt.ylabel('Mean Square Error')
  plt.legend()
  plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 60)                15120
#
#  dense_5 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7542
# Epoch 1: val_loss improved from inf to 1.83076, saving model to modelo-1.h5
# 1/1 [==============================] - 3s 3s/step - loss: 1.7542 - val_loss: 1.8308
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7437
# Epoch 2: val_loss improved from 1.83076 to 1.82198, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 1.7437 - val_loss: 1.8220
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7352
# Epoch 3: val_loss improved from 1.82198 to 1.81344, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 1.7352 - val_loss: 1.8134
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7268
# Epoch 4: val_loss improved from 1.81344 to 1.80429, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 1.7268 - val_loss: 1.8043
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7179
# Epoch 5: val_loss improved from 1.80429 to 1.79383, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 1.7179 - val_loss: 1.7938
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7077
# Epoch 6: val_loss improved from 1.79383 to 1.78114, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 1.7077 - val_loss: 1.7811
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6952
# Epoch 7: val_loss improved from 1.78114 to 1.76494, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 1.6952 - val_loss: 1.7649
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6794
# Epoch 8: val_loss improved from 1.76494 to 1.74327, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 1.6794 - val_loss: 1.7433
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6581
# Epoch 9: val_loss improved from 1.74327 to 1.71311, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 1.6581 - val_loss: 1.7131
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6286
# Epoch 10: val_loss improved from 1.71311 to 1.67001, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 1.6286 - val_loss: 1.6700
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5864
# Epoch 11: val_loss improved from 1.67001 to 1.60797, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 1.5864 - val_loss: 1.6080
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5258
# Epoch 12: val_loss improved from 1.60797 to 1.52034, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 1.5258 - val_loss: 1.5203
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4403
# Epoch 13: val_loss improved from 1.52034 to 1.40378, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 59ms/step - loss: 1.4403 - val_loss: 1.4038
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3270
# Epoch 14: val_loss improved from 1.40378 to 1.26562, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 1.3270 - val_loss: 1.2656
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1934
# Epoch 15: val_loss improved from 1.26562 to 1.12553, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 1.1934 - val_loss: 1.1255
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0586
# Epoch 16: val_loss improved from 1.12553 to 1.00204, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 1.0586 - val_loss: 1.0020
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9405
# Epoch 17: val_loss improved from 1.00204 to 0.90171, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.9405 - val_loss: 0.9017
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8450
# Epoch 18: val_loss improved from 0.90171 to 0.82283, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.8450 - val_loss: 0.8228
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7704
# Epoch 19: val_loss improved from 0.82283 to 0.76146, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 59ms/step - loss: 0.7704 - val_loss: 0.7615
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7126
# Epoch 20: val_loss improved from 0.76146 to 0.71384, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.7126 - val_loss: 0.7138
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6680
# Epoch 21: val_loss improved from 0.71384 to 0.67687, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 0.6680 - val_loss: 0.6769
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6334
# Epoch 22: val_loss improved from 0.67687 to 0.64807, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6334 - val_loss: 0.6481
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6066
# Epoch 23: val_loss improved from 0.64807 to 0.62551, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6066 - val_loss: 0.6255
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5857
# Epoch 24: val_loss improved from 0.62551 to 0.60771, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.5857 - val_loss: 0.6077
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5693
# Epoch 25: val_loss improved from 0.60771 to 0.59357, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5693 - val_loss: 0.5936
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5562
# Epoch 26: val_loss improved from 0.59357 to 0.58225, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.5562 - val_loss: 0.5822
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5458
# Epoch 27: val_loss improved from 0.58225 to 0.57312, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.5458 - val_loss: 0.5731
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5374
# Epoch 28: val_loss improved from 0.57312 to 0.56573, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5374 - val_loss: 0.5657
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5306
# Epoch 29: val_loss improved from 0.56573 to 0.55972, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.5306 - val_loss: 0.5597
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5251
# Epoch 30: val_loss improved from 0.55972 to 0.55481, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 0.5251 - val_loss: 0.5548
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5206
# Epoch 31: val_loss improved from 0.55481 to 0.55080, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.5206 - val_loss: 0.5508
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5169
# Epoch 32: val_loss improved from 0.55080 to 0.54751, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.5169 - val_loss: 0.5475
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5139
# Epoch 33: val_loss improved from 0.54751 to 0.54480, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5139 - val_loss: 0.5448
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5114
# Epoch 34: val_loss improved from 0.54480 to 0.54257, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.5114 - val_loss: 0.5426
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5094
# Epoch 35: val_loss improved from 0.54257 to 0.54071, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.5094 - val_loss: 0.5407
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5077
# Epoch 36: val_loss improved from 0.54071 to 0.53915, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5077 - val_loss: 0.5392
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5063
# Epoch 37: val_loss improved from 0.53915 to 0.53783, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 84ms/step - loss: 0.5063 - val_loss: 0.5378
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5051
# Epoch 38: val_loss improved from 0.53783 to 0.53670, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.5051 - val_loss: 0.5367
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5041
# Epoch 39: val_loss improved from 0.53670 to 0.53571, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.5041 - val_loss: 0.5357
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5032
# Epoch 40: val_loss improved from 0.53571 to 0.53482, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.5032 - val_loss: 0.5348
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5023
# Epoch 41: val_loss improved from 0.53482 to 0.53400, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.5023 - val_loss: 0.5340
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5016
# Epoch 42: val_loss improved from 0.53400 to 0.53323, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.5016 - val_loss: 0.5332
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5009
# Epoch 43: val_loss improved from 0.53323 to 0.53247, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5009 - val_loss: 0.5325
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5002
# Epoch 44: val_loss improved from 0.53247 to 0.53171, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.5002 - val_loss: 0.5317
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4994
# Epoch 45: val_loss improved from 0.53171 to 0.53093, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4994 - val_loss: 0.5309
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4987
# Epoch 46: val_loss improved from 0.53093 to 0.53009, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.4987 - val_loss: 0.5301
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4979
# Epoch 47: val_loss improved from 0.53009 to 0.52919, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4979 - val_loss: 0.5292
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4970
# Epoch 48: val_loss improved from 0.52919 to 0.52820, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.4970 - val_loss: 0.5282
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4961
# Epoch 49: val_loss improved from 0.52820 to 0.52711, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.4961 - val_loss: 0.5271
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4950
# Epoch 50: val_loss improved from 0.52711 to 0.52589, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.4950 - val_loss: 0.5259
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4939
# Epoch 51: val_loss improved from 0.52589 to 0.52453, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.4939 - val_loss: 0.5245
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4926
# Epoch 52: val_loss improved from 0.52453 to 0.52298, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.4926 - val_loss: 0.5230
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4911
# Epoch 53: val_loss improved from 0.52298 to 0.52122, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.4911 - val_loss: 0.5212
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4894
# Epoch 54: val_loss improved from 0.52122 to 0.51919, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 0.4894 - val_loss: 0.5192
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4875
# Epoch 55: val_loss improved from 0.51919 to 0.51684, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.4875 - val_loss: 0.5168
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4853
# Epoch 56: val_loss improved from 0.51684 to 0.51404, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.4853 - val_loss: 0.5140
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4826
# Epoch 57: val_loss improved from 0.51404 to 0.51062, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4826 - val_loss: 0.5106
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4793
# Epoch 58: val_loss improved from 0.51062 to 0.50624, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 0.4793 - val_loss: 0.5062
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4752
# Epoch 59: val_loss improved from 0.50624 to 0.50155, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.4752 - val_loss: 0.5016
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4703
# Epoch 60: val_loss improved from 0.50155 to 0.49457, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.4703 - val_loss: 0.4946
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4651
# Epoch 61: val_loss did not improve from 0.49457
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4651 - val_loss: 0.4950
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4619
# Epoch 62: val_loss improved from 0.49457 to 0.48243, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4619 - val_loss: 0.4824
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4560
# Epoch 63: val_loss improved from 0.48243 to 0.48209, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.4560 - val_loss: 0.4821
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4489
# Epoch 64: val_loss improved from 0.48209 to 0.46318, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4489 - val_loss: 0.4632
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4376
# Epoch 65: val_loss improved from 0.46318 to 0.45906, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.4376 - val_loss: 0.4591
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4271
# Epoch 66: val_loss improved from 0.45906 to 0.43803, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.4271 - val_loss: 0.4380
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4138
# Epoch 67: val_loss improved from 0.43803 to 0.43428, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.4138 - val_loss: 0.4343
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4029
# Epoch 68: val_loss improved from 0.43428 to 0.41221, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.4029 - val_loss: 0.4122
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3910
# Epoch 69: val_loss improved from 0.41221 to 0.40996, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 0.3910 - val_loss: 0.4100
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3793
# Epoch 70: val_loss improved from 0.40996 to 0.38265, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.3793 - val_loss: 0.3826
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3639
# Epoch 71: val_loss improved from 0.38265 to 0.37372, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.3639 - val_loss: 0.3737
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3454
# Epoch 72: val_loss improved from 0.37372 to 0.34301, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.3454 - val_loss: 0.3430
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3260
# Epoch 73: val_loss improved from 0.34301 to 0.33406, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.3260 - val_loss: 0.3341
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3085
# Epoch 74: val_loss improved from 0.33406 to 0.30698, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.3085 - val_loss: 0.3070
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2926
# Epoch 75: val_loss improved from 0.30698 to 0.30131, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.2926 - val_loss: 0.3013
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2782
# Epoch 76: val_loss improved from 0.30131 to 0.27318, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.2782 - val_loss: 0.2732
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2613
# Epoch 77: val_loss improved from 0.27318 to 0.26675, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 87ms/step - loss: 0.2613 - val_loss: 0.2668
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2465
# Epoch 78: val_loss improved from 0.26675 to 0.23537, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.2465 - val_loss: 0.2354
# Epoch 79/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2255
# Epoch 79: val_loss improved from 0.23537 to 0.22972, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2255 - val_loss: 0.2297
# Epoch 80/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2126
# Epoch 80: val_loss improved from 0.22972 to 0.20076, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.2126 - val_loss: 0.2008
# Epoch 81/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1929
# Epoch 81: val_loss improved from 0.20076 to 0.19887, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1929 - val_loss: 0.1989
# Epoch 82/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1847
# Epoch 82: val_loss improved from 0.19887 to 0.17228, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1847 - val_loss: 0.1723
# Epoch 83/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1664
# Epoch 83: val_loss did not improve from 0.17228
# 1/1 [==============================] - 0s 47ms/step - loss: 0.1664 - val_loss: 0.1737
# Epoch 84/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1621
# Epoch 84: val_loss improved from 0.17228 to 0.14729, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1621 - val_loss: 0.1473
# Epoch 85/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1431
# Epoch 85: val_loss did not improve from 0.14729
# 1/1 [==============================] - 0s 47ms/step - loss: 0.1431 - val_loss: 0.1504
# Epoch 86/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1412
# Epoch 86: val_loss improved from 0.14729 to 0.12493, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1412 - val_loss: 0.1249
# Epoch 87/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1222
# Epoch 87: val_loss did not improve from 0.12493
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1222 - val_loss: 0.1293
# Epoch 88/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1223
# Epoch 88: val_loss improved from 0.12493 to 0.10662, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1223 - val_loss: 0.1066
# Epoch 89/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1052
# Epoch 89: val_loss did not improve from 0.10662
# 1/1 [==============================] - 0s 47ms/step - loss: 0.1052 - val_loss: 0.1127
# Epoch 90/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1074
# Epoch 90: val_loss improved from 0.10662 to 0.09267, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1074 - val_loss: 0.0927
# Epoch 91/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0923
# Epoch 91: val_loss did not improve from 0.09267
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0923 - val_loss: 0.1003
# Epoch 92/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0965
# Epoch 92: val_loss improved from 0.09267 to 0.08207, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0965 - val_loss: 0.0821
# Epoch 93/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0827
# Epoch 93: val_loss did not improve from 0.08207
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0827 - val_loss: 0.0907
# Epoch 94/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0882
# Epoch 94: val_loss improved from 0.08207 to 0.07371, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0882 - val_loss: 0.0737
# Epoch 95/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0750
# Epoch 95: val_loss did not improve from 0.07371
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0750 - val_loss: 0.0829
# Epoch 96/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0812
# Epoch 96: val_loss improved from 0.07371 to 0.06699, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0812 - val_loss: 0.0670
# Epoch 97/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0689
# Epoch 97: val_loss did not improve from 0.06699
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0689 - val_loss: 0.0764
# Epoch 98/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0754
# Epoch 98: val_loss improved from 0.06699 to 0.06167, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0754 - val_loss: 0.0617
# Epoch 99/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0640
# Epoch 99: val_loss did not improve from 0.06167
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0640 - val_loss: 0.0713
# Epoch 100/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0708
# Epoch 100: val_loss improved from 0.06167 to 0.05757, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0708 - val_loss: 0.0576
#
#  La media del mse, 0-fold es : 0.5852601021528244
#
#  La desviacion estandar del mse, 0-fold es : 0.47420795452956715
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 60)                15120
#
#  dense_6 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.8959
# Epoch 1: val_loss improved from inf to 1.40095, saving model to modelo-2.h5
# 2/2 [==============================] - 4s 825ms/step - loss: 1.8589 - val_loss: 1.4009
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8909
# Epoch 2: val_loss improved from 1.40095 to 1.38855, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 1.8415 - val_loss: 1.3886
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7474
# Epoch 3: val_loss improved from 1.38855 to 1.36255, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 1.8276 - val_loss: 1.3626
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8311
# Epoch 4: val_loss improved from 1.36255 to 1.33480, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 92ms/step - loss: 1.7983 - val_loss: 1.3348
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7181
# Epoch 5: val_loss improved from 1.33480 to 1.26927, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 1.7678 - val_loss: 1.2693
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6588
# Epoch 6: val_loss improved from 1.26927 to 1.14489, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 1.6945 - val_loss: 1.1449
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5925
# Epoch 7: val_loss improved from 1.14489 to 0.99270, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 1.5573 - val_loss: 0.9927
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4172
# Epoch 8: val_loss improved from 0.99270 to 0.78457, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 1.3872 - val_loss: 0.7846
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1777
# Epoch 9: val_loss improved from 0.78457 to 0.62530, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.1489 - val_loss: 0.6253
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9094
# Epoch 10: val_loss improved from 0.62530 to 0.47787, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.9545 - val_loss: 0.4779
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7777
# Epoch 11: val_loss improved from 0.47787 to 0.43782, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.7576 - val_loss: 0.4378
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7339
# Epoch 12: val_loss improved from 0.43782 to 0.40943, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.7142 - val_loss: 0.4094
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6557
# Epoch 13: val_loss improved from 0.40943 to 0.39079, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.6809 - val_loss: 0.3908
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6421
# Epoch 14: val_loss improved from 0.39079 to 0.36852, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 0.6265 - val_loss: 0.3685
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6200
# Epoch 15: val_loss improved from 0.36852 to 0.36198, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.6144 - val_loss: 0.3620
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6315
# Epoch 16: val_loss did not improve from 0.36198
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6243 - val_loss: 0.3658
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6525
# Epoch 17: val_loss did not improve from 0.36198
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6399 - val_loss: 0.3693
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6639
# Epoch 18: val_loss did not improve from 0.36198
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6496 - val_loss: 0.3719
#
#  La media del mse, 1-fold es : 1.174664941098955
#
#  La desviacion estandar del mse, 1-fold es : 0.5109784495631331
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 60)                15120
#
#  dense_7 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 1.8362
# Epoch 1: val_loss improved from inf to 1.64155, saving model to modelo-3.h5
# 2/2 [==============================] - 2s 518ms/step - loss: 1.8048 - val_loss: 1.6416
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8154
# Epoch 2: val_loss improved from 1.64155 to 1.62714, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 1.7873 - val_loss: 1.6271
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7080
# Epoch 3: val_loss improved from 1.62714 to 1.60496, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 1.7713 - val_loss: 1.6050
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7776
# Epoch 4: val_loss improved from 1.60496 to 1.57931, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 1.7468 - val_loss: 1.5793
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7496
# Epoch 5: val_loss improved from 1.57931 to 1.53051, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 1.7186 - val_loss: 1.5305
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7127
# Epoch 6: val_loss improved from 1.53051 to 1.46304, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 1.6652 - val_loss: 1.4630
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6369
# Epoch 7: val_loss improved from 1.46304 to 1.35690, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 1.5906 - val_loss: 1.3569
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4997
# Epoch 8: val_loss improved from 1.35690 to 1.12538, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.4697 - val_loss: 1.1254
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2330
# Epoch 9: val_loss improved from 1.12538 to 0.92054, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 1.2042 - val_loss: 0.9205
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8839
# Epoch 10: val_loss improved from 0.92054 to 0.73778, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.9550 - val_loss: 0.7378
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7418
# Epoch 11: val_loss improved from 0.73778 to 0.71559, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 0.7266 - val_loss: 0.7156
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7172
# Epoch 12: val_loss improved from 0.71559 to 0.66823, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.7076 - val_loss: 0.6682
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6602
# Epoch 13: val_loss improved from 0.66823 to 0.64628, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.6425 - val_loss: 0.6463
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6279
# Epoch 14: val_loss improved from 0.64628 to 0.62107, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.6171 - val_loss: 0.6211
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5842
# Epoch 15: val_loss improved from 0.62107 to 0.61544, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.5752 - val_loss: 0.6154
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5922
# Epoch 16: val_loss did not improve from 0.61544
# 2/2 [==============================] - 0s 41ms/step - loss: 0.5815 - val_loss: 0.6162
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6021
# Epoch 17: val_loss did not improve from 0.61544
# 2/2 [==============================] - 0s 40ms/step - loss: 0.5898 - val_loss: 0.6180
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6085
# Epoch 18: val_loss did not improve from 0.61544
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5967 - val_loss: 0.6220
#
#  La media del mse, 2-fold es : 1.1527925729751587
#
#  La desviacion estandar del mse, 2-fold es : 0.5106107986588504
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 60)                15120
#
#  dense_8 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.7864
# Epoch 1: val_loss improved from inf to 1.80890, saving model to modelo-4.h5
# 2/2 [==============================] - 3s 531ms/step - loss: 1.7595 - val_loss: 1.8089
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7684
# Epoch 2: val_loss improved from 1.80890 to 1.79105, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 1.7417 - val_loss: 1.7910
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7700
# Epoch 3: val_loss improved from 1.79105 to 1.77227, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 1.7246 - val_loss: 1.7723
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7348
# Epoch 4: val_loss improved from 1.77227 to 1.73441, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.7062 - val_loss: 1.7344
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5223
# Epoch 5: val_loss improved from 1.73441 to 1.64267, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 1.6684 - val_loss: 1.6427
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4915
# Epoch 6: val_loss improved from 1.64267 to 1.47572, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 1.5797 - val_loss: 1.4757
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4629
# Epoch 7: val_loss improved from 1.47572 to 1.35092, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.4233 - val_loss: 1.3509
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2243
# Epoch 8: val_loss improved from 1.35092 to 1.03302, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 1.2969 - val_loss: 1.0330
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0347
# Epoch 9: val_loss improved from 1.03302 to 0.98118, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 1.0087 - val_loss: 0.9812
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9846
# Epoch 10: val_loss improved from 0.98118 to 0.93002, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 80ms/step - loss: 0.9587 - val_loss: 0.9300
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8302
# Epoch 11: val_loss improved from 0.93002 to 0.72886, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.9029 - val_loss: 0.7289
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7416
# Epoch 12: val_loss improved from 0.72886 to 0.72383, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.7278 - val_loss: 0.7238
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7400
# Epoch 13: val_loss improved from 0.72383 to 0.68865, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 89ms/step - loss: 0.7201 - val_loss: 0.6887
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7031
# Epoch 14: val_loss improved from 0.68865 to 0.68854, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 74ms/step - loss: 0.6885 - val_loss: 0.6885
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7057
# Epoch 15: val_loss improved from 0.68854 to 0.64997, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 0.6859 - val_loss: 0.6500
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6701
# Epoch 16: val_loss improved from 0.64997 to 0.62123, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 100ms/step - loss: 0.6513 - val_loss: 0.6212
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5790
# Epoch 17: val_loss improved from 0.62123 to 0.53937, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 82ms/step - loss: 0.6226 - val_loss: 0.5394
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5681
# Epoch 18: val_loss did not improve from 0.53937
# 2/2 [==============================] - 0s 54ms/step - loss: 0.5597 - val_loss: 0.5472
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5792
# Epoch 19: val_loss did not improve from 0.53937
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5627 - val_loss: 0.5405
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5263
# Epoch 20: val_loss improved from 0.53937 to 0.50572, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 88ms/step - loss: 0.5554 - val_loss: 0.5057
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5383
# Epoch 21: val_loss improved from 0.50572 to 0.50048, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.5342 - val_loss: 0.5005
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4864
# Epoch 22: val_loss did not improve from 0.50048
# 2/2 [==============================] - 0s 54ms/step - loss: 0.5362 - val_loss: 0.5195
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5768
# Epoch 23: val_loss improved from 0.50048 to 0.49909, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5643 - val_loss: 0.4991
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5296
# Epoch 24: val_loss did not improve from 0.49909
# 2/2 [==============================] - 0s 58ms/step - loss: 0.5400 - val_loss: 0.5150
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5593
# Epoch 25: val_loss improved from 0.49909 to 0.48935, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.5608 - val_loss: 0.4893
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5413
# Epoch 26: val_loss improved from 0.48935 to 0.48901, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.5272 - val_loss: 0.4890
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5093
# Epoch 27: val_loss did not improve from 0.48901
# 2/2 [==============================] - 0s 86ms/step - loss: 0.5292 - val_loss: 0.5088
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5474
# Epoch 28: val_loss improved from 0.48901 to 0.48314, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 88ms/step - loss: 0.5550 - val_loss: 0.4831
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5153
# Epoch 29: val_loss improved from 0.48314 to 0.48230, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5200 - val_loss: 0.4823
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5234
# Epoch 30: val_loss improved from 0.48230 to 0.47894, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 0.5111 - val_loss: 0.4789
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5229
# Epoch 31: val_loss did not improve from 0.47894
# 2/2 [==============================] - 0s 53ms/step - loss: 0.5109 - val_loss: 0.4813
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5241
# Epoch 32: val_loss did not improve from 0.47894
# 2/2 [==============================] - 0s 84ms/step - loss: 0.5091 - val_loss: 0.4829
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5148
# Epoch 33: val_loss did not improve from 0.47894
# 2/2 [==============================] - 0s 59ms/step - loss: 0.5091 - val_loss: 0.5001
#
#  La media del mse, 3-fold es : 0.8621734380722046
#
#  La desviacion estandar del mse, 3-fold es : 0.44856888226041014
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 60)                15120
#
#  dense_9 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.7221
# Epoch 1: val_loss improved from inf to 2.09864, saving model to modelo-5.h5
# 2/2 [==============================] - 3s 527ms/step - loss: 1.6905 - val_loss: 2.0986
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7050
# Epoch 2: val_loss improved from 2.09864 to 2.08265, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 1.6736 - val_loss: 2.0826
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6866
# Epoch 3: val_loss improved from 2.08265 to 2.06265, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.6589 - val_loss: 2.0626
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6293
# Epoch 4: val_loss improved from 2.06265 to 2.02592, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.6402 - val_loss: 2.0259
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5629
# Epoch 5: val_loss improved from 2.02592 to 1.95867, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.6067 - val_loss: 1.9587
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5883
# Epoch 6: val_loss improved from 1.95867 to 1.88752, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 1.5471 - val_loss: 1.8875
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5223
# Epoch 7: val_loss improved from 1.88752 to 1.76723, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 1.4819 - val_loss: 1.7672
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4124
# Epoch 8: val_loss improved from 1.76723 to 1.59735, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 1.3738 - val_loss: 1.5974
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2481
# Epoch 9: val_loss improved from 1.59735 to 1.31742, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 1.2223 - val_loss: 1.3174
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0176
# Epoch 10: val_loss improved from 1.31742 to 1.20590, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.9895 - val_loss: 1.2059
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9160
# Epoch 11: val_loss improved from 1.20590 to 1.03149, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.8932 - val_loss: 1.0315
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7764
# Epoch 12: val_loss improved from 1.03149 to 0.98821, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.7562 - val_loss: 0.9882
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7368
# Epoch 13: val_loss improved from 0.98821 to 0.88130, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.7172 - val_loss: 0.8813
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6557
# Epoch 14: val_loss improved from 0.88130 to 0.83411, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.6373 - val_loss: 0.8341
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6181
# Epoch 15: val_loss improved from 0.83411 to 0.77635, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.6005 - val_loss: 0.7763
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5772
# Epoch 16: val_loss improved from 0.77635 to 0.74150, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.5606 - val_loss: 0.7415
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5220
# Epoch 17: val_loss improved from 0.74150 to 0.65607, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5346 - val_loss: 0.6561
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5071
# Epoch 18: val_loss did not improve from 0.65607
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5040 - val_loss: 0.6846
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5189
# Epoch 19: val_loss did not improve from 0.65607
# 2/2 [==============================] - 0s 45ms/step - loss: 0.5042 - val_loss: 0.6853
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5171
# Epoch 20: val_loss did not improve from 0.65607
# 2/2 [==============================] - 0s 46ms/step - loss: 0.5022 - val_loss: 0.6855
#
#  La media del mse, 4-fold es : 1.0547167599201202
#
#  La desviacion estandar del mse, 4-fold es : 0.4687638956457676

# %%
# rellenar de ceros los espacios vacios de la lista con loss y validation

df_train_losses = pd.DataFrame(train_losses)

df_filled_train_losses = df_train_losses.fillna(0)

train_losses_completa = df_filled_train_losses.values.tolist()

df_val_losses = pd.DataFrame(val_losses)

df_filled_val_losses = df_val_losses.fillna(0)

val_losses_completa = df_filled_val_losses.values.tolist()

# %%
# Calcular el promedio de "average loss" para todos los pliegues y épocas
avg_train_losses = np.mean(train_losses_completa, axis=0)
avg_val_losses = np.mean(val_losses_completa, axis=0)

# vamos a graficar
plt.plot(avg_train_losses, label='Perdida entrenamiento') # Grafico esta para ver si estoy sobre entrenando
plt.plot(avg_val_losses, label='Perdida Validacion') # Grafico esta para ver si estoy sobre entrenando
plt.title('avg loss train, avg loss val vs epoch ')
plt.xlabel('epoch')
plt.ylabel('Mean Square Error')
plt.legend()
plt.show()

# %%
# Cargar el mejor modelo
best_model = load_model(best_model_path)

# %%
# Seleccionar una secuencia específica
index = 0
input_sequence = X_test[index]

# Hacer la predicción
y_pred = best_model.predict(np.expand_dims(input_sequence, axis=0))
# usamos el np.expand_dims() para agregar una dimensión adicional al inicio de input_sequence
print(y_pred.shape)
# Out:
# 1/1 [==============================] - 1s 602ms/step
# (1, 210)

# %%
# Desenrollar X_test para convertirlo en un array bidimensional
X_test_flattened = X_test.reshape(-1, X_test.shape[-1])

# Aplicar la transformación inversa utilizando el objeto StandardScaler
X_test_desnormalizado = sc.inverse_transform(X_test_flattened)

# Volver a darle forma a X_test_desnormalizado a su forma original
X_test = X_test_desnormalizado.reshape(X_test.shape)

# Desnormalizar los datos
y_pred = sc_y.inverse_transform(y_pred)

y_test = sc_y.inverse_transform(y_test)

print(y_pred.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (1, 210)
# (17, 210)
# (17, 15, 2)

# %%
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
Curva=0

plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

print('')
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(X_test[Curva,:,0],color='orange', label='Valores actuales y anteriores de insulina')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_test[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 229.472625

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_pred[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 257.14557415008545

# %%
# Media MSE y desviacion estandar MSE de las prediciones con la escala normal
mse = mean_squared_error(y_test[0,:].flatten(), y_pred.flatten())
std = np.sqrt(mse)
mediamse = np.mean(mse)

print('La media MSE:',mediamse)
print('La desviacion standar MSE', std)

# calcular la MAE
mae = mean_absolute_error(y_test[0,:], y_pred[0,:])
print('MAE:', mae)

# calcular la RMSE
rmse = np.sqrt(mean_squared_error(y_test[0,:], y_pred[0,:]))
print('RMSE:', rmse)
# Out:
# La media MSE: 101.24285023199796
# La desviacion standar MSE 10.061950617648547
# MAE: 8.962191255115329
# RMSE: 10.061950617648547
