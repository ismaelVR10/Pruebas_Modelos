# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Librerias
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split, KFold
from keras.callbacks import EarlyStopping

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import load_model

from keras.initializers import glorot_uniform

# %%
#Dataset Adulto 01
data = pd.read_csv('/content/gdrive/MyDrive/Proyecto_de_grado/SUSTENTACION3.0/FinalX3/adulto02/my_adult02A2_data.csv')

print(f"El archivo se ha cargado correctamente. Tiene {data.shape[0]} filas y {data.shape[1]} columnas.")
# Out:
# El archivo se ha cargado correctamente. Tiene 29638 filas y 3 columnas.

# %%
train_size = int(len(data) * 0.7)

train_data = data.iloc[:train_size, :] # 70% entrenamiento
test_data = data.iloc[train_size:, :] # 30% prueba

test_data = test_data.reset_index(drop=True)

# %%
#los indices donde hay ingestas
posicionestrain = train_data.loc[train_data.iloc[:, 0] != 0].index
posicionestest = test_data.loc[test_data.iloc[:, 0] != 0].index

df_posiciones_train = pd.DataFrame(posicionestrain)
df_posiciones_test = pd.DataFrame(posicionestest)

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_train = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_train)):
    anterior = df_posiciones_train.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_train.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_train.append(anterior)

ultimo_elemento_train = df_posiciones_train.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_train.extend(ultimo_elemento_train.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_train)
print(len(cumplen_train))
# Out:
# [494, 862, 1358, 1974, 2353, 2840, 3461, 3846, 4334, 4956, 5324, 5820, 6438, 6815, 7301, 7917, 8283, 8781, 9398, 9781, 10268, 10880, 11255, 11750, 12363, 12742, 13230, 13845, 14212, 14699, 15311, 15686, 16183, 16795, 17162, 17650, 18266, 18653, 19140, 19757, 20125, 20614]
# 42

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_test = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_test)):
    anterior = df_posiciones_test.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_test.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_test.append(anterior)

ultimo_elemento_test = df_posiciones_test.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_test.extend(ultimo_elemento_test.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_test)
print(len(cumplen_test))
# Out:
# [487, 855, 1342, 1956, 2335, 2823, 3439, 3805, 4301, 4916, 5291, 5779, 6398, 6765, 7253, 7868, 8234, 8720]
# 18

# %%
# pasar la escala de los carbohidratos de las ingestas a gramos
data.iloc[:,0] = data.iloc[:,0].apply(lambda x: (x*15)/1000)

# Grafica con mayor detalle, el pico del comportamiento de la glucosa despues de la primera ingesta
print('')
print('Grafica de los datos del dataset')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
plt.title('Ingestas, Insulina y Glucosa')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')

print('Caso 1: Primera ingesta o Desayuno del primer dia:')
plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 700])
plt.ylim([-5, 250])
plt.show()
print('')

print('Caso 2: Primera y segunda ingesta del primer dia:')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1200])
plt.ylim([-5, 500])
plt.show()


print('Caso 3: las tres ingestas del primer dia:')

plt.plot(data.index, data.iloc[:,0], color='blue', label='Ingestas')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Ingestas de carbohidratos')
plt.xlabel('t [min]')
plt.ylabel('gramos')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Dosificación de insulina')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
#plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1800])
plt.ylim([-5, 500])
plt.show()
# Out:
# Grafica de los datos del dataset
# Caso 1: Primera ingesta o Desayuno del primer dia:
# Caso 2: Primera y segunda ingesta del primer dia:
# Caso 3: las tres ingestas del primer dia:

# %%
#Preprocesar los datos:
X_train = train_data.iloc[:, 1:3].values
y_train = train_data.iloc[:,2].values

X_test = test_data.iloc[:, 1:3].values
y_test = test_data.iloc[:, 2].values

print('Tamaño de los datos de entrada, de X_train: ',X_train.shape)
print(f'Tiene {X_train.shape[0]} filas y {X_train.shape[1]} columna')
print('La primera ingesta al minuto 300, ingesta: ',X_train[300])
print('La primera ingesta hasta el minuto 327, ingesta: ',X_train[327])

print('La entrada son los valores de la insulina y glucosa \n',X_train)
print('Tamaño de los datos de salia, de y_train',y_train.shape)
print(f'Tiene {y_train.shape[0]} filas y {y_train.shape[-1]} columnas')
print('La salida son los valores de glucosa \n',y_train)
# Out:
# Tamaño de los datos de entrada, de X_train:  (20746, 2)
# Tiene 20746 filas y 2 columna
# La primera ingesta al minuto 300, ingesta:  [  1.6789 123.44  ]
# La primera ingesta hasta el minuto 327, ingesta:  [  1.6789 123.44  ]
# La entrada son los valores de la insulina y glucosa
#  [[  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  ...
#  [  1.6789 198.03  ]
#  [  1.6789 197.1   ]
#  [  1.6789 196.18  ]]
# Tamaño de los datos de salia, de y_train (20746,)
# Tiene 20746 filas y 20746 columnas
# La salida son los valores de glucosa
#  [123.44 123.44 123.44 ... 198.03 197.1  196.18]

# %%
# Normalizar los datos
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Normalizar y_train
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.reshape(-1, 1))
y_test = sc_y.transform(y_test.reshape(-1, 1))

# %%
# Reorganizar los datos en forma de secuencia
def to_sequences(data,  seq_size_input, seq_size_output):
    X = []
    y = []

    for i in range(len(data)-seq_size_input-seq_size_output+1):
        X.append(data[i:(i+seq_size_input), 0:2])
        y.append(data[(i+seq_size_input):(i+seq_size_input+seq_size_output), 2])

    return np.array(X), np.array(y)

# %%
#CON LOS DATOS NORMALIZADOS
seq_size_input = 15
seq_size_output = 210
X_train, y_train = to_sequences(np.hstack((X_train, y_train)), seq_size_input, seq_size_output)
X_test, y_test = to_sequences(np.hstack((X_test, y_test)), seq_size_input, seq_size_output)
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (20522, 210)
# (20522, 15, 2)
# (8668, 210)
# (8668, 15, 2)

# %%
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
flattened_data = np.reshape(X_train, (X_train.shape[0], -1))

df_X_train = pd.DataFrame(flattened_data)

# %%
flattened_test = np.reshape(X_test, (X_test.shape[0], -1))

df_X_test = pd.DataFrame(flattened_test)

# %%
df_y_train = pd.DataFrame(y_train)
df_y_test = pd.DataFrame(y_test)

# %%
# Filtrar el dataframe para mantener solo las filas especificadas
df_X_train_seleccionado = df_X_train[df_X_train.index.isin(cumplen_train)]
df_y_train_seleccionado = df_y_train[df_y_train.index.isin(cumplen_train)]
df_X_test_seleccionado = df_X_test[df_X_test.index.isin(cumplen_test)]
df_y_test_seleccionado = df_y_test[df_y_test.index.isin(cumplen_test)]

# %%
print('Grafica de los datos del dataset')
#plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')

Numerocurva = 0

plt.plot(df_X_train_seleccionado.iloc[Numerocurva, 1::2],color='green',label='Entrada glucosa') #Para mostrar solo la glucosa
plt.plot(df_X_train_seleccionado.iloc[Numerocurva, ::2],color='orange',label='Entrada insulina') #Para mostrar solo la glucosa
plt.plot(range(seq_size_input*2, seq_size_output + seq_size_input*2),df_y_train_seleccionado.iloc[Numerocurva,:], color='red',label='Salida glucosa')
plt.title('Entradas y salidas, entrenamiento')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')
# Out:
# Grafica de los datos del dataset

# %%
X_train = df_X_train_seleccionado.values
y_train = df_y_train_seleccionado.values
X_test = df_X_test_seleccionado.values
y_test = df_y_test_seleccionado.values

print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 30)
# (17, 210)
# (17, 30)

# %%
print(len(X_test))
# Out:
# 17

# %%
X_train = np.reshape(X_train, (len(X_train), seq_size_input, 2))

X_test = np.reshape(X_test, (len(X_test), seq_size_input, 2))
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 15, 2)
# (17, 210)
# (17, 15, 2)

# %%
kf = KFold(n_splits=5)
kf.get_n_splits(X_train)
KFold(n_splits=5, random_state=None, shuffle=False)


# Crear listas para almacenar los valores del "average loss" de entrenamiento y validación en cada pliegue
train_losses = []
val_losses = []

#Para guardar el mejor modelo
best_loss = float('inf')
best_model_path = ""

for i, (train_index, test_index) in enumerate(kf.split(X_train,y_train)):
  model = Sequential()
  model.add(LSTM(60, activation='tanh', input_shape=(seq_size_input, 2), kernel_initializer=glorot_uniform()))
  model.add(Dense(seq_size_output, activation='linear', kernel_initializer=glorot_uniform()))


  model.compile(optimizer='adam', loss='mse')
  print(model.summary())

  filepath = f"modelo-{i+1}.h5"
  early_stop = EarlyStopping(monitor='val_loss', patience=3)
  checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

  X, y =  X_train[train_index], y_train[train_index]
  X_val, y_val = X_train[test_index], y_train[test_index]


  history = model.fit(X, y, epochs=100, batch_size=32,validation_data=(X_val, y_val),callbacks=[checkpoint, early_stop] )

  mediamse = np.mean( history.history['loss'] )
  stdmse = np.std(  history.history['loss'])
  print('')
  print(f" La media del mse, {i}-fold es : {mediamse}")
  print('')
  print(f" La desviacion estandar del mse, {i}-fold es : {stdmse}")

  # Obtener los valores de "average loss" para el pliegue actual
  fold_train_losses = model.history.history['loss']
  fold_val_losses = model.history.history['val_loss']

  # Almacenar los valores de "average loss" para el pliegue actual
  train_losses.append(fold_train_losses)
  val_losses.append(fold_val_losses)

  if min(fold_val_losses) < best_loss:
        best_loss = min(fold_val_losses)
        best_model_path = filepath

  history.history.keys() # aqui me muestra que esta guardando, con history me guarda todos los valores que calcula durante el proceso de entrenamiento

  # vamos a graficar
  plt.plot(history.history['loss'], label='Perdida') # Grafico esta para ver si estoy sobre entrenando
  plt.plot(history.history['val_loss'], label='Validacion') # Grafico esta para ver si estoy sobre entrenando
  plt.xlabel('epoch')
  plt.ylabel('Mean Square Error')
  plt.legend()
  plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60)                15120
#
#  dense (Dense)               (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7525
# Epoch 1: val_loss improved from inf to 1.83402, saving model to modelo-1.h5
# 1/1 [==============================] - 3s 3s/step - loss: 1.7525 - val_loss: 1.8340
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7468
# Epoch 2: val_loss improved from 1.83402 to 1.82814, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 1.7468 - val_loss: 1.8281
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7410
# Epoch 3: val_loss improved from 1.82814 to 1.82203, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 1.7410 - val_loss: 1.8220
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7351
# Epoch 4: val_loss improved from 1.82203 to 1.81553, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 1.7351 - val_loss: 1.8155
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7287
# Epoch 5: val_loss improved from 1.81553 to 1.80849, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 1.7287 - val_loss: 1.8085
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7218
# Epoch 6: val_loss improved from 1.80849 to 1.80072, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 1.7218 - val_loss: 1.8007
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7142
# Epoch 7: val_loss improved from 1.80072 to 1.79201, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 1.7142 - val_loss: 1.7920
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7056
# Epoch 8: val_loss improved from 1.79201 to 1.78209, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 1.7056 - val_loss: 1.7821
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6959
# Epoch 9: val_loss improved from 1.78209 to 1.77068, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 1.6959 - val_loss: 1.7707
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6846
# Epoch 10: val_loss improved from 1.77068 to 1.75740, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 1.6846 - val_loss: 1.7574
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6716
# Epoch 11: val_loss improved from 1.75740 to 1.74182, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 1.6716 - val_loss: 1.7418
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6563
# Epoch 12: val_loss improved from 1.74182 to 1.72337, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 1.6563 - val_loss: 1.7234
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6381
# Epoch 13: val_loss improved from 1.72337 to 1.70136, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 1.6381 - val_loss: 1.7014
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6165
# Epoch 14: val_loss improved from 1.70136 to 1.67491, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 1.6165 - val_loss: 1.6749
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5904
# Epoch 15: val_loss improved from 1.67491 to 1.64294, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 1.5904 - val_loss: 1.6429
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5590
# Epoch 16: val_loss improved from 1.64294 to 1.60418, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 1.5590 - val_loss: 1.6042
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5210
# Epoch 17: val_loss improved from 1.60418 to 1.55717, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 1.5210 - val_loss: 1.5572
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4749
# Epoch 18: val_loss improved from 1.55717 to 1.50042, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 1.4749 - val_loss: 1.5004
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4194
# Epoch 19: val_loss improved from 1.50042 to 1.43268, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 1.4194 - val_loss: 1.4327
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3533
# Epoch 20: val_loss improved from 1.43268 to 1.35346, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 1.3533 - val_loss: 1.3535
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2763
# Epoch 21: val_loss improved from 1.35346 to 1.26379, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 1.2763 - val_loss: 1.2638
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1896
# Epoch 22: val_loss improved from 1.26379 to 1.16698, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 83ms/step - loss: 1.1896 - val_loss: 1.1670
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0966
# Epoch 23: val_loss improved from 1.16698 to 1.06890, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 1.0966 - val_loss: 1.0689
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0032
# Epoch 24: val_loss improved from 1.06890 to 0.97681, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 1.0032 - val_loss: 0.9768
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9162
# Epoch 25: val_loss improved from 0.97681 to 0.89653, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.9162 - val_loss: 0.8965
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8410
# Epoch 26: val_loss improved from 0.89653 to 0.83011, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 79ms/step - loss: 0.8410 - val_loss: 0.8301
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7794
# Epoch 27: val_loss improved from 0.83011 to 0.77648, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.7794 - val_loss: 0.7765
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7301
# Epoch 28: val_loss improved from 0.77648 to 0.73353, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 0.7301 - val_loss: 0.7335
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6911
# Epoch 29: val_loss improved from 0.73353 to 0.69892, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6911 - val_loss: 0.6989
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6599
# Epoch 30: val_loss improved from 0.69892 to 0.66999, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.6599 - val_loss: 0.6700
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6338
# Epoch 31: val_loss improved from 0.66999 to 0.64437, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.6338 - val_loss: 0.6444
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6105
# Epoch 32: val_loss improved from 0.64437 to 0.62038, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.6105 - val_loss: 0.6204
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5880
# Epoch 33: val_loss improved from 0.62038 to 0.59801, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.5880 - val_loss: 0.5980
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5665
# Epoch 34: val_loss improved from 0.59801 to 0.57924, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 0.5665 - val_loss: 0.5792
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5480
# Epoch 35: val_loss improved from 0.57924 to 0.56467, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5480 - val_loss: 0.5647
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5334
# Epoch 36: val_loss improved from 0.56467 to 0.55006, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.5334 - val_loss: 0.5501
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5191
# Epoch 37: val_loss improved from 0.55006 to 0.53372, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.5191 - val_loss: 0.5337
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5036
# Epoch 38: val_loss improved from 0.53372 to 0.51685, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.5036 - val_loss: 0.5168
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4879
# Epoch 39: val_loss improved from 0.51685 to 0.50134, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.4879 - val_loss: 0.5013
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4738
# Epoch 40: val_loss improved from 0.50134 to 0.48758, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4738 - val_loss: 0.4876
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4612
# Epoch 41: val_loss improved from 0.48758 to 0.47426, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4612 - val_loss: 0.4743
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4482
# Epoch 42: val_loss improved from 0.47426 to 0.46175, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.4482 - val_loss: 0.4618
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4353
# Epoch 43: val_loss improved from 0.46175 to 0.45212, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.4353 - val_loss: 0.4521
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4250
# Epoch 44: val_loss improved from 0.45212 to 0.44135, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.4250 - val_loss: 0.4413
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4143
# Epoch 45: val_loss improved from 0.44135 to 0.42754, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.4143 - val_loss: 0.4275
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4016
# Epoch 46: val_loss improved from 0.42754 to 0.41450, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4016 - val_loss: 0.4145
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3898
# Epoch 47: val_loss improved from 0.41450 to 0.40169, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.3898 - val_loss: 0.4017
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3777
# Epoch 48: val_loss improved from 0.40169 to 0.38899, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 0.3777 - val_loss: 0.3890
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3650
# Epoch 49: val_loss improved from 0.38899 to 0.37609, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.3650 - val_loss: 0.3761
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3525
# Epoch 50: val_loss improved from 0.37609 to 0.36019, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.3525 - val_loss: 0.3602
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3380
# Epoch 51: val_loss improved from 0.36019 to 0.34448, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.3380 - val_loss: 0.3445
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3236
# Epoch 52: val_loss improved from 0.34448 to 0.32805, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.3236 - val_loss: 0.3281
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3080
# Epoch 53: val_loss improved from 0.32805 to 0.31247, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.3080 - val_loss: 0.3125
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2931
# Epoch 54: val_loss improved from 0.31247 to 0.29595, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.2931 - val_loss: 0.2959
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2778
# Epoch 55: val_loss improved from 0.29595 to 0.28003, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.2778 - val_loss: 0.2800
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2633
# Epoch 56: val_loss improved from 0.28003 to 0.26403, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.2633 - val_loss: 0.2640
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2482
# Epoch 57: val_loss improved from 0.26403 to 0.24878, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.2482 - val_loss: 0.2488
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2339
# Epoch 58: val_loss improved from 0.24878 to 0.23261, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 77ms/step - loss: 0.2339 - val_loss: 0.2326
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2191
# Epoch 59: val_loss improved from 0.23261 to 0.21754, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.2191 - val_loss: 0.2175
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2053
# Epoch 60: val_loss improved from 0.21754 to 0.20340, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.2053 - val_loss: 0.2034
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1921
# Epoch 61: val_loss improved from 0.20340 to 0.18945, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1921 - val_loss: 0.1894
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1794
# Epoch 62: val_loss improved from 0.18945 to 0.17630, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1794 - val_loss: 0.1763
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1679
# Epoch 63: val_loss improved from 0.17630 to 0.16438, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1679 - val_loss: 0.1644
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1569
# Epoch 64: val_loss improved from 0.16438 to 0.15373, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1569 - val_loss: 0.1537
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1471
# Epoch 65: val_loss improved from 0.15373 to 0.14296, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1471 - val_loss: 0.1430
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1380
# Epoch 66: val_loss improved from 0.14296 to 0.13339, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 112ms/step - loss: 0.1380 - val_loss: 0.1334
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1299
# Epoch 67: val_loss improved from 0.13339 to 0.12547, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 84ms/step - loss: 0.1299 - val_loss: 0.1255
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1224
# Epoch 68: val_loss improved from 0.12547 to 0.11849, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 129ms/step - loss: 0.1224 - val_loss: 0.1185
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1158
# Epoch 69: val_loss improved from 0.11849 to 0.11130, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 97ms/step - loss: 0.1158 - val_loss: 0.1113
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1098
# Epoch 70: val_loss improved from 0.11130 to 0.10460, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 84ms/step - loss: 0.1098 - val_loss: 0.1046
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1043
# Epoch 71: val_loss improved from 0.10460 to 0.09924, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 109ms/step - loss: 0.1043 - val_loss: 0.0992
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0993
# Epoch 72: val_loss improved from 0.09924 to 0.09517, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0993 - val_loss: 0.0952
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0946
# Epoch 73: val_loss improved from 0.09517 to 0.09121, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0946 - val_loss: 0.0912
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0901
# Epoch 74: val_loss improved from 0.09121 to 0.08610, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0901 - val_loss: 0.0861
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0857
# Epoch 75: val_loss improved from 0.08610 to 0.08072, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0857 - val_loss: 0.0807
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0813
# Epoch 76: val_loss improved from 0.08072 to 0.07609, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0813 - val_loss: 0.0761
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0767
# Epoch 77: val_loss improved from 0.07609 to 0.07152, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0767 - val_loss: 0.0715
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0718
# Epoch 78: val_loss improved from 0.07152 to 0.06642, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0718 - val_loss: 0.0664
# Epoch 79/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0669
# Epoch 79: val_loss improved from 0.06642 to 0.06284, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0669 - val_loss: 0.0628
# Epoch 80/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0631
# Epoch 80: val_loss improved from 0.06284 to 0.06043, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0631 - val_loss: 0.0604
# Epoch 81/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0609
# Epoch 81: val_loss improved from 0.06043 to 0.05826, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0609 - val_loss: 0.0583
# Epoch 82/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0585
# Epoch 82: val_loss improved from 0.05826 to 0.05356, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0585 - val_loss: 0.0536
# Epoch 83/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0547
# Epoch 83: val_loss improved from 0.05356 to 0.04990, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0547 - val_loss: 0.0499
# Epoch 84/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0505
# Epoch 84: val_loss improved from 0.04990 to 0.04666, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0505 - val_loss: 0.0467
# Epoch 85/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0475
# Epoch 85: val_loss improved from 0.04666 to 0.04482, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0475 - val_loss: 0.0448
# Epoch 86/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0458
# Epoch 86: val_loss improved from 0.04482 to 0.04297, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0458 - val_loss: 0.0430
# Epoch 87/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0438
# Epoch 87: val_loss improved from 0.04297 to 0.03992, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0438 - val_loss: 0.0399
# Epoch 88/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0410
# Epoch 88: val_loss improved from 0.03992 to 0.03669, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0410 - val_loss: 0.0367
# Epoch 89/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0383
# Epoch 89: val_loss improved from 0.03669 to 0.03524, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0383 - val_loss: 0.0352
# Epoch 90/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0364
# Epoch 90: val_loss improved from 0.03524 to 0.03342, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0364 - val_loss: 0.0334
# Epoch 91/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0355
# Epoch 91: val_loss improved from 0.03342 to 0.03305, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0355 - val_loss: 0.0330
# Epoch 92/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0341
# Epoch 92: val_loss improved from 0.03305 to 0.02969, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0341 - val_loss: 0.0297
# Epoch 93/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0323
# Epoch 93: val_loss improved from 0.02969 to 0.02933, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0323 - val_loss: 0.0293
# Epoch 94/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0304
# Epoch 94: val_loss improved from 0.02933 to 0.02657, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0304 - val_loss: 0.0266
# Epoch 95/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0287
# Epoch 95: val_loss improved from 0.02657 to 0.02540, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0287 - val_loss: 0.0254
# Epoch 96/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0277
# Epoch 96: val_loss did not improve from 0.02540
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0277 - val_loss: 0.0254
# Epoch 97/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0267
# Epoch 97: val_loss improved from 0.02540 to 0.02227, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0267 - val_loss: 0.0223
# Epoch 98/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0250
# Epoch 98: val_loss improved from 0.02227 to 0.02162, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0250 - val_loss: 0.0216
# Epoch 99/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0237
# Epoch 99: val_loss improved from 0.02162 to 0.02108, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0237 - val_loss: 0.0211
# Epoch 100/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0231
# Epoch 100: val_loss improved from 0.02108 to 0.01985, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0231 - val_loss: 0.0199
#
#  La media del mse, 0-fold es : 0.5721283904463053
#
#  La desviacion estandar del mse, 0-fold es : 0.5973497929838808
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 60)                15120
#
#  dense_1 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.8970
# Epoch 1: val_loss improved from inf to 1.40785, saving model to modelo-2.h5
# 2/2 [==============================] - 3s 653ms/step - loss: 1.8612 - val_loss: 1.4078
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8497
# Epoch 2: val_loss improved from 1.40785 to 1.39682, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.8502 - val_loss: 1.3968
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7617
# Epoch 3: val_loss improved from 1.39682 to 1.38419, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.8384 - val_loss: 1.3842
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8750
# Epoch 4: val_loss improved from 1.38419 to 1.36925, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 1.8251 - val_loss: 1.3692
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8457
# Epoch 5: val_loss improved from 1.36925 to 1.34989, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.8090 - val_loss: 1.3499
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8241
# Epoch 6: val_loss improved from 1.34989 to 1.32302, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.7885 - val_loss: 1.3230
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7954
# Epoch 7: val_loss improved from 1.32302 to 1.28426, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.7603 - val_loss: 1.2843
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6355
# Epoch 8: val_loss improved from 1.28426 to 1.22956, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 1.7188 - val_loss: 1.2296
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6632
# Epoch 9: val_loss improved from 1.22956 to 1.15123, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 1.6611 - val_loss: 1.1512
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6248
# Epoch 10: val_loss improved from 1.15123 to 1.04418, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 1.5789 - val_loss: 1.0442
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5054
# Epoch 11: val_loss improved from 1.04418 to 0.91884, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 1.4628 - val_loss: 0.9188
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2822
# Epoch 12: val_loss improved from 0.91884 to 0.78543, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 1.3173 - val_loss: 0.7854
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1303
# Epoch 13: val_loss improved from 0.78543 to 0.66271, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 1.1590 - val_loss: 0.6627
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0348
# Epoch 14: val_loss improved from 0.66271 to 0.57600, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 1.0091 - val_loss: 0.5760
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8356
# Epoch 15: val_loss improved from 0.57600 to 0.51685, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.8839 - val_loss: 0.5169
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7689
# Epoch 16: val_loss improved from 0.51685 to 0.48243, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.7978 - val_loss: 0.4824
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7520
# Epoch 17: val_loss improved from 0.48243 to 0.46661, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.7420 - val_loss: 0.4666
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6732
# Epoch 18: val_loss improved from 0.46661 to 0.45945, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.6998 - val_loss: 0.4594
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6936
# Epoch 19: val_loss improved from 0.45945 to 0.45889, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6783 - val_loss: 0.4589
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6615
# Epoch 20: val_loss improved from 0.45889 to 0.44326, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.6632 - val_loss: 0.4433
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5986
# Epoch 21: val_loss improved from 0.44326 to 0.42990, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.6400 - val_loss: 0.4299
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6160
# Epoch 22: val_loss improved from 0.42990 to 0.41944, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.6228 - val_loss: 0.4194
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6180
# Epoch 23: val_loss improved from 0.41944 to 0.39797, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.6076 - val_loss: 0.3980
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6059
# Epoch 24: val_loss improved from 0.39797 to 0.37862, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.5897 - val_loss: 0.3786
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5878
# Epoch 25: val_loss improved from 0.37862 to 0.36179, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.5754 - val_loss: 0.3618
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5461
# Epoch 26: val_loss improved from 0.36179 to 0.35195, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5660 - val_loss: 0.3520
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5626
# Epoch 27: val_loss improved from 0.35195 to 0.35103, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.5572 - val_loss: 0.3510
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5540
# Epoch 28: val_loss improved from 0.35103 to 0.34883, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5520 - val_loss: 0.3488
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5587
# Epoch 29: val_loss improved from 0.34883 to 0.34052, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.5451 - val_loss: 0.3405
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5111
# Epoch 30: val_loss improved from 0.34052 to 0.33777, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.5371 - val_loss: 0.3378
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5455
# Epoch 31: val_loss did not improve from 0.33777
# 2/2 [==============================] - 0s 47ms/step - loss: 0.5299 - val_loss: 0.3491
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4962
# Epoch 32: val_loss did not improve from 0.33777
# 2/2 [==============================] - 0s 45ms/step - loss: 0.5334 - val_loss: 0.3732
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5668
# Epoch 33: val_loss did not improve from 0.33777
# 2/2 [==============================] - 0s 46ms/step - loss: 0.5502 - val_loss: 0.3982
#
#  La media del mse, 1-fold es : 1.0457878112792969
#
#  La desviacion estandar del mse, 1-fold es : 0.5254811446932077
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 60)                15120
#
#  dense_2 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.8479
# Epoch 1: val_loss improved from inf to 1.64458, saving model to modelo-3.h5
# 2/2 [==============================] - 3s 772ms/step - loss: 1.8014 - val_loss: 1.6446
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8227
# Epoch 2: val_loss improved from 1.64458 to 1.63406, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 80ms/step - loss: 1.7904 - val_loss: 1.6341
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8261
# Epoch 3: val_loss improved from 1.63406 to 1.62218, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 1.7792 - val_loss: 1.6222
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7971
# Epoch 4: val_loss improved from 1.62218 to 1.60781, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 1.7663 - val_loss: 1.6078
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6346
# Epoch 5: val_loss improved from 1.60781 to 1.58961, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 92ms/step - loss: 1.7505 - val_loss: 1.5896
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6160
# Epoch 6: val_loss improved from 1.58961 to 1.56587, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 80ms/step - loss: 1.7306 - val_loss: 1.5659
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7360
# Epoch 7: val_loss improved from 1.56587 to 1.53314, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 1.7048 - val_loss: 1.5331
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7033
# Epoch 8: val_loss improved from 1.53314 to 1.48618, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 1.6687 - val_loss: 1.4862
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5211
# Epoch 9: val_loss improved from 1.48618 to 1.42023, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 1.6154 - val_loss: 1.4202
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5708
# Epoch 10: val_loss improved from 1.42023 to 1.32694, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 1.5425 - val_loss: 1.3269
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4661
# Epoch 11: val_loss improved from 1.32694 to 1.19627, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 1.4365 - val_loss: 1.1963
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2891
# Epoch 12: val_loss improved from 1.19627 to 1.03732, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 1.2834 - val_loss: 1.0373
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1252
# Epoch 13: val_loss improved from 1.03732 to 0.89004, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 1.0970 - val_loss: 0.8900
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9377
# Epoch 14: val_loss improved from 0.89004 to 0.78762, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 91ms/step - loss: 0.9153 - val_loss: 0.7876
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8021
# Epoch 15: val_loss improved from 0.78762 to 0.72594, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 94ms/step - loss: 0.7826 - val_loss: 0.7259
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7127
# Epoch 16: val_loss improved from 0.72594 to 0.68477, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 82ms/step - loss: 0.6964 - val_loss: 0.6848
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6331
# Epoch 17: val_loss improved from 0.68477 to 0.65625, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.6357 - val_loss: 0.6562
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5967
# Epoch 18: val_loss improved from 0.65625 to 0.63559, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.5957 - val_loss: 0.6356
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5770
# Epoch 19: val_loss improved from 0.63559 to 0.61122, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 0.5634 - val_loss: 0.6112
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5376
# Epoch 20: val_loss improved from 0.61122 to 0.58917, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.5377 - val_loss: 0.5892
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5343
# Epoch 21: val_loss improved from 0.58917 to 0.57533, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 86ms/step - loss: 0.5200 - val_loss: 0.5753
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5161
# Epoch 22: val_loss improved from 0.57533 to 0.56658, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 0.5146 - val_loss: 0.5666
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5104
# Epoch 23: val_loss improved from 0.56658 to 0.55873, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 0.5080 - val_loss: 0.5587
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5067
# Epoch 24: val_loss improved from 0.55873 to 0.55299, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 0.5001 - val_loss: 0.5530
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4571
# Epoch 25: val_loss improved from 0.55299 to 0.54738, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 0.4995 - val_loss: 0.5474
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4668
# Epoch 26: val_loss did not improve from 0.54738
# 2/2 [==============================] - 0s 54ms/step - loss: 0.4906 - val_loss: 0.5490
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4821
# Epoch 27: val_loss did not improve from 0.54738
# 2/2 [==============================] - 0s 55ms/step - loss: 0.4810 - val_loss: 0.5685
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4890
# Epoch 28: val_loss did not improve from 0.54738
# 2/2 [==============================] - 0s 66ms/step - loss: 0.4850 - val_loss: 0.6000
#
#  La media del mse, 2-fold es : 1.0604383775166102
#
#  La desviacion estandar del mse, 2-fold es : 0.5412656549460843
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 60)                15120
#
#  dense_3 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.8081
# Epoch 1: val_loss improved from inf to 1.81988, saving model to modelo-4.h5
# 2/2 [==============================] - 3s 547ms/step - loss: 1.7621 - val_loss: 1.8199
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7974
# Epoch 2: val_loss improved from 1.81988 to 1.80961, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.7522 - val_loss: 1.8096
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7747
# Epoch 3: val_loss improved from 1.80961 to 1.79750, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.7422 - val_loss: 1.7975
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7780
# Epoch 4: val_loss improved from 1.79750 to 1.78250, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 1.7305 - val_loss: 1.7825
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7608
# Epoch 5: val_loss improved from 1.78250 to 1.76314, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 1.7160 - val_loss: 1.7631
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7425
# Epoch 6: val_loss improved from 1.76314 to 1.73672, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 1.6972 - val_loss: 1.7367
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5556
# Epoch 7: val_loss improved from 1.73672 to 1.70023, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 1.6712 - val_loss: 1.7002
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5544
# Epoch 8: val_loss improved from 1.70023 to 1.64795, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 1.6358 - val_loss: 1.6480
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6315
# Epoch 9: val_loss improved from 1.64795 to 1.57109, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.5865 - val_loss: 1.5711
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5573
# Epoch 10: val_loss improved from 1.57109 to 1.46161, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 1.5133 - val_loss: 1.4616
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3335
# Epoch 11: val_loss improved from 1.46161 to 1.31873, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.4058 - val_loss: 1.3187
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3133
# Epoch 12: val_loss improved from 1.31873 to 1.15912, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 1.2755 - val_loss: 1.1591
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1517
# Epoch 13: val_loss improved from 1.15912 to 0.99916, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 1.1245 - val_loss: 0.9992
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0043
# Epoch 14: val_loss improved from 0.99916 to 0.86609, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.9772 - val_loss: 0.8661
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8198
# Epoch 15: val_loss improved from 0.86609 to 0.76147, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.8494 - val_loss: 0.7615
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7769
# Epoch 16: val_loss improved from 0.76147 to 0.68565, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.7597 - val_loss: 0.6856
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6527
# Epoch 17: val_loss improved from 0.68565 to 0.62904, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6879 - val_loss: 0.6290
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6356
# Epoch 18: val_loss improved from 0.62904 to 0.58676, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 0.6398 - val_loss: 0.5868
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6244
# Epoch 19: val_loss improved from 0.58676 to 0.56127, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.6090 - val_loss: 0.5613
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5366
# Epoch 20: val_loss improved from 0.56127 to 0.54962, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.5878 - val_loss: 0.5496
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5814
# Epoch 21: val_loss improved from 0.54962 to 0.54654, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.5883 - val_loss: 0.5465
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6005
# Epoch 22: val_loss improved from 0.54654 to 0.53846, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.5890 - val_loss: 0.5385
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5950
# Epoch 23: val_loss improved from 0.53846 to 0.52654, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.5828 - val_loss: 0.5265
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5756
# Epoch 24: val_loss improved from 0.52654 to 0.51665, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5713 - val_loss: 0.5166
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5705
# Epoch 25: val_loss improved from 0.51665 to 0.50821, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.5612 - val_loss: 0.5082
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5630
# Epoch 26: val_loss improved from 0.50821 to 0.49813, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5521 - val_loss: 0.4981
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5153
# Epoch 27: val_loss improved from 0.49813 to 0.49233, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.5414 - val_loss: 0.4923
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5396
# Epoch 28: val_loss improved from 0.49233 to 0.49111, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.5334 - val_loss: 0.4911
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5317
# Epoch 29: val_loss improved from 0.49111 to 0.48868, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.5333 - val_loss: 0.4887
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5430
# Epoch 30: val_loss improved from 0.48868 to 0.48346, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5304 - val_loss: 0.4835
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5102
# Epoch 31: val_loss improved from 0.48346 to 0.48050, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.5241 - val_loss: 0.4805
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5307
# Epoch 32: val_loss improved from 0.48050 to 0.47861, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5193 - val_loss: 0.4786
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5292
# Epoch 33: val_loss improved from 0.47861 to 0.47623, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.5168 - val_loss: 0.4762
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5248
# Epoch 34: val_loss improved from 0.47623 to 0.47512, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.5127 - val_loss: 0.4751
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4601
# Epoch 35: val_loss improved from 0.47512 to 0.47361, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.5107 - val_loss: 0.4736
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5058
# Epoch 36: val_loss improved from 0.47361 to 0.47141, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.5068 - val_loss: 0.4714
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4778
# Epoch 37: val_loss did not improve from 0.47141
# 2/2 [==============================] - 0s 44ms/step - loss: 0.5060 - val_loss: 0.4753
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5266
# Epoch 38: val_loss did not improve from 0.47141
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5155 - val_loss: 0.4849
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5198
# Epoch 39: val_loss did not improve from 0.47141
# 2/2 [==============================] - 0s 44ms/step - loss: 0.5289 - val_loss: 0.4866
#
#  La media del mse, 3-fold es : 0.921733578046163
#
#  La desviacion estandar del mse, 3-fold es : 0.4911402073430727
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 60)                15120
#
#  dense_4 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.7366
# Epoch 1: val_loss improved from inf to 2.10662, saving model to modelo-5.h5
# 2/2 [==============================] - 3s 1s/step - loss: 1.6904 - val_loss: 2.1066
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7263
# Epoch 2: val_loss improved from 2.10662 to 2.09730, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 85ms/step - loss: 1.6815 - val_loss: 2.0973
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7182
# Epoch 3: val_loss improved from 2.09730 to 2.08718, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 86ms/step - loss: 1.6729 - val_loss: 2.0872
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5440
# Epoch 4: val_loss improved from 2.08718 to 2.07492, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 82ms/step - loss: 1.6633 - val_loss: 2.0749
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6810
# Epoch 5: val_loss improved from 2.07492 to 2.05970, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 1.6523 - val_loss: 2.0597
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6647
# Epoch 6: val_loss improved from 2.05970 to 2.04005, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 1.6385 - val_loss: 2.0401
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6628
# Epoch 7: val_loss improved from 2.04005 to 2.01377, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 80ms/step - loss: 1.6207 - val_loss: 2.0138
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6383
# Epoch 8: val_loss improved from 2.01377 to 1.97745, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 85ms/step - loss: 1.5965 - val_loss: 1.9774
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5074
# Epoch 9: val_loss improved from 1.97745 to 1.92612, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 92ms/step - loss: 1.5621 - val_loss: 1.9261
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5425
# Epoch 10: val_loss improved from 1.92612 to 1.84990, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 106ms/step - loss: 1.5153 - val_loss: 1.8499
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4859
# Epoch 11: val_loss improved from 1.84990 to 1.73603, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 1.4460 - val_loss: 1.7360
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3731
# Epoch 12: val_loss improved from 1.73603 to 1.57476, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 84ms/step - loss: 1.3426 - val_loss: 1.5748
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2272
# Epoch 13: val_loss improved from 1.57476 to 1.37218, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 81ms/step - loss: 1.2003 - val_loss: 1.3722
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0318
# Epoch 14: val_loss improved from 1.37218 to 1.16855, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 91ms/step - loss: 1.0272 - val_loss: 1.1685
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8294
# Epoch 15: val_loss improved from 1.16855 to 1.00756, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 87ms/step - loss: 0.8626 - val_loss: 1.0076
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7668
# Epoch 16: val_loss improved from 1.00756 to 0.90233, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 0.7513 - val_loss: 0.9023
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6938
# Epoch 17: val_loss improved from 0.90233 to 0.82895, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 81ms/step - loss: 0.6764 - val_loss: 0.8290
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6330
# Epoch 18: val_loss improved from 0.82895 to 0.77567, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 109ms/step - loss: 0.6258 - val_loss: 0.7757
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5362
# Epoch 19: val_loss improved from 0.77567 to 0.73086, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 111ms/step - loss: 0.5837 - val_loss: 0.7309
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5597
# Epoch 20: val_loss improved from 0.73086 to 0.69412, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5543 - val_loss: 0.6941
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5354
# Epoch 21: val_loss improved from 0.69412 to 0.67057, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5307 - val_loss: 0.6706
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4931
# Epoch 22: val_loss improved from 0.67057 to 0.65071, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 0.5116 - val_loss: 0.6507
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4746
# Epoch 23: val_loss improved from 0.65071 to 0.62968, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 91ms/step - loss: 0.4963 - val_loss: 0.6297
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4906
# Epoch 24: val_loss improved from 0.62968 to 0.61620, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 93ms/step - loss: 0.4887 - val_loss: 0.6162
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4831
# Epoch 25: val_loss improved from 0.61620 to 0.61435, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 0.4922 - val_loss: 0.6144
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5174
# Epoch 26: val_loss did not improve from 0.61435
# 2/2 [==============================] - 0s 56ms/step - loss: 0.5099 - val_loss: 0.6217
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5300
# Epoch 27: val_loss did not improve from 0.61435
# 2/2 [==============================] - 0s 74ms/step - loss: 0.5379 - val_loss: 0.6150
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5321
# Epoch 28: val_loss improved from 0.61435 to 0.58264, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 0.5378 - val_loss: 0.5826
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4926
# Epoch 29: val_loss did not improve from 0.58264
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4971 - val_loss: 0.5863
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4898
# Epoch 30: val_loss did not improve from 0.58264
# 2/2 [==============================] - 0s 65ms/step - loss: 0.4790 - val_loss: 0.6168
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4838
# Epoch 31: val_loss did not improve from 0.58264
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4873 - val_loss: 0.6327
#
#  La media del mse, 4-fold es : 0.9978113683962053
#
#  La desviacion estandar del mse, 4-fold es : 0.4993684171742124

# %%
# rellenar de ceros los espacios vacios de la lista con loss y validation

df_train_losses = pd.DataFrame(train_losses)

df_filled_train_losses = df_train_losses.fillna(0)

train_losses_completa = df_filled_train_losses.values.tolist()

df_val_losses = pd.DataFrame(val_losses)

df_filled_val_losses = df_val_losses.fillna(0)

val_losses_completa = df_filled_val_losses.values.tolist()

# %%
# Calcular el promedio de "average loss" para todos los pliegues y épocas
avg_train_losses = np.mean(train_losses_completa, axis=0)
avg_val_losses = np.mean(val_losses_completa, axis=0)

# vamos a graficar
plt.plot(avg_train_losses, label='Perdida entrenamiento') # Grafico esta para ver si estoy sobre entrenando
plt.plot(avg_val_losses, label='Perdida Validacion') # Grafico esta para ver si estoy sobre entrenando
plt.title('avg loss train, avg loss val vs epoch ')
plt.xlabel('epoch')
plt.ylabel('Mean Square Error')
plt.legend()
plt.show()

# %%
# Cargar el mejor modelo
best_model = load_model(best_model_path)

# %%
# Seleccionar una secuencia específica
index = 0
input_sequence = X_test[index]

# Hacer la predicción
y_pred = best_model.predict(np.expand_dims(input_sequence, axis=0))
# usamos el np.expand_dims() para agregar una dimensión adicional al inicio de input_sequence
print(y_pred.shape)
# Out:
# 1/1 [==============================] - 1s 662ms/step
# (1, 210)

# %%
# Desenrollar X_test para convertirlo en un array bidimensional
X_test_flattened = X_test.reshape(-1, X_test.shape[-1])

# Aplicar la transformación inversa utilizando el objeto StandardScaler
X_test_desnormalizado = sc.inverse_transform(X_test_flattened)

# Volver a darle forma a X_test_desnormalizado a su forma original
X_test = X_test_desnormalizado.reshape(X_test.shape)

# Desnormalizar los datos
y_pred = sc_y.inverse_transform(y_pred)

y_test = sc_y.inverse_transform(y_test)

print(y_pred.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (1, 210)
# (17, 210)
# (17, 15, 2)

# %%
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
Curva=0

plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

print('')
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(X_test[Curva,:,0],color='orange', label='Valores actuales y anteriores de insulina')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_test[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 229.472625

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_pred[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 234.07966884613037

# %%
# Media MSE y desviacion estandar MSE de las prediciones con la escala normal
mse = mean_squared_error(y_test[0,:].flatten(), y_pred.flatten())
std = np.sqrt(mse)
mediamse = np.mean(mse)

print('La media MSE:',mediamse)
print('La desviacion standar MSE', std)

# calcular la MAE
mae = mean_absolute_error(y_test[0,:], y_pred[0,:])
print('MAE:', mae)

# calcular la RMSE
rmse = np.sqrt(mean_squared_error(y_test[0,:], y_pred[0,:]))
print('RMSE:', rmse)
# Out:
# La media MSE: 29.45306277591125
# La desviacion standar MSE 5.427067603771971
# MAE: 3.8759716157459074
# RMSE: 5.427067603771971
