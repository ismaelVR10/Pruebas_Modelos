# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Librerias
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split, KFold
from keras.callbacks import EarlyStopping

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import load_model

from keras.initializers import he_uniform

from keras.layers import LeakyReLU

# %%
#Dataset Adulto 01
data = pd.read_csv('/content/gdrive/MyDrive/Proyecto_de_grado/SUSTENTACION3.0/FinalX3/adulto02/my_adult02A2_data.csv')

print(f"El archivo se ha cargado correctamente. Tiene {data.shape[0]} filas y {data.shape[1]} columnas.")
# Out:
# El archivo se ha cargado correctamente. Tiene 29638 filas y 3 columnas.

# %%
train_size = int(len(data) * 0.7)

train_data = data.iloc[:train_size, :] # 70% entrenamiento
test_data = data.iloc[train_size:, :] # 30% prueba

test_data = test_data.reset_index(drop=True)

# %%
#los indices donde hay ingestas
posicionestrain = train_data.loc[train_data.iloc[:, 0] != 0].index
posicionestest = test_data.loc[test_data.iloc[:, 0] != 0].index

df_posiciones_train = pd.DataFrame(posicionestrain)
df_posiciones_test = pd.DataFrame(posicionestest)

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_train = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_train)):
    anterior = df_posiciones_train.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_train.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_train.append(anterior)

ultimo_elemento_train = df_posiciones_train.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_train.extend(ultimo_elemento_train.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_train)
print(len(cumplen_train))
# Out:
# [494, 862, 1358, 1974, 2353, 2840, 3461, 3846, 4334, 4956, 5324, 5820, 6438, 6815, 7301, 7917, 8283, 8781, 9398, 9781, 10268, 10880, 11255, 11750, 12363, 12742, 13230, 13845, 14212, 14699, 15311, 15686, 16183, 16795, 17162, 17650, 18266, 18653, 19140, 19757, 20125, 20614]
# 42

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_test = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_test)):
    anterior = df_posiciones_test.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_test.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_test.append(anterior)

ultimo_elemento_test = df_posiciones_test.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_test.extend(ultimo_elemento_test.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_test)
print(len(cumplen_test))
# Out:
# [487, 855, 1342, 1956, 2335, 2823, 3439, 3805, 4301, 4916, 5291, 5779, 6398, 6765, 7253, 7868, 8234, 8720]
# 18

# %%
# pasar la escala de los carbohidratos de las ingestas a gramos
data.iloc[:,0] = data.iloc[:,0].apply(lambda x: (x*15)/1000)

# Grafica con mayor detalle, el pico del comportamiento de la glucosa despues de la primera ingesta
print('')
print('Grafica de los datos del dataset')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
plt.title('Ingestas, Insulina y Glucosa')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')

print('Caso 1: Primera ingesta o Desayuno del primer dia:')
plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 700])
plt.ylim([-5, 250])
plt.show()
print('')

print('Caso 2: Primera y segunda ingesta del primer dia:')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1200])
plt.ylim([-5, 500])
plt.show()


print('Caso 3: las tres ingestas del primer dia:')

plt.plot(data.index, data.iloc[:,0], color='blue', label='Ingestas')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Ingestas de carbohidratos')
plt.xlabel('t [min]')
plt.ylabel('gramos')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Dosificación de insulina')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
#plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1800])
plt.ylim([-5, 500])
plt.show()
# Out:
# Grafica de los datos del dataset
# Caso 1: Primera ingesta o Desayuno del primer dia:
# Caso 2: Primera y segunda ingesta del primer dia:
# Caso 3: las tres ingestas del primer dia:

# %%
#Preprocesar los datos:
X_train = train_data.iloc[:, 1:3].values
y_train = train_data.iloc[:,2].values

X_test = test_data.iloc[:, 1:3].values
y_test = test_data.iloc[:, 2].values

print('Tamaño de los datos de entrada, de X_train: ',X_train.shape)
print(f'Tiene {X_train.shape[0]} filas y {X_train.shape[1]} columna')
print('La primera ingesta al minuto 300, ingesta: ',X_train[300])
print('La primera ingesta hasta el minuto 327, ingesta: ',X_train[327])

print('La entrada son los valores de la insulina y glucosa \n',X_train)
print('Tamaño de los datos de salia, de y_train',y_train.shape)
print(f'Tiene {y_train.shape[0]} filas y {y_train.shape[-1]} columnas')
print('La salida son los valores de glucosa \n',y_train)
# Out:
# Tamaño de los datos de entrada, de X_train:  (20746, 2)
# Tiene 20746 filas y 2 columna
# La primera ingesta al minuto 300, ingesta:  [  1.6789 123.44  ]
# La primera ingesta hasta el minuto 327, ingesta:  [  1.6789 123.44  ]
# La entrada son los valores de la insulina y glucosa
#  [[  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  ...
#  [  1.6789 198.03  ]
#  [  1.6789 197.1   ]
#  [  1.6789 196.18  ]]
# Tamaño de los datos de salia, de y_train (20746,)
# Tiene 20746 filas y 20746 columnas
# La salida son los valores de glucosa
#  [123.44 123.44 123.44 ... 198.03 197.1  196.18]

# %%
# Normalizar los datos
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Normalizar y_train
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.reshape(-1, 1))
y_test = sc_y.transform(y_test.reshape(-1, 1))

# %%
# Reorganizar los datos en forma de secuencia
def to_sequences(data,  seq_size_input, seq_size_output):
    X = []
    y = []

    for i in range(len(data)-seq_size_input-seq_size_output+1):
        X.append(data[i:(i+seq_size_input), 0:2])
        y.append(data[(i+seq_size_input):(i+seq_size_input+seq_size_output), 2])

    return np.array(X), np.array(y)

# %%
#CON LOS DATOS NORMALIZADOS
seq_size_input = 15
seq_size_output = 210
X_train, y_train = to_sequences(np.hstack((X_train, y_train)), seq_size_input, seq_size_output)
X_test, y_test = to_sequences(np.hstack((X_test, y_test)), seq_size_input, seq_size_output)
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (20522, 210)
# (20522, 15, 2)
# (8668, 210)
# (8668, 15, 2)

# %%
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
flattened_data = np.reshape(X_train, (X_train.shape[0], -1))

df_X_train = pd.DataFrame(flattened_data)

# %%
flattened_test = np.reshape(X_test, (X_test.shape[0], -1))

df_X_test = pd.DataFrame(flattened_test)

# %%
df_y_train = pd.DataFrame(y_train)
df_y_test = pd.DataFrame(y_test)

# %%
# Filtrar el dataframe para mantener solo las filas especificadas
df_X_train_seleccionado = df_X_train[df_X_train.index.isin(cumplen_train)]
df_y_train_seleccionado = df_y_train[df_y_train.index.isin(cumplen_train)]
df_X_test_seleccionado = df_X_test[df_X_test.index.isin(cumplen_test)]
df_y_test_seleccionado = df_y_test[df_y_test.index.isin(cumplen_test)]

# %%
print('Grafica de los datos del dataset')
#plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')

Numerocurva = 0

plt.plot(df_X_train_seleccionado.iloc[Numerocurva, 1::2],color='green',label='Entrada glucosa') #Para mostrar solo la glucosa
plt.plot(df_X_train_seleccionado.iloc[Numerocurva, ::2],color='orange',label='Entrada insulina') #Para mostrar solo la glucosa
plt.plot(range(seq_size_input*2, seq_size_output + seq_size_input*2),df_y_train_seleccionado.iloc[Numerocurva,:], color='red',label='Salida glucosa')
plt.title('Entradas y salidas, entrenamiento')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')
# Out:
# Grafica de los datos del dataset

# %%
X_train = df_X_train_seleccionado.values
y_train = df_y_train_seleccionado.values
X_test = df_X_test_seleccionado.values
y_test = df_y_test_seleccionado.values

print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 30)
# (17, 210)
# (17, 30)

# %%
print(len(X_test))
# Out:
# 17

# %%
X_train = np.reshape(X_train, (len(X_train), seq_size_input, 2))

X_test = np.reshape(X_test, (len(X_test), seq_size_input, 2))
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 15, 2)
# (17, 210)
# (17, 15, 2)

# %%
kf = KFold(n_splits=5)
kf.get_n_splits(X_train)
KFold(n_splits=5, random_state=None, shuffle=False)


# Crear listas para almacenar los valores del "average loss" de entrenamiento y validación en cada pliegue
train_losses = []
val_losses = []

#Para guardar el mejor modelo
best_loss = float('inf')
best_model_path = ""

for i, (train_index, test_index) in enumerate(kf.split(X_train,y_train)):
  model = Sequential()
  model.add(LSTM(60, activation=LeakyReLU(alpha=0.2), input_shape=(seq_size_input, 2), kernel_initializer=he_uniform()))
  model.add(Dense(seq_size_output, activation='linear', kernel_initializer=he_uniform()))


  model.compile(optimizer='adam', loss='mse')
  print(model.summary())

  filepath = f"modelo-{i+1}.h5"
  early_stop = EarlyStopping(monitor='val_loss', patience=3)
  checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

  X, y =  X_train[train_index], y_train[train_index]
  X_val, y_val = X_train[test_index], y_train[test_index]


  history = model.fit(X, y, epochs=100, batch_size=32,validation_data=(X_val, y_val),callbacks=[checkpoint, early_stop] )

  mediamse = np.mean( history.history['loss'] )
  stdmse = np.std(  history.history['loss'])
  print('')
  print(f" La media del mse, {i}-fold es : {mediamse}")
  print('')
  print(f" La desviacion estandar del mse, {i}-fold es : {stdmse}")

  # Obtener los valores de "average loss" para el pliegue actual
  fold_train_losses = model.history.history['loss']
  fold_val_losses = model.history.history['val_loss']

  # Almacenar los valores de "average loss" para el pliegue actual
  train_losses.append(fold_train_losses)
  val_losses.append(fold_val_losses)

  if min(fold_val_losses) < best_loss:
        best_loss = min(fold_val_losses)
        best_model_path = filepath

  history.history.keys() # aqui me muestra que esta guardando, con history me guarda todos los valores que calcula durante el proceso de entrenamiento

  # vamos a graficar
  plt.plot(history.history['loss'], label='Perdida') # Grafico esta para ver si estoy sobre entrenando
  plt.plot(history.history['val_loss'], label='Validacion') # Grafico esta para ver si estoy sobre entrenando
  plt.xlabel('epoch')
  plt.ylabel('Mean Square Error')
  plt.legend()
  plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 60)                15120
#
#  dense_5 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8645
# Epoch 1: val_loss improved from inf to 1.92322, saving model to modelo-1.h5
# 1/1 [==============================] - 1s 1s/step - loss: 1.8645 - val_loss: 1.9232
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8328
# Epoch 2: val_loss improved from 1.92322 to 1.89247, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 1.8328 - val_loss: 1.8925
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8031
# Epoch 3: val_loss improved from 1.89247 to 1.86338, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 56ms/step - loss: 1.8031 - val_loss: 1.8634
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7750
# Epoch 4: val_loss improved from 1.86338 to 1.83552, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 1.7750 - val_loss: 1.8355
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7481
# Epoch 5: val_loss improved from 1.83552 to 1.80860, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 59ms/step - loss: 1.7481 - val_loss: 1.8086
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7222
# Epoch 6: val_loss improved from 1.80860 to 1.78239, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 56ms/step - loss: 1.7222 - val_loss: 1.7824
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6970
# Epoch 7: val_loss improved from 1.78239 to 1.75671, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 55ms/step - loss: 1.6970 - val_loss: 1.7567
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6723
# Epoch 8: val_loss improved from 1.75671 to 1.73136, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 1.6723 - val_loss: 1.7314
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6480
# Epoch 9: val_loss improved from 1.73136 to 1.70617, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 1.6480 - val_loss: 1.7062
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6238
# Epoch 10: val_loss improved from 1.70617 to 1.68099, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 1.6238 - val_loss: 1.6810
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5996
# Epoch 11: val_loss improved from 1.68099 to 1.65564, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 1.5996 - val_loss: 1.6556
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5753
# Epoch 12: val_loss improved from 1.65564 to 1.62996, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 1.5753 - val_loss: 1.6300
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5506
# Epoch 13: val_loss improved from 1.62996 to 1.60366, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 1.5506 - val_loss: 1.6037
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5254
# Epoch 14: val_loss improved from 1.60366 to 1.57649, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 1.5254 - val_loss: 1.5765
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4994
# Epoch 15: val_loss improved from 1.57649 to 1.54830, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 59ms/step - loss: 1.4994 - val_loss: 1.5483
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4724
# Epoch 16: val_loss improved from 1.54830 to 1.51865, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 1.4724 - val_loss: 1.5187
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4440
# Epoch 17: val_loss improved from 1.51865 to 1.48728, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 57ms/step - loss: 1.4440 - val_loss: 1.4873
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4141
# Epoch 18: val_loss improved from 1.48728 to 1.45402, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 1.4141 - val_loss: 1.4540
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3824
# Epoch 19: val_loss improved from 1.45402 to 1.41861, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 57ms/step - loss: 1.3824 - val_loss: 1.4186
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3487
# Epoch 20: val_loss improved from 1.41861 to 1.38081, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 86ms/step - loss: 1.3487 - val_loss: 1.3808
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3128
# Epoch 21: val_loss improved from 1.38081 to 1.34050, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 85ms/step - loss: 1.3128 - val_loss: 1.3405
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2746
# Epoch 22: val_loss improved from 1.34050 to 1.29760, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 101ms/step - loss: 1.2746 - val_loss: 1.2976
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2341
# Epoch 23: val_loss improved from 1.29760 to 1.25239, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 101ms/step - loss: 1.2341 - val_loss: 1.2524
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1915
# Epoch 24: val_loss improved from 1.25239 to 1.20522, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 1.1915 - val_loss: 1.2052
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1471
# Epoch 25: val_loss improved from 1.20522 to 1.15638, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 99ms/step - loss: 1.1471 - val_loss: 1.1564
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1012
# Epoch 26: val_loss improved from 1.15638 to 1.10647, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 1.1012 - val_loss: 1.1065
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0541
# Epoch 27: val_loss improved from 1.10647 to 1.05635, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 1.0541 - val_loss: 1.0564
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0067
# Epoch 28: val_loss improved from 1.05635 to 1.00681, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 84ms/step - loss: 1.0067 - val_loss: 1.0068
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9597
# Epoch 29: val_loss improved from 1.00681 to 0.95802, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 100ms/step - loss: 0.9597 - val_loss: 0.9580
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9133
# Epoch 30: val_loss improved from 0.95802 to 0.90953, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 84ms/step - loss: 0.9133 - val_loss: 0.9095
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8672
# Epoch 31: val_loss improved from 0.90953 to 0.86171, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 89ms/step - loss: 0.8672 - val_loss: 0.8617
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8220
# Epoch 32: val_loss improved from 0.86171 to 0.81556, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 77ms/step - loss: 0.8220 - val_loss: 0.8156
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7784
# Epoch 33: val_loss improved from 0.81556 to 0.77129, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 90ms/step - loss: 0.7784 - val_loss: 0.7713
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7368
# Epoch 34: val_loss improved from 0.77129 to 0.72806, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 111ms/step - loss: 0.7368 - val_loss: 0.7281
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6962
# Epoch 35: val_loss improved from 0.72806 to 0.68493, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 101ms/step - loss: 0.6962 - val_loss: 0.6849
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6557
# Epoch 36: val_loss improved from 0.68493 to 0.64185, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.6557 - val_loss: 0.6418
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6153
# Epoch 37: val_loss improved from 0.64185 to 0.59989, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 77ms/step - loss: 0.6153 - val_loss: 0.5999
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5760
# Epoch 38: val_loss improved from 0.59989 to 0.55976, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 108ms/step - loss: 0.5760 - val_loss: 0.5598
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5383
# Epoch 39: val_loss improved from 0.55976 to 0.52062, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 83ms/step - loss: 0.5383 - val_loss: 0.5206
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5013
# Epoch 40: val_loss improved from 0.52062 to 0.48225, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 102ms/step - loss: 0.5013 - val_loss: 0.4823
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4647
# Epoch 41: val_loss improved from 0.48225 to 0.44622, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 94ms/step - loss: 0.4647 - val_loss: 0.4462
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4302
# Epoch 42: val_loss improved from 0.44622 to 0.41298, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 84ms/step - loss: 0.4302 - val_loss: 0.4130
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3984
# Epoch 43: val_loss improved from 0.41298 to 0.38153, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 80ms/step - loss: 0.3984 - val_loss: 0.3815
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3682
# Epoch 44: val_loss improved from 0.38153 to 0.35170, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 83ms/step - loss: 0.3682 - val_loss: 0.3517
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3397
# Epoch 45: val_loss improved from 0.35170 to 0.32398, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 87ms/step - loss: 0.3397 - val_loss: 0.3240
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3133
# Epoch 46: val_loss improved from 0.32398 to 0.29736, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 90ms/step - loss: 0.3133 - val_loss: 0.2974
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2877
# Epoch 47: val_loss improved from 0.29736 to 0.27152, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 98ms/step - loss: 0.2877 - val_loss: 0.2715
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2628
# Epoch 48: val_loss improved from 0.27152 to 0.24766, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 83ms/step - loss: 0.2628 - val_loss: 0.2477
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2399
# Epoch 49: val_loss improved from 0.24766 to 0.22545, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.2399 - val_loss: 0.2255
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2186
# Epoch 50: val_loss improved from 0.22545 to 0.20462, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.2186 - val_loss: 0.2046
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1987
# Epoch 51: val_loss improved from 0.20462 to 0.18590, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 89ms/step - loss: 0.1987 - val_loss: 0.1859
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1808
# Epoch 52: val_loss improved from 0.18590 to 0.16894, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1808 - val_loss: 0.1689
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1646
# Epoch 53: val_loss improved from 0.16894 to 0.15335, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 109ms/step - loss: 0.1646 - val_loss: 0.1534
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1496
# Epoch 54: val_loss improved from 0.15335 to 0.13963, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1496 - val_loss: 0.1396
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1364
# Epoch 55: val_loss improved from 0.13963 to 0.12718, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1364 - val_loss: 0.1272
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1245
# Epoch 56: val_loss improved from 0.12718 to 0.11576, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 79ms/step - loss: 0.1245 - val_loss: 0.1158
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1136
# Epoch 57: val_loss improved from 0.11576 to 0.10566, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.1136 - val_loss: 0.1057
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1040
# Epoch 58: val_loss improved from 0.10566 to 0.09639, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1040 - val_loss: 0.0964
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0951
# Epoch 59: val_loss improved from 0.09639 to 0.08802, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0951 - val_loss: 0.0880
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0870
# Epoch 60: val_loss improved from 0.08802 to 0.08058, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0870 - val_loss: 0.0806
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0799
# Epoch 61: val_loss improved from 0.08058 to 0.07366, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0799 - val_loss: 0.0737
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0733
# Epoch 62: val_loss improved from 0.07366 to 0.06753, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0733 - val_loss: 0.0675
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0675
# Epoch 63: val_loss improved from 0.06753 to 0.06213, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0675 - val_loss: 0.0621
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0623
# Epoch 64: val_loss improved from 0.06213 to 0.05737, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0623 - val_loss: 0.0574
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0577
# Epoch 65: val_loss improved from 0.05737 to 0.05335, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0577 - val_loss: 0.0533
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0538
# Epoch 66: val_loss improved from 0.05335 to 0.04969, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0538 - val_loss: 0.0497
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0503
# Epoch 67: val_loss improved from 0.04969 to 0.04642, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0503 - val_loss: 0.0464
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0473
# Epoch 68: val_loss improved from 0.04642 to 0.04344, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0473 - val_loss: 0.0434
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0444
# Epoch 69: val_loss improved from 0.04344 to 0.04065, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0444 - val_loss: 0.0407
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0417
# Epoch 70: val_loss improved from 0.04065 to 0.03814, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0417 - val_loss: 0.0381
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0392
# Epoch 71: val_loss improved from 0.03814 to 0.03579, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0392 - val_loss: 0.0358
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0370
# Epoch 72: val_loss improved from 0.03579 to 0.03375, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0370 - val_loss: 0.0338
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0350
# Epoch 73: val_loss improved from 0.03375 to 0.03200, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0350 - val_loss: 0.0320
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0332
# Epoch 74: val_loss improved from 0.03200 to 0.03049, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0332 - val_loss: 0.0305
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0317
# Epoch 75: val_loss improved from 0.03049 to 0.02918, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0317 - val_loss: 0.0292
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0303
# Epoch 76: val_loss improved from 0.02918 to 0.02794, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0303 - val_loss: 0.0279
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0291
# Epoch 77: val_loss improved from 0.02794 to 0.02683, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0291 - val_loss: 0.0268
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0279
# Epoch 78: val_loss improved from 0.02683 to 0.02578, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0279 - val_loss: 0.0258
# Epoch 79/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0268
# Epoch 79: val_loss improved from 0.02578 to 0.02485, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0268 - val_loss: 0.0248
# Epoch 80/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0258
# Epoch 80: val_loss improved from 0.02485 to 0.02397, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0258 - val_loss: 0.0240
# Epoch 81/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0249
# Epoch 81: val_loss improved from 0.02397 to 0.02317, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0249 - val_loss: 0.0232
# Epoch 82/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0241
# Epoch 82: val_loss improved from 0.02317 to 0.02245, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0241 - val_loss: 0.0225
# Epoch 83/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0233
# Epoch 83: val_loss improved from 0.02245 to 0.02178, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0233 - val_loss: 0.0218
# Epoch 84/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0226
# Epoch 84: val_loss improved from 0.02178 to 0.02111, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0226 - val_loss: 0.0211
# Epoch 85/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0220
# Epoch 85: val_loss improved from 0.02111 to 0.02042, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0220 - val_loss: 0.0204
# Epoch 86/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0213
# Epoch 86: val_loss improved from 0.02042 to 0.01977, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0213 - val_loss: 0.0198
# Epoch 87/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0206
# Epoch 87: val_loss improved from 0.01977 to 0.01915, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0206 - val_loss: 0.0191
# Epoch 88/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0200
# Epoch 88: val_loss improved from 0.01915 to 0.01858, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0200 - val_loss: 0.0186
# Epoch 89/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0194
# Epoch 89: val_loss improved from 0.01858 to 0.01804, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0194 - val_loss: 0.0180
# Epoch 90/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0189
# Epoch 90: val_loss improved from 0.01804 to 0.01755, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0189 - val_loss: 0.0176
# Epoch 91/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0184
# Epoch 91: val_loss improved from 0.01755 to 0.01710, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0184 - val_loss: 0.0171
# Epoch 92/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0179
# Epoch 92: val_loss improved from 0.01710 to 0.01668, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0179 - val_loss: 0.0167
# Epoch 93/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0175
# Epoch 93: val_loss improved from 0.01668 to 0.01626, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0175 - val_loss: 0.0163
# Epoch 94/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0170
# Epoch 94: val_loss improved from 0.01626 to 0.01586, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0170 - val_loss: 0.0159
# Epoch 95/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 95: val_loss improved from 0.01586 to 0.01548, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0166 - val_loss: 0.0155
# Epoch 96/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 96: val_loss improved from 0.01548 to 0.01513, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0162 - val_loss: 0.0151
# Epoch 97/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0158
# Epoch 97: val_loss improved from 0.01513 to 0.01478, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0158 - val_loss: 0.0148
# Epoch 98/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0154
# Epoch 98: val_loss improved from 0.01478 to 0.01444, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0154 - val_loss: 0.0144
# Epoch 99/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0151
# Epoch 99: val_loss improved from 0.01444 to 0.01411, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0151 - val_loss: 0.0141
# Epoch 100/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0147
# Epoch 100: val_loss improved from 0.01411 to 0.01380, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0147 - val_loss: 0.0138
#
#  La media del mse, 0-fold es : 0.5613472202792764
#
#  La desviacion estandar del mse, 0-fold es : 0.6295722758664126
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 60)                15120
#
#  dense_6 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 2.0137
# Epoch 1: val_loss improved from inf to 1.53755, saving model to modelo-2.h5
# 2/2 [==============================] - 2s 285ms/step - loss: 2.0618 - val_loss: 1.5376
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 2.0183
# Epoch 2: val_loss improved from 1.53755 to 1.48189, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 1.9808 - val_loss: 1.4819
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9647
# Epoch 3: val_loss improved from 1.48189 to 1.43550, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 1.9188 - val_loss: 1.4355
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9140
# Epoch 4: val_loss improved from 1.43550 to 1.39652, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 1.8673 - val_loss: 1.3965
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8695
# Epoch 5: val_loss improved from 1.39652 to 1.36293, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 1.8236 - val_loss: 1.3629
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8316
# Epoch 6: val_loss improved from 1.36293 to 1.33240, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 1.7851 - val_loss: 1.3324
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7952
# Epoch 7: val_loss improved from 1.33240 to 1.30359, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 1.7498 - val_loss: 1.3036
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6248
# Epoch 8: val_loss improved from 1.30359 to 1.27426, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 1.7152 - val_loss: 1.2743
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7262
# Epoch 9: val_loss improved from 1.27426 to 1.24425, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 1.6807 - val_loss: 1.2442
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6716
# Epoch 10: val_loss improved from 1.24425 to 1.21302, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 1.6439 - val_loss: 1.2130
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6360
# Epoch 11: val_loss improved from 1.21302 to 1.17851, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 1.6057 - val_loss: 1.1785
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6063
# Epoch 12: val_loss improved from 1.17851 to 1.14075, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 1.5641 - val_loss: 1.1407
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5505
# Epoch 13: val_loss improved from 1.14075 to 1.09847, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 1.5181 - val_loss: 1.0985
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4669
# Epoch 14: val_loss improved from 1.09847 to 1.04753, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 1.4660 - val_loss: 1.0475
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3129
# Epoch 15: val_loss improved from 1.04753 to 0.98877, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 1.4013 - val_loss: 0.9888
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3652
# Epoch 16: val_loss improved from 0.98877 to 0.93026, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 1.3307 - val_loss: 0.9303
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2792
# Epoch 17: val_loss improved from 0.93026 to 0.86701, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 1.2516 - val_loss: 0.8670
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1960
# Epoch 18: val_loss improved from 0.86701 to 0.79889, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 1.1668 - val_loss: 0.7989
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9845
# Epoch 19: val_loss improved from 0.79889 to 0.72667, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.0696 - val_loss: 0.7267
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9266
# Epoch 20: val_loss improved from 0.72667 to 0.66139, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.9694 - val_loss: 0.6614
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8964
# Epoch 21: val_loss improved from 0.66139 to 0.62514, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 0.8781 - val_loss: 0.6251
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8491
# Epoch 22: val_loss improved from 0.62514 to 0.52722, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 0.8310 - val_loss: 0.5272
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6763
# Epoch 23: val_loss improved from 0.52722 to 0.47194, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.7091 - val_loss: 0.4719
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6387
# Epoch 24: val_loss improved from 0.47194 to 0.45361, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.6220 - val_loss: 0.4536
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5951
# Epoch 25: val_loss improved from 0.45361 to 0.43305, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5794 - val_loss: 0.4330
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5510
# Epoch 26: val_loss improved from 0.43305 to 0.39073, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.5405 - val_loss: 0.3907
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4960
# Epoch 27: val_loss improved from 0.39073 to 0.33306, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 0.4829 - val_loss: 0.3331
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4328
# Epoch 28: val_loss improved from 0.33306 to 0.28470, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.4219 - val_loss: 0.2847
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4040
# Epoch 29: val_loss improved from 0.28470 to 0.25504, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.3934 - val_loss: 0.2550
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3734
# Epoch 30: val_loss improved from 0.25504 to 0.22943, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.3722 - val_loss: 0.2294
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3368
# Epoch 31: val_loss improved from 0.22943 to 0.20365, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.3304 - val_loss: 0.2036
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2926
# Epoch 32: val_loss improved from 0.20365 to 0.18063, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 0.2870 - val_loss: 0.1806
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2527
# Epoch 33: val_loss improved from 0.18063 to 0.15904, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.2474 - val_loss: 0.1590
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1963
# Epoch 34: val_loss did not improve from 0.15904
# 2/2 [==============================] - 0s 40ms/step - loss: 0.2143 - val_loss: 0.1636
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2078
# Epoch 35: val_loss did not improve from 0.15904
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2039 - val_loss: 0.1942
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2274
# Epoch 36: val_loss improved from 0.15904 to 0.15256, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 0.2423 - val_loss: 0.1526
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1953
# Epoch 37: val_loss improved from 0.15256 to 0.10872, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 0.1909 - val_loss: 0.1087
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1460
# Epoch 38: val_loss did not improve from 0.10872
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1432 - val_loss: 0.1650
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2369
# Epoch 39: val_loss improved from 0.10872 to 0.09451, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 0.2356 - val_loss: 0.0945
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1317
# Epoch 40: val_loss improved from 0.09451 to 0.08940, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.1287 - val_loss: 0.0894
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1073
# Epoch 41: val_loss did not improve from 0.08940
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1056 - val_loss: 0.1177
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1368
# Epoch 42: val_loss did not improve from 0.08940
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1352 - val_loss: 0.1244
# Epoch 43/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1345
# Epoch 43: val_loss improved from 0.08940 to 0.08364, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.1386 - val_loss: 0.0836
# Epoch 44/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0920
# Epoch 44: val_loss improved from 0.08364 to 0.05464, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0911 - val_loss: 0.0546
# Epoch 45/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0901
# Epoch 45: val_loss did not improve from 0.05464
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0881 - val_loss: 0.0699
# Epoch 46/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1505
# Epoch 46: val_loss improved from 0.05464 to 0.04879, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1530 - val_loss: 0.0488
# Epoch 47/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0669
# Epoch 47: val_loss did not improve from 0.04879
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0658 - val_loss: 0.1064
# Epoch 48/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1072
# Epoch 48: val_loss did not improve from 0.04879
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1133 - val_loss: 0.1337
# Epoch 49/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1391
# Epoch 49: val_loss did not improve from 0.04879
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1422 - val_loss: 0.0947
#
#  La media del mse, 1-fold es : 0.8297449070580152
#
#  La desviacion estandar del mse, 1-fold es : 0.673285211922638
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 60)                15120
#
#  dense_7 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 1.9030
# Epoch 1: val_loss improved from inf to 1.67391, saving model to modelo-3.h5
# 2/2 [==============================] - 2s 270ms/step - loss: 1.8577 - val_loss: 1.6739
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8467
# Epoch 2: val_loss improved from 1.67391 to 1.63134, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 1.8031 - val_loss: 1.6313
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7909
# Epoch 3: val_loss improved from 1.63134 to 1.59493, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 1.7616 - val_loss: 1.5949
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7519
# Epoch 4: val_loss improved from 1.59493 to 1.56133, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 72ms/step - loss: 1.7248 - val_loss: 1.5613
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7192
# Epoch 5: val_loss improved from 1.56133 to 1.52868, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 81ms/step - loss: 1.6900 - val_loss: 1.5287
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6843
# Epoch 6: val_loss improved from 1.52868 to 1.49598, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 1.6557 - val_loss: 1.4960
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6527
# Epoch 7: val_loss improved from 1.49598 to 1.46258, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 86ms/step - loss: 1.6209 - val_loss: 1.4626
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5784
# Epoch 8: val_loss improved from 1.46258 to 1.42586, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 1.5847 - val_loss: 1.4259
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5851
# Epoch 9: val_loss improved from 1.42586 to 1.38509, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 1.5455 - val_loss: 1.3851
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5418
# Epoch 10: val_loss improved from 1.38509 to 1.34110, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 77ms/step - loss: 1.5012 - val_loss: 1.3411
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4913
# Epoch 11: val_loss improved from 1.34110 to 1.29262, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 1.4537 - val_loss: 1.2926
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4259
# Epoch 12: val_loss improved from 1.29262 to 1.23646, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 77ms/step - loss: 1.4014 - val_loss: 1.2365
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3631
# Epoch 13: val_loss improved from 1.23646 to 1.16765, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 1.3406 - val_loss: 1.1677
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3007
# Epoch 14: val_loss improved from 1.16765 to 1.08616, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 1.2667 - val_loss: 1.0862
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2093
# Epoch 15: val_loss improved from 1.08616 to 0.99391, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 1.1785 - val_loss: 0.9939
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1001
# Epoch 16: val_loss improved from 0.99391 to 0.89456, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0785 - val_loss: 0.8946
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9889
# Epoch 17: val_loss improved from 0.89456 to 0.83011, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.9694 - val_loss: 0.8301
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9088
# Epoch 18: val_loss improved from 0.83011 to 0.78319, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 89ms/step - loss: 0.8907 - val_loss: 0.7832
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8516
# Epoch 19: val_loss improved from 0.78319 to 0.66322, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.8309 - val_loss: 0.6632
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6749
# Epoch 20: val_loss improved from 0.66322 to 0.57764, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.7053 - val_loss: 0.5776
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6109
# Epoch 21: val_loss improved from 0.57764 to 0.50254, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 88ms/step - loss: 0.6210 - val_loss: 0.5025
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5491
# Epoch 22: val_loss improved from 0.50254 to 0.43888, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5394 - val_loss: 0.4389
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4708
# Epoch 23: val_loss improved from 0.43888 to 0.41821, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 88ms/step - loss: 0.4602 - val_loss: 0.4182
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4156
# Epoch 24: val_loss improved from 0.41821 to 0.34067, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 86ms/step - loss: 0.4217 - val_loss: 0.3407
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3273
# Epoch 25: val_loss improved from 0.34067 to 0.29106, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 89ms/step - loss: 0.3460 - val_loss: 0.2911
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3085
# Epoch 26: val_loss improved from 0.29106 to 0.24934, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.3041 - val_loss: 0.2493
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2454
# Epoch 27: val_loss improved from 0.24934 to 0.20970, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.2568 - val_loss: 0.2097
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2107
# Epoch 28: val_loss did not improve from 0.20970
# 2/2 [==============================] - 0s 65ms/step - loss: 0.2073 - val_loss: 0.2154
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1987
# Epoch 29: val_loss improved from 0.20970 to 0.15819, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.1990 - val_loss: 0.1582
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1517
# Epoch 30: val_loss improved from 0.15819 to 0.13473, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1501 - val_loss: 0.1347
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1325
# Epoch 31: val_loss improved from 0.13473 to 0.11551, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1335 - val_loss: 0.1155
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1066
# Epoch 32: val_loss improved from 0.11551 to 0.10187, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 89ms/step - loss: 0.1094 - val_loss: 0.1019
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0913
# Epoch 33: val_loss improved from 0.10187 to 0.08874, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0921 - val_loss: 0.0887
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0791
# Epoch 34: val_loss improved from 0.08874 to 0.08131, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0794 - val_loss: 0.0813
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0690
# Epoch 35: val_loss improved from 0.08131 to 0.07349, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 88ms/step - loss: 0.0698 - val_loss: 0.0735
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0624
# Epoch 36: val_loss improved from 0.07349 to 0.06615, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0619 - val_loss: 0.0662
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0554
# Epoch 37: val_loss improved from 0.06615 to 0.06111, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0553 - val_loss: 0.0611
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0504
# Epoch 38: val_loss improved from 0.06111 to 0.05809, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0505 - val_loss: 0.0581
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0476
# Epoch 39: val_loss improved from 0.05809 to 0.05709, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0469 - val_loss: 0.0571
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0449
# Epoch 40: val_loss improved from 0.05709 to 0.05058, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0448 - val_loss: 0.0506
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0427
# Epoch 41: val_loss did not improve from 0.05058
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0429 - val_loss: 0.0577
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0534
# ...
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4436
# Epoch 12: val_loss improved from 1.44959 to 1.39780, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 1.4055 - val_loss: 1.3978
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2758
# Epoch 13: val_loss improved from 1.39780 to 1.33758, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 1.3555 - val_loss: 1.3376
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2038
# Epoch 14: val_loss improved from 1.33758 to 1.26415, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.2991 - val_loss: 1.2641
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2661
# Epoch 15: val_loss improved from 1.26415 to 1.19261, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 1.2375 - val_loss: 1.1926
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2043
# Epoch 16: val_loss improved from 1.19261 to 1.11780, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.1782 - val_loss: 1.1178
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0488
# Epoch 17: val_loss improved from 1.11780 to 1.03737, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 1.1072 - val_loss: 1.0374
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9899
# Epoch 18: val_loss improved from 1.03737 to 0.98476, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 1.0308 - val_loss: 0.9848
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0038
# Epoch 19: val_loss improved from 0.98476 to 0.87194, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.9946 - val_loss: 0.8719
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8905
# Epoch 20: val_loss improved from 0.87194 to 0.75408, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 0.8726 - val_loss: 0.7541
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6736
# Epoch 21: val_loss improved from 0.75408 to 0.67505, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.7463 - val_loss: 0.6751
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6304
# Epoch 22: val_loss improved from 0.67505 to 0.56892, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.6617 - val_loss: 0.5689
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5359
# Epoch 23: val_loss improved from 0.56892 to 0.50686, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.5568 - val_loss: 0.5069
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5089
# Epoch 24: val_loss did not improve from 0.50686
# 2/2 [==============================] - 0s 41ms/step - loss: 0.5012 - val_loss: 0.5423
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5444
# Epoch 25: val_loss improved from 0.50686 to 0.40933, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.5331 - val_loss: 0.4093
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4117
# Epoch 26: val_loss improved from 0.40933 to 0.30980, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.4032 - val_loss: 0.3098
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3123
# Epoch 27: val_loss improved from 0.30980 to 0.29845, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.3059 - val_loss: 0.2985
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2732
# Epoch 28: val_loss improved from 0.29845 to 0.26702, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.2927 - val_loss: 0.2670
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2579
# Epoch 29: val_loss improved from 0.26702 to 0.21066, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 0.2602 - val_loss: 0.2107
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2109
# Epoch 30: val_loss improved from 0.21066 to 0.20707, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.2074 - val_loss: 0.2071
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1840
# Epoch 31: val_loss improved from 0.20707 to 0.15992, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.2070 - val_loss: 0.1599
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1602
# Epoch 32: val_loss did not improve from 0.15992
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1575 - val_loss: 0.2102
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1985
# Epoch 33: val_loss did not improve from 0.15992
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2067 - val_loss: 0.2522
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2338
# Epoch 34: val_loss did not improve from 0.15992
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2441 - val_loss: 0.2141
#
#  La media del mse, 3-fold es : 0.9971764131503946
#
#  La desviacion estandar del mse, 3-fold es : 0.5744271006474257
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 60)                15120
#
#  dense_9 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 1.8819
# Epoch 1: val_loss improved from inf to 2.22530, saving model to modelo-5.h5
# 2/2 [==============================] - 2s 278ms/step - loss: 1.8521 - val_loss: 2.2253
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7268
# Epoch 2: val_loss improved from 2.22530 to 2.17237, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 1.7933 - val_loss: 2.1724
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5962
# Epoch 3: val_loss improved from 2.17237 to 2.12641, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 1.7460 - val_loss: 2.1264
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7026
# Epoch 4: val_loss improved from 2.12641 to 2.08516, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 1.7073 - val_loss: 2.0852
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6996
# Epoch 5: val_loss improved from 2.08516 to 2.04732, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.6721 - val_loss: 2.0473
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6666
# Epoch 6: val_loss improved from 2.04732 to 2.01189, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 1.6395 - val_loss: 2.0119
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6389
# Epoch 7: val_loss improved from 2.01189 to 1.97774, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 1.6087 - val_loss: 1.9777
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6207
# Epoch 8: val_loss improved from 1.97774 to 1.94418, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 1.5790 - val_loss: 1.9442
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4880
# Epoch 9: val_loss improved from 1.94418 to 1.90821, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 1.5492 - val_loss: 1.9082
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5456
# Epoch 10: val_loss improved from 1.90821 to 1.86895, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 1.5188 - val_loss: 1.8689
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4255
# Epoch 11: val_loss improved from 1.86895 to 1.82509, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 1.4845 - val_loss: 1.8251
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4728
# Epoch 12: val_loss improved from 1.82509 to 1.77540, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 1.4480 - val_loss: 1.7754
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3492
# Epoch 13: val_loss improved from 1.77540 to 1.71770, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 1.4051 - val_loss: 1.7177
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3811
# Epoch 14: val_loss improved from 1.71770 to 1.65006, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 1.3580 - val_loss: 1.6501
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3364
# Epoch 15: val_loss improved from 1.65006 to 1.57453, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 1.3029 - val_loss: 1.5745
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2740
# Epoch 16: val_loss improved from 1.57453 to 1.49437, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 1.2419 - val_loss: 1.4944
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2083
# Epoch 17: val_loss improved from 1.49437 to 1.41165, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 1.1775 - val_loss: 1.4117
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1295
# Epoch 18: val_loss improved from 1.41165 to 1.32027, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 1.1107 - val_loss: 1.3203
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0569
# Epoch 19: val_loss improved from 1.32027 to 1.21765, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 1.0382 - val_loss: 1.2176
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9833
# Epoch 20: val_loss improved from 1.21765 to 1.12865, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.9586 - val_loss: 1.1287
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9040
# Epoch 21: val_loss improved from 1.12865 to 1.04886, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.8878 - val_loss: 1.0489
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8443
# Epoch 22: val_loss improved from 1.04886 to 0.95633, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.8229 - val_loss: 0.9563
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7649
# Epoch 23: val_loss improved from 0.95633 to 0.86616, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.7490 - val_loss: 0.8662
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6403
# Epoch 24: val_loss improved from 0.86616 to 0.76652, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 0.6766 - val_loss: 0.7665
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5894
# Epoch 25: val_loss improved from 0.76652 to 0.66444, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.6004 - val_loss: 0.6644
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5337
# Epoch 26: val_loss improved from 0.66444 to 0.58120, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 0.5227 - val_loss: 0.5812
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4692
# Epoch 27: val_loss improved from 0.58120 to 0.48677, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 0.4585 - val_loss: 0.4868
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3968
# Epoch 28: val_loss improved from 0.48677 to 0.43528, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.3875 - val_loss: 0.4353
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3568
# Epoch 29: val_loss improved from 0.43528 to 0.38566, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.3483 - val_loss: 0.3857
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3157
# Epoch 30: val_loss improved from 0.38566 to 0.32623, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.3096 - val_loss: 0.3262
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2682
# Epoch 31: val_loss improved from 0.32623 to 0.30099, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.2624 - val_loss: 0.3010
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2437
# Epoch 32: val_loss improved from 0.30099 to 0.25840, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.2391 - val_loss: 0.2584
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2107
# Epoch 33: val_loss improved from 0.25840 to 0.22117, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.2063 - val_loss: 0.2212
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1825
# Epoch 34: val_loss improved from 0.22117 to 0.19737, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1790 - val_loss: 0.1974
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1490
# Epoch 35: val_loss improved from 0.19737 to 0.16605, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 0.1594 - val_loss: 0.1661
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1371
# Epoch 36: val_loss improved from 0.16605 to 0.15393, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1344 - val_loss: 0.1539
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1090
# Epoch 37: val_loss improved from 0.15393 to 0.13528, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 0.1210 - val_loss: 0.1353
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1152
# Epoch 38: val_loss did not improve from 0.13528
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1143 - val_loss: 0.2345
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1946
# Epoch 39: val_loss did not improve from 0.13528
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1901 - val_loss: 0.2682
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2187
# Epoch 40: val_loss did not improve from 0.13528
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2143 - val_loss: 0.2264
#
#  La media del mse, 4-fold es : 0.9193696780130267
#
#  La desviacion estandar del mse, 4-fold es : 0.5936377321152689

# %%
# rellenar de ceros los espacios vacios de la lista con loss y validation

df_train_losses = pd.DataFrame(train_losses)

df_filled_train_losses = df_train_losses.fillna(0)

train_losses_completa = df_filled_train_losses.values.tolist()

df_val_losses = pd.DataFrame(val_losses)

df_filled_val_losses = df_val_losses.fillna(0)

val_losses_completa = df_filled_val_losses.values.tolist()

# %%
# Calcular el promedio de "average loss" para todos los pliegues y épocas
avg_train_losses = np.mean(train_losses_completa, axis=0)
avg_val_losses = np.mean(val_losses_completa, axis=0)

# vamos a graficar
plt.plot(avg_train_losses, label='Perdida entrenamiento') # Grafico esta para ver si estoy sobre entrenando
plt.plot(avg_val_losses, label='Perdida Validacion') # Grafico esta para ver si estoy sobre entrenando
plt.title('avg loss train, avg loss val vs epoch ')
plt.xlabel('epoch')
plt.ylabel('Mean Square Error')
plt.legend()
plt.show()

# %%
# Cargar el mejor modelo
best_model = load_model(best_model_path)

# %%
# Seleccionar una secuencia específica
index = 0
input_sequence = X_test[index]

# Hacer la predicción
y_pred = best_model.predict(np.expand_dims(input_sequence, axis=0))
# usamos el np.expand_dims() para agregar una dimensión adicional al inicio de input_sequence
print(y_pred.shape)
# Out:
# 1/1 [==============================] - 0s 180ms/step
# (1, 210)

# %%
# Desenrollar X_test para convertirlo en un array bidimensional
X_test_flattened = X_test.reshape(-1, X_test.shape[-1])

# Aplicar la transformación inversa utilizando el objeto StandardScaler
X_test_desnormalizado = sc.inverse_transform(X_test_flattened)

# Volver a darle forma a X_test_desnormalizado a su forma original
X_test = X_test_desnormalizado.reshape(X_test.shape)

# Desnormalizar los datos
y_pred = sc_y.inverse_transform(y_pred)

y_test = sc_y.inverse_transform(y_test)

print(y_pred.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (1, 210)
# (17, 210)
# (17, 15, 2)

# %%
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
Curva=0

plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

print('')
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(X_test[Curva,:,0],color='orange', label='Valores actuales y anteriores de insulina')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_test[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 229.472625

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_pred[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 233.39455410003663

# %%
# Media MSE y desviacion estandar MSE de las prediciones con la escala normal
mse = mean_squared_error(y_test[0,:].flatten(), y_pred.flatten())
std = np.sqrt(mse)
mediamse = np.mean(mse)

print('La media MSE:',mediamse)
print('La desviacion standar MSE', std)

# calcular la MAE
mae = mean_absolute_error(y_test[0,:], y_pred[0,:])
print('MAE:', mae)

# calcular la RMSE
rmse = np.sqrt(mean_squared_error(y_test[0,:], y_pred[0,:]))
print('RMSE:', rmse)
# Out:
# La media MSE: 35.22875192878536
# La desviacion standar MSE 5.935381363382252
# MAE: 4.450866800944011
# RMSE: 5.935381363382252
