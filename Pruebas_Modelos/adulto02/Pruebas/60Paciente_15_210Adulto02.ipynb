# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#Librerias
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split, KFold
from keras.callbacks import EarlyStopping

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import load_model

from keras.initializers import glorot_uniform

# %%
#Dataset Adulto 01
data = pd.read_csv('/content/gdrive/MyDrive/Proyecto_de_grado/SUSTENTACION3.0/FinalX3/my_adult02A2_data.csv')

print(f"El archivo se ha cargado correctamente. Tiene {data.shape[0]} filas y {data.shape[1]} columnas.")
# Out:
# El archivo se ha cargado correctamente. Tiene 29638 filas y 3 columnas.

# %%
train_size = int(len(data) * 0.7)

train_data = data.iloc[:train_size, :] # 70% entrenamiento
test_data = data.iloc[train_size:, :] # 30% prueba

test_data = test_data.reset_index(drop=True)

# %%
#los indices donde hay ingestas
posicionestrain = train_data.loc[train_data.iloc[:, 0] != 0].index
posicionestest = test_data.loc[test_data.iloc[:, 0] != 0].index

df_posiciones_train = pd.DataFrame(posicionestrain)
df_posiciones_test = pd.DataFrame(posicionestest)

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_train = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_train)):
    anterior = df_posiciones_train.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_train.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_train.append(anterior)

ultimo_elemento_train = df_posiciones_train.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_train.extend(ultimo_elemento_train.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_train)
print(len(cumplen_train))
# Out:
# [494, 862, 1358, 1974, 2353, 2840, 3461, 3846, 4334, 4956, 5324, 5820, 6438, 6815, 7301, 7917, 8283, 8781, 9398, 9781, 10268, 10880, 11255, 11750, 12363, 12742, 13230, 13845, 14212, 14699, 15311, 15686, 16183, 16795, 17162, 17650, 18266, 18653, 19140, 19757, 20125, 20614]
# 42

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_test = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_test)):
    anterior = df_posiciones_test.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_test.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_test.append(anterior)

ultimo_elemento_test = df_posiciones_test.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_test.extend(ultimo_elemento_test.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_test)
print(len(cumplen_test))
# Out:
# [487, 855, 1342, 1956, 2335, 2823, 3439, 3805, 4301, 4916, 5291, 5779, 6398, 6765, 7253, 7868, 8234, 8720]
# 18

# %%
# pasar la escala de los carbohidratos de las ingestas a gramos
data.iloc[:,0] = data.iloc[:,0].apply(lambda x: (x*15)/1000)

# Grafica con mayor detalle, el pico del comportamiento de la glucosa despues de la primera ingesta
print('')
print('Grafica de los datos del dataset')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
plt.title('Ingestas, Insulina y Glucosa')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')

print('Caso 1: Primera ingesta o Desayuno del primer dia:')
plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 700])
plt.ylim([-5, 250])
plt.show()
print('')

print('Caso 2: Primera y segunda ingesta del primer dia:')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1200])
plt.ylim([-5, 500])
plt.show()


print('Caso 3: las tres ingestas del primer dia:')

plt.plot(data.index, data.iloc[:,0], color='blue', label='Ingestas')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Ingestas de carbohidratos')
plt.xlabel('t [min]')
plt.ylabel('gramos')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Dosificación de insulina')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
#plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1800])
plt.ylim([-5, 500])
plt.show()
# Out:
# Grafica de los datos del dataset
# Caso 1: Primera ingesta o Desayuno del primer dia:
# Caso 2: Primera y segunda ingesta del primer dia:
# Caso 3: las tres ingestas del primer dia:

# %%
#Preprocesar los datos:
X_train = train_data.iloc[:, 1:3].values
y_train = train_data.iloc[:,2].values

X_test = test_data.iloc[:, 1:3].values
y_test = test_data.iloc[:, 2].values

print('Tamaño de los datos de entrada, de X_train: ',X_train.shape)
print(f'Tiene {X_train.shape[0]} filas y {X_train.shape[1]} columna')
print('La primera ingesta al minuto 300, ingesta: ',X_train[300])
print('La primera ingesta hasta el minuto 327, ingesta: ',X_train[327])

print('La entrada son los valores de la insulina y glucosa \n',X_train)
print('Tamaño de los datos de salia, de y_train',y_train.shape)
print(f'Tiene {y_train.shape[0]} filas y {y_train.shape[-1]} columnas')
print('La salida son los valores de glucosa \n',y_train)
# Out:
# Tamaño de los datos de entrada, de X_train:  (20746, 2)
# Tiene 20746 filas y 2 columna
# La primera ingesta al minuto 300, ingesta:  [  1.6789 123.44  ]
# La primera ingesta hasta el minuto 327, ingesta:  [  1.6789 123.44  ]
# La entrada son los valores de la insulina y glucosa
#  [[  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  ...
#  [  1.6789 198.03  ]
#  [  1.6789 197.1   ]
#  [  1.6789 196.18  ]]
# Tamaño de los datos de salia, de y_train (20746,)
# Tiene 20746 filas y 20746 columnas
# La salida son los valores de glucosa
#  [123.44 123.44 123.44 ... 198.03 197.1  196.18]

# %%
# Normalizar los datos
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Normalizar y_train
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.reshape(-1, 1))
y_test = sc_y.transform(y_test.reshape(-1, 1))

# %%
# Reorganizar los datos en forma de secuencia
def to_sequences(data,  seq_size_input, seq_size_output):
    X = []
    y = []

    for i in range(len(data)-seq_size_input-seq_size_output+1):
        X.append(data[i:(i+seq_size_input), 0:2])
        y.append(data[(i+seq_size_input):(i+seq_size_input+seq_size_output), 2])

    return np.array(X), np.array(y)

# %%
#CON LOS DATOS NORMALIZADOS
seq_size_input = 15
seq_size_output = 210
X_train, y_train = to_sequences(np.hstack((X_train, y_train)), seq_size_input, seq_size_output)
X_test, y_test = to_sequences(np.hstack((X_test, y_test)), seq_size_input, seq_size_output)
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (20522, 210)
# (20522, 15, 2)
# (8668, 210)
# (8668, 15, 2)

# %%
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
flattened_data = np.reshape(X_train, (X_train.shape[0], -1))

df_X_train = pd.DataFrame(flattened_data)

# %%
flattened_test = np.reshape(X_test, (X_test.shape[0], -1))

df_X_test = pd.DataFrame(flattened_test)

# %%
df_y_train = pd.DataFrame(y_train)
df_y_test = pd.DataFrame(y_test)

# %%
# Filtrar el dataframe para mantener solo las filas especificadas
df_X_train_seleccionado = df_X_train[df_X_train.index.isin(cumplen_train)]
df_y_train_seleccionado = df_y_train[df_y_train.index.isin(cumplen_train)]
df_X_test_seleccionado = df_X_test[df_X_test.index.isin(cumplen_test)]
df_y_test_seleccionado = df_y_test[df_y_test.index.isin(cumplen_test)]

# %%
print('Grafica de los datos del dataset')
#plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')

Numerocurva = 0

plt.plot(df_X_train_seleccionado.iloc[Numerocurva, 1::2],color='green',label='Entrada glucosa') #Para mostrar solo la glucosa
plt.plot(df_X_train_seleccionado.iloc[Numerocurva, ::2],color='orange',label='Entrada insulina') #Para mostrar solo la glucosa
plt.plot(range(seq_size_input*2, seq_size_output + seq_size_input*2),df_y_train_seleccionado.iloc[Numerocurva,:], color='red',label='Salida glucosa')
plt.title('Entradas y salidas, entrenamiento')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')
# Out:
# Grafica de los datos del dataset

# %%
X_train = df_X_train_seleccionado.values
y_train = df_y_train_seleccionado.values
X_test = df_X_test_seleccionado.values
y_test = df_y_test_seleccionado.values

print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 30)
# (17, 210)
# (17, 30)

# %%
print(len(X_test))
# Out:
# 17

# %%
X_train = np.reshape(X_train, (len(X_train), seq_size_input, 2))

X_test = np.reshape(X_test, (len(X_test), seq_size_input, 2))
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 15, 2)
# (17, 210)
# (17, 15, 2)

# %%
kf = KFold(n_splits=5)
kf.get_n_splits(X_train)
KFold(n_splits=5, random_state=None, shuffle=False)


# Crear listas para almacenar los valores del "average loss" de entrenamiento y validación en cada pliegue
train_losses = []
val_losses = []

#Para guardar el mejor modelo
best_loss = float('inf')
best_model_path = ""

for i, (train_index, test_index) in enumerate(kf.split(X_train,y_train)):
  model = Sequential()
  model.add(LSTM(60, activation='tanh', input_shape=(seq_size_input, 2), kernel_initializer=glorot_uniform()))
  model.add(Dense(seq_size_output, activation='linear', kernel_initializer=glorot_uniform()))


  model.compile(optimizer='adam', loss='mse')
  print(model.summary())

  filepath = f"modelo-{i+1}.h5"
  early_stop = EarlyStopping(monitor='val_loss', patience=3)
  checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

  X, y =  X_train[train_index], y_train[train_index]
  X_val, y_val = X_train[test_index], y_train[test_index]


  history = model.fit(X, y, epochs=100, batch_size=32,validation_data=(X_val, y_val),callbacks=[checkpoint, early_stop] )

  mediamse = np.mean( history.history['loss'] )
  stdmse = np.std(  history.history['loss'])
  print('')
  print(f" La media del mse, {i}-fold es : {mediamse}")
  print('')
  print(f" La desviacion estandar del mse, {i}-fold es : {stdmse}")

  # Obtener los valores de "average loss" para el pliegue actual
  fold_train_losses = model.history.history['loss']
  fold_val_losses = model.history.history['val_loss']

  # Almacenar los valores de "average loss" para el pliegue actual
  train_losses.append(fold_train_losses)
  val_losses.append(fold_val_losses)

  if min(fold_val_losses) < best_loss:
        best_loss = min(fold_val_losses)
        best_model_path = filepath

  history.history.keys() # aqui me muestra que esta guardando, con history me guarda todos los valores que calcula durante el proceso de entrenamiento

  # vamos a graficar
  plt.plot(history.history['loss'], label='Perdida') # Grafico esta para ver si estoy sobre entrenando
  plt.plot(history.history['val_loss'], label='Validacion') # Grafico esta para ver si estoy sobre entrenando
  plt.xlabel('epoch')
  plt.ylabel('Mean Square Error')
  plt.legend()
  plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 60)                15120
#
#  dense_5 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7531
# Epoch 1: val_loss improved from inf to 1.83459, saving model to modelo-1.h5
# 1/1 [==============================] - 2s 2s/step - loss: 1.7531 - val_loss: 1.8346
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7473
# Epoch 2: val_loss improved from 1.83459 to 1.82838, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 1.7473 - val_loss: 1.8284
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7412
# Epoch 3: val_loss improved from 1.82838 to 1.82178, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 1.7412 - val_loss: 1.8218
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7348
# Epoch 4: val_loss improved from 1.82178 to 1.81467, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 1.7348 - val_loss: 1.8147
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7279
# Epoch 5: val_loss improved from 1.81467 to 1.80691, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 1.7279 - val_loss: 1.8069
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7203
# Epoch 6: val_loss improved from 1.80691 to 1.79831, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 1.7203 - val_loss: 1.7983
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7118
# Epoch 7: val_loss improved from 1.79831 to 1.78866, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 1.7118 - val_loss: 1.7887
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7024
# Epoch 8: val_loss improved from 1.78866 to 1.77767, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 1.7024 - val_loss: 1.7777
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6916
# Epoch 9: val_loss improved from 1.77767 to 1.76503, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 1.6916 - val_loss: 1.7650
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6792
# Epoch 10: val_loss improved from 1.76503 to 1.75030, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 1.6792 - val_loss: 1.7503
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6647
# Epoch 11: val_loss improved from 1.75030 to 1.73299, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 1.6647 - val_loss: 1.7330
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6477
# Epoch 12: val_loss improved from 1.73299 to 1.71245, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 1.6477 - val_loss: 1.7125
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6275
# Epoch 13: val_loss improved from 1.71245 to 1.68792, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 1.6275 - val_loss: 1.6879
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6034
# Epoch 14: val_loss improved from 1.68792 to 1.65848, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 1.6034 - val_loss: 1.6585
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5745
# Epoch 15: val_loss improved from 1.65848 to 1.62304, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 1.5745 - val_loss: 1.6230
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5397
# Epoch 16: val_loss improved from 1.62304 to 1.58039, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 1.5397 - val_loss: 1.5804
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4979
# Epoch 17: val_loss improved from 1.58039 to 1.52933, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 80ms/step - loss: 1.4979 - val_loss: 1.5293
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4479
# Epoch 18: val_loss improved from 1.52933 to 1.46884, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 1.4479 - val_loss: 1.4688
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3889
# Epoch 19: val_loss improved from 1.46884 to 1.39851, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 1.3889 - val_loss: 1.3985
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3205
# Epoch 20: val_loss improved from 1.39851 to 1.31913, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 1.3205 - val_loss: 1.3191
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2436
# Epoch 21: val_loss improved from 1.31913 to 1.23317, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 1.2436 - val_loss: 1.2332
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1608
# Epoch 22: val_loss improved from 1.23317 to 1.14485, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 1.1608 - val_loss: 1.1448
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0763
# Epoch 23: val_loss improved from 1.14485 to 1.05926, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 1.0763 - val_loss: 1.0593
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9949
# Epoch 24: val_loss improved from 1.05926 to 0.98068, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.9949 - val_loss: 0.9807
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9206
# Epoch 25: val_loss improved from 0.98068 to 0.91134, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.9206 - val_loss: 0.9113
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8555
# Epoch 26: val_loss improved from 0.91134 to 0.85162, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.8555 - val_loss: 0.8516
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7998
# Epoch 27: val_loss improved from 0.85162 to 0.80107, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.7998 - val_loss: 0.8011
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7531
# Epoch 28: val_loss improved from 0.80107 to 0.75904, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.7531 - val_loss: 0.7590
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7147
# Epoch 29: val_loss improved from 0.75904 to 0.72461, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.7147 - val_loss: 0.7246
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6836
# Epoch 30: val_loss improved from 0.72461 to 0.69643, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 81ms/step - loss: 0.6836 - val_loss: 0.6964
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6583
# Epoch 31: val_loss improved from 0.69643 to 0.67299, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 106ms/step - loss: 0.6583 - val_loss: 0.6730
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6375
# Epoch 32: val_loss improved from 0.67299 to 0.65298, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 100ms/step - loss: 0.6375 - val_loss: 0.6530
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6196
# Epoch 33: val_loss improved from 0.65298 to 0.63530, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6196 - val_loss: 0.6353
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6036
# Epoch 34: val_loss improved from 0.63530 to 0.61909, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 119ms/step - loss: 0.6036 - val_loss: 0.6191
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5886
# Epoch 35: val_loss improved from 0.61909 to 0.60377, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 94ms/step - loss: 0.5886 - val_loss: 0.6038
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5741
# Epoch 36: val_loss improved from 0.60377 to 0.58922, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 106ms/step - loss: 0.5741 - val_loss: 0.5892
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5600
# Epoch 37: val_loss improved from 0.58922 to 0.57600, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 96ms/step - loss: 0.5600 - val_loss: 0.5760
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5468
# Epoch 38: val_loss improved from 0.57600 to 0.56532, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 92ms/step - loss: 0.5468 - val_loss: 0.5653
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5357
# Epoch 39: val_loss improved from 0.56532 to 0.55777, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 117ms/step - loss: 0.5357 - val_loss: 0.5578
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5275
# Epoch 40: val_loss improved from 0.55777 to 0.55171, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 94ms/step - loss: 0.5275 - val_loss: 0.5517
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5209
# Epoch 41: val_loss improved from 0.55171 to 0.54543, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 112ms/step - loss: 0.5209 - val_loss: 0.5454
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5142
# Epoch 42: val_loss improved from 0.54543 to 0.53825, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 116ms/step - loss: 0.5142 - val_loss: 0.5382
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5068
# Epoch 43: val_loss improved from 0.53825 to 0.53007, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 90ms/step - loss: 0.5068 - val_loss: 0.5301
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4986
# Epoch 44: val_loss improved from 0.53007 to 0.52138, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 89ms/step - loss: 0.4986 - val_loss: 0.5214
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4902
# Epoch 45: val_loss improved from 0.52138 to 0.51342, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 110ms/step - loss: 0.4902 - val_loss: 0.5134
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4827
# Epoch 46: val_loss improved from 0.51342 to 0.50720, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 89ms/step - loss: 0.4827 - val_loss: 0.5072
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4771
# Epoch 47: val_loss improved from 0.50720 to 0.50199, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 113ms/step - loss: 0.4771 - val_loss: 0.5020
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4724
# Epoch 48: val_loss improved from 0.50199 to 0.49561, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 106ms/step - loss: 0.4724 - val_loss: 0.4956
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4663
# Epoch 49: val_loss improved from 0.49561 to 0.48663, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 0.4663 - val_loss: 0.4866
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4572
# Epoch 50: val_loss improved from 0.48663 to 0.47707, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 99ms/step - loss: 0.4572 - val_loss: 0.4771
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4472
# Epoch 51: val_loss improved from 0.47707 to 0.46990, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 119ms/step - loss: 0.4472 - val_loss: 0.4699
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4396
# Epoch 52: val_loss improved from 0.46990 to 0.46185, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 111ms/step - loss: 0.4396 - val_loss: 0.4619
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4319
# Epoch 53: val_loss improved from 0.46185 to 0.45075, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 84ms/step - loss: 0.4319 - val_loss: 0.4507
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4218
# Epoch 54: val_loss improved from 0.45075 to 0.43830, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 85ms/step - loss: 0.4218 - val_loss: 0.4383
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4106
# Epoch 55: val_loss improved from 0.43830 to 0.42539, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 87ms/step - loss: 0.4106 - val_loss: 0.4254
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3986
# Epoch 56: val_loss improved from 0.42539 to 0.41316, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 88ms/step - loss: 0.3986 - val_loss: 0.4132
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3868
# Epoch 57: val_loss improved from 0.41316 to 0.40108, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 83ms/step - loss: 0.3868 - val_loss: 0.4011
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3755
# Epoch 58: val_loss improved from 0.40108 to 0.38549, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 98ms/step - loss: 0.3755 - val_loss: 0.3855
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3614
# Epoch 59: val_loss improved from 0.38549 to 0.36937, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 103ms/step - loss: 0.3614 - val_loss: 0.3694
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3468
# Epoch 60: val_loss improved from 0.36937 to 0.35399, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 101ms/step - loss: 0.3468 - val_loss: 0.3540
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3324
# Epoch 61: val_loss improved from 0.35399 to 0.34000, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 0.3324 - val_loss: 0.3400
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3192
# Epoch 62: val_loss improved from 0.34000 to 0.32393, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 93ms/step - loss: 0.3192 - val_loss: 0.3239
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3044
# Epoch 63: val_loss improved from 0.32393 to 0.30702, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 89ms/step - loss: 0.3044 - val_loss: 0.3070
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2888
# Epoch 64: val_loss improved from 0.30702 to 0.29083, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 84ms/step - loss: 0.2888 - val_loss: 0.2908
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2735
# Epoch 65: val_loss improved from 0.29083 to 0.27632, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 84ms/step - loss: 0.2735 - val_loss: 0.2763
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2600
# Epoch 66: val_loss improved from 0.27632 to 0.26111, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 98ms/step - loss: 0.2600 - val_loss: 0.2611
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2460
# Epoch 67: val_loss improved from 0.26111 to 0.24585, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 96ms/step - loss: 0.2460 - val_loss: 0.2458
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2321
# Epoch 68: val_loss improved from 0.24585 to 0.23130, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 112ms/step - loss: 0.2321 - val_loss: 0.2313
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2186
# Epoch 69: val_loss improved from 0.23130 to 0.21761, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 92ms/step - loss: 0.2186 - val_loss: 0.2176
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2062
# Epoch 70: val_loss improved from 0.21761 to 0.20496, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 113ms/step - loss: 0.2062 - val_loss: 0.2050
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1948
# Epoch 71: val_loss improved from 0.20496 to 0.19313, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 93ms/step - loss: 0.1948 - val_loss: 0.1931
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1838
# Epoch 72: val_loss improved from 0.19313 to 0.18204, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 90ms/step - loss: 0.1838 - val_loss: 0.1820
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1735
# Epoch 73: val_loss improved from 0.18204 to 0.17101, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 100ms/step - loss: 0.1735 - val_loss: 0.1710
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1637
# Epoch 74: val_loss improved from 0.17101 to 0.16095, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 111ms/step - loss: 0.1637 - val_loss: 0.1609
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1548
# Epoch 75: val_loss improved from 0.16095 to 0.15218, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 99ms/step - loss: 0.1548 - val_loss: 0.1522
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1465
# Epoch 76: val_loss improved from 0.15218 to 0.14415, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 111ms/step - loss: 0.1465 - val_loss: 0.1442
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1388
# Epoch 77: val_loss improved from 0.14415 to 0.13597, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 87ms/step - loss: 0.1388 - val_loss: 0.1360
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1315
# Epoch 78: val_loss improved from 0.13597 to 0.12829, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1315 - val_loss: 0.1283
# Epoch 79/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1248
# Epoch 79: val_loss improved from 0.12829 to 0.12173, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.1248 - val_loss: 0.1217
# Epoch 80/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1183
# Epoch 80: val_loss improved from 0.12173 to 0.11565, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.1183 - val_loss: 0.1156
# Epoch 81/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1123
# Epoch 81: val_loss improved from 0.11565 to 0.10898, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1123 - val_loss: 0.1090
# Epoch 82/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1065
# Epoch 82: val_loss improved from 0.10898 to 0.10304, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1065 - val_loss: 0.1030
# Epoch 83/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1010
# Epoch 83: val_loss improved from 0.10304 to 0.09793, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1010 - val_loss: 0.0979
# Epoch 84/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0959
# Epoch 84: val_loss improved from 0.09793 to 0.09217, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0959 - val_loss: 0.0922
# Epoch 85/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0908
# Epoch 85: val_loss improved from 0.09217 to 0.08705, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0908 - val_loss: 0.0870
# Epoch 86/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0860
# Epoch 86: val_loss improved from 0.08705 to 0.08227, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0860 - val_loss: 0.0823
# Epoch 87/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0813
# Epoch 87: val_loss improved from 0.08227 to 0.07718, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0813 - val_loss: 0.0772
# Epoch 88/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0767
# Epoch 88: val_loss improved from 0.07718 to 0.07270, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0767 - val_loss: 0.0727
# Epoch 89/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0722
# Epoch 89: val_loss improved from 0.07270 to 0.06837, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0722 - val_loss: 0.0684
# Epoch 90/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0682
# Epoch 90: val_loss improved from 0.06837 to 0.06443, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0682 - val_loss: 0.0644
# Epoch 91/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0645
# Epoch 91: val_loss improved from 0.06443 to 0.06022, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0645 - val_loss: 0.0602
# Epoch 92/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0609
# Epoch 92: val_loss improved from 0.06022 to 0.05693, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0609 - val_loss: 0.0569
# Epoch 93/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0574
# Epoch 93: val_loss improved from 0.05693 to 0.05330, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0574 - val_loss: 0.0533
# Epoch 94/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0540
# Epoch 94: val_loss improved from 0.05330 to 0.05018, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0540 - val_loss: 0.0502
# Epoch 95/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0508
# Epoch 95: val_loss improved from 0.05018 to 0.04724, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0508 - val_loss: 0.0472
# Epoch 96/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0479
# Epoch 96: val_loss improved from 0.04724 to 0.04401, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0479 - val_loss: 0.0440
# Epoch 97/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0450
# Epoch 97: val_loss improved from 0.04401 to 0.04111, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0450 - val_loss: 0.0411
# Epoch 98/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0422
# Epoch 98: val_loss improved from 0.04111 to 0.03776, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0422 - val_loss: 0.0378
# Epoch 99/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0397
# Epoch 99: val_loss improved from 0.03776 to 0.03710, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0397 - val_loss: 0.0371
# Epoch 100/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0384
# Epoch 100: val_loss did not improve from 0.03710
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0384 - val_loss: 0.0388
#
#  La media del mse, 0-fold es : 0.6208683954924346
#
#  La desviacion estandar del mse, 0-fold es : 0.5656224350659651
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 60)                15120
#
#  dense_6 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.7753
# Epoch 1: val_loss improved from inf to 1.41134, saving model to modelo-2.h5
# 2/2 [==============================] - 3s 554ms/step - loss: 1.8627 - val_loss: 1.4113
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9023
# Epoch 2: val_loss improved from 1.41134 to 1.40342, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 1.8527 - val_loss: 1.4034
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8761
# Epoch 3: val_loss improved from 1.40342 to 1.39525, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 1.8437 - val_loss: 1.3953
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8669
# Epoch 4: val_loss improved from 1.39525 to 1.38597, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 1.8346 - val_loss: 1.3860
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7107
# Epoch 5: val_loss improved from 1.38597 to 1.37491, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 1.8242 - val_loss: 1.3749
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8622
# Epoch 6: val_loss improved from 1.37491 to 1.36169, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 1.8122 - val_loss: 1.3617
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8478
# Epoch 7: val_loss improved from 1.36169 to 1.34545, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 1.7976 - val_loss: 1.3455
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8092
# Epoch 8: val_loss improved from 1.34545 to 1.32407, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 1.7798 - val_loss: 1.3241
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8041
# Epoch 9: val_loss improved from 1.32407 to 1.29475, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.7568 - val_loss: 1.2947
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7738
# Epoch 10: val_loss improved from 1.29475 to 1.25432, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.7253 - val_loss: 1.2543
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7140
# Epoch 11: val_loss improved from 1.25432 to 1.19639, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 1.6816 - val_loss: 1.1964
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6210
# Epoch 12: val_loss improved from 1.19639 to 1.11198, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 1.6187 - val_loss: 1.1120
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5597
# Epoch 13: val_loss improved from 1.11198 to 0.99147, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 1.5278 - val_loss: 0.9915
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4000
# Epoch 14: val_loss improved from 0.99147 to 0.83810, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.3938 - val_loss: 0.8381
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2514
# Epoch 15: val_loss improved from 0.83810 to 0.68334, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 1.2217 - val_loss: 0.6833
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0612
# Epoch 16: val_loss improved from 0.68334 to 0.56756, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 1.0355 - val_loss: 0.5676
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9061
# Epoch 17: val_loss improved from 0.56756 to 0.49812, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.8832 - val_loss: 0.4981
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7267
# Epoch 18: val_loss improved from 0.49812 to 0.46158, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.7755 - val_loss: 0.4616
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7347
# Epoch 19: val_loss improved from 0.46158 to 0.44573, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.7169 - val_loss: 0.4457
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6927
# Epoch 20: val_loss improved from 0.44573 to 0.42676, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.6780 - val_loss: 0.4268
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6490
# Epoch 21: val_loss improved from 0.42676 to 0.39728, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.6450 - val_loss: 0.3973
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6257
# Epoch 22: val_loss improved from 0.39728 to 0.36797, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6118 - val_loss: 0.3680
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6038
# Epoch 23: val_loss improved from 0.36797 to 0.34674, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5879 - val_loss: 0.3467
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5779
# Epoch 24: val_loss improved from 0.34674 to 0.33295, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.5738 - val_loss: 0.3330
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5767
# Epoch 25: val_loss improved from 0.33295 to 0.32784, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.5685 - val_loss: 0.3278
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5111
# Epoch 26: val_loss improved from 0.32784 to 0.31498, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.5755 - val_loss: 0.3150
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5676
# Epoch 27: val_loss improved from 0.31498 to 0.29779, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5572 - val_loss: 0.2978
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5309
# Epoch 28: val_loss improved from 0.29779 to 0.29156, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.5260 - val_loss: 0.2916
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5179
# Epoch 29: val_loss improved from 0.29156 to 0.28637, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5115 - val_loss: 0.2864
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5195
# Epoch 30: val_loss improved from 0.28637 to 0.27897, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5044 - val_loss: 0.2790
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5127
# Epoch 31: val_loss improved from 0.27897 to 0.27212, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.4978 - val_loss: 0.2721
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4719
# Epoch 32: val_loss improved from 0.27212 to 0.26316, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.4924 - val_loss: 0.2632
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4902
# Epoch 33: val_loss improved from 0.26316 to 0.25688, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.4770 - val_loss: 0.2569
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4098
# Epoch 34: val_loss did not improve from 0.25688
# 2/2 [==============================] - 0s 46ms/step - loss: 0.4579 - val_loss: 0.2596
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4281
# Epoch 35: val_loss did not improve from 0.25688
# 2/2 [==============================] - 0s 40ms/step - loss: 0.4459 - val_loss: 0.2946
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4641
# Epoch 36: val_loss did not improve from 0.25688
# 2/2 [==============================] - 0s 46ms/step - loss: 0.4655 - val_loss: 0.2833
#
#  La media del mse, 1-fold es : 1.0588965680864122
#
#  La desviacion estandar del mse, 1-fold es : 0.5672946718832259
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 60)                15120
#
#  dense_7 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 3s - loss: 1.6868
# Epoch 1: val_loss improved from inf to 1.64793, saving model to modelo-3.h5
# 2/2 [==============================] - 4s 871ms/step - loss: 1.8043 - val_loss: 1.6479
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8417
# Epoch 2: val_loss improved from 1.64793 to 1.63865, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 1.7939 - val_loss: 1.6386
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8330
# Epoch 3: val_loss improved from 1.63865 to 1.62859, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 1.7837 - val_loss: 1.6286
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6562
# Epoch 4: val_loss improved from 1.62859 to 1.61643, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 1.7724 - val_loss: 1.6164
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8077
# Epoch 5: val_loss improved from 1.61643 to 1.60125, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.7594 - val_loss: 1.6013
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7719
# Epoch 6: val_loss improved from 1.60125 to 1.58126, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 1.7426 - val_loss: 1.5813
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7516
# Epoch 7: val_loss improved from 1.58126 to 1.55302, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 1.7207 - val_loss: 1.5530
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7240
# Epoch 8: val_loss improved from 1.55302 to 1.51179, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 1.6896 - val_loss: 1.5118
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6718
# Epoch 9: val_loss improved from 1.51179 to 1.45022, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.6439 - val_loss: 1.4502
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4877
# Epoch 10: val_loss improved from 1.45022 to 1.36329, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.5739 - val_loss: 1.3633
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5084
# Epoch 11: val_loss improved from 1.36329 to 1.24307, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 92ms/step - loss: 1.4779 - val_loss: 1.2431
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3804
# Epoch 12: val_loss improved from 1.24307 to 1.09347, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 1.3420 - val_loss: 1.0935
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1086
# Epoch 13: val_loss improved from 1.09347 to 0.94508, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.1615 - val_loss: 0.9451
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0174
# Epoch 14: val_loss improved from 0.94508 to 0.83534, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.9909 - val_loss: 0.8353
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8750
# Epoch 15: val_loss improved from 0.83534 to 0.76321, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.8538 - val_loss: 0.7632
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7781
# Epoch 16: val_loss improved from 0.76321 to 0.71206, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.7617 - val_loss: 0.7121
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7146
# Epoch 17: val_loss improved from 0.71206 to 0.67063, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.6964 - val_loss: 0.6706
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6411
# Epoch 18: val_loss improved from 0.67063 to 0.63533, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.6442 - val_loss: 0.6353
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6063
# Epoch 19: val_loss improved from 0.63533 to 0.61039, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.5994 - val_loss: 0.6104
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5769
# Epoch 20: val_loss improved from 0.61039 to 0.59164, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.5626 - val_loss: 0.5916
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5531
# Epoch 21: val_loss improved from 0.59164 to 0.57656, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5384 - val_loss: 0.5766
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5279
# Epoch 22: val_loss improved from 0.57656 to 0.56431, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.5207 - val_loss: 0.5643
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5132
# Epoch 23: val_loss improved from 0.56431 to 0.55701, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5092 - val_loss: 0.5570
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5227
# Epoch 24: val_loss improved from 0.55701 to 0.55589, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.5076 - val_loss: 0.5559
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5274
# Epoch 25: val_loss improved from 0.55589 to 0.55515, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.5128 - val_loss: 0.5551
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5249
# Epoch 26: val_loss improved from 0.55515 to 0.55374, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.5161 - val_loss: 0.5537
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4805
# Epoch 27: val_loss improved from 0.55374 to 0.54193, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.5187 - val_loss: 0.5419
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5185
# Epoch 28: val_loss improved from 0.54193 to 0.53101, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 0.5032 - val_loss: 0.5310
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4961
# Epoch 29: val_loss did not improve from 0.53101
# 2/2 [==============================] - 0s 43ms/step - loss: 0.4820 - val_loss: 0.5322
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4633
# Epoch 30: val_loss did not improve from 0.53101
# 2/2 [==============================] - 0s 44ms/step - loss: 0.4732 - val_loss: 0.5400
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4844
# Epoch 31: val_loss did not improve from 0.53101
# 2/2 [==============================] - 0s 44ms/step - loss: 0.4724 - val_loss: 0.5495
#
#  La media del mse, 2-fold es : 1.0299744779063809
#
#  La desviacion estandar del mse, 2-fold es : 0.5402429865947114
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 60)                15120
#
#  dense_8 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.7926
# Epoch 1: val_loss improved from inf to 1.81969, saving model to modelo-4.h5
# 2/2 [==============================] - 3s 588ms/step - loss: 1.7616 - val_loss: 1.8197
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7806
# Epoch 2: val_loss improved from 1.81969 to 1.80995, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 1.7521 - val_loss: 1.8099
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7333
# Epoch 3: val_loss improved from 1.80995 to 1.79890, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 1.7426 - val_loss: 1.7989
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6421
# Epoch 4: val_loss improved from 1.79890 to 1.78584, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 1.7318 - val_loss: 1.7858
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7671
# Epoch 5: val_loss improved from 1.78584 to 1.77031, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.7194 - val_loss: 1.7703
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6401
# Epoch 6: val_loss improved from 1.77031 to 1.75035, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 1.7040 - val_loss: 1.7504
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7306
# Epoch 7: val_loss improved from 1.75035 to 1.72340, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 1.6850 - val_loss: 1.7234
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7042
# Epoch 8: val_loss improved from 1.72340 to 1.68580, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 1.6590 - val_loss: 1.6858
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6146
# Epoch 9: val_loss improved from 1.68580 to 1.63153, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 1.6221 - val_loss: 1.6315
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4737
# Epoch 10: val_loss improved from 1.63153 to 1.55289, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.5692 - val_loss: 1.5529
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3852
# Epoch 11: val_loss improved from 1.55289 to 1.44209, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 1.4931 - val_loss: 1.4421
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4317
# Epoch 12: val_loss improved from 1.44209 to 1.30118, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.3910 - val_loss: 1.3012
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1884
# Epoch 13: val_loss improved from 1.30118 to 1.13995, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 1.2529 - val_loss: 1.1400
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1340
# Epoch 14: val_loss improved from 1.13995 to 0.98434, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.1060 - val_loss: 0.9843
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9025
# Epoch 15: val_loss improved from 0.98434 to 0.85318, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.9557 - val_loss: 0.8532
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8613
# Epoch 16: val_loss improved from 0.85318 to 0.75803, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.8420 - val_loss: 0.7580
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7741
# Epoch 17: val_loss improved from 0.75803 to 0.68835, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.7542 - val_loss: 0.6884
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7095
# Epoch 18: val_loss improved from 0.68835 to 0.63208, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.6911 - val_loss: 0.6321
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6578
# Epoch 19: val_loss improved from 0.63208 to 0.58783, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6409 - val_loss: 0.5878
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5746
# Epoch 20: val_loss improved from 0.58783 to 0.55138, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5996 - val_loss: 0.5514
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5374
# Epoch 21: val_loss improved from 0.55138 to 0.52685, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 80ms/step - loss: 0.5674 - val_loss: 0.5269
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5269
# Epoch 22: val_loss improved from 0.52685 to 0.52414, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.5504 - val_loss: 0.5241
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5651
# Epoch 23: val_loss did not improve from 0.52414
# 2/2 [==============================] - 0s 48ms/step - loss: 0.5583 - val_loss: 0.5435
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6011
# Epoch 24: val_loss did not improve from 0.52414
# 2/2 [==============================] - 0s 41ms/step - loss: 0.5895 - val_loss: 0.5623
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6094
# Epoch 25: val_loss did not improve from 0.52414
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6127 - val_loss: 0.5736
#
#  La media del mse, 3-fold es : 1.1820596480369567
#
#  La desviacion estandar del mse, 3-fold es : 0.4848960683359718
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 60)                15120
#
#  dense_9 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 3s - loss: 1.6055
# Epoch 1: val_loss improved from inf to 2.10202, saving model to modelo-5.h5
# 2/2 [==============================] - 4s 769ms/step - loss: 1.6878 - val_loss: 2.1020
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7200
# Epoch 2: val_loss improved from 2.10202 to 2.08987, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 1.6772 - val_loss: 2.0899
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7090
# Epoch 3: val_loss improved from 2.08987 to 2.07663, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 82ms/step - loss: 1.6664 - val_loss: 2.0766
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6987
# Epoch 4: val_loss improved from 2.07663 to 2.06105, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 1.6542 - val_loss: 2.0610
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6698
# Epoch 5: val_loss improved from 2.06105 to 2.04124, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 87ms/step - loss: 1.6397 - val_loss: 2.0412
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6640
# Epoch 6: val_loss improved from 2.04124 to 2.01482, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 1.6212 - val_loss: 2.0148
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6413
# Epoch 7: val_loss improved from 2.01482 to 1.97894, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 84ms/step - loss: 1.5965 - val_loss: 1.9789
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4979
# Epoch 8: val_loss improved from 1.97894 to 1.92912, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 74ms/step - loss: 1.5621 - val_loss: 1.9291
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4279
# Epoch 9: val_loss improved from 1.92912 to 1.85771, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 1.5151 - val_loss: 1.8577
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4811
# Epoch 10: val_loss improved from 1.85771 to 1.75354, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 1.4501 - val_loss: 1.7535
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2462
# Epoch 11: val_loss improved from 1.75354 to 1.61067, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 1.3526 - val_loss: 1.6107
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1939
# Epoch 12: val_loss improved from 1.61067 to 1.43155, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 1.2264 - val_loss: 1.4315
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1108
# Epoch 13: val_loss improved from 1.43155 to 1.24948, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 1.0801 - val_loss: 1.2495
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9602
# Epoch 14: val_loss improved from 1.24948 to 1.10733, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.9349 - val_loss: 1.1073
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8462
# Epoch 15: val_loss improved from 1.10733 to 1.00419, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.8247 - val_loss: 1.0042
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7020
# Epoch 16: val_loss improved from 1.00419 to 0.91085, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.7411 - val_loss: 0.9108
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6363
# Epoch 17: val_loss improved from 0.91085 to 0.82086, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.6697 - val_loss: 0.8209
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5891
# Epoch 18: val_loss improved from 0.82086 to 0.74966, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6074 - val_loss: 0.7497
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5746
# Epoch 19: val_loss improved from 0.74966 to 0.70690, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5721 - val_loss: 0.7069
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5408
# Epoch 20: val_loss improved from 0.70690 to 0.67932, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.5499 - val_loss: 0.6793
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5431
# Epoch 21: val_loss improved from 0.67932 to 0.65931, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.5437 - val_loss: 0.6593
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5459
# Epoch 22: val_loss improved from 0.65931 to 0.64075, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5355 - val_loss: 0.6408
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5204
# Epoch 23: val_loss improved from 0.64075 to 0.62578, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.5196 - val_loss: 0.6258
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4891
# Epoch 24: val_loss improved from 0.62578 to 0.61773, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.5010 - val_loss: 0.6177
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4859
# Epoch 25: val_loss improved from 0.61773 to 0.61403, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.4876 - val_loss: 0.6140
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4775
# Epoch 26: val_loss did not improve from 0.61403
# 2/2 [==============================] - 0s 47ms/step - loss: 0.4795 - val_loss: 0.6198
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4885
# Epoch 27: val_loss did not improve from 0.61403
# 2/2 [==============================] - 0s 65ms/step - loss: 0.4752 - val_loss: 0.6351
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4916
# Epoch 28: val_loss did not improve from 0.61403
# 2/2 [==============================] - 0s 45ms/step - loss: 0.4777 - val_loss: 0.6507
#
#  La media del mse, 4-fold es : 1.023177603525775
#
#  La desviacion estandar del mse, 4-fold es : 0.48703917693624277

# %%
# rellenar de ceros los espacios vacios de la lista con loss y validation

df_train_losses = pd.DataFrame(train_losses)

df_filled_train_losses = df_train_losses.fillna(0)

train_losses_completa = df_filled_train_losses.values.tolist()

df_val_losses = pd.DataFrame(val_losses)

df_filled_val_losses = df_val_losses.fillna(0)

val_losses_completa = df_filled_val_losses.values.tolist()

# %%
# Calcular el promedio de "average loss" para todos los pliegues y épocas
avg_train_losses = np.mean(train_losses_completa, axis=0)
avg_val_losses = np.mean(val_losses_completa, axis=0)

# vamos a graficar
plt.plot(avg_train_losses, label='Perdida entrenamiento') # Grafico esta para ver si estoy sobre entrenando
plt.plot(avg_val_losses, label='Perdida Validacion') # Grafico esta para ver si estoy sobre entrenando
plt.title('avg loss train, avg loss val vs epoch ')
plt.xlabel('epoch')
plt.ylabel('Mean Square Error')
plt.legend()
plt.show()

# %%
# Cargar el mejor modelo
best_model = load_model(best_model_path)

# %%
# Seleccionar una secuencia específica
index = 0
input_sequence = X_test[index]

# Hacer la predicción
y_pred = best_model.predict(np.expand_dims(input_sequence, axis=0))
# usamos el np.expand_dims() para agregar una dimensión adicional al inicio de input_sequence
print(y_pred.shape)
# Out:
# 1/1 [==============================] - 0s 441ms/step
# (1, 210)

# %%
# Desenrollar X_test para convertirlo en un array bidimensional
X_test_flattened = X_test.reshape(-1, X_test.shape[-1])

# Aplicar la transformación inversa utilizando el objeto StandardScaler
X_test_desnormalizado = sc.inverse_transform(X_test_flattened)

# Volver a darle forma a X_test_desnormalizado a su forma original
X_test = X_test_desnormalizado.reshape(X_test.shape)

# Desnormalizar los datos
y_pred = sc_y.inverse_transform(y_pred)

y_test = sc_y.inverse_transform(y_test)

print(y_pred.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (1, 210)
# (17, 210)
# (17, 15, 2)

# %%
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
Curva=0

plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

print('')
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(X_test[Curva,:,0],color='orange', label='Valores actuales y anteriores de insulina')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_test[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 229.472625

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_pred[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 246.1017042160034

# %%
# Media MSE y desviacion estandar MSE de las prediciones con la escala normal
mse = mean_squared_error(y_test[0,:].flatten(), y_pred.flatten())
std = np.sqrt(mse)
mediamse = np.mean(mse)

print('La media MSE:',mediamse)
print('La desviacion standar MSE', std)

# calcular la MAE
mae = mean_absolute_error(y_test[0,:], y_pred[0,:])
print('MAE:', mae)

# calcular la RMSE
rmse = np.sqrt(mean_squared_error(y_test[0,:], y_pred[0,:]))
print('RMSE:', rmse)
# Out:
# La media MSE: 70.540891266466
# La desviacion standar MSE 8.39886249836643
# MAE: 6.26409009951637
# RMSE: 8.39886249836643
