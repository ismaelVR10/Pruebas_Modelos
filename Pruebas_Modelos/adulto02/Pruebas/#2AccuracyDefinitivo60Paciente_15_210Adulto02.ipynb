# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Librerias
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split, KFold
from keras.callbacks import EarlyStopping

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import load_model

from keras.initializers import he_uniform

from tensorflow.keras.optimizers import RMSprop

# %%
#Dataset Adulto 02
data = pd.read_csv('/content/gdrive/MyDrive/Proyecto_de_grado/SUSTENTACION3.0/FinalX3/adulto02/my_adult02A2_data.csv')

print(f"El archivo se ha cargado correctamente. Tiene {data.shape[0]} filas y {data.shape[1]} columnas.")
# Out:
# El archivo se ha cargado correctamente. Tiene 29638 filas y 3 columnas.

# %%
train_size = int(len(data) * 0.7)

train_data = data.iloc[:train_size, :] # 70% entrenamiento
test_data = data.iloc[train_size:, :] # 30% prueba

test_data = test_data.reset_index(drop=True)

# %%
#los indices donde hay ingestas
posicionestrain = train_data.loc[train_data.iloc[:, 0] != 0].index
posicionestest = test_data.loc[test_data.iloc[:, 0] != 0].index

df_posiciones_train = pd.DataFrame(posicionestrain)
df_posiciones_test = pd.DataFrame(posicionestest)

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_train = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_train)):
    anterior = df_posiciones_train.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_train.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_train.append(anterior)

ultimo_elemento_train = df_posiciones_train.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_train.extend(ultimo_elemento_train.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_train)
print(len(cumplen_train))
# Out:
# [494, 862, 1358, 1974, 2353, 2840, 3461, 3846, 4334, 4956, 5324, 5820, 6438, 6815, 7301, 7917, 8283, 8781, 9398, 9781, 10268, 10880, 11255, 11750, 12363, 12742, 13230, 13845, 14212, 14699, 15311, 15686, 16183, 16795, 17162, 17650, 18266, 18653, 19140, 19757, 20125, 20614]
# 42

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_test = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_test)):
    anterior = df_posiciones_test.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_test.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_test.append(anterior)

ultimo_elemento_test = df_posiciones_test.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_test.extend(ultimo_elemento_test.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_test)
print(len(cumplen_test))
# Out:
# [487, 855, 1342, 1956, 2335, 2823, 3439, 3805, 4301, 4916, 5291, 5779, 6398, 6765, 7253, 7868, 8234, 8720]
# 18

# %%
# pasar la escala de los carbohidratos de las ingestas a gramos
data.iloc[:,0] = data.iloc[:,0].apply(lambda x: (x*15)/1000)

# Grafica con mayor detalle, el pico del comportamiento de la glucosa despues de la primera ingesta
print('')
print('Grafica de los datos del dataset')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
plt.title('Ingestas, Insulina y Glucosa')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')

print('Caso 1: Primera ingesta o Desayuno del primer dia:')
plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 700])
plt.ylim([-5, 250])
plt.show()
print('')

print('Caso 2: Primera y segunda ingesta del primer dia:')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1200])
plt.ylim([-5, 500])
plt.show()


print('Caso 3: las tres ingestas del primer dia:')

plt.plot(data.index, data.iloc[:,0], color='blue', label='Ingestas')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Ingestas de carbohidratos')
plt.xlabel('t [min]')
plt.ylabel('gramos')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Dosificación de insulina')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
#plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1800])
plt.ylim([-5, 500])
plt.show()
# Out:
# Grafica de los datos del dataset
# Caso 1: Primera ingesta o Desayuno del primer dia:
# Caso 2: Primera y segunda ingesta del primer dia:
# Caso 3: las tres ingestas del primer dia:

# %%
#Preprocesar los datos:
X_train = train_data.iloc[:, 1:3].values
y_train = train_data.iloc[:,2].values

X_test = test_data.iloc[:, 1:3].values
y_test = test_data.iloc[:, 2].values

print('Tamaño de los datos de entrada, de X_train: ',X_train.shape)
print(f'Tiene {X_train.shape[0]} filas y {X_train.shape[1]} columna')
print('La primera ingesta al minuto 300, ingesta: ',X_train[300])
print('La primera ingesta hasta el minuto 327, ingesta: ',X_train[327])

print('La entrada son los valores de la insulina y glucosa \n',X_train)
print('Tamaño de los datos de salia, de y_train',y_train.shape)
print(f'Tiene {y_train.shape[0]} filas y {y_train.shape[-1]} columnas')
print('La salida son los valores de glucosa \n',y_train)
# Out:
# Tamaño de los datos de entrada, de X_train:  (20746, 2)
# Tiene 20746 filas y 2 columna
# La primera ingesta al minuto 300, ingesta:  [  1.6789 123.44  ]
# La primera ingesta hasta el minuto 327, ingesta:  [  1.6789 123.44  ]
# La entrada son los valores de la insulina y glucosa
#  [[  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  ...
#  [  1.6789 198.03  ]
#  [  1.6789 197.1   ]
#  [  1.6789 196.18  ]]
# Tamaño de los datos de salia, de y_train (20746,)
# Tiene 20746 filas y 20746 columnas
# La salida son los valores de glucosa
#  [123.44 123.44 123.44 ... 198.03 197.1  196.18]

# %%
# Normalizar los datos
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Normalizar y_train
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.reshape(-1, 1))
y_test = sc_y.transform(y_test.reshape(-1, 1))

# %%
# Reorganizar los datos en forma de secuencia
def to_sequences(data,  seq_size_input, seq_size_output):
    X = []
    y = []

    for i in range(len(data)-seq_size_input-seq_size_output+1):
        X.append(data[i:(i+seq_size_input), 0:2])
        y.append(data[(i+seq_size_input):(i+seq_size_input+seq_size_output), 2])

    return np.array(X), np.array(y)

# %%
#CON LOS DATOS NORMALIZADOS
seq_size_input = 15
seq_size_output = 210
X_train, y_train = to_sequences(np.hstack((X_train, y_train)), seq_size_input, seq_size_output)
X_test, y_test = to_sequences(np.hstack((X_test, y_test)), seq_size_input, seq_size_output)
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (20522, 210)
# (20522, 15, 2)
# (8668, 210)
# (8668, 15, 2)

# %%
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
flattened_data = np.reshape(X_train, (X_train.shape[0], -1))

df_X_train = pd.DataFrame(flattened_data)

# %%
flattened_test = np.reshape(X_test, (X_test.shape[0], -1))

df_X_test = pd.DataFrame(flattened_test)

# %%
df_y_train = pd.DataFrame(y_train)
df_y_test = pd.DataFrame(y_test)

# %%
# Filtrar el dataframe para mantener solo las filas especificadas
df_X_train_seleccionado = df_X_train[df_X_train.index.isin(cumplen_train)]
df_y_train_seleccionado = df_y_train[df_y_train.index.isin(cumplen_train)]
df_X_test_seleccionado = df_X_test[df_X_test.index.isin(cumplen_test)]
df_y_test_seleccionado = df_y_test[df_y_test.index.isin(cumplen_test)]

# %%
print('Grafica de los datos del dataset')
#plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')

Numerocurva = 0

plt.plot(df_X_train_seleccionado.iloc[Numerocurva, 1::2],color='green',label='Entrada glucosa') #Para mostrar solo la glucosa
plt.plot(df_X_train_seleccionado.iloc[Numerocurva, ::2],color='orange',label='Entrada insulina') #Para mostrar solo la glucosa
plt.plot(range(seq_size_input*2, seq_size_output + seq_size_input*2),df_y_train_seleccionado.iloc[Numerocurva,:], color='red',label='Salida glucosa')
plt.title('Entradas y salidas, entrenamiento')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')
# Out:
# Grafica de los datos del dataset

# %%
X_train = df_X_train_seleccionado.values
y_train = df_y_train_seleccionado.values
X_test = df_X_test_seleccionado.values
y_test = df_y_test_seleccionado.values

print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 30)
# (17, 210)
# (17, 30)

# %%
print(len(X_test))
# Out:
# 17

# %%
X_train = np.reshape(X_train, (len(X_train), seq_size_input, 2))

X_test = np.reshape(X_test, (len(X_test), seq_size_input, 2))
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 15, 2)
# (17, 210)
# (17, 15, 2)

# %%
kf = KFold(n_splits=5)
kf.get_n_splits(X_train)
KFold(n_splits=5, random_state=None, shuffle=False)


# Crear listas para almacenar los valores del "average loss" de entrenamiento y validación en cada pliegue
train_losses = []
val_losses = []

#Para guardar el mejor modelo
best_loss = float('inf')
best_model_path = ""

for i, (train_index, test_index) in enumerate(kf.split(X_train,y_train)):
  model = Sequential()
  model.add(LSTM(60, activation='tanh', input_shape=(seq_size_input, 2), kernel_initializer=he_uniform()))
  model.add(Dense(seq_size_output, activation='linear', kernel_initializer=he_uniform()))


  model.compile(optimizer=RMSprop(), loss='mse', metrics=['accuracy'])
  print(model.summary())

  filepath = f"modelo-{i+1}.h5"
  early_stop = EarlyStopping(monitor='val_loss', patience=3)
  checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

  X, y =  X_train[train_index], y_train[train_index]
  X_val, y_val = X_train[test_index], y_train[test_index]


  history = model.fit(X, y, epochs=100, batch_size=32,validation_data=(X_val, y_val),callbacks=[checkpoint, early_stop])

  mediamse = np.mean( history.history['loss'] )
  stdmse = np.std(  history.history['loss'])
  print('')
  print(f" La media del mse, {i}-fold es : {mediamse}")
  print('')
  print(f" La desviacion estandar del mse, {i}-fold es : {stdmse}")

  # Obtener los valores de "average loss" para el pliegue actual
  fold_train_losses = model.history.history['loss']
  fold_val_losses = model.history.history['val_loss']

  # Almacenar los valores de "average loss" para el pliegue actual
  train_losses.append(fold_train_losses)
  val_losses.append(fold_val_losses)

  if min(fold_val_losses) < best_loss:
        best_loss = min(fold_val_losses)
        best_model_path = filepath

  history.history.keys() # aqui me muestra que esta guardando, con history me guarda todos los valores que calcula durante el proceso de entrenamiento

  # vamos a graficar
  plt.plot(history.history['loss'], label='Perdida') # Grafico esta para ver si estoy sobre entrenando
  plt.plot(history.history['val_loss'], label='Validacion') # Grafico esta para ver si estoy sobre entrenando
  plt.xlabel('epoch')
  plt.ylabel('Mean Square Error')
  plt.legend()
  plt.show()

  print(' ')
  # Historial de precisión durante el entrenamiento y la evaluación
  accuracy_train = history.history['accuracy']  # Lista con la precisión durante el entrenamiento
  accuracy_test = history.history['val_accuracy']  # Lista con la precisión durante la evaluación

  # Crear gráfico de precisión
  plt.plot(accuracy_train, label='Precisión en entrenamiento')
  plt.plot(accuracy_test, label='Precisión en evaluación')
  plt.title('Precisión del modelo LSTM')
  plt.xlabel('Época')
  plt.ylabel('Precisión')
  plt.legend()
  plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60)                15120
#
#  dense (Dense)               (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8369 - accuracy: 0.0000e+00
# Epoch 1: val_loss improved from inf to 1.81754, saving model to modelo-1.h5
# 1/1 [==============================] - 6s 6s/step - loss: 1.8369 - accuracy: 0.0000e+00 - val_loss: 1.8175 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7360 - accuracy: 0.0938
# Epoch 2: val_loss improved from 1.81754 to 1.74786, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 189ms/step - loss: 1.7360 - accuracy: 0.0938 - val_loss: 1.7479 - val_accuracy: 0.1111
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6682 - accuracy: 0.0938
# Epoch 3: val_loss improved from 1.74786 to 1.68854, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 129ms/step - loss: 1.6682 - accuracy: 0.0938 - val_loss: 1.6885 - val_accuracy: 0.1111
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6107 - accuracy: 0.0938
# Epoch 4: val_loss improved from 1.68854 to 1.63370, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 132ms/step - loss: 1.6107 - accuracy: 0.0938 - val_loss: 1.6337 - val_accuracy: 0.1111
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5576 - accuracy: 0.0938
# Epoch 5: val_loss improved from 1.63370 to 1.58058, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 123ms/step - loss: 1.5576 - accuracy: 0.0938 - val_loss: 1.5806 - val_accuracy: 0.1111
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5062 - accuracy: 0.0938
# Epoch 6: val_loss improved from 1.58058 to 1.52756, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 99ms/step - loss: 1.5062 - accuracy: 0.0938 - val_loss: 1.5276 - val_accuracy: 0.1111
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4550 - accuracy: 0.0938
# Epoch 7: val_loss improved from 1.52756 to 1.47358, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 92ms/step - loss: 1.4550 - accuracy: 0.0938 - val_loss: 1.4736 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4029 - accuracy: 0.0000e+00
# Epoch 8: val_loss improved from 1.47358 to 1.41793, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 173ms/step - loss: 1.4029 - accuracy: 0.0000e+00 - val_loss: 1.4179 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3492 - accuracy: 0.0000e+00
# Epoch 9: val_loss improved from 1.41793 to 1.36016, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 367ms/step - loss: 1.3492 - accuracy: 0.0000e+00 - val_loss: 1.3602 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2935 - accuracy: 0.0000e+00
# Epoch 10: val_loss improved from 1.36016 to 1.30009, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 182ms/step - loss: 1.2935 - accuracy: 0.0000e+00 - val_loss: 1.3001 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2357 - accuracy: 0.0000e+00
# Epoch 11: val_loss improved from 1.30009 to 1.23780, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 175ms/step - loss: 1.2357 - accuracy: 0.0000e+00 - val_loss: 1.2378 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1758 - accuracy: 0.0000e+00
# Epoch 12: val_loss improved from 1.23780 to 1.17364, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 296ms/step - loss: 1.1758 - accuracy: 0.0000e+00 - val_loss: 1.1736 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1142 - accuracy: 0.0000e+00
# Epoch 13: val_loss improved from 1.17364 to 1.10819, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 314ms/step - loss: 1.1142 - accuracy: 0.0000e+00 - val_loss: 1.1082 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0515 - accuracy: 0.0000e+00
# Epoch 14: val_loss improved from 1.10819 to 1.04230, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 251ms/step - loss: 1.0515 - accuracy: 0.0000e+00 - val_loss: 1.0423 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9884 - accuracy: 0.0000e+00
# Epoch 15: val_loss improved from 1.04230 to 0.97691, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 376ms/step - loss: 0.9884 - accuracy: 0.0000e+00 - val_loss: 0.9769 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9259 - accuracy: 0.0000e+00
# Epoch 16: val_loss improved from 0.97691 to 0.91302, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 315ms/step - loss: 0.9259 - accuracy: 0.0000e+00 - val_loss: 0.9130 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8650 - accuracy: 0.0000e+00
# Epoch 17: val_loss improved from 0.91302 to 0.85148, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 232ms/step - loss: 0.8650 - accuracy: 0.0000e+00 - val_loss: 0.8515 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8063 - accuracy: 0.0000e+00
# Epoch 18: val_loss improved from 0.85148 to 0.79295, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 236ms/step - loss: 0.8063 - accuracy: 0.0000e+00 - val_loss: 0.7929 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7506 - accuracy: 0.0000e+00
# Epoch 19: val_loss improved from 0.79295 to 0.73782, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 245ms/step - loss: 0.7506 - accuracy: 0.0000e+00 - val_loss: 0.7378 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6983 - accuracy: 0.0000e+00
# Epoch 20: val_loss improved from 0.73782 to 0.68625, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 261ms/step - loss: 0.6983 - accuracy: 0.0000e+00 - val_loss: 0.6863 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6494 - accuracy: 0.0000e+00
# Epoch 21: val_loss improved from 0.68625 to 0.63820, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 211ms/step - loss: 0.6494 - accuracy: 0.0000e+00 - val_loss: 0.6382 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6038 - accuracy: 0.0000e+00
# Epoch 22: val_loss improved from 0.63820 to 0.59354, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 226ms/step - loss: 0.6038 - accuracy: 0.0000e+00 - val_loss: 0.5935 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5615 - accuracy: 0.0000e+00
# Epoch 23: val_loss improved from 0.59354 to 0.55209, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 221ms/step - loss: 0.5615 - accuracy: 0.0000e+00 - val_loss: 0.5521 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5223 - accuracy: 0.0000e+00
# Epoch 24: val_loss improved from 0.55209 to 0.51366, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 356ms/step - loss: 0.5223 - accuracy: 0.0000e+00 - val_loss: 0.5137 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4860 - accuracy: 0.0000e+00
# Epoch 25: val_loss improved from 0.51366 to 0.47805, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 246ms/step - loss: 0.4860 - accuracy: 0.0000e+00 - val_loss: 0.4781 - val_accuracy: 0.0000e+00
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4524 - accuracy: 0.0000e+00
# Epoch 26: val_loss improved from 0.47805 to 0.44509, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 186ms/step - loss: 0.4524 - accuracy: 0.0000e+00 - val_loss: 0.4451 - val_accuracy: 0.0000e+00
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4214 - accuracy: 0.0000e+00
# Epoch 27: val_loss improved from 0.44509 to 0.41457, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 135ms/step - loss: 0.4214 - accuracy: 0.0000e+00 - val_loss: 0.4146 - val_accuracy: 0.0000e+00
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3927 - accuracy: 0.0000e+00
# Epoch 28: val_loss improved from 0.41457 to 0.38634, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 250ms/step - loss: 0.3927 - accuracy: 0.0000e+00 - val_loss: 0.3863 - val_accuracy: 0.0000e+00
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3661 - accuracy: 0.0000e+00
# Epoch 29: val_loss improved from 0.38634 to 0.36021, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 188ms/step - loss: 0.3661 - accuracy: 0.0000e+00 - val_loss: 0.3602 - val_accuracy: 0.0000e+00
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3416 - accuracy: 0.0000e+00
# Epoch 30: val_loss improved from 0.36021 to 0.33603, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 228ms/step - loss: 0.3416 - accuracy: 0.0000e+00 - val_loss: 0.3360 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3190 - accuracy: 0.0000e+00
# Epoch 31: val_loss improved from 0.33603 to 0.31365, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 311ms/step - loss: 0.3190 - accuracy: 0.0000e+00 - val_loss: 0.3137 - val_accuracy: 0.0000e+00
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2981 - accuracy: 0.0000e+00
# Epoch 32: val_loss improved from 0.31365 to 0.29293, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 292ms/step - loss: 0.2981 - accuracy: 0.0000e+00 - val_loss: 0.2929 - val_accuracy: 0.0000e+00
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2787 - accuracy: 0.0000e+00
# Epoch 33: val_loss improved from 0.29293 to 0.27375, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 192ms/step - loss: 0.2787 - accuracy: 0.0000e+00 - val_loss: 0.2737 - val_accuracy: 0.0000e+00
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2608 - accuracy: 0.0000e+00
# Epoch 34: val_loss improved from 0.27375 to 0.25597, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 151ms/step - loss: 0.2608 - accuracy: 0.0000e+00 - val_loss: 0.2560 - val_accuracy: 0.0000e+00
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2443 - accuracy: 0.0000e+00
# Epoch 35: val_loss improved from 0.25597 to 0.23949, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 196ms/step - loss: 0.2443 - accuracy: 0.0000e+00 - val_loss: 0.2395 - val_accuracy: 0.0000e+00
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2290 - accuracy: 0.0000e+00
# Epoch 36: val_loss improved from 0.23949 to 0.22420, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 198ms/step - loss: 0.2290 - accuracy: 0.0000e+00 - val_loss: 0.2242 - val_accuracy: 0.0000e+00
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2148 - accuracy: 0.0000e+00
# Epoch 37: val_loss improved from 0.22420 to 0.21001, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 172ms/step - loss: 0.2148 - accuracy: 0.0000e+00 - val_loss: 0.2100 - val_accuracy: 0.0000e+00
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2016 - accuracy: 0.0000e+00
# Epoch 38: val_loss improved from 0.21001 to 0.19683, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 161ms/step - loss: 0.2016 - accuracy: 0.0000e+00 - val_loss: 0.1968 - val_accuracy: 0.0000e+00
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1894 - accuracy: 0.0000e+00
# Epoch 39: val_loss improved from 0.19683 to 0.18457, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 231ms/step - loss: 0.1894 - accuracy: 0.0000e+00 - val_loss: 0.1846 - val_accuracy: 0.0000e+00
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1780 - accuracy: 0.0000e+00
# Epoch 40: val_loss improved from 0.18457 to 0.17316, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 141ms/step - loss: 0.1780 - accuracy: 0.0000e+00 - val_loss: 0.1732 - val_accuracy: 0.0000e+00
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1674 - accuracy: 0.0000e+00
# Epoch 41: val_loss improved from 0.17316 to 0.16253, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 218ms/step - loss: 0.1674 - accuracy: 0.0000e+00 - val_loss: 0.1625 - val_accuracy: 0.0000e+00
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1576 - accuracy: 0.0000e+00
# Epoch 42: val_loss improved from 0.16253 to 0.15262, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 92ms/step - loss: 0.1576 - accuracy: 0.0000e+00 - val_loss: 0.1526 - val_accuracy: 0.0000e+00
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1484 - accuracy: 0.0000e+00
# Epoch 43: val_loss improved from 0.15262 to 0.14337, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.1484 - accuracy: 0.0000e+00 - val_loss: 0.1434 - val_accuracy: 0.0000e+00
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1398 - accuracy: 0.0000e+00
# Epoch 44: val_loss improved from 0.14337 to 0.13473, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 80ms/step - loss: 0.1398 - accuracy: 0.0000e+00 - val_loss: 0.1347 - val_accuracy: 0.0000e+00
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1317 - accuracy: 0.0000e+00
# Epoch 45: val_loss improved from 0.13473 to 0.12665, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 96ms/step - loss: 0.1317 - accuracy: 0.0000e+00 - val_loss: 0.1267 - val_accuracy: 0.0000e+00
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1242 - accuracy: 0.0000e+00
# Epoch 46: val_loss improved from 0.12665 to 0.11909, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1242 - accuracy: 0.0000e+00 - val_loss: 0.1191 - val_accuracy: 0.0000e+00
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.0000e+00
# Epoch 47: val_loss improved from 0.11909 to 0.11202, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 97ms/step - loss: 0.1172 - accuracy: 0.0000e+00 - val_loss: 0.1120 - val_accuracy: 0.0000e+00
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1106 - accuracy: 0.0312
# Epoch 48: val_loss improved from 0.11202 to 0.10538, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 93ms/step - loss: 0.1106 - accuracy: 0.0312 - val_loss: 0.1054 - val_accuracy: 0.0000e+00
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1044 - accuracy: 0.0312
# Epoch 49: val_loss improved from 0.10538 to 0.09917, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 99ms/step - loss: 0.1044 - accuracy: 0.0312 - val_loss: 0.0992 - val_accuracy: 0.1111
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0986 - accuracy: 0.0625
# Epoch 50: val_loss improved from 0.09917 to 0.09333, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0986 - accuracy: 0.0625 - val_loss: 0.0933 - val_accuracy: 0.1111
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0931 - accuracy: 0.0625
# Epoch 51: val_loss improved from 0.09333 to 0.08786, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0931 - accuracy: 0.0625 - val_loss: 0.0879 - val_accuracy: 0.1111
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0880 - accuracy: 0.1250
# Epoch 52: val_loss improved from 0.08786 to 0.08270, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0880 - accuracy: 0.1250 - val_loss: 0.0827 - val_accuracy: 0.1111
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.1562
# Epoch 53: val_loss improved from 0.08270 to 0.07795, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0831 - accuracy: 0.1562 - val_loss: 0.0780 - val_accuracy: 0.2222
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0786 - accuracy: 0.1562
# Epoch 54: val_loss improved from 0.07795 to 0.07322, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0786 - accuracy: 0.1562 - val_loss: 0.0732 - val_accuracy: 0.2222
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0743 - accuracy: 0.1562
# Epoch 55: val_loss improved from 0.07322 to 0.07041, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0743 - accuracy: 0.1562 - val_loss: 0.0704 - val_accuracy: 0.2222
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0709 - accuracy: 0.1562
# Epoch 56: val_loss improved from 0.07041 to 0.06774, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0709 - accuracy: 0.1562 - val_loss: 0.0677 - val_accuracy: 0.1111
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0708 - accuracy: 0.0625
# Epoch 57: val_loss did not improve from 0.06774
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0708 - accuracy: 0.0625 - val_loss: 0.0699 - val_accuracy: 0.2222
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0696 - accuracy: 0.1875
# Epoch 58: val_loss improved from 0.06774 to 0.06004, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0696 - accuracy: 0.1875 - val_loss: 0.0600 - val_accuracy: 0.2222
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0633 - accuracy: 0.1562
# Epoch 59: val_loss improved from 0.06004 to 0.05785, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0633 - accuracy: 0.1562 - val_loss: 0.0578 - val_accuracy: 0.2222
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0587 - accuracy: 0.1562
# Epoch 60: val_loss improved from 0.05785 to 0.05206, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0587 - accuracy: 0.1562 - val_loss: 0.0521 - val_accuracy: 0.2222
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0547 - accuracy: 0.1562
# Epoch 61: val_loss improved from 0.05206 to 0.05012, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0547 - accuracy: 0.1562 - val_loss: 0.0501 - val_accuracy: 0.2222
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0517 - accuracy: 0.1562
# Epoch 62: val_loss improved from 0.05012 to 0.04639, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0517 - accuracy: 0.1562 - val_loss: 0.0464 - val_accuracy: 0.2222
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0490 - accuracy: 0.1562
# Epoch 63: val_loss improved from 0.04639 to 0.04455, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0490 - accuracy: 0.1562 - val_loss: 0.0446 - val_accuracy: 0.2222
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0464 - accuracy: 0.1562
# Epoch 64: val_loss improved from 0.04455 to 0.04149, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0464 - accuracy: 0.1562 - val_loss: 0.0415 - val_accuracy: 0.2222
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0441 - accuracy: 0.1562
# Epoch 65: val_loss improved from 0.04149 to 0.03991, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0441 - accuracy: 0.1562 - val_loss: 0.0399 - val_accuracy: 0.2222
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0419 - accuracy: 0.1562
# Epoch 66: val_loss improved from 0.03991 to 0.03714, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0419 - accuracy: 0.1562 - val_loss: 0.0371 - val_accuracy: 0.2222
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0398 - accuracy: 0.1562
# Epoch 67: val_loss improved from 0.03714 to 0.03601, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0398 - accuracy: 0.1562 - val_loss: 0.0360 - val_accuracy: 0.2222
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0379 - accuracy: 0.1562
# Epoch 68: val_loss improved from 0.03601 to 0.03332, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0379 - accuracy: 0.1562 - val_loss: 0.0333 - val_accuracy: 0.2222
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0362 - accuracy: 0.1562
# Epoch 69: val_loss improved from 0.03332 to 0.03313, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0362 - accuracy: 0.1562 - val_loss: 0.0331 - val_accuracy: 0.2222
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.0938
# Epoch 70: val_loss improved from 0.03313 to 0.03040, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0348 - accuracy: 0.0938 - val_loss: 0.0304 - val_accuracy: 0.2222
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0337 - accuracy: 0.0938
# Epoch 71: val_loss did not improve from 0.03040
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0337 - accuracy: 0.0938 - val_loss: 0.0318 - val_accuracy: 0.1111
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.0312
# Epoch 72: val_loss improved from 0.03040 to 0.02849, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0331 - accuracy: 0.0312 - val_loss: 0.0285 - val_accuracy: 0.2222
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0323 - accuracy: 0.0625
# Epoch 73: val_loss did not improve from 0.02849
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0323 - accuracy: 0.0625 - val_loss: 0.0299 - val_accuracy: 0.0000e+00
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0311 - accuracy: 0.0000e+00
# Epoch 74: val_loss improved from 0.02849 to 0.02552, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0311 - accuracy: 0.0000e+00 - val_loss: 0.0255 - val_accuracy: 0.2222
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 0.0625
# Epoch 75: val_loss did not improve from 0.02552
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0291 - accuracy: 0.0625 - val_loss: 0.0260 - val_accuracy: 0.0000e+00
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.0000e+00
# Epoch 76: val_loss improved from 0.02552 to 0.02255, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0274 - accuracy: 0.0000e+00 - val_loss: 0.0226 - val_accuracy: 0.2222
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.0625
# Epoch 77: val_loss did not improve from 0.02255
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0257 - accuracy: 0.0625 - val_loss: 0.0228 - val_accuracy: 0.1111
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0244 - accuracy: 0.0000e+00
# Epoch 78: val_loss improved from 0.02255 to 0.02031, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0244 - accuracy: 0.0000e+00 - val_loss: 0.0203 - val_accuracy: 0.1111
# Epoch 79/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.0625
# Epoch 79: val_loss did not improve from 0.02031
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0232 - accuracy: 0.0625 - val_loss: 0.0206 - val_accuracy: 0.2222
# Epoch 80/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.0625
# Epoch 80: val_loss improved from 0.02031 to 0.01852, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0222 - accuracy: 0.0625 - val_loss: 0.0185 - val_accuracy: 0.1111
# Epoch 81/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.0312
# Epoch 81: val_loss did not improve from 0.01852
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0213 - accuracy: 0.0312 - val_loss: 0.0190 - val_accuracy: 0.0000e+00
# Epoch 82/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.0625
# Epoch 82: val_loss improved from 0.01852 to 0.01714, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0205 - accuracy: 0.0625 - val_loss: 0.0171 - val_accuracy: 0.1111
# Epoch 83/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.0312
# Epoch 83: val_loss did not improve from 0.01714
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0199 - accuracy: 0.0312 - val_loss: 0.0181 - val_accuracy: 0.0000e+00
# Epoch 84/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.0000e+00
# Epoch 84: val_loss improved from 0.01714 to 0.01621, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0194 - accuracy: 0.0000e+00 - val_loss: 0.0162 - val_accuracy: 0.1111
# Epoch 85/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0190 - accuracy: 0.0312
# Epoch 85: val_loss did not improve from 0.01621
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0190 - accuracy: 0.0312 - val_loss: 0.0176 - val_accuracy: 0.0000e+00
# Epoch 86/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.0000e+00
# Epoch 86: val_loss improved from 0.01621 to 0.01550, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0188 - accuracy: 0.0000e+00 - val_loss: 0.0155 - val_accuracy: 0.1111
# Epoch 87/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.0312
# Epoch 87: val_loss did not improve from 0.01550
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0184 - accuracy: 0.0312 - val_loss: 0.0168 - val_accuracy: 0.0000e+00
# Epoch 88/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.0000e+00
# Epoch 88: val_loss improved from 0.01550 to 0.01443, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0179 - accuracy: 0.0000e+00 - val_loss: 0.0144 - val_accuracy: 0.1111
# Epoch 89/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 0.0000e+00
# Epoch 89: val_loss did not improve from 0.01443
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0172 - accuracy: 0.0000e+00 - val_loss: 0.0153 - val_accuracy: 0.0000e+00
# Epoch 90/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.0000e+00
# Epoch 90: val_loss improved from 0.01443 to 0.01320, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0165 - accuracy: 0.0000e+00 - val_loss: 0.0132 - val_accuracy: 0.1111
# Epoch 91/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.0000e+00
# Epoch 91: val_loss did not improve from 0.01320
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0157 - accuracy: 0.0000e+00 - val_loss: 0.0139 - val_accuracy: 0.0000e+00
# Epoch 92/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 0.0000e+00
# Epoch 92: val_loss improved from 0.01320 to 0.01220, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0151 - accuracy: 0.0000e+00 - val_loss: 0.0122 - val_accuracy: 0.1111
# Epoch 93/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.0000e+00
# Epoch 93: val_loss did not improve from 0.01220
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0145 - accuracy: 0.0000e+00 - val_loss: 0.0129 - val_accuracy: 0.0000e+00
# Epoch 94/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.0000e+00
# Epoch 94: val_loss improved from 0.01220 to 0.01148, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0141 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 0.1111
# Epoch 95/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.0000e+00
# Epoch 95: val_loss did not improve from 0.01148
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0137 - accuracy: 0.0000e+00 - val_loss: 0.0123 - val_accuracy: 0.0000e+00
# Epoch 96/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.0000e+00
# Epoch 96: val_loss improved from 0.01148 to 0.01103, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0134 - accuracy: 0.0000e+00 - val_loss: 0.0110 - val_accuracy: 0.1111
# Epoch 97/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.0000e+00
# Epoch 97: val_loss did not improve from 0.01103
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0132 - accuracy: 0.0000e+00 - val_loss: 0.0120 - val_accuracy: 0.0000e+00
# Epoch 98/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.0000e+00
# Epoch 98: val_loss improved from 0.01103 to 0.01078, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0131 - accuracy: 0.0000e+00 - val_loss: 0.0108 - val_accuracy: 0.1111
# Epoch 99/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.0000e+00
# Epoch 99: val_loss did not improve from 0.01078
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0129 - accuracy: 0.0000e+00 - val_loss: 0.0118 - val_accuracy: 0.0000e+00
# Epoch 100/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.0000e+00
# Epoch 100: val_loss improved from 0.01078 to 0.01054, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0128 - accuracy: 0.0000e+00 - val_loss: 0.0105 - val_accuracy: 0.1111
#
#  La media del mse, 0-fold es : 0.35335318848490715
#
#  La desviacion estandar del mse, 0-fold es : 0.49354335680454736
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 60)                15120
#
#  dense_1 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 2.0046 - accuracy: 0.0000e+00
# Epoch 1: val_loss improved from inf to 1.40707, saving model to modelo-2.h5
# 2/2 [==============================] - 3s 625ms/step - loss: 1.9703 - accuracy: 0.0000e+00 - val_loss: 1.4071 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8084 - accuracy: 0.0000e+00
# Epoch 2: val_loss improved from 1.40707 to 1.31730, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 1.8455 - accuracy: 0.0000e+00 - val_loss: 1.3173 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7758 - accuracy: 0.0000e+00
# Epoch 3: val_loss improved from 1.31730 to 1.25329, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 1.7411 - accuracy: 0.0000e+00 - val_loss: 1.2533 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7183 - accuracy: 0.0000e+00
# Epoch 4: val_loss improved from 1.25329 to 1.19875, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 84ms/step - loss: 1.6750 - accuracy: 0.0000e+00 - val_loss: 1.1988 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5274 - accuracy: 0.0000e+00
# Epoch 5: val_loss improved from 1.19875 to 1.09358, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 77ms/step - loss: 1.6138 - accuracy: 0.0000e+00 - val_loss: 1.0936 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5166 - accuracy: 0.0000e+00
# Epoch 6: val_loss improved from 1.09358 to 1.02049, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 1.4886 - accuracy: 0.0000e+00 - val_loss: 1.0205 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4487 - accuracy: 0.0000e+00
# Epoch 7: val_loss improved from 1.02049 to 0.96788, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 1.4107 - accuracy: 0.0000e+00 - val_loss: 0.9679 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3777 - accuracy: 0.0000e+00
# Epoch 8: val_loss improved from 0.96788 to 0.88584, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.3506 - accuracy: 0.0000e+00 - val_loss: 0.8858 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2857 - accuracy: 0.0000e+00
# Epoch 9: val_loss improved from 0.88584 to 0.80869, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 1.2579 - accuracy: 0.0000e+00 - val_loss: 0.8087 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2002 - accuracy: 0.0000e+00
# Epoch 10: val_loss improved from 0.80869 to 0.75604, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.1687 - accuracy: 0.0000e+00 - val_loss: 0.7560 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0739 - accuracy: 0.0000e+00
# Epoch 11: val_loss improved from 0.75604 to 0.63873, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 1.1009 - accuracy: 0.0000e+00 - val_loss: 0.6387 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9707 - accuracy: 0.0000e+00
# Epoch 12: val_loss improved from 0.63873 to 0.59013, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.9482 - accuracy: 0.0000e+00 - val_loss: 0.5901 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9134 - accuracy: 0.0000e+00
# Epoch 13: val_loss improved from 0.59013 to 0.54201, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.8931 - accuracy: 0.0000e+00 - val_loss: 0.5420 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8568 - accuracy: 0.0000e+00
# Epoch 14: val_loss improved from 0.54201 to 0.51266, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.8355 - accuracy: 0.0000e+00 - val_loss: 0.5127 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7633 - accuracy: 0.0000e+00
# Epoch 15: val_loss improved from 0.51266 to 0.43386, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 0.7955 - accuracy: 0.0000e+00 - val_loss: 0.4339 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6980 - accuracy: 0.0000e+00
# Epoch 16: val_loss improved from 0.43386 to 0.40193, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6808 - accuracy: 0.0000e+00 - val_loss: 0.4019 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6169 - accuracy: 0.0000e+00
# Epoch 17: val_loss improved from 0.40193 to 0.35390, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.6449 - accuracy: 0.0000e+00 - val_loss: 0.3539 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5090 - accuracy: 0.0000e+00
# Epoch 18: val_loss improved from 0.35390 to 0.32741, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.5671 - accuracy: 0.0000e+00 - val_loss: 0.3274 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5230 - accuracy: 0.0000e+00
# Epoch 19: val_loss improved from 0.32741 to 0.28016, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.5107 - accuracy: 0.0000e+00 - val_loss: 0.2802 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4753 - accuracy: 0.0000e+00
# Epoch 20: val_loss improved from 0.28016 to 0.26509, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.4640 - accuracy: 0.0000e+00 - val_loss: 0.2651 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4554 - accuracy: 0.0938
# Epoch 21: val_loss improved from 0.26509 to 0.25552, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.4454 - accuracy: 0.1212 - val_loss: 0.2555 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4441 - accuracy: 0.0000e+00
# Epoch 22: val_loss improved from 0.25552 to 0.23498, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.4331 - accuracy: 0.0000e+00 - val_loss: 0.2350 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4173 - accuracy: 0.0000e+00
# Epoch 23: val_loss improved from 0.23498 to 0.21890, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4072 - accuracy: 0.0000e+00 - val_loss: 0.2189 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3956 - accuracy: 0.0000e+00
# Epoch 24: val_loss improved from 0.21890 to 0.21170, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.3860 - accuracy: 0.0000e+00 - val_loss: 0.2117 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3589 - accuracy: 0.0000e+00
# Epoch 25: val_loss improved from 0.21170 to 0.17758, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.3715 - accuracy: 0.0000e+00 - val_loss: 0.1776 - val_accuracy: 0.0000e+00
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3206 - accuracy: 0.0938
# Epoch 26: val_loss improved from 0.17758 to 0.16083, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.3134 - accuracy: 0.0909 - val_loss: 0.1608 - val_accuracy: 0.0000e+00
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2990 - accuracy: 0.1562
# Epoch 27: val_loss improved from 0.16083 to 0.15087, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.2920 - accuracy: 0.1515 - val_loss: 0.1509 - val_accuracy: 0.0000e+00
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2835 - accuracy: 0.1250
# Epoch 28: val_loss did not improve from 0.15087
# 2/2 [==============================] - 0s 46ms/step - loss: 0.2770 - accuracy: 0.1515 - val_loss: 0.1565 - val_accuracy: 0.0000e+00
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2586 - accuracy: 0.0312
# Epoch 29: val_loss improved from 0.15087 to 0.13487, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.2788 - accuracy: 0.0303 - val_loss: 0.1349 - val_accuracy: 0.0000e+00
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2279 - accuracy: 0.1562
# Epoch 30: val_loss improved from 0.13487 to 0.12436, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.2226 - accuracy: 0.1515 - val_loss: 0.1244 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2217 - accuracy: 0.0000e+00
# Epoch 31: val_loss improved from 0.12436 to 0.11239, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 88ms/step - loss: 0.2163 - accuracy: 0.0000e+00 - val_loss: 0.1124 - val_accuracy: 0.0000e+00
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2042 - accuracy: 0.0000e+00
# Epoch 32: val_loss improved from 0.11239 to 0.10074, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1999 - accuracy: 0.0000e+00 - val_loss: 0.1007 - val_accuracy: 0.0000e+00
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1858 - accuracy: 0.1250
# Epoch 33: val_loss improved from 0.10074 to 0.09456, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 89ms/step - loss: 0.1810 - accuracy: 0.1212 - val_loss: 0.0946 - val_accuracy: 0.0000e+00
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1758 - accuracy: 0.0938
# Epoch 34: val_loss did not improve from 0.09456
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1716 - accuracy: 0.1212 - val_loss: 0.0980 - val_accuracy: 0.0000e+00
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1674 - accuracy: 0.0000e+00
# Epoch 35: val_loss improved from 0.09456 to 0.09281, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1755 - accuracy: 0.0000e+00 - val_loss: 0.0928 - val_accuracy: 0.0000e+00
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1369 - accuracy: 0.1250
# Epoch 36: val_loss improved from 0.09281 to 0.06999, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1368 - accuracy: 0.1515 - val_loss: 0.0700 - val_accuracy: 0.0000e+00
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1260 - accuracy: 0.0625
# Epoch 37: val_loss improved from 0.06999 to 0.06780, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1238 - accuracy: 0.0606 - val_loss: 0.0678 - val_accuracy: 0.0000e+00
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1163 - accuracy: 0.1250
# Epoch 38: val_loss improved from 0.06780 to 0.06576, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 0.1139 - accuracy: 0.1212 - val_loss: 0.0658 - val_accuracy: 0.0000e+00
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1106 - accuracy: 0.1562
# Epoch 39: val_loss improved from 0.06576 to 0.06198, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1080 - accuracy: 0.1818 - val_loss: 0.0620 - val_accuracy: 0.0000e+00
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1140 - accuracy: 0.0000e+00
# Epoch 40: val_loss improved from 0.06198 to 0.05889, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.1111 - accuracy: 0.0000e+00 - val_loss: 0.0589 - val_accuracy: 0.0000e+00
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1073 - accuracy: 0.0000e+00
# Epoch 41: val_loss improved from 0.05889 to 0.05430, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1051 - accuracy: 0.0000e+00 - val_loss: 0.0543 - val_accuracy: 0.0000e+00
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0832 - accuracy: 0.1250
# Epoch 42: val_loss did not improve from 0.05430
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0873 - accuracy: 0.1212 - val_loss: 0.0749 - val_accuracy: 0.0000e+00
# Epoch 43/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0788 - accuracy: 0.1875
# Epoch 43: val_loss did not improve from 0.05430
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0796 - accuracy: 0.1818 - val_loss: 0.0570 - val_accuracy: 0.0000e+00
# Epoch 44/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0607 - accuracy: 0.0625
# Epoch 44: val_loss did not improve from 0.05430
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0623 - accuracy: 0.0606 - val_loss: 0.0787 - val_accuracy: 0.0000e+00
#
#  La media del mse, 1-fold es : 0.6423229798674583
#
#  La desviacion estandar del mse, 1-fold es : 0.5636132088160011
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 60)                15120
#
#  dense_2 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.8963 - accuracy: 0.0000e+00
# Epoch 1: val_loss improved from inf to 1.66745, saving model to modelo-3.h5
# 2/2 [==============================] - 4s 969ms/step - loss: 1.9278 - accuracy: 0.0000e+00 - val_loss: 1.6675 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8413 - accuracy: 0.0000e+00
# Epoch 2: val_loss improved from 1.66745 to 1.60531, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 1.7951 - accuracy: 0.0000e+00 - val_loss: 1.6053 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7691 - accuracy: 0.0000e+00
# Epoch 3: val_loss improved from 1.60531 to 1.55170, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 106ms/step - loss: 1.7359 - accuracy: 0.0000e+00 - val_loss: 1.5517 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6471 - accuracy: 0.0000e+00
# Epoch 4: val_loss improved from 1.55170 to 1.47257, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 1.6771 - accuracy: 0.0000e+00 - val_loss: 1.4726 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6260 - accuracy: 0.0000e+00
# Epoch 5: val_loss improved from 1.47257 to 1.42146, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 109ms/step - loss: 1.5850 - accuracy: 0.0000e+00 - val_loss: 1.4215 - val_accuracy: 0.0000e+00
# Epoch 6/100
# ...
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.9146 - accuracy: 0.0000e+00
# Epoch 1: val_loss improved from inf to 2.21636, saving model to modelo-5.h5
# 2/2 [==============================] - 3s 620ms/step - loss: 1.8680 - accuracy: 0.0000e+00 - val_loss: 2.2164 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8061 - accuracy: 0.0000e+00
# Epoch 2: val_loss improved from 2.21636 to 2.14702, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 93ms/step - loss: 1.7604 - accuracy: 0.0000e+00 - val_loss: 2.1470 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7277 - accuracy: 0.0000e+00
# Epoch 3: val_loss improved from 2.14702 to 2.06725, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 93ms/step - loss: 1.6969 - accuracy: 0.0000e+00 - val_loss: 2.0672 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5024 - accuracy: 0.0000e+00
# Epoch 4: val_loss improved from 2.06725 to 1.93427, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 89ms/step - loss: 1.6216 - accuracy: 0.0000e+00 - val_loss: 1.9343 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5503 - accuracy: 0.0000e+00
# Epoch 5: val_loss improved from 1.93427 to 1.87459, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 1.5185 - accuracy: 0.0000e+00 - val_loss: 1.8746 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5013 - accuracy: 0.0000e+00
# Epoch 6: val_loss improved from 1.87459 to 1.82255, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 85ms/step - loss: 1.4624 - accuracy: 0.0000e+00 - val_loss: 1.8226 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4459 - accuracy: 0.0000e+00
# Epoch 7: val_loss improved from 1.82255 to 1.74568, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 116ms/step - loss: 1.4146 - accuracy: 0.0000e+00 - val_loss: 1.7457 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3070 - accuracy: 0.0000e+00
# Epoch 8: val_loss improved from 1.74568 to 1.57795, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 130ms/step - loss: 1.3431 - accuracy: 0.0000e+00 - val_loss: 1.5780 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1102 - accuracy: 0.0000e+00
# Epoch 9: val_loss improved from 1.57795 to 1.39842, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 120ms/step - loss: 1.2076 - accuracy: 0.0000e+00 - val_loss: 1.3984 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0728 - accuracy: 0.0000e+00
# Epoch 10: val_loss improved from 1.39842 to 1.29054, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 124ms/step - loss: 1.0729 - accuracy: 0.0000e+00 - val_loss: 1.2905 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0106 - accuracy: 0.0000e+00
# Epoch 11: val_loss improved from 1.29054 to 1.24337, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 0.9855 - accuracy: 0.0000e+00 - val_loss: 1.2434 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9636 - accuracy: 0.0000e+00
# Epoch 12: val_loss improved from 1.24337 to 1.17872, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 127ms/step - loss: 0.9414 - accuracy: 0.0000e+00 - val_loss: 1.1787 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9083 - accuracy: 0.0000e+00
# Epoch 13: val_loss improved from 1.17872 to 1.11310, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 124ms/step - loss: 0.8868 - accuracy: 0.0000e+00 - val_loss: 1.1131 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8551 - accuracy: 0.0000e+00
# Epoch 14: val_loss improved from 1.11310 to 1.06671, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 129ms/step - loss: 0.8331 - accuracy: 0.0000e+00 - val_loss: 1.0667 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7483 - accuracy: 0.0000e+00
# Epoch 15: val_loss improved from 1.06671 to 0.89916, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 116ms/step - loss: 0.7906 - accuracy: 0.0000e+00 - val_loss: 0.8992 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6921 - accuracy: 0.0000e+00
# Epoch 16: val_loss improved from 0.89916 to 0.87134, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 139ms/step - loss: 0.6754 - accuracy: 0.0000e+00 - val_loss: 0.8713 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5848 - accuracy: 0.0000e+00
# Epoch 17: val_loss improved from 0.87134 to 0.74485, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 0.6441 - accuracy: 0.0000e+00 - val_loss: 0.7448 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5539 - accuracy: 0.0000e+00
# Epoch 18: val_loss improved from 0.74485 to 0.68067, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 115ms/step - loss: 0.5633 - accuracy: 0.0000e+00 - val_loss: 0.6807 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5251 - accuracy: 0.0000e+00
# Epoch 19: val_loss improved from 0.68067 to 0.63812, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 135ms/step - loss: 0.5182 - accuracy: 0.0000e+00 - val_loss: 0.6381 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4930 - accuracy: 0.0000e+00
# Epoch 20: val_loss improved from 0.63812 to 0.61495, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 115ms/step - loss: 0.4812 - accuracy: 0.0000e+00 - val_loss: 0.6150 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4434 - accuracy: 0.0000e+00
# Epoch 21: val_loss improved from 0.61495 to 0.54792, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 111ms/step - loss: 0.4546 - accuracy: 0.0000e+00 - val_loss: 0.5479 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4265 - accuracy: 0.0000e+00
# Epoch 22: val_loss improved from 0.54792 to 0.53259, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 0.4166 - accuracy: 0.0000e+00 - val_loss: 0.5326 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4011 - accuracy: 0.0000e+00
# Epoch 23: val_loss improved from 0.53259 to 0.51126, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 123ms/step - loss: 0.3928 - accuracy: 0.0000e+00 - val_loss: 0.5113 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3785 - accuracy: 0.0000e+00
# Epoch 24: val_loss improved from 0.51126 to 0.46614, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 106ms/step - loss: 0.3735 - accuracy: 0.0000e+00 - val_loss: 0.4661 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3088 - accuracy: 0.0000e+00
# Epoch 25: val_loss improved from 0.46614 to 0.39910, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 119ms/step - loss: 0.3423 - accuracy: 0.0000e+00 - val_loss: 0.3991 - val_accuracy: 0.0000e+00
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3120 - accuracy: 0.0000e+00
# Epoch 26: val_loss improved from 0.39910 to 0.35559, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 129ms/step - loss: 0.3154 - accuracy: 0.0000e+00 - val_loss: 0.3556 - val_accuracy: 0.0000e+00
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2854 - accuracy: 0.0000e+00
# Epoch 27: val_loss improved from 0.35559 to 0.33233, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 126ms/step - loss: 0.2803 - accuracy: 0.0000e+00 - val_loss: 0.3323 - val_accuracy: 0.0000e+00
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2538 - accuracy: 0.0000e+00
# Epoch 28: val_loss improved from 0.33233 to 0.32005, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 116ms/step - loss: 0.2496 - accuracy: 0.0000e+00 - val_loss: 0.3200 - val_accuracy: 0.0000e+00
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2130 - accuracy: 0.0000e+00
# Epoch 29: val_loss improved from 0.32005 to 0.27227, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 113ms/step - loss: 0.2367 - accuracy: 0.0000e+00 - val_loss: 0.2723 - val_accuracy: 0.0000e+00
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2145 - accuracy: 0.0000e+00
# Epoch 30: val_loss improved from 0.27227 to 0.23163, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 108ms/step - loss: 0.2234 - accuracy: 0.0000e+00 - val_loss: 0.2316 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1957 - accuracy: 0.0000e+00
# Epoch 31: val_loss improved from 0.23163 to 0.21468, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 119ms/step - loss: 0.1925 - accuracy: 0.0000e+00 - val_loss: 0.2147 - val_accuracy: 0.0000e+00
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1745 - accuracy: 0.0000e+00
# Epoch 32: val_loss improved from 0.21468 to 0.20772, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 0.1702 - accuracy: 0.0000e+00 - val_loss: 0.2077 - val_accuracy: 0.0000e+00
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1650 - accuracy: 0.0000e+00
# Epoch 33: val_loss improved from 0.20772 to 0.19728, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 107ms/step - loss: 0.1624 - accuracy: 0.0000e+00 - val_loss: 0.1973 - val_accuracy: 0.0000e+00
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1580 - accuracy: 0.0000e+00
# Epoch 34: val_loss improved from 0.19728 to 0.19095, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 0.1542 - accuracy: 0.0000e+00 - val_loss: 0.1910 - val_accuracy: 0.0000e+00
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1516 - accuracy: 0.0000e+00
# Epoch 35: val_loss did not improve from 0.19095
# 2/2 [==============================] - 0s 74ms/step - loss: 0.1479 - accuracy: 0.0000e+00 - val_loss: 0.2017 - val_accuracy: 0.0000e+00
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1486 - accuracy: 0.0000e+00
# Epoch 36: val_loss improved from 0.19095 to 0.15273, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 0.1549 - accuracy: 0.0000e+00 - val_loss: 0.1527 - val_accuracy: 0.0000e+00
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1361 - accuracy: 0.0000e+00
# Epoch 37: val_loss improved from 0.15273 to 0.13831, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 116ms/step - loss: 0.1344 - accuracy: 0.0000e+00 - val_loss: 0.1383 - val_accuracy: 0.0000e+00
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1152 - accuracy: 0.0000e+00
# Epoch 38: val_loss improved from 0.13831 to 0.13084, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 124ms/step - loss: 0.1131 - accuracy: 0.0000e+00 - val_loss: 0.1308 - val_accuracy: 0.0000e+00
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1102 - accuracy: 0.0000e+00
# Epoch 39: val_loss did not improve from 0.13084
# 2/2 [==============================] - 0s 89ms/step - loss: 0.1076 - accuracy: 0.0000e+00 - val_loss: 0.1368 - val_accuracy: 0.0000e+00
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1126 - accuracy: 0.0000e+00
# Epoch 40: val_loss improved from 0.13084 to 0.11914, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1097 - accuracy: 0.0000e+00 - val_loss: 0.1191 - val_accuracy: 0.0000e+00
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0980 - accuracy: 0.0000e+00
# Epoch 41: val_loss improved from 0.11914 to 0.11054, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0978 - accuracy: 0.0000e+00 - val_loss: 0.1105 - val_accuracy: 0.0000e+00
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0912 - accuracy: 0.0000e+00
# Epoch 42: val_loss improved from 0.11054 to 0.10076, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0903 - accuracy: 0.0000e+00 - val_loss: 0.1008 - val_accuracy: 0.0000e+00
# Epoch 43/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0854 - accuracy: 0.0000e+00
# Epoch 43: val_loss improved from 0.10076 to 0.09120, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0841 - accuracy: 0.0000e+00 - val_loss: 0.0912 - val_accuracy: 0.0000e+00
# Epoch 44/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0688 - accuracy: 0.0000e+00
# Epoch 44: val_loss improved from 0.09120 to 0.08548, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0769 - accuracy: 0.0000e+00 - val_loss: 0.0855 - val_accuracy: 0.0000e+00
# Epoch 45/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1008 - accuracy: 0.0000e+00
# Epoch 45: val_loss did not improve from 0.08548
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0996 - accuracy: 0.0000e+00 - val_loss: 0.0966 - val_accuracy: 0.0000e+00
# Epoch 46/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0751 - accuracy: 0.0000e+00
# Epoch 46: val_loss improved from 0.08548 to 0.05017, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 122ms/step - loss: 0.0864 - accuracy: 0.0000e+00 - val_loss: 0.0502 - val_accuracy: 0.0000e+00
# Epoch 47/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0672 - accuracy: 0.0312
# Epoch 47: val_loss improved from 0.05017 to 0.03966, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0696 - accuracy: 0.0303 - val_loss: 0.0397 - val_accuracy: 0.0000e+00
# Epoch 48/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0603 - accuracy: 0.0000e+00
# Epoch 48: val_loss improved from 0.03966 to 0.03575, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0597 - accuracy: 0.0000e+00 - val_loss: 0.0357 - val_accuracy: 0.0000e+00
# Epoch 49/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0494 - accuracy: 0.0000e+00
# Epoch 49: val_loss did not improve from 0.03575
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0498 - accuracy: 0.0000e+00 - val_loss: 0.0690 - val_accuracy: 0.0000e+00
# Epoch 50/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0718 - accuracy: 0.0000e+00
# Epoch 50: val_loss did not improve from 0.03575
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0711 - accuracy: 0.0000e+00 - val_loss: 0.0887 - val_accuracy: 0.0000e+00
# Epoch 51/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0877 - accuracy: 0.0000e+00
# Epoch 51: val_loss did not improve from 0.03575
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0859 - accuracy: 0.0000e+00 - val_loss: 0.0388 - val_accuracy: 0.0000e+00
#
#  La media del mse, 4-fold es : 0.5468439952123398
#
#  La desviacion estandar del mse, 4-fold es : 0.538377251990913

# %%
# rellenar de ceros los espacios vacios de la lista con loss y validation

df_train_losses = pd.DataFrame(train_losses)

df_filled_train_losses = df_train_losses.fillna(0)

train_losses_completa = df_filled_train_losses.values.tolist()

df_val_losses = pd.DataFrame(val_losses)

df_filled_val_losses = df_val_losses.fillna(0)

val_losses_completa = df_filled_val_losses.values.tolist()

# %%
# Calcular el promedio de "average loss" para todos los pliegues y épocas
avg_train_losses = np.mean(train_losses_completa, axis=0)
avg_val_losses = np.mean(val_losses_completa, axis=0)

# vamos a graficar
plt.plot(avg_train_losses, label='Perdida entrenamiento') # Grafico esta para ver si estoy sobre entrenando
plt.plot(avg_val_losses, label='Perdida Validacion') # Grafico esta para ver si estoy sobre entrenando
plt.title('avg loss train, avg loss val vs epoch ')
plt.xlabel('epoch')
plt.ylabel('Mean Square Error')
plt.legend()
plt.show()

# %%
# Cargar el mejor modelo
best_model = load_model(best_model_path)

# %%
# Seleccionar una secuencia específica
index = 0
input_sequence = X_test[index]

# Hacer la predicción
y_pred = best_model.predict(np.expand_dims(input_sequence, axis=0))
# usamos el np.expand_dims() para agregar una dimensión adicional al inicio de input_sequence
print(y_pred.shape)
# Out:
# 1/1 [==============================] - 0s 330ms/step
# (1, 210)

# %%
# Desenrollar X_test para convertirlo en un array bidimensional
X_test_flattened = X_test.reshape(-1, X_test.shape[-1])

# Aplicar la transformación inversa utilizando el objeto StandardScaler
X_test_desnormalizado = sc.inverse_transform(X_test_flattened)

# Volver a darle forma a X_test_desnormalizado a su forma original
X_test = X_test_desnormalizado.reshape(X_test.shape)

# Desnormalizar los datos
y_pred = sc_y.inverse_transform(y_pred)

y_test = sc_y.inverse_transform(y_test)

print(y_pred.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (1, 210)
# (17, 210)
# (17, 15, 2)

# %%
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
Curva=0

plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

print('')
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(X_test[Curva,:,0],color='orange', label='Valores actuales y anteriores de insulina')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_test[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 229.472625

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_pred[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 232.666083984375

# %%
# Media MSE y desviacion estandar MSE de las prediciones con la escala normal
mse = mean_squared_error(y_test[0,:].flatten(), y_pred.flatten())
std = np.sqrt(mse)
mediamse = np.mean(mse)

print('La media MSE:',mediamse)
print('La desviacion standar MSE', std)

# calcular la MAE
mae = mean_absolute_error(y_test[0,:], y_pred[0,:])
print('MAE:', mae)

# calcular la RMSE
rmse = np.sqrt(mean_squared_error(y_test[0,:], y_pred[0,:]))
print('RMSE:', rmse)
# Out:
# La media MSE: 12.461004765110069
# La desviacion standar MSE 3.5300148392195276
# MAE: 2.4448387887137284
# RMSE: 3.5300148392195276
