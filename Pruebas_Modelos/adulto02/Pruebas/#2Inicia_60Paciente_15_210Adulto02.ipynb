# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Librerias
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split, KFold
from keras.callbacks import EarlyStopping

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import load_model

from keras.initializers import random_uniform

# %%
#Dataset Adulto 01
data = pd.read_csv('/content/gdrive/MyDrive/Proyecto_de_grado/SUSTENTACION3.0/FinalX3/adulto02/my_adult02A2_data.csv')

print(f"El archivo se ha cargado correctamente. Tiene {data.shape[0]} filas y {data.shape[1]} columnas.")
# Out:
# El archivo se ha cargado correctamente. Tiene 29638 filas y 3 columnas.

# %%
train_size = int(len(data) * 0.7)

train_data = data.iloc[:train_size, :] # 70% entrenamiento
test_data = data.iloc[train_size:, :] # 30% prueba

test_data = test_data.reset_index(drop=True)

# %%
#los indices donde hay ingestas
posicionestrain = train_data.loc[train_data.iloc[:, 0] != 0].index
posicionestest = test_data.loc[test_data.iloc[:, 0] != 0].index

df_posiciones_train = pd.DataFrame(posicionestrain)
df_posiciones_test = pd.DataFrame(posicionestest)

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_train = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_train)):
    anterior = df_posiciones_train.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_train.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_train.append(anterior)

ultimo_elemento_train = df_posiciones_train.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_train.extend(ultimo_elemento_train.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_train)
print(len(cumplen_train))
# Out:
# [494, 862, 1358, 1974, 2353, 2840, 3461, 3846, 4334, 4956, 5324, 5820, 6438, 6815, 7301, 7917, 8283, 8781, 9398, 9781, 10268, 10880, 11255, 11750, 12363, 12742, 13230, 13845, 14212, 14699, 15311, 15686, 16183, 16795, 17162, 17650, 18266, 18653, 19140, 19757, 20125, 20614]
# 42

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_test = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_test)):
    anterior = df_posiciones_test.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_test.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_test.append(anterior)

ultimo_elemento_test = df_posiciones_test.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_test.extend(ultimo_elemento_test.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_test)
print(len(cumplen_test))
# Out:
# [487, 855, 1342, 1956, 2335, 2823, 3439, 3805, 4301, 4916, 5291, 5779, 6398, 6765, 7253, 7868, 8234, 8720]
# 18

# %%
# pasar la escala de los carbohidratos de las ingestas a gramos
data.iloc[:,0] = data.iloc[:,0].apply(lambda x: (x*15)/1000)

# Grafica con mayor detalle, el pico del comportamiento de la glucosa despues de la primera ingesta
print('')
print('Grafica de los datos del dataset')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
plt.title('Ingestas, Insulina y Glucosa')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')

print('Caso 1: Primera ingesta o Desayuno del primer dia:')
plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 700])
plt.ylim([-5, 250])
plt.show()
print('')

print('Caso 2: Primera y segunda ingesta del primer dia:')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1200])
plt.ylim([-5, 500])
plt.show()


print('Caso 3: las tres ingestas del primer dia:')

plt.plot(data.index, data.iloc[:,0], color='blue', label='Ingestas')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Ingestas de carbohidratos')
plt.xlabel('t [min]')
plt.ylabel('gramos')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Dosificación de insulina')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
#plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1800])
plt.ylim([-5, 500])
plt.show()
# Out:
# Grafica de los datos del dataset
# Caso 1: Primera ingesta o Desayuno del primer dia:
# Caso 2: Primera y segunda ingesta del primer dia:
# Caso 3: las tres ingestas del primer dia:

# %%
#Preprocesar los datos:
X_train = train_data.iloc[:, 1:3].values
y_train = train_data.iloc[:,2].values

X_test = test_data.iloc[:, 1:3].values
y_test = test_data.iloc[:, 2].values

print('Tamaño de los datos de entrada, de X_train: ',X_train.shape)
print(f'Tiene {X_train.shape[0]} filas y {X_train.shape[1]} columna')
print('La primera ingesta al minuto 300, ingesta: ',X_train[300])
print('La primera ingesta hasta el minuto 327, ingesta: ',X_train[327])

print('La entrada son los valores de la insulina y glucosa \n',X_train)
print('Tamaño de los datos de salia, de y_train',y_train.shape)
print(f'Tiene {y_train.shape[0]} filas y {y_train.shape[-1]} columnas')
print('La salida son los valores de glucosa \n',y_train)
# Out:
# Tamaño de los datos de entrada, de X_train:  (20746, 2)
# Tiene 20746 filas y 2 columna
# La primera ingesta al minuto 300, ingesta:  [  1.6789 123.44  ]
# La primera ingesta hasta el minuto 327, ingesta:  [  1.6789 123.44  ]
# La entrada son los valores de la insulina y glucosa
#  [[  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  ...
#  [  1.6789 198.03  ]
#  [  1.6789 197.1   ]
#  [  1.6789 196.18  ]]
# Tamaño de los datos de salia, de y_train (20746,)
# Tiene 20746 filas y 20746 columnas
# La salida son los valores de glucosa
#  [123.44 123.44 123.44 ... 198.03 197.1  196.18]

# %%
# Normalizar los datos
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Normalizar y_train
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.reshape(-1, 1))
y_test = sc_y.transform(y_test.reshape(-1, 1))

# %%
# Reorganizar los datos en forma de secuencia
def to_sequences(data,  seq_size_input, seq_size_output):
    X = []
    y = []

    for i in range(len(data)-seq_size_input-seq_size_output+1):
        X.append(data[i:(i+seq_size_input), 0:2])
        y.append(data[(i+seq_size_input):(i+seq_size_input+seq_size_output), 2])

    return np.array(X), np.array(y)

# %%
#CON LOS DATOS NORMALIZADOS
seq_size_input = 15
seq_size_output = 210
X_train, y_train = to_sequences(np.hstack((X_train, y_train)), seq_size_input, seq_size_output)
X_test, y_test = to_sequences(np.hstack((X_test, y_test)), seq_size_input, seq_size_output)
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (20522, 210)
# (20522, 15, 2)
# (8668, 210)
# (8668, 15, 2)

# %%
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
flattened_data = np.reshape(X_train, (X_train.shape[0], -1))

df_X_train = pd.DataFrame(flattened_data)

# %%
flattened_test = np.reshape(X_test, (X_test.shape[0], -1))

df_X_test = pd.DataFrame(flattened_test)

# %%
df_y_train = pd.DataFrame(y_train)
df_y_test = pd.DataFrame(y_test)

# %%
# Filtrar el dataframe para mantener solo las filas especificadas
df_X_train_seleccionado = df_X_train[df_X_train.index.isin(cumplen_train)]
df_y_train_seleccionado = df_y_train[df_y_train.index.isin(cumplen_train)]
df_X_test_seleccionado = df_X_test[df_X_test.index.isin(cumplen_test)]
df_y_test_seleccionado = df_y_test[df_y_test.index.isin(cumplen_test)]

# %%
print('Grafica de los datos del dataset')
#plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')

Numerocurva = 0

plt.plot(df_X_train_seleccionado.iloc[Numerocurva, 1::2],color='green',label='Entrada glucosa') #Para mostrar solo la glucosa
plt.plot(df_X_train_seleccionado.iloc[Numerocurva, ::2],color='orange',label='Entrada insulina') #Para mostrar solo la glucosa
plt.plot(range(seq_size_input*2, seq_size_output + seq_size_input*2),df_y_train_seleccionado.iloc[Numerocurva,:], color='red',label='Salida glucosa')
plt.title('Entradas y salidas, entrenamiento')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')
# Out:
# Grafica de los datos del dataset

# %%
X_train = df_X_train_seleccionado.values
y_train = df_y_train_seleccionado.values
X_test = df_X_test_seleccionado.values
y_test = df_y_test_seleccionado.values

print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 30)
# (17, 210)
# (17, 30)

# %%
print(len(X_test))
# Out:
# 17

# %%
X_train = np.reshape(X_train, (len(X_train), seq_size_input, 2))

X_test = np.reshape(X_test, (len(X_test), seq_size_input, 2))
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 15, 2)
# (17, 210)
# (17, 15, 2)

# %%
kf = KFold(n_splits=5)
kf.get_n_splits(X_train)
KFold(n_splits=5, random_state=None, shuffle=False)


# Crear listas para almacenar los valores del "average loss" de entrenamiento y validación en cada pliegue
train_losses = []
val_losses = []

#Para guardar el mejor modelo
best_loss = float('inf')
best_model_path = ""

for i, (train_index, test_index) in enumerate(kf.split(X_train,y_train)):
  model = Sequential()
  model.add(LSTM(60, activation='tanh', input_shape=(seq_size_input, 2), kernel_initializer=random_uniform()))
  model.add(Dense(seq_size_output, activation='linear', kernel_initializer=random_uniform()))


  model.compile(optimizer='adam', loss='mse')
  print(model.summary())

  filepath = f"modelo-{i+1}.h5"
  early_stop = EarlyStopping(monitor='val_loss', patience=3)
  checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

  X, y =  X_train[train_index], y_train[train_index]
  X_val, y_val = X_train[test_index], y_train[test_index]


  history = model.fit(X, y, epochs=100, batch_size=32,validation_data=(X_val, y_val),callbacks=[checkpoint, early_stop] )

  mediamse = np.mean( history.history['loss'] )
  stdmse = np.std(  history.history['loss'])
  print('')
  print(f" La media del mse, {i}-fold es : {mediamse}")
  print('')
  print(f" La desviacion estandar del mse, {i}-fold es : {stdmse}")

  # Obtener los valores de "average loss" para el pliegue actual
  fold_train_losses = model.history.history['loss']
  fold_val_losses = model.history.history['val_loss']

  # Almacenar los valores de "average loss" para el pliegue actual
  train_losses.append(fold_train_losses)
  val_losses.append(fold_val_losses)

  if min(fold_val_losses) < best_loss:
        best_loss = min(fold_val_losses)
        best_model_path = filepath

  history.history.keys() # aqui me muestra que esta guardando, con history me guarda todos los valores que calcula durante el proceso de entrenamiento

  # vamos a graficar
  plt.plot(history.history['loss'], label='Perdida') # Grafico esta para ver si estoy sobre entrenando
  plt.plot(history.history['val_loss'], label='Validacion') # Grafico esta para ver si estoy sobre entrenando
  plt.xlabel('epoch')
  plt.ylabel('Mean Square Error')
  plt.legend()
  plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 60)                15120
#
#  dense_5 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7551
# Epoch 1: val_loss improved from inf to 1.83975, saving model to modelo-1.h5
# 1/1 [==============================] - 2s 2s/step - loss: 1.7551 - val_loss: 1.8398
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7524
# Epoch 2: val_loss improved from 1.83975 to 1.83687, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 1.7524 - val_loss: 1.8369
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7496
# Epoch 3: val_loss improved from 1.83687 to 1.83382, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 1.7496 - val_loss: 1.8338
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7466
# Epoch 4: val_loss improved from 1.83382 to 1.83052, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 1.7466 - val_loss: 1.8305
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7434
# Epoch 5: val_loss improved from 1.83052 to 1.82690, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 1.7434 - val_loss: 1.8269
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7399
# Epoch 6: val_loss improved from 1.82690 to 1.82288, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 1.7399 - val_loss: 1.8229
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7360
# Epoch 7: val_loss improved from 1.82288 to 1.81840, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 1.7360 - val_loss: 1.8184
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7316
# Epoch 8: val_loss improved from 1.81840 to 1.81333, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 1.7316 - val_loss: 1.8133
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7266
# Epoch 9: val_loss improved from 1.81333 to 1.80757, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 1.7266 - val_loss: 1.8076
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7210
# Epoch 10: val_loss improved from 1.80757 to 1.80094, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 1.7210 - val_loss: 1.8009
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7145
# Epoch 11: val_loss improved from 1.80094 to 1.79327, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 1.7145 - val_loss: 1.7933
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7070
# Epoch 12: val_loss improved from 1.79327 to 1.78430, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 1.7070 - val_loss: 1.7843
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6983
# Epoch 13: val_loss improved from 1.78430 to 1.77372, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 1.6983 - val_loss: 1.7737
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6879
# Epoch 14: val_loss improved from 1.77372 to 1.76115, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 1.6879 - val_loss: 1.7611
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6756
# Epoch 15: val_loss improved from 1.76115 to 1.74605, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 1.6756 - val_loss: 1.7461
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6609
# Epoch 16: val_loss improved from 1.74605 to 1.72776, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 1.6609 - val_loss: 1.7278
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6430
# Epoch 17: val_loss improved from 1.72776 to 1.70539, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 78ms/step - loss: 1.6430 - val_loss: 1.7054
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6211
# Epoch 18: val_loss improved from 1.70539 to 1.67777, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 79ms/step - loss: 1.6211 - val_loss: 1.6778
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5941
# Epoch 19: val_loss improved from 1.67777 to 1.64341, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 77ms/step - loss: 1.5941 - val_loss: 1.6434
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5606
# Epoch 20: val_loss improved from 1.64341 to 1.60040, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 1.5606 - val_loss: 1.6004
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5186
# Epoch 21: val_loss improved from 1.60040 to 1.54640, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 1.5186 - val_loss: 1.5464
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4659
# Epoch 22: val_loss improved from 1.54640 to 1.47877, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 1.4659 - val_loss: 1.4788
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4000
# Epoch 23: val_loss improved from 1.47877 to 1.39506, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 1.4000 - val_loss: 1.3951
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3186
# Epoch 24: val_loss improved from 1.39506 to 1.29411, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 1.3186 - val_loss: 1.2941
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2208
# Epoch 25: val_loss improved from 1.29411 to 1.17798, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 1.2208 - val_loss: 1.1780
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1087
# Epoch 26: val_loss improved from 1.17798 to 1.05406, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 1.1087 - val_loss: 1.0541
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9900
# Epoch 27: val_loss improved from 1.05406 to 0.93512, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 0.9900 - val_loss: 0.9351
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8770
# Epoch 28: val_loss improved from 0.93512 to 0.83430, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.8770 - val_loss: 0.8343
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7825
# Epoch 29: val_loss improved from 0.83430 to 0.75779, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.7825 - val_loss: 0.7578
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7118
# Epoch 30: val_loss improved from 0.75779 to 0.70331, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 78ms/step - loss: 0.7118 - val_loss: 0.7033
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6623
# Epoch 31: val_loss improved from 0.70331 to 0.66487, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 0.6623 - val_loss: 0.6649
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6280
# Epoch 32: val_loss improved from 0.66487 to 0.63709, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 80ms/step - loss: 0.6280 - val_loss: 0.6371
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6036
# Epoch 33: val_loss improved from 0.63709 to 0.61633, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.6036 - val_loss: 0.6163
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5855
# Epoch 34: val_loss improved from 0.61633 to 0.60031, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 0.5855 - val_loss: 0.6003
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5716
# Epoch 35: val_loss improved from 0.60031 to 0.58762, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.5716 - val_loss: 0.5876
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5605
# Epoch 36: val_loss improved from 0.58762 to 0.57736, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.5605 - val_loss: 0.5774
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5512
# Epoch 37: val_loss improved from 0.57736 to 0.56899, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.5512 - val_loss: 0.5690
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5434
# Epoch 38: val_loss improved from 0.56899 to 0.56220, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.5434 - val_loss: 0.5622
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5368
# Epoch 39: val_loss improved from 0.56220 to 0.55680, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 0.5368 - val_loss: 0.5568
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5312
# Epoch 40: val_loss improved from 0.55680 to 0.55266, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 0.5312 - val_loss: 0.5527
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5265
# Epoch 41: val_loss improved from 0.55266 to 0.54968, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.5265 - val_loss: 0.5497
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5228
# Epoch 42: val_loss improved from 0.54968 to 0.54773, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 79ms/step - loss: 0.5228 - val_loss: 0.5477
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5200
# Epoch 43: val_loss improved from 0.54773 to 0.54667, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.5200 - val_loss: 0.5467
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5179
# Epoch 44: val_loss improved from 0.54667 to 0.54633, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.5179 - val_loss: 0.5463
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5165
# Epoch 45: val_loss did not improve from 0.54633
# 1/1 [==============================] - 0s 54ms/step - loss: 0.5165 - val_loss: 0.5465
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5156
# Epoch 46: val_loss did not improve from 0.54633
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5156 - val_loss: 0.5469
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5151
# Epoch 47: val_loss did not improve from 0.54633
# 1/1 [==============================] - 0s 49ms/step - loss: 0.5151 - val_loss: 0.5475
#
#  La media del mse, 0-fold es : 1.1652730158034792
#
#  La desviacion estandar del mse, 0-fold es : 0.5239362315413923
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 60)                15120
#
#  dense_6 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.9104
# Epoch 1: val_loss improved from inf to 1.41300, saving model to modelo-2.h5
# 2/2 [==============================] - 3s 810ms/step - loss: 1.8606 - val_loss: 1.4130
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9043
# Epoch 2: val_loss improved from 1.41300 to 1.40808, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 80ms/step - loss: 1.8554 - val_loss: 1.4081
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8812
# Epoch 3: val_loss improved from 1.40808 to 1.40212, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 81ms/step - loss: 1.8500 - val_loss: 1.4021
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8917
# Epoch 4: val_loss improved from 1.40212 to 1.39446, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 81ms/step - loss: 1.8436 - val_loss: 1.3945
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7483
# Epoch 5: val_loss improved from 1.39446 to 1.38461, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 114ms/step - loss: 1.8351 - val_loss: 1.3846
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8739
# Epoch 6: val_loss improved from 1.38461 to 1.37148, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 100ms/step - loss: 1.8247 - val_loss: 1.3715
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8429
# Epoch 7: val_loss improved from 1.37148 to 1.35266, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 109ms/step - loss: 1.8104 - val_loss: 1.3527
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8201
# Epoch 8: val_loss improved from 1.35266 to 1.32437, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 93ms/step - loss: 1.7901 - val_loss: 1.3244
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6638
# Epoch 9: val_loss improved from 1.32437 to 1.28312, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 114ms/step - loss: 1.7591 - val_loss: 1.2831
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5728
# Epoch 10: val_loss improved from 1.28312 to 1.22280, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 111ms/step - loss: 1.7140 - val_loss: 1.2228
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6796
# Epoch 11: val_loss improved from 1.22280 to 1.12895, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 1.6496 - val_loss: 1.1289
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5783
# Epoch 12: val_loss improved from 1.12895 to 0.98272, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 77ms/step - loss: 1.5469 - val_loss: 0.9827
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4274
# Epoch 13: val_loss improved from 0.98272 to 0.79535, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 1.3866 - val_loss: 0.7953
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2088
# Epoch 14: val_loss improved from 0.79535 to 0.62425, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 1.1743 - val_loss: 0.6243
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9498
# Epoch 15: val_loss improved from 0.62425 to 0.50068, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 111ms/step - loss: 0.9643 - val_loss: 0.5007
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7581
# Epoch 16: val_loss improved from 0.50068 to 0.43002, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 122ms/step - loss: 0.8040 - val_loss: 0.4300
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7214
# Epoch 17: val_loss improved from 0.43002 to 0.39914, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 0.7084 - val_loss: 0.3991
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5864
# Epoch 18: val_loss improved from 0.39914 to 0.38803, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 84ms/step - loss: 0.6462 - val_loss: 0.3880
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6223
# Epoch 19: val_loss did not improve from 0.38803
# 2/2 [==============================] - 0s 74ms/step - loss: 0.6208 - val_loss: 0.3897
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6038
# Epoch 20: val_loss improved from 0.38803 to 0.38632, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 84ms/step - loss: 0.6049 - val_loss: 0.3863
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5921
# Epoch 21: val_loss improved from 0.38632 to 0.37537, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 86ms/step - loss: 0.5931 - val_loss: 0.3754
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5794
# Epoch 22: val_loss improved from 0.37537 to 0.35999, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 80ms/step - loss: 0.5810 - val_loss: 0.3600
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5859
# Epoch 23: val_loss improved from 0.35999 to 0.34593, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.5704 - val_loss: 0.3459
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5322
# Epoch 24: val_loss improved from 0.34593 to 0.33973, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.5648 - val_loss: 0.3397
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5398
# Epoch 25: val_loss did not improve from 0.33973
# 2/2 [==============================] - 0s 67ms/step - loss: 0.5602 - val_loss: 0.3417
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5711
# Epoch 26: val_loss did not improve from 0.33973
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5586 - val_loss: 0.3459
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5428
# Epoch 27: val_loss did not improve from 0.33973
# 2/2 [==============================] - 0s 76ms/step - loss: 0.5572 - val_loss: 0.3522
#
#  La media del mse, 1-fold es : 1.1938769066775288
#
#  La desviacion estandar del mse, 1-fold es : 0.557323769230181
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 60)                15120
#
#  dense_7 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.8518
# Epoch 1: val_loss improved from inf to 1.65091, saving model to modelo-3.h5
# 2/2 [==============================] - 3s 526ms/step - loss: 1.8027 - val_loss: 1.6509
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6799
# Epoch 2: val_loss improved from 1.65091 to 1.64570, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 1.7972 - val_loss: 1.6457
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8405
# Epoch 3: val_loss improved from 1.64570 to 1.63966, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.7916 - val_loss: 1.6397
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8128
# Epoch 4: val_loss improved from 1.63966 to 1.63202, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 1.7850 - val_loss: 1.6320
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7742
# Epoch 5: val_loss improved from 1.63202 to 1.62158, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 1.7765 - val_loss: 1.6216
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8111
# Epoch 6: val_loss improved from 1.62158 to 1.60714, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 1.7652 - val_loss: 1.6071
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7798
# Epoch 7: val_loss improved from 1.60714 to 1.58655, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 1.7492 - val_loss: 1.5866
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7734
# Epoch 8: val_loss improved from 1.58655 to 1.55620, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.7267 - val_loss: 1.5562
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7407
# Epoch 9: val_loss improved from 1.55620 to 1.51117, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 1.6935 - val_loss: 1.5112
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6741
# Epoch 10: val_loss improved from 1.51117 to 1.44210, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.6435 - val_loss: 1.4421
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6012
# Epoch 11: val_loss improved from 1.44210 to 1.33341, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 72ms/step - loss: 1.5672 - val_loss: 1.3334
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4762
# Epoch 12: val_loss improved from 1.33341 to 1.17380, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 74ms/step - loss: 1.4458 - val_loss: 1.1738
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1889
# Epoch 13: val_loss improved from 1.17380 to 0.99162, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 74ms/step - loss: 1.2600 - val_loss: 0.9916
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0869
# Epoch 14: val_loss improved from 0.99162 to 0.84187, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 1.0563 - val_loss: 0.8419
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8116
# Epoch 15: val_loss improved from 0.84187 to 0.73645, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.8682 - val_loss: 0.7364
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7595
# Epoch 16: val_loss improved from 0.73645 to 0.67477, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.7416 - val_loss: 0.6748
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6212
# Epoch 17: val_loss improved from 0.67477 to 0.63882, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6511 - val_loss: 0.6388
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6146
# Epoch 18: val_loss improved from 0.63882 to 0.62071, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.5985 - val_loss: 0.6207
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5204
# Epoch 19: val_loss improved from 0.62071 to 0.61806, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.5582 - val_loss: 0.6181
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5531
# Epoch 20: val_loss did not improve from 0.61806
# 2/2 [==============================] - 0s 47ms/step - loss: 0.5401 - val_loss: 0.6321
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5208
# Epoch 21: val_loss did not improve from 0.61806
# 2/2 [==============================] - 0s 41ms/step - loss: 0.5348 - val_loss: 0.6603
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5448
# Epoch 22: val_loss did not improve from 0.61806
# 2/2 [==============================] - 0s 41ms/step - loss: 0.5499 - val_loss: 0.6871
#
#  La media del mse, 2-fold es : 1.2683077400380915
#
#  La desviacion estandar del mse, 2-fold es : 0.5176764246656679
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 60)                15120
#
#  dense_8 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.7879
# Epoch 1: val_loss improved from inf to 1.82335, saving model to modelo-4.h5
# 2/2 [==============================] - 3s 541ms/step - loss: 1.7611 - val_loss: 1.8233
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6902
# Epoch 2: val_loss improved from 1.82335 to 1.81736, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.7556 - val_loss: 1.8174
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7820
# Epoch 3: val_loss improved from 1.81736 to 1.81027, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 1.7499 - val_loss: 1.8103
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7900
# Epoch 4: val_loss improved from 1.81027 to 1.80136, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 1.7430 - val_loss: 1.8014
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7793
# Epoch 5: val_loss improved from 1.80136 to 1.78968, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 1.7344 - val_loss: 1.7897
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7692
# Epoch 6: val_loss improved from 1.78968 to 1.77352, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 1.7231 - val_loss: 1.7735
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6127
# Epoch 7: val_loss improved from 1.77352 to 1.75103, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 106ms/step - loss: 1.7071 - val_loss: 1.7510
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7123
# Epoch 8: val_loss improved from 1.75103 to 1.71752, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 118ms/step - loss: 1.6856 - val_loss: 1.7175
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7002
# Epoch 9: val_loss improved from 1.71752 to 1.66485, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 126ms/step - loss: 1.6534 - val_loss: 1.6649
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6306
# Epoch 10: val_loss improved from 1.66485 to 1.58133, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 1.6022 - val_loss: 1.5813
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4328
# Epoch 11: val_loss improved from 1.58133 to 1.45643, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 1.5198 - val_loss: 1.4564
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4330
# Epoch 12: val_loss improved from 1.45643 to 1.27645, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 1.4022 - val_loss: 1.2764
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2581
# Epoch 13: val_loss improved from 1.27645 to 1.05128, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 1.2311 - val_loss: 1.0513
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0522
# Epoch 14: val_loss improved from 1.05128 to 0.86159, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 80ms/step - loss: 1.0224 - val_loss: 0.8616
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8673
# Epoch 15: val_loss improved from 0.86159 to 0.73293, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.8448 - val_loss: 0.7329
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7455
# Epoch 16: val_loss improved from 0.73293 to 0.65023, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 88ms/step - loss: 0.7288 - val_loss: 0.6502
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6682
# Epoch 17: val_loss improved from 0.65023 to 0.60099, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 87ms/step - loss: 0.6535 - val_loss: 0.6010
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6196
# Epoch 18: val_loss improved from 0.60099 to 0.57331, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 0.6089 - val_loss: 0.5733
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6002
# Epoch 19: val_loss improved from 0.57331 to 0.55762, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 107ms/step - loss: 0.5832 - val_loss: 0.5576
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5772
# Epoch 20: val_loss improved from 0.55762 to 0.55120, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 0.5692 - val_loss: 0.5512
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5724
# Epoch 21: val_loss did not improve from 0.55120
# 2/2 [==============================] - 0s 58ms/step - loss: 0.5631 - val_loss: 0.5555
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5360
# Epoch 22: val_loss improved from 0.55120 to 0.54768, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 85ms/step - loss: 0.5672 - val_loss: 0.5477
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5725
# Epoch 23: val_loss improved from 0.54768 to 0.53047, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 85ms/step - loss: 0.5608 - val_loss: 0.5305
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4768
# Epoch 24: val_loss improved from 0.53047 to 0.51037, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.5448 - val_loss: 0.5104
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5369
# Epoch 25: val_loss improved from 0.51037 to 0.49371, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 87ms/step - loss: 0.5318 - val_loss: 0.4937
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4597
# Epoch 26: val_loss improved from 0.49371 to 0.48403, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5170 - val_loss: 0.4840
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5131
# Epoch 27: val_loss improved from 0.48403 to 0.48189, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 81ms/step - loss: 0.5162 - val_loss: 0.4819
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5309
# Epoch 28: val_loss did not improve from 0.48189
# 2/2 [==============================] - 0s 74ms/step - loss: 0.5176 - val_loss: 0.4825
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5310
# Epoch 29: val_loss did not improve from 0.48189
# 2/2 [==============================] - 0s 72ms/step - loss: 0.5205 - val_loss: 0.4819
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5214
# Epoch 30: val_loss improved from 0.48189 to 0.47929, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 82ms/step - loss: 0.5205 - val_loss: 0.4793
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5306
# Epoch 31: val_loss improved from 0.47929 to 0.47692, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 0.5166 - val_loss: 0.4769
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4813
# Epoch 32: val_loss improved from 0.47692 to 0.47621, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5132 - val_loss: 0.4762
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5123
# Epoch 33: val_loss improved from 0.47621 to 0.47559, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 88ms/step - loss: 0.5107 - val_loss: 0.4756
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5107
# Epoch 34: val_loss did not improve from 0.47559
# 2/2 [==============================] - 0s 72ms/step - loss: 0.5095 - val_loss: 0.4757
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5133
# Epoch 35: val_loss did not improve from 0.47559
# 2/2 [==============================] - 0s 72ms/step - loss: 0.5085 - val_loss: 0.4765
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5039
# Epoch 36: val_loss improved from 0.47559 to 0.47537, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 0.5073 - val_loss: 0.4754
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5209
# Epoch 37: val_loss improved from 0.47537 to 0.47360, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 106ms/step - loss: 0.5063 - val_loss: 0.4736
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5072
# Epoch 38: val_loss improved from 0.47360 to 0.47291, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 0.5055 - val_loss: 0.4729
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5188
# Epoch 39: val_loss did not improve from 0.47291
# 2/2 [==============================] - 0s 58ms/step - loss: 0.5042 - val_loss: 0.4733
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5000
# Epoch 40: val_loss improved from 0.47291 to 0.47250, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 80ms/step - loss: 0.5036 - val_loss: 0.4725
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4854
# Epoch 41: val_loss improved from 0.47250 to 0.46932, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 88ms/step - loss: 0.5018 - val_loss: 0.4693
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5134
# Epoch 42: val_loss improved from 0.46932 to 0.46826, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.5013 - val_loss: 0.4683
# Epoch 43/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4980
# Epoch 43: val_loss did not improve from 0.46826
# 2/2 [==============================] - 0s 59ms/step - loss: 0.5018 - val_loss: 0.4698
# Epoch 44/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5064
# Epoch 44: val_loss did not improve from 0.46826
# 2/2 [==============================] - 0s 58ms/step - loss: 0.5072 - val_loss: 0.4718
# Epoch 45/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5069
# Epoch 45: val_loss improved from 0.46826 to 0.46769, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 85ms/step - loss: 0.5101 - val_loss: 0.4677
# Epoch 46/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5155
# Epoch 46: val_loss improved from 0.46769 to 0.46295, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 86ms/step - loss: 0.5042 - val_loss: 0.4629
# Epoch 47/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4964
# Epoch 47: val_loss improved from 0.46295 to 0.46240, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 100ms/step - loss: 0.4976 - val_loss: 0.4624
# Epoch 48/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4743
# Epoch 48: val_loss improved from 0.46240 to 0.46047, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 0.4945 - val_loss: 0.4605
# Epoch 49/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5049
# Epoch 49: val_loss improved from 0.46047 to 0.45863, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 114ms/step - loss: 0.4932 - val_loss: 0.4586
# Epoch 50/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5059
# Epoch 50: val_loss improved from 0.45863 to 0.45698, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.4926 - val_loss: 0.4570
# Epoch 51/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5015
# Epoch 51: val_loss improved from 0.45698 to 0.45488, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.4910 - val_loss: 0.4549
# Epoch 52/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4883
# Epoch 52: val_loss improved from 0.45488 to 0.45474, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.4875 - val_loss: 0.4547
# Epoch 53/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4845
# Epoch 53: val_loss did not improve from 0.45474
# 2/2 [==============================] - 0s 49ms/step - loss: 0.4845 - val_loss: 0.4609
# Epoch 54/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4931
# Epoch 54: val_loss did not improve from 0.45474
# 2/2 [==============================] - 0s 43ms/step - loss: 0.4871 - val_loss: 0.4734
# Epoch 55/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4994
# Epoch 55: val_loss did not improve from 0.45474
# 2/2 [==============================] - 0s 43ms/step - loss: 0.4955 - val_loss: 0.4900
#
#  La media del mse, 3-fold es : 0.8031603802334178
#
#  La desviacion estandar del mse, 3-fold es : 0.4775980041653865
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 60)                15120
#
#  dense_9 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.7373
# Epoch 1: val_loss improved from inf to 2.11235, saving model to modelo-5.h5
# 2/2 [==============================] - 3s 549ms/step - loss: 1.6911 - val_loss: 2.1123
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7134
# Epoch 2: val_loss improved from 2.11235 to 2.10628, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 1.6861 - val_loss: 2.1063
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5278
# Epoch 3: val_loss improved from 2.10628 to 2.09866, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 1.6804 - val_loss: 2.0987
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7035
# Epoch 4: val_loss improved from 2.09866 to 2.08888, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 74ms/step - loss: 1.6736 - val_loss: 2.0889
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7088
# Epoch 5: val_loss improved from 2.08888 to 2.07525, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 1.6647 - val_loss: 2.0752
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6978
# Epoch 6: val_loss improved from 2.07525 to 2.05563, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 1.6522 - val_loss: 2.0556
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6613
# Epoch 7: val_loss improved from 2.05563 to 2.02603, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 1.6340 - val_loss: 2.0260
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6501
# Epoch 8: val_loss improved from 2.02603 to 1.97945, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 1.6067 - val_loss: 1.9795
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5082
# Epoch 9: val_loss improved from 1.97945 to 1.90925, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 1.5627 - val_loss: 1.9092
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5418
# Epoch 10: val_loss improved from 1.90925 to 1.79998, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 1.4994 - val_loss: 1.8000
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3597
# Epoch 11: val_loss improved from 1.79998 to 1.63666, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 1.3974 - val_loss: 1.6367
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2914
# Epoch 12: val_loss improved from 1.63666 to 1.42255, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 1.2550 - val_loss: 1.4226
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0934
# Epoch 13: val_loss improved from 1.42255 to 1.18975, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0692 - val_loss: 1.1897
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8833
# Epoch 14: val_loss improved from 1.18975 to 0.98949, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.8768 - val_loss: 0.9895
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7468
# Epoch 15: val_loss improved from 0.98949 to 0.85179, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.7273 - val_loss: 0.8518
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6417
# Epoch 16: val_loss improved from 0.85179 to 0.77031, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.6326 - val_loss: 0.7703
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5853
# Epoch 17: val_loss improved from 0.77031 to 0.72488, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.5760 - val_loss: 0.7249
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5486
# Epoch 18: val_loss improved from 0.72488 to 0.70101, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 0.5419 - val_loss: 0.7010
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5312
# Epoch 19: val_loss improved from 0.70101 to 0.68528, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.5206 - val_loss: 0.6853
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5216
# Epoch 20: val_loss improved from 0.68528 to 0.67275, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5070 - val_loss: 0.6727
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5012
# Epoch 21: val_loss improved from 0.67275 to 0.67124, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.4981 - val_loss: 0.6712
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4974
# Epoch 22: val_loss did not improve from 0.67124
# 2/2 [==============================] - 0s 42ms/step - loss: 0.4951 - val_loss: 0.6816
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5071
# Epoch 23: val_loss did not improve from 0.67124
# 2/2 [==============================] - 0s 49ms/step - loss: 0.4986 - val_loss: 0.7000
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5134
# Epoch 24: val_loss did not improve from 0.67124
# 2/2 [==============================] - 0s 45ms/step - loss: 0.5072 - val_loss: 0.7235
#
#  La media del mse, 4-fold es : 1.1022471884886424
#
#  La desviacion estandar del mse, 4-fold es : 0.5055199908793268

# %%
# rellenar de ceros los espacios vacios de la lista con loss y validation

df_train_losses = pd.DataFrame(train_losses)

df_filled_train_losses = df_train_losses.fillna(0)

train_losses_completa = df_filled_train_losses.values.tolist()

df_val_losses = pd.DataFrame(val_losses)

df_filled_val_losses = df_val_losses.fillna(0)

val_losses_completa = df_filled_val_losses.values.tolist()

# %%
# Calcular el promedio de "average loss" para todos los pliegues y épocas
avg_train_losses = np.mean(train_losses_completa, axis=0)
avg_val_losses = np.mean(val_losses_completa, axis=0)

# vamos a graficar
plt.plot(avg_train_losses, label='Perdida entrenamiento') # Grafico esta para ver si estoy sobre entrenando
plt.plot(avg_val_losses, label='Perdida Validacion') # Grafico esta para ver si estoy sobre entrenando
plt.title('avg loss train, avg loss val vs epoch ')
plt.xlabel('epoch')
plt.ylabel('Mean Square Error')
plt.legend()
plt.show()

# %%
# Cargar el mejor modelo
best_model = load_model(best_model_path)

# %%
# Seleccionar una secuencia específica
index = 0
input_sequence = X_test[index]

# Hacer la predicción
y_pred = best_model.predict(np.expand_dims(input_sequence, axis=0))
# usamos el np.expand_dims() para agregar una dimensión adicional al inicio de input_sequence
print(y_pred.shape)
# Out:
# 1/1 [==============================] - 0s 418ms/step
# (1, 210)

# %%
# Desenrollar X_test para convertirlo en un array bidimensional
X_test_flattened = X_test.reshape(-1, X_test.shape[-1])

# Aplicar la transformación inversa utilizando el objeto StandardScaler
X_test_desnormalizado = sc.inverse_transform(X_test_flattened)

# Volver a darle forma a X_test_desnormalizado a su forma original
X_test = X_test_desnormalizado.reshape(X_test.shape)

# Desnormalizar los datos
y_pred = sc_y.inverse_transform(y_pred)

y_test = sc_y.inverse_transform(y_test)

print(y_pred.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (1, 210)
# (17, 210)
# (17, 15, 2)

# %%
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
Curva=0

plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

print('')
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(X_test[Curva,:,0],color='orange', label='Valores actuales y anteriores de insulina')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_test[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 229.472625

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_pred[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 331.4107191467285

# %%
# Media MSE y desviacion estandar MSE de las prediciones con la escala normal
mse = mean_squared_error(y_test[0,:].flatten(), y_pred.flatten())
std = np.sqrt(mse)
mediamse = np.mean(mse)

print('La media MSE:',mediamse)
print('La desviacion standar MSE', std)

# calcular la MAE
mae = mean_absolute_error(y_test[0,:], y_pred[0,:])
print('MAE:', mae)

# calcular la RMSE
rmse = np.sqrt(mean_squared_error(y_test[0,:], y_pred[0,:]))
print('RMSE:', rmse)
# Out:
# La media MSE: 1214.963674408122
# La desviacion standar MSE 34.856329043778004
# MAE: 32.41455426606678
# RMSE: 34.856329043778004
