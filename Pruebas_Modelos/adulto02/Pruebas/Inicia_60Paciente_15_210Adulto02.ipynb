# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Librerias
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split, KFold
from keras.callbacks import EarlyStopping

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import load_model

from keras.initializers import he_uniform

# %%
#Dataset Adulto 01
data = pd.read_csv('/content/gdrive/MyDrive/Proyecto_de_grado/SUSTENTACION3.0/FinalX3/adulto02/my_adult02A2_data.csv')

print(f"El archivo se ha cargado correctamente. Tiene {data.shape[0]} filas y {data.shape[1]} columnas.")
# Out:
# El archivo se ha cargado correctamente. Tiene 29638 filas y 3 columnas.

# %%
train_size = int(len(data) * 0.7)

train_data = data.iloc[:train_size, :] # 70% entrenamiento
test_data = data.iloc[train_size:, :] # 30% prueba

test_data = test_data.reset_index(drop=True)

# %%
#los indices donde hay ingestas
posicionestrain = train_data.loc[train_data.iloc[:, 0] != 0].index
posicionestest = test_data.loc[test_data.iloc[:, 0] != 0].index

df_posiciones_train = pd.DataFrame(posicionestrain)
df_posiciones_test = pd.DataFrame(posicionestest)

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_train = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_train)):
    anterior = df_posiciones_train.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_train.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_train.append(anterior)

ultimo_elemento_train = df_posiciones_train.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_train.extend(ultimo_elemento_train.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_train)
print(len(cumplen_train))
# Out:
# [494, 862, 1358, 1974, 2353, 2840, 3461, 3846, 4334, 4956, 5324, 5820, 6438, 6815, 7301, 7917, 8283, 8781, 9398, 9781, 10268, 10880, 11255, 11750, 12363, 12742, 13230, 13845, 14212, 14699, 15311, 15686, 16183, 16795, 17162, 17650, 18266, 18653, 19140, 19757, 20125, 20614]
# 42

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_test = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_test)):
    anterior = df_posiciones_test.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_test.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_test.append(anterior)

ultimo_elemento_test = df_posiciones_test.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_test.extend(ultimo_elemento_test.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_test)
print(len(cumplen_test))
# Out:
# [487, 855, 1342, 1956, 2335, 2823, 3439, 3805, 4301, 4916, 5291, 5779, 6398, 6765, 7253, 7868, 8234, 8720]
# 18

# %%
# pasar la escala de los carbohidratos de las ingestas a gramos
data.iloc[:,0] = data.iloc[:,0].apply(lambda x: (x*15)/1000)

# Grafica con mayor detalle, el pico del comportamiento de la glucosa despues de la primera ingesta
print('')
print('Grafica de los datos del dataset')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
plt.title('Ingestas, Insulina y Glucosa')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')

print('Caso 1: Primera ingesta o Desayuno del primer dia:')
plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 700])
plt.ylim([-5, 250])
plt.show()
print('')

print('Caso 2: Primera y segunda ingesta del primer dia:')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1200])
plt.ylim([-5, 500])
plt.show()


print('Caso 3: las tres ingestas del primer dia:')

plt.plot(data.index, data.iloc[:,0], color='blue', label='Ingestas')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Ingestas de carbohidratos')
plt.xlabel('t [min]')
plt.ylabel('gramos')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Dosificación de insulina')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
#plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1800])
plt.ylim([-5, 500])
plt.show()
# Out:
# Grafica de los datos del dataset
# Caso 1: Primera ingesta o Desayuno del primer dia:
# Caso 2: Primera y segunda ingesta del primer dia:
# Caso 3: las tres ingestas del primer dia:

# %%
#Preprocesar los datos:
X_train = train_data.iloc[:, 1:3].values
y_train = train_data.iloc[:,2].values

X_test = test_data.iloc[:, 1:3].values
y_test = test_data.iloc[:, 2].values

print('Tamaño de los datos de entrada, de X_train: ',X_train.shape)
print(f'Tiene {X_train.shape[0]} filas y {X_train.shape[1]} columna')
print('La primera ingesta al minuto 300, ingesta: ',X_train[300])
print('La primera ingesta hasta el minuto 327, ingesta: ',X_train[327])

print('La entrada son los valores de la insulina y glucosa \n',X_train)
print('Tamaño de los datos de salia, de y_train',y_train.shape)
print(f'Tiene {y_train.shape[0]} filas y {y_train.shape[-1]} columnas')
print('La salida son los valores de glucosa \n',y_train)
# Out:
# Tamaño de los datos de entrada, de X_train:  (20746, 2)
# Tiene 20746 filas y 2 columna
# La primera ingesta al minuto 300, ingesta:  [  1.6789 123.44  ]
# La primera ingesta hasta el minuto 327, ingesta:  [  1.6789 123.44  ]
# La entrada son los valores de la insulina y glucosa
#  [[  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  ...
#  [  1.6789 198.03  ]
#  [  1.6789 197.1   ]
#  [  1.6789 196.18  ]]
# Tamaño de los datos de salia, de y_train (20746,)
# Tiene 20746 filas y 20746 columnas
# La salida son los valores de glucosa
#  [123.44 123.44 123.44 ... 198.03 197.1  196.18]

# %%
# Normalizar los datos
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Normalizar y_train
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.reshape(-1, 1))
y_test = sc_y.transform(y_test.reshape(-1, 1))

# %%
# Reorganizar los datos en forma de secuencia
def to_sequences(data,  seq_size_input, seq_size_output):
    X = []
    y = []

    for i in range(len(data)-seq_size_input-seq_size_output+1):
        X.append(data[i:(i+seq_size_input), 0:2])
        y.append(data[(i+seq_size_input):(i+seq_size_input+seq_size_output), 2])

    return np.array(X), np.array(y)

# %%
#CON LOS DATOS NORMALIZADOS
seq_size_input = 15
seq_size_output = 210
X_train, y_train = to_sequences(np.hstack((X_train, y_train)), seq_size_input, seq_size_output)
X_test, y_test = to_sequences(np.hstack((X_test, y_test)), seq_size_input, seq_size_output)
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (20522, 210)
# (20522, 15, 2)
# (8668, 210)
# (8668, 15, 2)

# %%
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
flattened_data = np.reshape(X_train, (X_train.shape[0], -1))

df_X_train = pd.DataFrame(flattened_data)

# %%
flattened_test = np.reshape(X_test, (X_test.shape[0], -1))

df_X_test = pd.DataFrame(flattened_test)

# %%
df_y_train = pd.DataFrame(y_train)
df_y_test = pd.DataFrame(y_test)

# %%
# Filtrar el dataframe para mantener solo las filas especificadas
df_X_train_seleccionado = df_X_train[df_X_train.index.isin(cumplen_train)]
df_y_train_seleccionado = df_y_train[df_y_train.index.isin(cumplen_train)]
df_X_test_seleccionado = df_X_test[df_X_test.index.isin(cumplen_test)]
df_y_test_seleccionado = df_y_test[df_y_test.index.isin(cumplen_test)]

# %%
print('Grafica de los datos del dataset')
#plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')

Numerocurva = 0

plt.plot(df_X_train_seleccionado.iloc[Numerocurva, 1::2],color='green',label='Entrada glucosa') #Para mostrar solo la glucosa
plt.plot(df_X_train_seleccionado.iloc[Numerocurva, ::2],color='orange',label='Entrada insulina') #Para mostrar solo la glucosa
plt.plot(range(seq_size_input*2, seq_size_output + seq_size_input*2),df_y_train_seleccionado.iloc[Numerocurva,:], color='red',label='Salida glucosa')
plt.title('Entradas y salidas, entrenamiento')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')
# Out:
# Grafica de los datos del dataset

# %%
X_train = df_X_train_seleccionado.values
y_train = df_y_train_seleccionado.values
X_test = df_X_test_seleccionado.values
y_test = df_y_test_seleccionado.values

print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 30)
# (17, 210)
# (17, 30)

# %%
print(len(X_test))
# Out:
# 17

# %%
X_train = np.reshape(X_train, (len(X_train), seq_size_input, 2))

X_test = np.reshape(X_test, (len(X_test), seq_size_input, 2))
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 15, 2)
# (17, 210)
# (17, 15, 2)

# %%
kf = KFold(n_splits=5)
kf.get_n_splits(X_train)
KFold(n_splits=5, random_state=None, shuffle=False)


# Crear listas para almacenar los valores del "average loss" de entrenamiento y validación en cada pliegue
train_losses = []
val_losses = []

#Para guardar el mejor modelo
best_loss = float('inf')
best_model_path = ""

for i, (train_index, test_index) in enumerate(kf.split(X_train,y_train)):
  model = Sequential()
  model.add(LSTM(60, activation='tanh', input_shape=(seq_size_input, 2), kernel_initializer=he_uniform()))
  model.add(Dense(seq_size_output, activation='linear', kernel_initializer=he_uniform()))


  model.compile(optimizer='adam', loss='mse')
  print(model.summary())

  filepath = f"modelo-{i+1}.h5"
  early_stop = EarlyStopping(monitor='val_loss', patience=3)
  checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

  X, y =  X_train[train_index], y_train[train_index]
  X_val, y_val = X_train[test_index], y_train[test_index]


  history = model.fit(X, y, epochs=100, batch_size=32,validation_data=(X_val, y_val),callbacks=[checkpoint, early_stop] )

  mediamse = np.mean( history.history['loss'] )
  stdmse = np.std(  history.history['loss'])
  print('')
  print(f" La media del mse, {i}-fold es : {mediamse}")
  print('')
  print(f" La desviacion estandar del mse, {i}-fold es : {stdmse}")

  # Obtener los valores de "average loss" para el pliegue actual
  fold_train_losses = model.history.history['loss']
  fold_val_losses = model.history.history['val_loss']

  # Almacenar los valores de "average loss" para el pliegue actual
  train_losses.append(fold_train_losses)
  val_losses.append(fold_val_losses)

  if min(fold_val_losses) < best_loss:
        best_loss = min(fold_val_losses)
        best_model_path = filepath

  history.history.keys() # aqui me muestra que esta guardando, con history me guarda todos los valores que calcula durante el proceso de entrenamiento

  # vamos a graficar
  plt.plot(history.history['loss'], label='Perdida') # Grafico esta para ver si estoy sobre entrenando
  plt.plot(history.history['val_loss'], label='Validacion') # Grafico esta para ver si estoy sobre entrenando
  plt.xlabel('epoch')
  plt.ylabel('Mean Square Error')
  plt.legend()
  plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 60)                15120
#
#  dense_5 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8311
# Epoch 1: val_loss improved from inf to 1.88578, saving model to modelo-1.h5
# 1/1 [==============================] - 2s 2s/step - loss: 1.8311 - val_loss: 1.8858
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8001
# Epoch 2: val_loss improved from 1.88578 to 1.85556, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 80ms/step - loss: 1.8001 - val_loss: 1.8556
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7705
# Epoch 3: val_loss improved from 1.85556 to 1.82639, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 75ms/step - loss: 1.7705 - val_loss: 1.8264
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7421
# Epoch 4: val_loss improved from 1.82639 to 1.79794, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 81ms/step - loss: 1.7421 - val_loss: 1.7979
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7144
# Epoch 5: val_loss improved from 1.79794 to 1.76993, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 90ms/step - loss: 1.7144 - val_loss: 1.7699
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6871
# Epoch 6: val_loss improved from 1.76993 to 1.74212, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 81ms/step - loss: 1.6871 - val_loss: 1.7421
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6601
# Epoch 7: val_loss improved from 1.74212 to 1.71430, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 115ms/step - loss: 1.6601 - val_loss: 1.7143
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6331
# Epoch 8: val_loss improved from 1.71430 to 1.68625, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 1.6331 - val_loss: 1.6862
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6060
# Epoch 9: val_loss improved from 1.68625 to 1.65776, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 90ms/step - loss: 1.6060 - val_loss: 1.6578
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5784
# Epoch 10: val_loss improved from 1.65776 to 1.62865, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 105ms/step - loss: 1.5784 - val_loss: 1.6287
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5502
# Epoch 11: val_loss improved from 1.62865 to 1.59872, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 89ms/step - loss: 1.5502 - val_loss: 1.5987
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5213
# Epoch 12: val_loss improved from 1.59872 to 1.56778, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 81ms/step - loss: 1.5213 - val_loss: 1.5678
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4913
# Epoch 13: val_loss improved from 1.56778 to 1.53563, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 100ms/step - loss: 1.4913 - val_loss: 1.5356
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4603
# Epoch 14: val_loss improved from 1.53563 to 1.50209, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 92ms/step - loss: 1.4603 - val_loss: 1.5021
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4279
# Epoch 15: val_loss improved from 1.50209 to 1.46698, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 102ms/step - loss: 1.4279 - val_loss: 1.4670
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3940
# Epoch 16: val_loss improved from 1.46698 to 1.43013, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 101ms/step - loss: 1.3940 - val_loss: 1.4301
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3585
# Epoch 17: val_loss improved from 1.43013 to 1.39140, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 1.3585 - val_loss: 1.3914
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3212
# Epoch 18: val_loss improved from 1.39140 to 1.35067, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 1.3212 - val_loss: 1.3507
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2820
# Epoch 19: val_loss improved from 1.35067 to 1.30791, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 1.2820 - val_loss: 1.3079
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2408
# Epoch 20: val_loss improved from 1.30791 to 1.26315, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 1.2408 - val_loss: 1.2631
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1978
# Epoch 21: val_loss improved from 1.26315 to 1.21653, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 1.1978 - val_loss: 1.2165
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1531
# Epoch 22: val_loss improved from 1.21653 to 1.16833, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 1.1531 - val_loss: 1.1683
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1069
# Epoch 23: val_loss improved from 1.16833 to 1.11898, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 1.1069 - val_loss: 1.1190
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0597
# Epoch 24: val_loss improved from 1.11898 to 1.06905, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 1.0597 - val_loss: 1.0691
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0120
# Epoch 25: val_loss improved from 1.06905 to 1.01923, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 1.0120 - val_loss: 1.0192
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9646
# Epoch 26: val_loss improved from 1.01923 to 0.97023, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 0.9646 - val_loss: 0.9702
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9180
# Epoch 27: val_loss improved from 0.97023 to 0.92273, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 50ms/step - loss: 0.9180 - val_loss: 0.9227
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8729
# Epoch 28: val_loss improved from 0.92273 to 0.87724, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 56ms/step - loss: 0.8729 - val_loss: 0.8772
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8299
# Epoch 29: val_loss improved from 0.87724 to 0.83401, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 59ms/step - loss: 0.8299 - val_loss: 0.8340
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7891
# Epoch 30: val_loss improved from 0.83401 to 0.79298, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 0.7891 - val_loss: 0.7930
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7504
# Epoch 31: val_loss improved from 0.79298 to 0.75383, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 0.7504 - val_loss: 0.7538
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7135
# Epoch 32: val_loss improved from 0.75383 to 0.71606, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 55ms/step - loss: 0.7135 - val_loss: 0.7161
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6778
# Epoch 33: val_loss improved from 0.71606 to 0.67913, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6778 - val_loss: 0.6791
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6429
# Epoch 34: val_loss improved from 0.67913 to 0.64262, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 50ms/step - loss: 0.6429 - val_loss: 0.6426
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6083
# Epoch 35: val_loss improved from 0.64262 to 0.60630, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 0.6083 - val_loss: 0.6063
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5737
# Epoch 36: val_loss improved from 0.60630 to 0.57017, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 0.5737 - val_loss: 0.5702
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5392
# Epoch 37: val_loss improved from 0.57017 to 0.53449, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5392 - val_loss: 0.5345
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5051
# Epoch 38: val_loss improved from 0.53449 to 0.49964, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5051 - val_loss: 0.4996
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4717
# Epoch 39: val_loss improved from 0.49964 to 0.46610, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4717 - val_loss: 0.4661
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4396
# Epoch 40: val_loss improved from 0.46610 to 0.43433, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 54ms/step - loss: 0.4396 - val_loss: 0.4343
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4092
# Epoch 41: val_loss improved from 0.43433 to 0.40465, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4092 - val_loss: 0.4047
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3810
# Epoch 42: val_loss improved from 0.40465 to 0.37720, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 54ms/step - loss: 0.3810 - val_loss: 0.3772
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3550
# Epoch 43: val_loss improved from 0.37720 to 0.35186, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3550 - val_loss: 0.3519
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3311
# Epoch 44: val_loss improved from 0.35186 to 0.32828, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3311 - val_loss: 0.3283
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3090
# Epoch 45: val_loss improved from 0.32828 to 0.30605, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.3090 - val_loss: 0.3061
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2883
# Epoch 46: val_loss improved from 0.30605 to 0.28480, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.2883 - val_loss: 0.2848
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2685
# Epoch 47: val_loss improved from 0.28480 to 0.26433, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.2685 - val_loss: 0.2643
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2496
# Epoch 48: val_loss improved from 0.26433 to 0.24469, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 93ms/step - loss: 0.2496 - val_loss: 0.2447
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2315
# Epoch 49: val_loss improved from 0.24469 to 0.22609, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.2315 - val_loss: 0.2261
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2144
# Epoch 50: val_loss improved from 0.22609 to 0.20886, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 78ms/step - loss: 0.2144 - val_loss: 0.2089
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1986
# Epoch 51: val_loss improved from 0.20886 to 0.19322, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1986 - val_loss: 0.1932
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1845
# Epoch 52: val_loss improved from 0.19322 to 0.17925, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1845 - val_loss: 0.1793
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1719
# Epoch 53: val_loss improved from 0.17925 to 0.16679, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.1719 - val_loss: 0.1668
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1607
# Epoch 54: val_loss improved from 0.16679 to 0.15550, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1607 - val_loss: 0.1555
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1507
# Epoch 55: val_loss improved from 0.15550 to 0.14504, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1507 - val_loss: 0.1450
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1413
# Epoch 56: val_loss improved from 0.14504 to 0.13519, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1413 - val_loss: 0.1352
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1324
# Epoch 57: val_loss improved from 0.13519 to 0.12591, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1324 - val_loss: 0.1259
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1239
# Epoch 58: val_loss improved from 0.12591 to 0.11732, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1239 - val_loss: 0.1173
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1159
# Epoch 59: val_loss improved from 0.11732 to 0.10956, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 83ms/step - loss: 0.1159 - val_loss: 0.1096
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1087
# Epoch 60: val_loss improved from 0.10956 to 0.10267, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.1087 - val_loss: 0.1027
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1022
# Epoch 61: val_loss improved from 0.10267 to 0.09657, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 89ms/step - loss: 0.1022 - val_loss: 0.0966
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0965
# Epoch 62: val_loss improved from 0.09657 to 0.09106, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0965 - val_loss: 0.0911
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0913
# Epoch 63: val_loss improved from 0.09106 to 0.08594, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0913 - val_loss: 0.0859
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0864
# Epoch 64: val_loss improved from 0.08594 to 0.08108, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0864 - val_loss: 0.0811
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0819
# Epoch 65: val_loss improved from 0.08108 to 0.07643, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0819 - val_loss: 0.0764
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0775
# Epoch 66: val_loss improved from 0.07643 to 0.07203, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0775 - val_loss: 0.0720
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0734
# Epoch 67: val_loss improved from 0.07203 to 0.06795, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0734 - val_loss: 0.0679
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0697
# Epoch 68: val_loss improved from 0.06795 to 0.06424, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0697 - val_loss: 0.0642
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0662
# Epoch 69: val_loss improved from 0.06424 to 0.06091, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0662 - val_loss: 0.0609
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0631
# Epoch 70: val_loss improved from 0.06091 to 0.05789, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0631 - val_loss: 0.0579
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0603
# Epoch 71: val_loss improved from 0.05789 to 0.05512, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0603 - val_loss: 0.0551
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0577
# Epoch 72: val_loss improved from 0.05512 to 0.05254, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0577 - val_loss: 0.0525
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0551
# Epoch 73: val_loss improved from 0.05254 to 0.05013, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0551 - val_loss: 0.0501
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0527
# Epoch 74: val_loss improved from 0.05013 to 0.04788, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0527 - val_loss: 0.0479
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0504
# Epoch 75: val_loss improved from 0.04788 to 0.04582, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0504 - val_loss: 0.0458
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0482
# Epoch 76: val_loss improved from 0.04582 to 0.04392, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0482 - val_loss: 0.0439
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0462
# Epoch 77: val_loss improved from 0.04392 to 0.04218, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0462 - val_loss: 0.0422
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0443
# Epoch 78: val_loss improved from 0.04218 to 0.04053, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0443 - val_loss: 0.0405
# Epoch 79/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0426
# Epoch 79: val_loss improved from 0.04053 to 0.03894, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0426 - val_loss: 0.0389
# Epoch 80/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0409
# Epoch 80: val_loss improved from 0.03894 to 0.03739, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0409 - val_loss: 0.0374
# Epoch 81/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0393
# Epoch 81: val_loss improved from 0.03739 to 0.03585, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0393 - val_loss: 0.0359
# Epoch 82/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0378
# Epoch 82: val_loss improved from 0.03585 to 0.03436, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0378 - val_loss: 0.0344
# Epoch 83/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0363
# Epoch 83: val_loss improved from 0.03436 to 0.03293, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0363 - val_loss: 0.0329
# Epoch 84/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0349
# Epoch 84: val_loss improved from 0.03293 to 0.03159, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0349 - val_loss: 0.0316
# Epoch 85/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0336
# Epoch 85: val_loss improved from 0.03159 to 0.03035, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0336 - val_loss: 0.0303
# Epoch 86/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0324
# Epoch 86: val_loss improved from 0.03035 to 0.02920, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0324 - val_loss: 0.0292
# Epoch 87/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0312
# Epoch 87: val_loss improved from 0.02920 to 0.02813, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0312 - val_loss: 0.0281
# Epoch 88/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0301
# Epoch 88: val_loss improved from 0.02813 to 0.02713, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0301 - val_loss: 0.0271
# Epoch 89/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0291
# Epoch 89: val_loss improved from 0.02713 to 0.02620, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0291 - val_loss: 0.0262
# Epoch 90/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0281
# Epoch 90: val_loss improved from 0.02620 to 0.02534, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0281 - val_loss: 0.0253
# Epoch 91/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0272
# Epoch 91: val_loss improved from 0.02534 to 0.02453, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0272 - val_loss: 0.0245
# Epoch 92/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0263
# Epoch 92: val_loss improved from 0.02453 to 0.02376, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0263 - val_loss: 0.0238
# Epoch 93/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0254
# Epoch 93: val_loss improved from 0.02376 to 0.02303, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0254 - val_loss: 0.0230
# Epoch 94/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0246
# Epoch 94: val_loss improved from 0.02303 to 0.02232, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0246 - val_loss: 0.0223
# Epoch 95/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0239
# Epoch 95: val_loss improved from 0.02232 to 0.02162, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0239 - val_loss: 0.0216
# Epoch 96/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0231
# Epoch 96: val_loss improved from 0.02162 to 0.02093, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0231 - val_loss: 0.0209
# Epoch 97/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0224
# Epoch 97: val_loss improved from 0.02093 to 0.02026, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0224 - val_loss: 0.0203
# Epoch 98/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0218
# Epoch 98: val_loss improved from 0.02026 to 0.01962, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0218 - val_loss: 0.0196
# Epoch 99/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0211
# Epoch 99: val_loss improved from 0.01962 to 0.01901, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0211 - val_loss: 0.0190
# Epoch 100/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0205
# Epoch 100: val_loss improved from 0.01901 to 0.01844, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0205 - val_loss: 0.0184
#
#  La media del mse, 0-fold es : 0.5329824189841748
#
#  La desviacion estandar del mse, 0-fold es : 0.5945860938980628
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 60)                15120
#
#  dense_6 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 2.0164
# Epoch 1: val_loss improved from inf to 1.47122, saving model to modelo-2.h5
# 2/2 [==============================] - 3s 708ms/step - loss: 1.9818 - val_loss: 1.4712
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9536
# Epoch 2: val_loss improved from 1.47122 to 1.41872, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 1.9154 - val_loss: 1.4187
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9094
# Epoch 3: val_loss improved from 1.41872 to 1.37360, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 1.8599 - val_loss: 1.3736
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6984
# Epoch 4: val_loss improved from 1.37360 to 1.33283, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.8107 - val_loss: 1.3328
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8021
# Epoch 5: val_loss improved from 1.33283 to 1.29366, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 88ms/step - loss: 1.7665 - val_loss: 1.2937
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7693
# Epoch 6: val_loss improved from 1.29366 to 1.25566, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 81ms/step - loss: 1.7228 - val_loss: 1.2557
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5935
# Epoch 7: val_loss improved from 1.25566 to 1.21672, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.6797 - val_loss: 1.2167
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6667
# Epoch 8: val_loss improved from 1.21672 to 1.17522, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 1.6370 - val_loss: 1.1752
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4861
# Epoch 9: val_loss improved from 1.17522 to 1.13055, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 1.5894 - val_loss: 1.1306
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5696
# Epoch 10: val_loss improved from 1.13055 to 1.08276, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 1.5404 - val_loss: 1.0828
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4542
# Epoch 11: val_loss improved from 1.08276 to 1.03134, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 1.4857 - val_loss: 1.0313
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4569
# Epoch 12: val_loss improved from 1.03134 to 0.97685, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 1.4287 - val_loss: 0.9768
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3379
# Epoch 13: val_loss improved from 0.97685 to 0.91964, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 1.3654 - val_loss: 0.9196
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3306
# Epoch 14: val_loss improved from 0.91964 to 0.86184, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.3007 - val_loss: 0.8618
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2614
# Epoch 15: val_loss improved from 0.86184 to 0.80593, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 1.2323 - val_loss: 0.8059
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1957
# Epoch 16: val_loss improved from 0.80593 to 0.75302, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 1.1656 - val_loss: 0.7530
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1257
# Epoch 17: val_loss improved from 0.75302 to 0.70229, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.1009 - val_loss: 0.7023
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0671
# Epoch 18: val_loss improved from 0.70229 to 0.65375, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 1.0398 - val_loss: 0.6538
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0068
# Epoch 19: val_loss improved from 0.65375 to 0.60862, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 0.9808 - val_loss: 0.6086
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9505
# Epoch 20: val_loss improved from 0.60862 to 0.56722, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 0.9260 - val_loss: 0.5672
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8965
# Epoch 21: val_loss improved from 0.56722 to 0.52782, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 0.8752 - val_loss: 0.5278
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8480
# Epoch 22: val_loss improved from 0.52782 to 0.48857, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 0.8263 - val_loss: 0.4886
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7152
# Epoch 23: val_loss improved from 0.48857 to 0.44491, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 0.7749 - val_loss: 0.4449
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7387
# Epoch 24: val_loss improved from 0.44491 to 0.40145, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.7200 - val_loss: 0.4014
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6790
# Epoch 25: val_loss improved from 0.40145 to 0.36407, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.6615 - val_loss: 0.3641
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6263
# Epoch 26: val_loss improved from 0.36407 to 0.33026, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6097 - val_loss: 0.3303
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5781
# Epoch 27: val_loss improved from 0.33026 to 0.29959, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 0.5627 - val_loss: 0.2996
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4850
# Epoch 28: val_loss improved from 0.29959 to 0.26908, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.5180 - val_loss: 0.2691
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4869
# Epoch 29: val_loss improved from 0.26908 to 0.23917, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.4743 - val_loss: 0.2392
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3913
# Epoch 30: val_loss improved from 0.23917 to 0.21114, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 0.4257 - val_loss: 0.2111
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3926
# Epoch 31: val_loss improved from 0.21114 to 0.18686, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 0.3821 - val_loss: 0.1869
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3477
# Epoch 32: val_loss improved from 0.18686 to 0.16707, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 0.3388 - val_loss: 0.1671
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2971
# Epoch 33: val_loss improved from 0.16707 to 0.15043, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.3016 - val_loss: 0.1504
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2785
# Epoch 34: val_loss improved from 0.15043 to 0.13529, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.2711 - val_loss: 0.1353
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2475
# Epoch 35: val_loss improved from 0.13529 to 0.12189, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 0.2424 - val_loss: 0.1219
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2214
# Epoch 36: val_loss improved from 0.12189 to 0.11114, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.2166 - val_loss: 0.1111
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1686
# Epoch 37: val_loss improved from 0.11114 to 0.10855, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1930 - val_loss: 0.1085
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1824
# Epoch 38: val_loss did not improve from 0.10855
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1784 - val_loss: 0.1110
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1648
# Epoch 39: val_loss improved from 0.10855 to 0.10152, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1661 - val_loss: 0.1015
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1405
# Epoch 40: val_loss improved from 0.10152 to 0.08667, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1454 - val_loss: 0.0867
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1263
# Epoch 41: val_loss improved from 0.08667 to 0.07695, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 0.1241 - val_loss: 0.0770
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1120
# Epoch 42: val_loss improved from 0.07695 to 0.07076, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1093 - val_loss: 0.0708
# Epoch 43/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1024
# Epoch 43: val_loss improved from 0.07076 to 0.06655, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0999 - val_loss: 0.0665
# Epoch 44/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0798
# Epoch 44: val_loss improved from 0.06655 to 0.06556, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0915 - val_loss: 0.0656
# Epoch 45/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0829
# Epoch 45: val_loss did not improve from 0.06556
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0818 - val_loss: 0.0720
# Epoch 46/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0759
# Epoch 46: val_loss did not improve from 0.06556
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0749 - val_loss: 0.0822
# Epoch 47/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0716
# Epoch 47: val_loss did not improve from 0.06556
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0744 - val_loss: 0.0872
#
#  La media del mse, 1-fold es : 0.8312594178826251
#
#  La desviacion estandar del mse, 1-fold es : 0.6226468574689434
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 60)                15120
#
#  dense_7 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 1.9590
# Epoch 1: val_loss improved from inf to 1.70931, saving model to modelo-3.h5
# 2/2 [==============================] - 2s 399ms/step - loss: 1.9093 - val_loss: 1.7093
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8908
# Epoch 2: val_loss improved from 1.70931 to 1.66473, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 1.8540 - val_loss: 1.6647
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8399
# Epoch 3: val_loss improved from 1.66473 to 1.62273, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 1.8073 - val_loss: 1.6227
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6682
# Epoch 4: val_loss improved from 1.62273 to 1.58125, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.7618 - val_loss: 1.5812
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7502
# Epoch 5: val_loss improved from 1.58125 to 1.54052, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 1.7171 - val_loss: 1.5405
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7159
# Epoch 6: val_loss improved from 1.54052 to 1.50086, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.6720 - val_loss: 1.5009
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6276
# Epoch 7: val_loss improved from 1.50086 to 1.45994, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 1.6273 - val_loss: 1.4599
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6110
# Epoch 8: val_loss improved from 1.45994 to 1.41638, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.5818 - val_loss: 1.4164
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5279
# Epoch 9: val_loss improved from 1.41638 to 1.36912, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 1.5320 - val_loss: 1.3691
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4745
# Epoch 10: val_loss improved from 1.36912 to 1.31641, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 1.4778 - val_loss: 1.3164
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3417
# Epoch 11: val_loss improved from 1.31641 to 1.25794, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 1.4158 - val_loss: 1.2579
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3176
# Epoch 12: val_loss improved from 1.25794 to 1.19439, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 1.3479 - val_loss: 1.1944
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3098
# Epoch 13: val_loss improved from 1.19439 to 1.13007, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 1.2754 - val_loss: 1.1301
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1786
# Epoch 14: val_loss improved from 1.13007 to 1.06527, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.1982 - val_loss: 1.0653
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1049
# Epoch 15: val_loss improved from 1.06527 to 0.99893, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 1.1223 - val_loss: 0.9989
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0733
# Epoch 16: val_loss improved from 0.99893 to 0.93596, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.0462 - val_loss: 0.9360
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9970
# Epoch 17: val_loss improved from 0.93596 to 0.87739, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 0.9719 - val_loss: 0.8774
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8516
# Epoch 18: val_loss improved from 0.87739 to 0.81948, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.9018 - val_loss: 0.8195
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8587
# Epoch 19: val_loss improved from 0.81948 to 0.76312, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 0.8380 - val_loss: 0.7631
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7897
# Epoch 20: val_loss improved from 0.76312 to 0.70851, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 0.7733 - val_loss: 0.7085
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7182
# Epoch 21: val_loss improved from 0.70851 to 0.65497, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 0.7122 - val_loss: 0.6550
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6021
# Epoch 22: val_loss improved from 0.65497 to 0.60183, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6515 - val_loss: 0.6018
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5658
# Epoch 23: val_loss improved from 0.60183 to 0.55042, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.5921 - val_loss: 0.5504
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5485
# Epoch 24: val_loss improved from 0.55042 to 0.50043, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5359 - val_loss: 0.5004
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4916
# Epoch 25: val_loss improved from 0.50043 to 0.44888, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 0.4804 - val_loss: 0.4489
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4358
# Epoch 26: val_loss improved from 0.44888 to 0.39911, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 0.4269 - val_loss: 0.3991
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3869
# Epoch 27: val_loss improved from 0.39911 to 0.35923, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 0.3776 - val_loss: 0.3592
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3462
# Epoch 28: val_loss improved from 0.35923 to 0.33126, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 0.3383 - val_loss: 0.3313
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3179
# Epoch 29: val_loss improved from 0.33126 to 0.30959, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 0.3105 - val_loss: 0.3096
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2945
# Epoch 30: val_loss improved from 0.30959 to 0.28636, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 0.2879 - val_loss: 0.2864
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2696
# Epoch 31: val_loss improved from 0.28636 to 0.26090, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 0.2635 - val_loss: 0.2609
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2428
# Epoch 32: val_loss improved from 0.26090 to 0.23822, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.2372 - val_loss: 0.2382
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2025
# Epoch 33: val_loss improved from 0.23822 to 0.22007, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.2130 - val_loss: 0.2201
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1998
# Epoch 34: val_loss improved from 0.22007 to 0.20792, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.1951 - val_loss: 0.2079
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1851
# Epoch 35: val_loss improved from 0.20792 to 0.19201, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1827 - val_loss: 0.1920
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1530
# Epoch 36: val_loss improved from 0.19201 to 0.17112, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 0.1662 - val_loss: 0.1711
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1502
# Epoch 37: val_loss improved from 0.17112 to 0.15292, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1470 - val_loss: 0.1529
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1326
# Epoch 38: val_loss improved from 0.15292 to 0.13863, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1298 - val_loss: 0.1386
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1187
# Epoch 39: val_loss improved from 0.13863 to 0.12746, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1163 - val_loss: 0.1275
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0966
# Epoch 40: val_loss improved from 0.12746 to 0.11690, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1051 - val_loss: 0.1169
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0984
# Epoch 41: val_loss improved from 0.11690 to 0.10692, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0962 - val_loss: 0.1069
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0894
# Epoch 42: val_loss improved from 0.10692 to 0.09884, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0877 - val_loss: 0.0988
# Epoch 43/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0781
# ...
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7009
# Epoch 4: val_loss improved from 2.09333 to 2.04821, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 1.6686 - val_loss: 2.0482
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6692
# Epoch 5: val_loss improved from 2.04821 to 2.00649, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 106ms/step - loss: 1.6276 - val_loss: 2.0065
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5009
# Epoch 6: val_loss improved from 2.00649 to 1.96296, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 1.5889 - val_loss: 1.9630
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4639
# Epoch 7: val_loss improved from 1.96296 to 1.91418, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 1.5504 - val_loss: 1.9142
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5350
# Epoch 8: val_loss improved from 1.91418 to 1.86377, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 1.5102 - val_loss: 1.8638
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5062
# Epoch 9: val_loss improved from 1.86377 to 1.81459, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 1.4681 - val_loss: 1.8146
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4532
# Epoch 10: val_loss improved from 1.81459 to 1.76548, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 1.4260 - val_loss: 1.7655
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3129
# Epoch 11: val_loss improved from 1.76548 to 1.71083, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 1.3827 - val_loss: 1.7108
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3644
# Epoch 12: val_loss improved from 1.71083 to 1.65090, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 1.3372 - val_loss: 1.6509
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3104
# Epoch 13: val_loss improved from 1.65090 to 1.58881, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 92ms/step - loss: 1.2866 - val_loss: 1.5888
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2573
# Epoch 14: val_loss improved from 1.58881 to 1.52358, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 92ms/step - loss: 1.2341 - val_loss: 1.5236
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2041
# Epoch 15: val_loss improved from 1.52358 to 1.45520, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 72ms/step - loss: 1.1791 - val_loss: 1.4552
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1467
# Epoch 16: val_loss improved from 1.45520 to 1.38426, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 80ms/step - loss: 1.1218 - val_loss: 1.3843
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0850
# Epoch 17: val_loss improved from 1.38426 to 1.31103, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 1.0628 - val_loss: 1.3110
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0250
# Epoch 18: val_loss improved from 1.31103 to 1.23647, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 1.0026 - val_loss: 1.2365
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9411
# Epoch 19: val_loss improved from 1.23647 to 1.15804, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 0.9411 - val_loss: 1.1580
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9030
# Epoch 20: val_loss improved from 1.15804 to 1.08022, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 106ms/step - loss: 0.8798 - val_loss: 1.0802
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8374
# Epoch 21: val_loss improved from 1.08022 to 1.00794, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.8182 - val_loss: 1.0079
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7783
# Epoch 22: val_loss improved from 1.00794 to 0.93947, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 0.7612 - val_loss: 0.9395
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6907
# Epoch 23: val_loss improved from 0.93947 to 0.86891, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 89ms/step - loss: 0.7059 - val_loss: 0.8689
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6688
# Epoch 24: val_loss improved from 0.86891 to 0.80001, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.6531 - val_loss: 0.8000
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6154
# Epoch 25: val_loss improved from 0.80001 to 0.73867, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 0.6002 - val_loss: 0.7387
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5660
# Epoch 26: val_loss improved from 0.73867 to 0.68382, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5521 - val_loss: 0.6838
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5018
# Epoch 27: val_loss improved from 0.68382 to 0.62855, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 0.5078 - val_loss: 0.6286
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4775
# Epoch 28: val_loss improved from 0.62855 to 0.57298, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4660 - val_loss: 0.5730
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3816
# Epoch 29: val_loss improved from 0.57298 to 0.51481, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.4219 - val_loss: 0.5148
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3915
# Epoch 30: val_loss improved from 0.51481 to 0.45758, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.3819 - val_loss: 0.4576
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3300
# Epoch 31: val_loss improved from 0.45758 to 0.40489, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 0.3406 - val_loss: 0.4049
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3125
# Epoch 32: val_loss improved from 0.40489 to 0.35541, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.3060 - val_loss: 0.3554
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2760
# Epoch 33: val_loss improved from 0.35541 to 0.31506, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.2699 - val_loss: 0.3151
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2020
# Epoch 34: val_loss improved from 0.31506 to 0.27966, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.2371 - val_loss: 0.2797
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2196
# Epoch 35: val_loss improved from 0.27966 to 0.24330, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.2143 - val_loss: 0.2433
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1937
# Epoch 36: val_loss improved from 0.24330 to 0.21094, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1904 - val_loss: 0.2109
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1715
# Epoch 37: val_loss improved from 0.21094 to 0.18347, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1687 - val_loss: 0.1835
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1544
# Epoch 38: val_loss improved from 0.18347 to 0.16266, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1509 - val_loss: 0.1627
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1375
# Epoch 39: val_loss improved from 0.16266 to 0.14684, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.1376 - val_loss: 0.1468
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1149
# Epoch 40: val_loss improved from 0.14684 to 0.13295, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.1247 - val_loss: 0.1330
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1135
# Epoch 41: val_loss improved from 0.13295 to 0.11938, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1140 - val_loss: 0.1194
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1062
# Epoch 42: val_loss improved from 0.11938 to 0.10749, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.1042 - val_loss: 0.1075
# Epoch 43/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0961
# Epoch 43: val_loss improved from 0.10749 to 0.09489, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0950 - val_loss: 0.0949
# Epoch 44/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0792
# Epoch 44: val_loss improved from 0.09489 to 0.08153, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0851 - val_loss: 0.0815
# Epoch 45/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0777
# Epoch 45: val_loss improved from 0.08153 to 0.07057, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0768 - val_loss: 0.0706
# Epoch 46/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0724
# Epoch 46: val_loss improved from 0.07057 to 0.06360, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0715 - val_loss: 0.0636
# Epoch 47/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0700
# Epoch 47: val_loss improved from 0.06360 to 0.05794, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0691 - val_loss: 0.0579
# Epoch 48/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0669
# Epoch 48: val_loss improved from 0.05794 to 0.05207, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0661 - val_loss: 0.0521
# Epoch 49/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0618
# Epoch 49: val_loss improved from 0.05207 to 0.04643, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0609 - val_loss: 0.0464
# Epoch 50/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0546
# Epoch 50: val_loss improved from 0.04643 to 0.04343, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0538 - val_loss: 0.0434
# Epoch 51/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0492
# Epoch 51: val_loss improved from 0.04343 to 0.04191, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0486 - val_loss: 0.0419
# Epoch 52/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0462
# Epoch 52: val_loss improved from 0.04191 to 0.04000, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0457 - val_loss: 0.0400
# Epoch 53/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0440
# Epoch 53: val_loss improved from 0.04000 to 0.03764, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0432 - val_loss: 0.0376
# Epoch 54/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0414
# Epoch 54: val_loss improved from 0.03764 to 0.03497, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0406 - val_loss: 0.0350
# Epoch 55/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0389
# Epoch 55: val_loss improved from 0.03497 to 0.03247, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0381 - val_loss: 0.0325
# Epoch 56/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0356
# Epoch 56: val_loss improved from 0.03247 to 0.03211, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0361 - val_loss: 0.0321
# Epoch 57/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0274
# Epoch 57: val_loss improved from 0.03211 to 0.03108, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0346 - val_loss: 0.0311
# Epoch 58/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0334
# Epoch 58: val_loss improved from 0.03108 to 0.02757, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0327 - val_loss: 0.0276
# Epoch 59/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0310
# Epoch 59: val_loss improved from 0.02757 to 0.02497, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0303 - val_loss: 0.0250
# Epoch 60/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0291
# Epoch 60: val_loss improved from 0.02497 to 0.02310, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0286 - val_loss: 0.0231
# Epoch 61/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0278
# Epoch 61: val_loss improved from 0.02310 to 0.02166, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0274 - val_loss: 0.0217
# Epoch 62/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0269
# Epoch 62: val_loss improved from 0.02166 to 0.02048, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0264 - val_loss: 0.0205
# Epoch 63/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0258
# Epoch 63: val_loss improved from 0.02048 to 0.01947, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0253 - val_loss: 0.0195
# Epoch 64/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0247
# Epoch 64: val_loss improved from 0.01947 to 0.01855, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0243 - val_loss: 0.0186
# Epoch 65/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0232
# Epoch 65: val_loss improved from 0.01855 to 0.01754, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0232 - val_loss: 0.0175
# Epoch 66/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0221
# Epoch 66: val_loss improved from 0.01754 to 0.01687, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0218 - val_loss: 0.0169
# Epoch 67/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0206
# Epoch 67: val_loss did not improve from 0.01687
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0205 - val_loss: 0.0172
# Epoch 68/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0205
# Epoch 68: val_loss did not improve from 0.01687
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0202 - val_loss: 0.0182
# Epoch 69/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0209
# Epoch 69: val_loss did not improve from 0.01687
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0205 - val_loss: 0.0181
#
#  La media del mse, 4-fold es : 0.535715077828238
#
#  La desviacion estandar del mse, 4-fold es : 0.5893028588126853

# %%
# rellenar de ceros los espacios vacios de la lista con loss y validation

df_train_losses = pd.DataFrame(train_losses)

df_filled_train_losses = df_train_losses.fillna(0)

train_losses_completa = df_filled_train_losses.values.tolist()

df_val_losses = pd.DataFrame(val_losses)

df_filled_val_losses = df_val_losses.fillna(0)

val_losses_completa = df_filled_val_losses.values.tolist()

# %%
# Calcular el promedio de "average loss" para todos los pliegues y épocas
avg_train_losses = np.mean(train_losses_completa, axis=0)
avg_val_losses = np.mean(val_losses_completa, axis=0)

# vamos a graficar
plt.plot(avg_train_losses, label='Perdida entrenamiento') # Grafico esta para ver si estoy sobre entrenando
plt.plot(avg_val_losses, label='Perdida Validacion') # Grafico esta para ver si estoy sobre entrenando
plt.title('avg loss train, avg loss val vs epoch ')
plt.xlabel('epoch')
plt.ylabel('Mean Square Error')
plt.legend()
plt.show()

# %%
# Cargar el mejor modelo
best_model = load_model(best_model_path)

# %%
# Seleccionar una secuencia específica
index = 0
input_sequence = X_test[index]

# Hacer la predicción
y_pred = best_model.predict(np.expand_dims(input_sequence, axis=0))
# usamos el np.expand_dims() para agregar una dimensión adicional al inicio de input_sequence
print(y_pred.shape)
# Out:
# 1/1 [==============================] - 0s 312ms/step
# (1, 210)

# %%
# Desenrollar X_test para convertirlo en un array bidimensional
X_test_flattened = X_test.reshape(-1, X_test.shape[-1])

# Aplicar la transformación inversa utilizando el objeto StandardScaler
X_test_desnormalizado = sc.inverse_transform(X_test_flattened)

# Volver a darle forma a X_test_desnormalizado a su forma original
X_test = X_test_desnormalizado.reshape(X_test.shape)

# Desnormalizar los datos
y_pred = sc_y.inverse_transform(y_pred)

y_test = sc_y.inverse_transform(y_test)

print(y_pred.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (1, 210)
# (17, 210)
# (17, 15, 2)

# %%
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
Curva=0

plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

print('')
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(X_test[Curva,:,0],color='orange', label='Valores actuales y anteriores de insulina')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_test[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 229.472625

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_pred[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 228.04855670928956

# %%
# Media MSE y desviacion estandar MSE de las prediciones con la escala normal
mse = mean_squared_error(y_test[0,:].flatten(), y_pred.flatten())
std = np.sqrt(mse)
mediamse = np.mean(mse)

print('La media MSE:',mediamse)
print('La desviacion standar MSE', std)

# calcular la MAE
mae = mean_absolute_error(y_test[0,:], y_pred[0,:])
print('MAE:', mae)

# calcular la RMSE
rmse = np.sqrt(mean_squared_error(y_test[0,:], y_pred[0,:]))
print('RMSE:', rmse)
# Out:
# La media MSE: 28.82392766219229
# La desviacion standar MSE 5.368792011448412
# MAE: 4.178342825753347
# RMSE: 5.368792011448412
