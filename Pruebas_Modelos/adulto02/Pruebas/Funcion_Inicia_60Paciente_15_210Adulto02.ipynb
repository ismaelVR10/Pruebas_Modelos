# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Librerias
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split, KFold
from keras.callbacks import EarlyStopping

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import load_model

from keras.initializers import he_uniform

from keras.activations import relu

# %%
#Dataset Adulto 01
data = pd.read_csv('/content/gdrive/MyDrive/Proyecto_de_grado/SUSTENTACION3.0/FinalX3/adulto02/my_adult02A2_data.csv')

print(f"El archivo se ha cargado correctamente. Tiene {data.shape[0]} filas y {data.shape[1]} columnas.")
# Out:
# El archivo se ha cargado correctamente. Tiene 29638 filas y 3 columnas.

# %%
train_size = int(len(data) * 0.7)

train_data = data.iloc[:train_size, :] # 70% entrenamiento
test_data = data.iloc[train_size:, :] # 30% prueba

test_data = test_data.reset_index(drop=True)

# %%
#los indices donde hay ingestas
posicionestrain = train_data.loc[train_data.iloc[:, 0] != 0].index
posicionestest = test_data.loc[test_data.iloc[:, 0] != 0].index

df_posiciones_train = pd.DataFrame(posicionestrain)
df_posiciones_test = pd.DataFrame(posicionestest)

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_train = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_train)):
    anterior = df_posiciones_train.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_train.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_train.append(anterior)

ultimo_elemento_train = df_posiciones_train.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_train.extend(ultimo_elemento_train.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_train)
print(len(cumplen_train))
# Out:
# [494, 862, 1358, 1974, 2353, 2840, 3461, 3846, 4334, 4956, 5324, 5820, 6438, 6815, 7301, 7917, 8283, 8781, 9398, 9781, 10268, 10880, 11255, 11750, 12363, 12742, 13230, 13845, 14212, 14699, 15311, 15686, 16183, 16795, 17162, 17650, 18266, 18653, 19140, 19757, 20125, 20614]
# 42

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_test = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_test)):
    anterior = df_posiciones_test.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_test.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_test.append(anterior)

ultimo_elemento_test = df_posiciones_test.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_test.extend(ultimo_elemento_test.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_test)
print(len(cumplen_test))
# Out:
# [487, 855, 1342, 1956, 2335, 2823, 3439, 3805, 4301, 4916, 5291, 5779, 6398, 6765, 7253, 7868, 8234, 8720]
# 18

# %%
# pasar la escala de los carbohidratos de las ingestas a gramos
data.iloc[:,0] = data.iloc[:,0].apply(lambda x: (x*15)/1000)

# Grafica con mayor detalle, el pico del comportamiento de la glucosa despues de la primera ingesta
print('')
print('Grafica de los datos del dataset')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
plt.title('Ingestas, Insulina y Glucosa')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')

print('Caso 1: Primera ingesta o Desayuno del primer dia:')
plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 700])
plt.ylim([-5, 250])
plt.show()
print('')

print('Caso 2: Primera y segunda ingesta del primer dia:')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1200])
plt.ylim([-5, 500])
plt.show()


print('Caso 3: las tres ingestas del primer dia:')

plt.plot(data.index, data.iloc[:,0], color='blue', label='Ingestas')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Ingestas de carbohidratos')
plt.xlabel('t [min]')
plt.ylabel('gramos')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Dosificación de insulina')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
#plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1800])
plt.ylim([-5, 500])
plt.show()
# Out:
# Grafica de los datos del dataset
# Caso 1: Primera ingesta o Desayuno del primer dia:
# Caso 2: Primera y segunda ingesta del primer dia:
# Caso 3: las tres ingestas del primer dia:

# %%
#Preprocesar los datos:
X_train = train_data.iloc[:, 1:3].values
y_train = train_data.iloc[:,2].values

X_test = test_data.iloc[:, 1:3].values
y_test = test_data.iloc[:, 2].values

print('Tamaño de los datos de entrada, de X_train: ',X_train.shape)
print(f'Tiene {X_train.shape[0]} filas y {X_train.shape[1]} columna')
print('La primera ingesta al minuto 300, ingesta: ',X_train[300])
print('La primera ingesta hasta el minuto 327, ingesta: ',X_train[327])

print('La entrada son los valores de la insulina y glucosa \n',X_train)
print('Tamaño de los datos de salia, de y_train',y_train.shape)
print(f'Tiene {y_train.shape[0]} filas y {y_train.shape[-1]} columnas')
print('La salida son los valores de glucosa \n',y_train)
# Out:
# Tamaño de los datos de entrada, de X_train:  (20746, 2)
# Tiene 20746 filas y 2 columna
# La primera ingesta al minuto 300, ingesta:  [  1.6789 123.44  ]
# La primera ingesta hasta el minuto 327, ingesta:  [  1.6789 123.44  ]
# La entrada son los valores de la insulina y glucosa
#  [[  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  ...
#  [  1.6789 198.03  ]
#  [  1.6789 197.1   ]
#  [  1.6789 196.18  ]]
# Tamaño de los datos de salia, de y_train (20746,)
# Tiene 20746 filas y 20746 columnas
# La salida son los valores de glucosa
#  [123.44 123.44 123.44 ... 198.03 197.1  196.18]

# %%
# Normalizar los datos
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Normalizar y_train
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.reshape(-1, 1))
y_test = sc_y.transform(y_test.reshape(-1, 1))

# %%
# Reorganizar los datos en forma de secuencia
def to_sequences(data,  seq_size_input, seq_size_output):
    X = []
    y = []

    for i in range(len(data)-seq_size_input-seq_size_output+1):
        X.append(data[i:(i+seq_size_input), 0:2])
        y.append(data[(i+seq_size_input):(i+seq_size_input+seq_size_output), 2])

    return np.array(X), np.array(y)

# %%
#CON LOS DATOS NORMALIZADOS
seq_size_input = 15
seq_size_output = 210
X_train, y_train = to_sequences(np.hstack((X_train, y_train)), seq_size_input, seq_size_output)
X_test, y_test = to_sequences(np.hstack((X_test, y_test)), seq_size_input, seq_size_output)
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (20522, 210)
# (20522, 15, 2)
# (8668, 210)
# (8668, 15, 2)

# %%
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
flattened_data = np.reshape(X_train, (X_train.shape[0], -1))

df_X_train = pd.DataFrame(flattened_data)

# %%
flattened_test = np.reshape(X_test, (X_test.shape[0], -1))

df_X_test = pd.DataFrame(flattened_test)

# %%
df_y_train = pd.DataFrame(y_train)
df_y_test = pd.DataFrame(y_test)

# %%
# Filtrar el dataframe para mantener solo las filas especificadas
df_X_train_seleccionado = df_X_train[df_X_train.index.isin(cumplen_train)]
df_y_train_seleccionado = df_y_train[df_y_train.index.isin(cumplen_train)]
df_X_test_seleccionado = df_X_test[df_X_test.index.isin(cumplen_test)]
df_y_test_seleccionado = df_y_test[df_y_test.index.isin(cumplen_test)]

# %%
print('Grafica de los datos del dataset')
#plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')

Numerocurva = 0

plt.plot(df_X_train_seleccionado.iloc[Numerocurva, 1::2],color='green',label='Entrada glucosa') #Para mostrar solo la glucosa
plt.plot(df_X_train_seleccionado.iloc[Numerocurva, ::2],color='orange',label='Entrada insulina') #Para mostrar solo la glucosa
plt.plot(range(seq_size_input*2, seq_size_output + seq_size_input*2),df_y_train_seleccionado.iloc[Numerocurva,:], color='red',label='Salida glucosa')
plt.title('Entradas y salidas, entrenamiento')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')
# Out:
# Grafica de los datos del dataset

# %%
X_train = df_X_train_seleccionado.values
y_train = df_y_train_seleccionado.values
X_test = df_X_test_seleccionado.values
y_test = df_y_test_seleccionado.values

print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 30)
# (17, 210)
# (17, 30)

# %%
print(len(X_test))
# Out:
# 17

# %%
X_train = np.reshape(X_train, (len(X_train), seq_size_input, 2))

X_test = np.reshape(X_test, (len(X_test), seq_size_input, 2))
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 15, 2)
# (17, 210)
# (17, 15, 2)

# %%
kf = KFold(n_splits=5)
kf.get_n_splits(X_train)
KFold(n_splits=5, random_state=None, shuffle=False)


# Crear listas para almacenar los valores del "average loss" de entrenamiento y validación en cada pliegue
train_losses = []
val_losses = []

#Para guardar el mejor modelo
best_loss = float('inf')
best_model_path = ""

for i, (train_index, test_index) in enumerate(kf.split(X_train,y_train)):
  model = Sequential()
  model.add(LSTM(60, activation='relu', input_shape=(seq_size_input, 2), kernel_initializer=he_uniform()))
  model.add(Dense(seq_size_output, activation='linear', kernel_initializer=he_uniform()))


  model.compile(optimizer='adam', loss='mse')
  print(model.summary())

  filepath = f"modelo-{i+1}.h5"
  early_stop = EarlyStopping(monitor='val_loss', patience=3)
  checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

  X, y =  X_train[train_index], y_train[train_index]
  X_val, y_val = X_train[test_index], y_train[test_index]


  history = model.fit(X, y, epochs=100, batch_size=32,validation_data=(X_val, y_val),callbacks=[checkpoint, early_stop] )

  mediamse = np.mean( history.history['loss'] )
  stdmse = np.std(  history.history['loss'])
  print('')
  print(f" La media del mse, {i}-fold es : {mediamse}")
  print('')
  print(f" La desviacion estandar del mse, {i}-fold es : {stdmse}")

  # Obtener los valores de "average loss" para el pliegue actual
  fold_train_losses = model.history.history['loss']
  fold_val_losses = model.history.history['val_loss']

  # Almacenar los valores de "average loss" para el pliegue actual
  train_losses.append(fold_train_losses)
  val_losses.append(fold_val_losses)

  if min(fold_val_losses) < best_loss:
        best_loss = min(fold_val_losses)
        best_model_path = filepath

  history.history.keys() # aqui me muestra que esta guardando, con history me guarda todos los valores que calcula durante el proceso de entrenamiento

  # vamos a graficar
  plt.plot(history.history['loss'], label='Perdida') # Grafico esta para ver si estoy sobre entrenando
  plt.plot(history.history['val_loss'], label='Validacion') # Grafico esta para ver si estoy sobre entrenando
  plt.xlabel('epoch')
  plt.ylabel('Mean Square Error')
  plt.legend()
  plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 60)                15120
#
#  dense_3 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7977
# Epoch 1: val_loss improved from inf to 1.84663, saving model to modelo-1.h5
# 1/1 [==============================] - 2s 2s/step - loss: 1.7977 - val_loss: 1.8466
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7623
# Epoch 2: val_loss improved from 1.84663 to 1.81354, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 124ms/step - loss: 1.7623 - val_loss: 1.8135
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7301
# Epoch 3: val_loss improved from 1.81354 to 1.78288, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 1.7301 - val_loss: 1.7829
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7003
# Epoch 4: val_loss improved from 1.78288 to 1.75402, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 93ms/step - loss: 1.7003 - val_loss: 1.7540
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6724
# Epoch 5: val_loss improved from 1.75402 to 1.72647, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 100ms/step - loss: 1.6724 - val_loss: 1.7265
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6458
# Epoch 6: val_loss improved from 1.72647 to 1.69981, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 83ms/step - loss: 1.6458 - val_loss: 1.6998
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6201
# Epoch 7: val_loss improved from 1.69981 to 1.67366, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 88ms/step - loss: 1.6201 - val_loss: 1.6737
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5949
# Epoch 8: val_loss improved from 1.67366 to 1.64768, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 79ms/step - loss: 1.5949 - val_loss: 1.6477
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5699
# Epoch 9: val_loss improved from 1.64768 to 1.62168, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 107ms/step - loss: 1.5699 - val_loss: 1.6217
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5448
# Epoch 10: val_loss improved from 1.62168 to 1.59540, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 91ms/step - loss: 1.5448 - val_loss: 1.5954
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5196
# Epoch 11: val_loss improved from 1.59540 to 1.56847, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 85ms/step - loss: 1.5196 - val_loss: 1.5685
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4938
# Epoch 12: val_loss improved from 1.56847 to 1.54057, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 103ms/step - loss: 1.4938 - val_loss: 1.5406
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4670
# Epoch 13: val_loss improved from 1.54057 to 1.51126, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 100ms/step - loss: 1.4670 - val_loss: 1.5113
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4389
# Epoch 14: val_loss improved from 1.51126 to 1.48022, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 77ms/step - loss: 1.4389 - val_loss: 1.4802
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4092
# Epoch 15: val_loss improved from 1.48022 to 1.44690, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 101ms/step - loss: 1.4092 - val_loss: 1.4469
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3773
# Epoch 16: val_loss improved from 1.44690 to 1.41094, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 83ms/step - loss: 1.3773 - val_loss: 1.4109
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3429
# Epoch 17: val_loss improved from 1.41094 to 1.37144, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 79ms/step - loss: 1.3429 - val_loss: 1.3714
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3053
# Epoch 18: val_loss improved from 1.37144 to 1.32799, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 87ms/step - loss: 1.3053 - val_loss: 1.3280
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2640
# Epoch 19: val_loss improved from 1.32799 to 1.28004, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 1.2640 - val_loss: 1.2800
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2186
# Epoch 20: val_loss improved from 1.28004 to 1.22816, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 1.2186 - val_loss: 1.2282
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1697
# Epoch 21: val_loss improved from 1.22816 to 1.17410, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 1.1697 - val_loss: 1.1741
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1192
# Epoch 22: val_loss improved from 1.17410 to 1.12155, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 59ms/step - loss: 1.1192 - val_loss: 1.1215
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0704
# Epoch 23: val_loss improved from 1.12155 to 1.07293, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 1.0704 - val_loss: 1.0729
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0259
# Epoch 24: val_loss improved from 1.07293 to 1.02462, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 1.0259 - val_loss: 1.0246
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9809
# Epoch 25: val_loss improved from 1.02462 to 0.97091, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.9809 - val_loss: 0.9709
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9296
# Epoch 26: val_loss improved from 0.97091 to 0.91323, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.9296 - val_loss: 0.9132
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8739
# Epoch 27: val_loss improved from 0.91323 to 0.85766, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.8739 - val_loss: 0.8577
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8204
# Epoch 28: val_loss improved from 0.85766 to 0.80737, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.8204 - val_loss: 0.8074
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7723
# Epoch 29: val_loss improved from 0.80737 to 0.76108, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.7723 - val_loss: 0.7611
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7284
# Epoch 30: val_loss improved from 0.76108 to 0.71630, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.7284 - val_loss: 0.7163
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6861
# Epoch 31: val_loss improved from 0.71630 to 0.67190, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.6861 - val_loss: 0.6719
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6443
# Epoch 32: val_loss improved from 0.67190 to 0.62894, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.6443 - val_loss: 0.6289
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6041
# Epoch 33: val_loss improved from 0.62894 to 0.58961, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.6041 - val_loss: 0.5896
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5673
# Epoch 34: val_loss improved from 0.58961 to 0.55349, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.5673 - val_loss: 0.5535
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5335
# Epoch 35: val_loss improved from 0.55349 to 0.51785, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.5335 - val_loss: 0.5179
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5000
# Epoch 36: val_loss improved from 0.51785 to 0.48301, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.5000 - val_loss: 0.4830
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4669
# Epoch 37: val_loss improved from 0.48301 to 0.45170, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.4669 - val_loss: 0.4517
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4370
# Epoch 38: val_loss improved from 0.45170 to 0.42355, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.4370 - val_loss: 0.4236
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4101
# Epoch 39: val_loss improved from 0.42355 to 0.39640, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.4101 - val_loss: 0.3964
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3843
# Epoch 40: val_loss improved from 0.39640 to 0.37009, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 77ms/step - loss: 0.3843 - val_loss: 0.3701
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3594
# Epoch 41: val_loss improved from 0.37009 to 0.34593, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.3594 - val_loss: 0.3459
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3365
# Epoch 42: val_loss improved from 0.34593 to 0.32294, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.3365 - val_loss: 0.3229
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3146
# Epoch 43: val_loss improved from 0.32294 to 0.29983, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.3146 - val_loss: 0.2998
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2925
# Epoch 44: val_loss improved from 0.29983 to 0.27802, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.2925 - val_loss: 0.2780
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2715
# Epoch 45: val_loss improved from 0.27802 to 0.25789, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.2715 - val_loss: 0.2579
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2521
# Epoch 46: val_loss improved from 0.25789 to 0.23844, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.2521 - val_loss: 0.2384
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2336
# Epoch 47: val_loss improved from 0.23844 to 0.22019, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.2336 - val_loss: 0.2202
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2163
# Epoch 48: val_loss improved from 0.22019 to 0.20402, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.2163 - val_loss: 0.2040
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2010
# Epoch 49: val_loss improved from 0.20402 to 0.18901, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.2010 - val_loss: 0.1890
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1866
# Epoch 50: val_loss improved from 0.18901 to 0.17508, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1866 - val_loss: 0.1751
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1731
# Epoch 51: val_loss improved from 0.17508 to 0.16288, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1731 - val_loss: 0.1629
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1613
# Epoch 52: val_loss improved from 0.16288 to 0.15155, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1613 - val_loss: 0.1516
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1504
# Epoch 53: val_loss improved from 0.15155 to 0.14080, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1504 - val_loss: 0.1408
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1402
# Epoch 54: val_loss improved from 0.14080 to 0.13124, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.1402 - val_loss: 0.1312
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1311
# Epoch 55: val_loss improved from 0.13124 to 0.12239, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1311 - val_loss: 0.1224
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1226
# Epoch 56: val_loss improved from 0.12239 to 0.11405, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1226 - val_loss: 0.1140
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1144
# Epoch 57: val_loss improved from 0.11405 to 0.10663, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1144 - val_loss: 0.1066
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1071
# Epoch 58: val_loss improved from 0.10663 to 0.09951, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1071 - val_loss: 0.0995
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1002
# Epoch 59: val_loss improved from 0.09951 to 0.09274, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1002 - val_loss: 0.0927
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0937
# Epoch 60: val_loss improved from 0.09274 to 0.08672, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0937 - val_loss: 0.0867
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0879
# Epoch 61: val_loss improved from 0.08672 to 0.08100, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0879 - val_loss: 0.0810
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0822
# Epoch 62: val_loss improved from 0.08100 to 0.07581, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0822 - val_loss: 0.0758
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0771
# Epoch 63: val_loss improved from 0.07581 to 0.07109, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0771 - val_loss: 0.0711
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0724
# Epoch 64: val_loss improved from 0.07109 to 0.06652, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0724 - val_loss: 0.0665
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0680
# Epoch 65: val_loss improved from 0.06652 to 0.06246, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0680 - val_loss: 0.0625
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0641
# Epoch 66: val_loss improved from 0.06246 to 0.05875, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0641 - val_loss: 0.0588
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0605
# Epoch 67: val_loss improved from 0.05875 to 0.05534, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0605 - val_loss: 0.0553
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0571
# Epoch 68: val_loss improved from 0.05534 to 0.05232, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0571 - val_loss: 0.0523
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0541
# Epoch 69: val_loss improved from 0.05232 to 0.04941, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0541 - val_loss: 0.0494
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0513
# Epoch 70: val_loss improved from 0.04941 to 0.04680, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0513 - val_loss: 0.0468
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0487
# Epoch 71: val_loss improved from 0.04680 to 0.04442, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0487 - val_loss: 0.0444
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0464
# Epoch 72: val_loss improved from 0.04442 to 0.04220, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0464 - val_loss: 0.0422
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0442
# Epoch 73: val_loss improved from 0.04220 to 0.04021, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0442 - val_loss: 0.0402
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0422
# Epoch 74: val_loss improved from 0.04021 to 0.03827, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0422 - val_loss: 0.0383
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0402
# Epoch 75: val_loss improved from 0.03827 to 0.03652, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0402 - val_loss: 0.0365
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0385
# Epoch 76: val_loss improved from 0.03652 to 0.03491, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0385 - val_loss: 0.0349
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0368
# Epoch 77: val_loss improved from 0.03491 to 0.03344, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0368 - val_loss: 0.0334
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0353
# Epoch 78: val_loss improved from 0.03344 to 0.03212, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0353 - val_loss: 0.0321
# Epoch 79/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0339
# Epoch 79: val_loss improved from 0.03212 to 0.03083, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 228ms/step - loss: 0.0339 - val_loss: 0.0308
# Epoch 80/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0325
# Epoch 80: val_loss improved from 0.03083 to 0.02968, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0325 - val_loss: 0.0297
# Epoch 81/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0313
# Epoch 81: val_loss improved from 0.02968 to 0.02858, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0313 - val_loss: 0.0286
# Epoch 82/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0302
# Epoch 82: val_loss improved from 0.02858 to 0.02758, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0302 - val_loss: 0.0276
# Epoch 83/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0291
# Epoch 83: val_loss improved from 0.02758 to 0.02660, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0291 - val_loss: 0.0266
# Epoch 84/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0281
# Epoch 84: val_loss improved from 0.02660 to 0.02564, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0281 - val_loss: 0.0256
# Epoch 85/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0271
# Epoch 85: val_loss improved from 0.02564 to 0.02474, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0271 - val_loss: 0.0247
# Epoch 86/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0262
# Epoch 86: val_loss improved from 0.02474 to 0.02388, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0262 - val_loss: 0.0239
# Epoch 87/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0253
# Epoch 87: val_loss improved from 0.02388 to 0.02307, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0253 - val_loss: 0.0231
# Epoch 88/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0244
# Epoch 88: val_loss improved from 0.02307 to 0.02225, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0244 - val_loss: 0.0222
# Epoch 89/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0236
# Epoch 89: val_loss improved from 0.02225 to 0.02149, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0236 - val_loss: 0.0215
# Epoch 90/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0228
# Epoch 90: val_loss improved from 0.02149 to 0.02077, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0228 - val_loss: 0.0208
# Epoch 91/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0221
# Epoch 91: val_loss improved from 0.02077 to 0.02011, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0221 - val_loss: 0.0201
# Epoch 92/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0214
# Epoch 92: val_loss improved from 0.02011 to 0.01944, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0214 - val_loss: 0.0194
# Epoch 93/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0207
# Epoch 93: val_loss improved from 0.01944 to 0.01883, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0207 - val_loss: 0.0188
# Epoch 94/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0201
# Epoch 94: val_loss improved from 0.01883 to 0.01825, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0201 - val_loss: 0.0182
# Epoch 95/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0195
# Epoch 95: val_loss improved from 0.01825 to 0.01772, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0195 - val_loss: 0.0177
# Epoch 96/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0189
# Epoch 96: val_loss improved from 0.01772 to 0.01721, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0189 - val_loss: 0.0172
# Epoch 97/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0183
# Epoch 97: val_loss improved from 0.01721 to 0.01672, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0183 - val_loss: 0.0167
# Epoch 98/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0178
# Epoch 98: val_loss improved from 0.01672 to 0.01626, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0178 - val_loss: 0.0163
# Epoch 99/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0173
# Epoch 99: val_loss improved from 0.01626 to 0.01582, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0173 - val_loss: 0.0158
# Epoch 100/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0168
# Epoch 100: val_loss improved from 0.01582 to 0.01537, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0168 - val_loss: 0.0154
#
#  La media del mse, 0-fold es : 0.5069150862656534
#
#  La desviacion estandar del mse, 0-fold es : 0.5857961489461478
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 60)                15120
#
#  dense_4 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 2.0404
# Epoch 1: val_loss improved from inf to 1.50727, saving model to modelo-2.h5
# 2/2 [==============================] - 2s 440ms/step - loss: 2.0036 - val_loss: 1.5073
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9947
# Epoch 2: val_loss improved from 1.50727 to 1.46510, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 92ms/step - loss: 1.9458 - val_loss: 1.4651
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8238
# Epoch 3: val_loss improved from 1.46510 to 1.42888, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 1.8984 - val_loss: 1.4289
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8902
# Epoch 4: val_loss improved from 1.42888 to 1.39655, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 86ms/step - loss: 1.8578 - val_loss: 1.3965
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8673
# Epoch 5: val_loss improved from 1.39655 to 1.36694, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 77ms/step - loss: 1.8205 - val_loss: 1.3669
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8217
# Epoch 6: val_loss improved from 1.36694 to 1.33902, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 1.7861 - val_loss: 1.3390
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7989
# Epoch 7: val_loss improved from 1.33902 to 1.31203, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 110ms/step - loss: 1.7536 - val_loss: 1.3120
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6154
# Epoch 8: val_loss improved from 1.31203 to 1.28444, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 93ms/step - loss: 1.7209 - val_loss: 1.2844
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7346
# Epoch 9: val_loss improved from 1.28444 to 1.25632, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 1.6888 - val_loss: 1.2563
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5220
# Epoch 10: val_loss improved from 1.25632 to 1.22690, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 77ms/step - loss: 1.6535 - val_loss: 1.2269
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6179
# Epoch 11: val_loss improved from 1.22690 to 1.19474, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 1.6185 - val_loss: 1.1947
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6106
# Epoch 12: val_loss improved from 1.19474 to 1.15965, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 106ms/step - loss: 1.5790 - val_loss: 1.1597
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5679
# Epoch 13: val_loss improved from 1.15965 to 1.12133, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 1.5359 - val_loss: 1.1213
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5299
# Epoch 14: val_loss improved from 1.12133 to 1.08095, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 91ms/step - loss: 1.4897 - val_loss: 1.0809
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4699
# Epoch 15: val_loss improved from 1.08095 to 1.03644, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 1.4391 - val_loss: 1.0364
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3247
# Epoch 16: val_loss improved from 1.03644 to 0.98548, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 80ms/step - loss: 1.3817 - val_loss: 0.9855
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3523
# Epoch 17: val_loss improved from 0.98548 to 0.93273, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 89ms/step - loss: 1.3187 - val_loss: 0.9327
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1874
# Epoch 18: val_loss improved from 0.93273 to 0.87210, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 1.2445 - val_loss: 0.8721
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1863
# Epoch 19: val_loss improved from 0.87210 to 0.81065, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 1.1642 - val_loss: 0.8106
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1024
# Epoch 20: val_loss improved from 0.81065 to 0.74239, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 1.0765 - val_loss: 0.7424
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0101
# Epoch 21: val_loss improved from 0.74239 to 0.68174, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.9847 - val_loss: 0.6817
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8651
# Epoch 22: val_loss improved from 0.68174 to 0.63008, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.9043 - val_loss: 0.6301
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8521
# Epoch 23: val_loss improved from 0.63008 to 0.57459, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.8362 - val_loss: 0.5746
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7923
# Epoch 24: val_loss improved from 0.57459 to 0.52655, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 87ms/step - loss: 0.7754 - val_loss: 0.5265
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7521
# Epoch 25: val_loss improved from 0.52655 to 0.47895, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 112ms/step - loss: 0.7322 - val_loss: 0.4789
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6639
# Epoch 26: val_loss improved from 0.47895 to 0.45265, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 80ms/step - loss: 0.6464 - val_loss: 0.4527
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5946
# Epoch 27: val_loss improved from 0.45265 to 0.41469, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5849 - val_loss: 0.4147
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5447
# Epoch 28: val_loss improved from 0.41469 to 0.35847, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5305 - val_loss: 0.3585
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4290
# Epoch 29: val_loss improved from 0.35847 to 0.34464, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.4675 - val_loss: 0.3446
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4155
# Epoch 30: val_loss did not improve from 0.34464
# 2/2 [==============================] - 0s 56ms/step - loss: 0.4348 - val_loss: 0.3473
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4414
# Epoch 31: val_loss improved from 0.34464 to 0.29790, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 92ms/step - loss: 0.4298 - val_loss: 0.2979
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3771
# Epoch 32: val_loss improved from 0.29790 to 0.23606, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.3674 - val_loss: 0.2361
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3002
# Epoch 33: val_loss improved from 0.23606 to 0.19169, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 94ms/step - loss: 0.2939 - val_loss: 0.1917
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2391
# Epoch 34: val_loss improved from 0.19169 to 0.16996, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 86ms/step - loss: 0.2498 - val_loss: 0.1700
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2243
# Epoch 35: val_loss improved from 0.16996 to 0.16681, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.2194 - val_loss: 0.1668
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2062
# Epoch 36: val_loss improved from 0.16681 to 0.16504, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 0.2016 - val_loss: 0.1650
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1864
# Epoch 37: val_loss improved from 0.16504 to 0.12322, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1932 - val_loss: 0.1232
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1513
# Epoch 38: val_loss improved from 0.12322 to 0.11235, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1484 - val_loss: 0.1124
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1704
# Epoch 39: val_loss improved from 0.11235 to 0.10637, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1809 - val_loss: 0.1064
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1194
# Epoch 40: val_loss did not improve from 0.10637
# 2/2 [==============================] - 0s 72ms/step - loss: 0.1227 - val_loss: 0.2020
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2387
# Epoch 41: val_loss did not improve from 0.10637
# 2/2 [==============================] - 0s 71ms/step - loss: 0.2329 - val_loss: 0.2482
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3035
# Epoch 42: val_loss did not improve from 0.10637
# 2/2 [==============================] - 0s 54ms/step - loss: 0.2981 - val_loss: 0.2510
#
#  La media del mse, 1-fold es : 0.995518144752298
#
#  La desviacion estandar del mse, 1-fold es : 0.6307972168590309
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 60)                15120
#
#  dense_5 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 1.9115
# Epoch 1: val_loss improved from inf to 1.74527, saving model to modelo-3.h5
# 2/2 [==============================] - 2s 281ms/step - loss: 1.9461 - val_loss: 1.7453
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9359
# Epoch 2: val_loss improved from 1.74527 to 1.70012, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.8888 - val_loss: 1.7001
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8902
# Epoch 3: val_loss improved from 1.70012 to 1.66235, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 1.8430 - val_loss: 1.6624
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8356
# Epoch 4: val_loss improved from 1.66235 to 1.62918, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.8049 - val_loss: 1.6292
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7366
# Epoch 5: val_loss improved from 1.62918 to 1.59731, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.7705 - val_loss: 1.5973
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7299
# Epoch 6: val_loss improved from 1.59731 to 1.56523, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 1.7372 - val_loss: 1.5652
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7013
# Epoch 7: val_loss improved from 1.56523 to 1.53253, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.7028 - val_loss: 1.5325
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6984
# Epoch 8: val_loss improved from 1.53253 to 1.49923, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 1.6675 - val_loss: 1.4992
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5420
# Epoch 9: val_loss improved from 1.49923 to 1.46436, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 1.6298 - val_loss: 1.4644
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5045
# Epoch 10: val_loss improved from 1.46436 to 1.42712, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.5905 - val_loss: 1.4271
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5905
# Epoch 11: val_loss improved from 1.42712 to 1.38840, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.5490 - val_loss: 1.3884
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5360
# Epoch 12: val_loss improved from 1.38840 to 1.34778, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 1.5037 - val_loss: 1.3478
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3809
# Epoch 13: val_loss improved from 1.34778 to 1.30293, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 1.4553 - val_loss: 1.3029
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3352
# Epoch 14: val_loss improved from 1.30293 to 1.25568, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 1.4011 - val_loss: 1.2557
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3176
# Epoch 15: val_loss improved from 1.25568 to 1.22167, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 1.3396 - val_loss: 1.2217
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3133
# Epoch 16: val_loss improved from 1.22167 to 1.16154, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 1.2855 - val_loss: 1.1615
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1609
# Epoch 17: val_loss improved from 1.16154 to 1.07181, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 1.2095 - val_loss: 1.0718
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1445
# Epoch 18: val_loss improved from 1.07181 to 0.98186, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 1.1197 - val_loss: 0.9819
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0089
# Epoch 19: val_loss improved from 0.98186 to 0.89089, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 1.0232 - val_loss: 0.8909
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9472
# Epoch 20: val_loss improved from 0.89089 to 0.80451, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.9280 - val_loss: 0.8045
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8568
# Epoch 21: val_loss improved from 0.80451 to 0.72486, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.8371 - val_loss: 0.7249
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7764
# Epoch 22: val_loss improved from 0.72486 to 0.65982, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.7588 - val_loss: 0.6598
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6469
# Epoch 23: val_loss improved from 0.65982 to 0.59976, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 0.6927 - val_loss: 0.5998
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6342
# Epoch 24: val_loss improved from 0.59976 to 0.54078, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 0.6327 - val_loss: 0.5408
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5786
# Epoch 25: val_loss improved from 0.54078 to 0.50209, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5670 - val_loss: 0.5021
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5279
# Epoch 26: val_loss improved from 0.50209 to 0.46465, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 0.5152 - val_loss: 0.4647
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4814
# Epoch 27: val_loss improved from 0.46465 to 0.40522, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.4696 - val_loss: 0.4052
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4216
# Epoch 28: val_loss improved from 0.40522 to 0.36212, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.4143 - val_loss: 0.3621
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3584
# Epoch 29: val_loss improved from 0.36212 to 0.32409, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.3724 - val_loss: 0.3241
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3384
# Epoch 30: val_loss improved from 0.32409 to 0.29134, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.3310 - val_loss: 0.2913
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2714
# Epoch 31: val_loss improved from 0.29134 to 0.25335, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.2892 - val_loss: 0.2534
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2644
# Epoch 32: val_loss improved from 0.25335 to 0.24652, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.2585 - val_loss: 0.2465
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2631
# Epoch 33: val_loss improved from 0.24652 to 0.22152, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.2583 - val_loss: 0.2215
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2343
# Epoch 34: val_loss improved from 0.22152 to 0.17830, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.2302 - val_loss: 0.1783
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1788
# Epoch 35: val_loss did not improve from 0.17830
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1757 - val_loss: 0.1910
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1779
# Epoch 36: val_loss improved from 0.17830 to 0.17794, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.1742 - val_loss: 0.1779
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1537
# Epoch 37: val_loss improved from 0.17794 to 0.13803, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1583 - val_loss: 0.1380
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1347
# Epoch 38: val_loss did not improve from 0.13803
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1329 - val_loss: 0.1676
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1650
# Epoch 39: val_loss improved from 0.13803 to 0.12596, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.1706 - val_loss: 0.1260
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1198
# Epoch 40: val_loss did not improve from 0.12596
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1191 - val_loss: 0.1517
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1336
# Epoch 41: val_loss did not improve from 0.12596
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1328 - val_loss: 0.2025
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1763
# Epoch 42: val_loss improved from 0.12596 to 0.09175, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.1762 - val_loss: 0.0917
# Epoch 43/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0814
# Epoch 43: val_loss did not improve from 0.09175
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0842 - val_loss: 0.1449
# Epoch 44/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1413
# Epoch 44: val_loss did not improve from 0.09175
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1480 - val_loss: 0.1151
# Epoch 45/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1157
# Epoch 45: val_loss improved from 0.09175 to 0.07543, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 0.1137 - val_loss: 0.0754
# Epoch 46/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0615
# Epoch 46: val_loss did not improve from 0.07543
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0606 - val_loss: 0.1545
# Epoch 47/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1272
# Epoch 47: val_loss did not improve from 0.07543
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1269 - val_loss: 0.1577
# Epoch 48/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1289
# Epoch 48: val_loss improved from 0.07543 to 0.07487, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1279 - val_loss: 0.0749
# Epoch 49/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0560
# Epoch 49: val_loss improved from 0.07487 to 0.06848, saving model to modelo-3.h5
# ...
# Epoch 59/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0571
# Epoch 59: val_loss improved from 0.05695 to 0.04615, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0569 - val_loss: 0.0461
# Epoch 60/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0485
# Epoch 60: val_loss did not improve from 0.04615
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0481 - val_loss: 0.0592
# Epoch 61/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0620
# Epoch 61: val_loss did not improve from 0.04615
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0617 - val_loss: 0.0560
# Epoch 62/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0595
# Epoch 62: val_loss improved from 0.04615 to 0.04295, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0585 - val_loss: 0.0429
# Epoch 63/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0457
# Epoch 63: val_loss improved from 0.04295 to 0.04083, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0450 - val_loss: 0.0408
# Epoch 64/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0427
# Epoch 64: val_loss did not improve from 0.04083
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0423 - val_loss: 0.0428
# Epoch 65/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0439
# Epoch 65: val_loss improved from 0.04083 to 0.03876, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0437 - val_loss: 0.0388
# Epoch 66/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0405
# Epoch 66: val_loss did not improve from 0.03876
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0400 - val_loss: 0.0408
# Epoch 67/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0434
# Epoch 67: val_loss did not improve from 0.03876
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0426 - val_loss: 0.0467
# Epoch 68/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0480
# Epoch 68: val_loss did not improve from 0.03876
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0485 - val_loss: 0.0407
#
#  La media del mse, 3-fold es : 0.6375908225446063
#
#  La desviacion estandar del mse, 3-fold es : 0.6328436133864417
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 60)                15120
#
#  dense_7 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 1.8533
# Epoch 1: val_loss improved from inf to 2.19586, saving model to modelo-5.h5
# 2/2 [==============================] - 2s 306ms/step - loss: 1.8219 - val_loss: 2.1959
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7042
# Epoch 2: val_loss improved from 2.19586 to 2.14406, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.7612 - val_loss: 2.1441
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7577
# Epoch 3: val_loss improved from 2.14406 to 2.10085, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.7145 - val_loss: 2.1008
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6654
# Epoch 4: val_loss improved from 2.10085 to 2.06235, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 1.6757 - val_loss: 2.0624
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6842
# Epoch 5: val_loss improved from 2.06235 to 2.02647, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.6416 - val_loss: 2.0265
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6517
# Epoch 6: val_loss improved from 2.02647 to 1.99264, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 1.6098 - val_loss: 1.9926
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5436
# Epoch 7: val_loss improved from 1.99264 to 1.95746, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 1.5796 - val_loss: 1.9575
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4031
# Epoch 8: val_loss improved from 1.95746 to 1.91843, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.5479 - val_loss: 1.9184
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5550
# Epoch 9: val_loss improved from 1.91843 to 1.87688, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 1.5149 - val_loss: 1.8769
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4434
# Epoch 10: val_loss improved from 1.87688 to 1.83095, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.4775 - val_loss: 1.8309
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4034
# Epoch 11: val_loss improved from 1.83095 to 1.77836, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 1.4364 - val_loss: 1.7784
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2833
# Epoch 12: val_loss improved from 1.77836 to 1.72605, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 1.3884 - val_loss: 1.7260
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3710
# Epoch 13: val_loss improved from 1.72605 to 1.69090, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 1.3452 - val_loss: 1.6909
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3479
# Epoch 14: val_loss improved from 1.69090 to 1.63441, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 1.3214 - val_loss: 1.6344
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2198
# Epoch 15: val_loss improved from 1.63441 to 1.54579, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 1.2777 - val_loss: 1.5458
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1441
# Epoch 16: val_loss improved from 1.54579 to 1.45167, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 1.2056 - val_loss: 1.4517
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1664
# Epoch 17: val_loss improved from 1.45167 to 1.32273, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 1.1405 - val_loss: 1.3227
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0575
# Epoch 18: val_loss improved from 1.32273 to 1.19672, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 1.0358 - val_loss: 1.1967
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9015
# Epoch 19: val_loss improved from 1.19672 to 1.10044, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.9243 - val_loss: 1.1004
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8474
# Epoch 20: val_loss improved from 1.10044 to 0.95431, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.8451 - val_loss: 0.9543
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7211
# Epoch 21: val_loss improved from 0.95431 to 0.77917, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.7329 - val_loss: 0.7792
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5838
# Epoch 22: val_loss improved from 0.77917 to 0.75782, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6128 - val_loss: 0.7578
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6321
# Epoch 23: val_loss improved from 0.75782 to 0.58330, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 88ms/step - loss: 0.6193 - val_loss: 0.5833
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4491
# Epoch 24: val_loss improved from 0.58330 to 0.51373, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.4621 - val_loss: 0.5137
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3931
# Epoch 25: val_loss improved from 0.51373 to 0.42616, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4018 - val_loss: 0.4262
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3123
# Epoch 26: val_loss improved from 0.42616 to 0.36326, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.3338 - val_loss: 0.3633
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2933
# Epoch 27: val_loss improved from 0.36326 to 0.31416, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.2892 - val_loss: 0.3142
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2441
# Epoch 28: val_loss improved from 0.31416 to 0.25366, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.2500 - val_loss: 0.2537
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2121
# Epoch 29: val_loss improved from 0.25366 to 0.22741, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.2080 - val_loss: 0.2274
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1940
# Epoch 30: val_loss improved from 0.22741 to 0.20583, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1912 - val_loss: 0.2058
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1669
# Epoch 31: val_loss improved from 0.20583 to 0.16607, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1753 - val_loss: 0.1661
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1466
# Epoch 32: val_loss did not improve from 0.16607
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1442 - val_loss: 0.2185
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1770
# Epoch 33: val_loss improved from 0.16607 to 0.16006, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 0.1746 - val_loss: 0.1601
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1347
# Epoch 34: val_loss improved from 0.16006 to 0.11315, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1343 - val_loss: 0.1131
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1071
# Epoch 35: val_loss improved from 0.11315 to 0.10312, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1060 - val_loss: 0.1031
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0989
# Epoch 36: val_loss improved from 0.10312 to 0.09413, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0989 - val_loss: 0.0941
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0879
# Epoch 37: val_loss did not improve from 0.09413
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0874 - val_loss: 0.1125
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0967
# Epoch 38: val_loss improved from 0.09413 to 0.08342, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0958 - val_loss: 0.0834
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0770
# Epoch 39: val_loss improved from 0.08342 to 0.07061, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0761 - val_loss: 0.0706
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0686
# Epoch 40: val_loss improved from 0.07061 to 0.06535, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0688 - val_loss: 0.0654
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0631
# Epoch 41: val_loss improved from 0.06535 to 0.06122, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0634 - val_loss: 0.0612
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0582
# Epoch 42: val_loss improved from 0.06122 to 0.05520, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0589 - val_loss: 0.0552
# Epoch 43/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0559
# Epoch 43: val_loss improved from 0.05520 to 0.05242, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0552 - val_loss: 0.0524
# Epoch 44/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0520
# Epoch 44: val_loss did not improve from 0.05242
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0521 - val_loss: 0.0587
# Epoch 45/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0561
# Epoch 45: val_loss did not improve from 0.05242
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0550 - val_loss: 0.0543
# Epoch 46/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0526
# Epoch 46: val_loss improved from 0.05242 to 0.04750, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0516 - val_loss: 0.0475
# Epoch 47/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0472
# Epoch 47: val_loss improved from 0.04750 to 0.04266, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0467 - val_loss: 0.0427
# Epoch 48/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0428
# Epoch 48: val_loss improved from 0.04266 to 0.04054, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0431 - val_loss: 0.0405
# Epoch 49/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0411
# Epoch 49: val_loss did not improve from 0.04054
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0415 - val_loss: 0.0413
# Epoch 50/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0425
# Epoch 50: val_loss improved from 0.04054 to 0.03885, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0422 - val_loss: 0.0389
# Epoch 51/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0391
# Epoch 51: val_loss improved from 0.03885 to 0.03720, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 0.0395 - val_loss: 0.0372
# Epoch 52/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0374
# Epoch 52: val_loss did not improve from 0.03720
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0368 - val_loss: 0.0391
# Epoch 53/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0332
# Epoch 53: val_loss did not improve from 0.03720
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0374 - val_loss: 0.0631
# Epoch 54/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0595
# Epoch 54: val_loss did not improve from 0.03720
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0592 - val_loss: 0.1757
#
#  La media del mse, 4-fold es : 0.6335294775112912
#
#  La desviacion estandar del mse, 4-fold es : 0.6370788479911398

# %%
# rellenar de ceros los espacios vacios de la lista con loss y validation

df_train_losses = pd.DataFrame(train_losses)

df_filled_train_losses = df_train_losses.fillna(0)

train_losses_completa = df_filled_train_losses.values.tolist()

df_val_losses = pd.DataFrame(val_losses)

df_filled_val_losses = df_val_losses.fillna(0)

val_losses_completa = df_filled_val_losses.values.tolist()

# %%
# Calcular el promedio de "average loss" para todos los pliegues y épocas
avg_train_losses = np.mean(train_losses_completa, axis=0)
avg_val_losses = np.mean(val_losses_completa, axis=0)

# vamos a graficar
plt.plot(avg_train_losses, label='Perdida entrenamiento') # Grafico esta para ver si estoy sobre entrenando
plt.plot(avg_val_losses, label='Perdida Validacion') # Grafico esta para ver si estoy sobre entrenando
plt.title('avg loss train, avg loss val vs epoch ')
plt.xlabel('epoch')
plt.ylabel('Mean Square Error')
plt.legend()
plt.show()

# %%
# Cargar el mejor modelo
best_model = load_model(best_model_path)

# %%
# Seleccionar una secuencia específica
index = 0
input_sequence = X_test[index]

# Hacer la predicción
y_pred = best_model.predict(np.expand_dims(input_sequence, axis=0))
# usamos el np.expand_dims() para agregar una dimensión adicional al inicio de input_sequence
print(y_pred.shape)
# Out:
# 1/1 [==============================] - 0s 200ms/step
# (1, 210)

# %%
# Desenrollar X_test para convertirlo en un array bidimensional
X_test_flattened = X_test.reshape(-1, X_test.shape[-1])

# Aplicar la transformación inversa utilizando el objeto StandardScaler
X_test_desnormalizado = sc.inverse_transform(X_test_flattened)

# Volver a darle forma a X_test_desnormalizado a su forma original
X_test = X_test_desnormalizado.reshape(X_test.shape)

# Desnormalizar los datos
y_pred = sc_y.inverse_transform(y_pred)

y_test = sc_y.inverse_transform(y_test)

print(y_pred.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (1, 210)
# (17, 210)
# (17, 15, 2)

# %%
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
Curva=0

plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

print('')
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(X_test[Curva,:,0],color='orange', label='Valores actuales y anteriores de insulina')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_test[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 229.472625

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_pred[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 234.83018474578859

# %%
# Media MSE y desviacion estandar MSE de las prediciones con la escala normal
mse = mean_squared_error(y_test[0,:].flatten(), y_pred.flatten())
std = np.sqrt(mse)
mediamse = np.mean(mse)

print('La media MSE:',mediamse)
print('La desviacion standar MSE', std)

# calcular la MAE
mae = mean_absolute_error(y_test[0,:], y_pred[0,:])
print('MAE:', mae)

# calcular la RMSE
rmse = np.sqrt(mean_squared_error(y_test[0,:], y_pred[0,:]))
print('RMSE:', rmse)
# Out:
# La media MSE: 38.85921004364469
# La desviacion standar MSE 6.233715588928058
# MAE: 4.650763343447731
# RMSE: 6.233715588928058
