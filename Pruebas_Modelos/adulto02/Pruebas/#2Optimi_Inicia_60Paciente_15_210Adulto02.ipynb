# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Librerias
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split, KFold
from keras.callbacks import EarlyStopping

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import load_model

from keras.initializers import he_uniform

from tensorflow.keras.optimizers import SGD

# %%
#Dataset Adulto 02
data = pd.read_csv('/content/gdrive/MyDrive/Proyecto_de_grado/SUSTENTACION3.0/FinalX3/adulto02/my_adult02A2_data.csv')

print(f"El archivo se ha cargado correctamente. Tiene {data.shape[0]} filas y {data.shape[1]} columnas.")
# Out:
# El archivo se ha cargado correctamente. Tiene 29638 filas y 3 columnas.

# %%
train_size = int(len(data) * 0.7)

train_data = data.iloc[:train_size, :] # 70% entrenamiento
test_data = data.iloc[train_size:, :] # 30% prueba

test_data = test_data.reset_index(drop=True)

# %%
#los indices donde hay ingestas
posicionestrain = train_data.loc[train_data.iloc[:, 0] != 0].index
posicionestest = test_data.loc[test_data.iloc[:, 0] != 0].index

df_posiciones_train = pd.DataFrame(posicionestrain)
df_posiciones_test = pd.DataFrame(posicionestest)

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_train = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_train)):
    anterior = df_posiciones_train.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_train.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_train.append(anterior)

ultimo_elemento_train = df_posiciones_train.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_train.extend(ultimo_elemento_train.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_train)
print(len(cumplen_train))
# Out:
# [494, 862, 1358, 1974, 2353, 2840, 3461, 3846, 4334, 4956, 5324, 5820, 6438, 6815, 7301, 7917, 8283, 8781, 9398, 9781, 10268, 10880, 11255, 11750, 12363, 12742, 13230, 13845, 14212, 14699, 15311, 15686, 16183, 16795, 17162, 17650, 18266, 18653, 19140, 19757, 20125, 20614]
# 42

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_test = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_test)):
    anterior = df_posiciones_test.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_test.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_test.append(anterior)

ultimo_elemento_test = df_posiciones_test.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_test.extend(ultimo_elemento_test.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_test)
print(len(cumplen_test))
# Out:
# [487, 855, 1342, 1956, 2335, 2823, 3439, 3805, 4301, 4916, 5291, 5779, 6398, 6765, 7253, 7868, 8234, 8720]
# 18

# %%
# pasar la escala de los carbohidratos de las ingestas a gramos
data.iloc[:,0] = data.iloc[:,0].apply(lambda x: (x*15)/1000)

# Grafica con mayor detalle, el pico del comportamiento de la glucosa despues de la primera ingesta
print('')
print('Grafica de los datos del dataset')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
plt.title('Ingestas, Insulina y Glucosa')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')

print('Caso 1: Primera ingesta o Desayuno del primer dia:')
plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 700])
plt.ylim([-5, 250])
plt.show()
print('')

print('Caso 2: Primera y segunda ingesta del primer dia:')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1200])
plt.ylim([-5, 500])
plt.show()


print('Caso 3: las tres ingestas del primer dia:')

plt.plot(data.index, data.iloc[:,0], color='blue', label='Ingestas')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Ingestas de carbohidratos')
plt.xlabel('t [min]')
plt.ylabel('gramos')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Dosificación de insulina')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
#plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1800])
plt.ylim([-5, 500])
plt.show()
# Out:
# Grafica de los datos del dataset
# Caso 1: Primera ingesta o Desayuno del primer dia:
# Caso 2: Primera y segunda ingesta del primer dia:
# Caso 3: las tres ingestas del primer dia:

# %%
#Preprocesar los datos:
X_train = train_data.iloc[:, 1:3].values
y_train = train_data.iloc[:,2].values

X_test = test_data.iloc[:, 1:3].values
y_test = test_data.iloc[:, 2].values

print('Tamaño de los datos de entrada, de X_train: ',X_train.shape)
print(f'Tiene {X_train.shape[0]} filas y {X_train.shape[1]} columna')
print('La primera ingesta al minuto 300, ingesta: ',X_train[300])
print('La primera ingesta hasta el minuto 327, ingesta: ',X_train[327])

print('La entrada son los valores de la insulina y glucosa \n',X_train)
print('Tamaño de los datos de salia, de y_train',y_train.shape)
print(f'Tiene {y_train.shape[0]} filas y {y_train.shape[-1]} columnas')
print('La salida son los valores de glucosa \n',y_train)
# Out:
# Tamaño de los datos de entrada, de X_train:  (20746, 2)
# Tiene 20746 filas y 2 columna
# La primera ingesta al minuto 300, ingesta:  [  1.6789 123.44  ]
# La primera ingesta hasta el minuto 327, ingesta:  [  1.6789 123.44  ]
# La entrada son los valores de la insulina y glucosa
#  [[  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  ...
#  [  1.6789 198.03  ]
#  [  1.6789 197.1   ]
#  [  1.6789 196.18  ]]
# Tamaño de los datos de salia, de y_train (20746,)
# Tiene 20746 filas y 20746 columnas
# La salida son los valores de glucosa
#  [123.44 123.44 123.44 ... 198.03 197.1  196.18]

# %%
# Normalizar los datos
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Normalizar y_train
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.reshape(-1, 1))
y_test = sc_y.transform(y_test.reshape(-1, 1))

# %%
# Reorganizar los datos en forma de secuencia
def to_sequences(data,  seq_size_input, seq_size_output):
    X = []
    y = []

    for i in range(len(data)-seq_size_input-seq_size_output+1):
        X.append(data[i:(i+seq_size_input), 0:2])
        y.append(data[(i+seq_size_input):(i+seq_size_input+seq_size_output), 2])

    return np.array(X), np.array(y)

# %%
#CON LOS DATOS NORMALIZADOS
seq_size_input = 15
seq_size_output = 210
X_train, y_train = to_sequences(np.hstack((X_train, y_train)), seq_size_input, seq_size_output)
X_test, y_test = to_sequences(np.hstack((X_test, y_test)), seq_size_input, seq_size_output)
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (20522, 210)
# (20522, 15, 2)
# (8668, 210)
# (8668, 15, 2)

# %%
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
flattened_data = np.reshape(X_train, (X_train.shape[0], -1))

df_X_train = pd.DataFrame(flattened_data)

# %%
flattened_test = np.reshape(X_test, (X_test.shape[0], -1))

df_X_test = pd.DataFrame(flattened_test)

# %%
df_y_train = pd.DataFrame(y_train)
df_y_test = pd.DataFrame(y_test)

# %%
# Filtrar el dataframe para mantener solo las filas especificadas
df_X_train_seleccionado = df_X_train[df_X_train.index.isin(cumplen_train)]
df_y_train_seleccionado = df_y_train[df_y_train.index.isin(cumplen_train)]
df_X_test_seleccionado = df_X_test[df_X_test.index.isin(cumplen_test)]
df_y_test_seleccionado = df_y_test[df_y_test.index.isin(cumplen_test)]

# %%
print('Grafica de los datos del dataset')
#plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')

Numerocurva = 0

plt.plot(df_X_train_seleccionado.iloc[Numerocurva, 1::2],color='green',label='Entrada glucosa') #Para mostrar solo la glucosa
plt.plot(df_X_train_seleccionado.iloc[Numerocurva, ::2],color='orange',label='Entrada insulina') #Para mostrar solo la glucosa
plt.plot(range(seq_size_input*2, seq_size_output + seq_size_input*2),df_y_train_seleccionado.iloc[Numerocurva,:], color='red',label='Salida glucosa')
plt.title('Entradas y salidas, entrenamiento')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')
# Out:
# Grafica de los datos del dataset

# %%
X_train = df_X_train_seleccionado.values
y_train = df_y_train_seleccionado.values
X_test = df_X_test_seleccionado.values
y_test = df_y_test_seleccionado.values

print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 30)
# (17, 210)
# (17, 30)

# %%
print(len(X_test))
# Out:
# 17

# %%
X_train = np.reshape(X_train, (len(X_train), seq_size_input, 2))

X_test = np.reshape(X_test, (len(X_test), seq_size_input, 2))
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 15, 2)
# (17, 210)
# (17, 15, 2)

# %%
kf = KFold(n_splits=5)
kf.get_n_splits(X_train)
KFold(n_splits=5, random_state=None, shuffle=False)


# Crear listas para almacenar los valores del "average loss" de entrenamiento y validación en cada pliegue
train_losses = []
val_losses = []

#Para guardar el mejor modelo
best_loss = float('inf')
best_model_path = ""

for i, (train_index, test_index) in enumerate(kf.split(X_train,y_train)):
  model = Sequential()
  model.add(LSTM(60, activation='tanh', input_shape=(seq_size_input, 2), kernel_initializer=he_uniform()))
  model.add(Dense(seq_size_output, activation='linear', kernel_initializer=he_uniform()))


  model.compile(optimizer=SGD(), loss='mse')
  print(model.summary())

  filepath = f"modelo-{i+1}.h5"
  early_stop = EarlyStopping(monitor='val_loss', patience=3)
  checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

  X, y =  X_train[train_index], y_train[train_index]
  X_val, y_val = X_train[test_index], y_train[test_index]


  history = model.fit(X, y, epochs=100, batch_size=32,validation_data=(X_val, y_val),callbacks=[checkpoint, early_stop] )

  mediamse = np.mean( history.history['loss'] )
  stdmse = np.std(  history.history['loss'])
  print('')
  print(f" La media del mse, {i}-fold es : {mediamse}")
  print('')
  print(f" La desviacion estandar del mse, {i}-fold es : {stdmse}")

  # Obtener los valores de "average loss" para el pliegue actual
  fold_train_losses = model.history.history['loss']
  fold_val_losses = model.history.history['val_loss']

  # Almacenar los valores de "average loss" para el pliegue actual
  train_losses.append(fold_train_losses)
  val_losses.append(fold_val_losses)

  if min(fold_val_losses) < best_loss:
        best_loss = min(fold_val_losses)
        best_model_path = filepath

  history.history.keys() # aqui me muestra que esta guardando, con history me guarda todos los valores que calcula durante el proceso de entrenamiento

  # vamos a graficar
  plt.plot(history.history['loss'], label='Perdida') # Grafico esta para ver si estoy sobre entrenando
  plt.plot(history.history['val_loss'], label='Validacion') # Grafico esta para ver si estoy sobre entrenando
  plt.xlabel('epoch')
  plt.ylabel('Mean Square Error')
  plt.legend()
  plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60)                15120
#
#  dense (Dense)               (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 1.9000
# Epoch 1: val_loss improved from inf to 1.98738, saving model to modelo-1.h5
# 1/1 [==============================] - 2s 2s/step - loss: 1.9000 - val_loss: 1.9874
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8984
# Epoch 2: val_loss improved from 1.98738 to 1.98572, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 1.8984 - val_loss: 1.9857
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8967
# Epoch 3: val_loss improved from 1.98572 to 1.98406, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 1.8967 - val_loss: 1.9841
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8951
# Epoch 4: val_loss improved from 1.98406 to 1.98241, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 1.8951 - val_loss: 1.9824
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8935
# Epoch 5: val_loss improved from 1.98241 to 1.98076, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 1.8935 - val_loss: 1.9808
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8919
# Epoch 6: val_loss improved from 1.98076 to 1.97913, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 1.8919 - val_loss: 1.9791
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8902
# Epoch 7: val_loss improved from 1.97913 to 1.97749, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 1.8902 - val_loss: 1.9775
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8886
# Epoch 8: val_loss improved from 1.97749 to 1.97587, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 1.8886 - val_loss: 1.9759
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8870
# Epoch 9: val_loss improved from 1.97587 to 1.97425, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 1.8870 - val_loss: 1.9743
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8854
# Epoch 10: val_loss improved from 1.97425 to 1.97264, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 50ms/step - loss: 1.8854 - val_loss: 1.9726
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8838
# Epoch 11: val_loss improved from 1.97264 to 1.97104, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 1.8838 - val_loss: 1.9710
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8823
# Epoch 12: val_loss improved from 1.97104 to 1.96944, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 53ms/step - loss: 1.8823 - val_loss: 1.9694
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8807
# Epoch 13: val_loss improved from 1.96944 to 1.96784, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 50ms/step - loss: 1.8807 - val_loss: 1.9678
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8791
# Epoch 14: val_loss improved from 1.96784 to 1.96626, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 1.8791 - val_loss: 1.9663
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8775
# Epoch 15: val_loss improved from 1.96626 to 1.96468, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 1.8775 - val_loss: 1.9647
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8760
# Epoch 16: val_loss improved from 1.96468 to 1.96310, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 1.8760 - val_loss: 1.9631
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8744
# Epoch 17: val_loss improved from 1.96310 to 1.96153, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 1.8744 - val_loss: 1.9615
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8729
# Epoch 18: val_loss improved from 1.96153 to 1.95997, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 54ms/step - loss: 1.8729 - val_loss: 1.9600
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8713
# Epoch 19: val_loss improved from 1.95997 to 1.95841, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 1.8713 - val_loss: 1.9584
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8698
# Epoch 20: val_loss improved from 1.95841 to 1.95686, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 1.8698 - val_loss: 1.9569
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8683
# Epoch 21: val_loss improved from 1.95686 to 1.95532, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 47ms/step - loss: 1.8683 - val_loss: 1.9553
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8668
# Epoch 22: val_loss improved from 1.95532 to 1.95378, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 1.8668 - val_loss: 1.9538
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8652
# Epoch 23: val_loss improved from 1.95378 to 1.95224, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 1.8652 - val_loss: 1.9522
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8637
# Epoch 24: val_loss improved from 1.95224 to 1.95071, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 1.8637 - val_loss: 1.9507
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8622
# Epoch 25: val_loss improved from 1.95071 to 1.94919, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 57ms/step - loss: 1.8622 - val_loss: 1.9492
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8607
# Epoch 26: val_loss improved from 1.94919 to 1.94767, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 57ms/step - loss: 1.8607 - val_loss: 1.9477
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8592
# Epoch 27: val_loss improved from 1.94767 to 1.94616, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 55ms/step - loss: 1.8592 - val_loss: 1.9462
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8577
# Epoch 28: val_loss improved from 1.94616 to 1.94465, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 1.8577 - val_loss: 1.9447
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8562
# Epoch 29: val_loss improved from 1.94465 to 1.94315, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 1.8562 - val_loss: 1.9431
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8548
# Epoch 30: val_loss improved from 1.94315 to 1.94165, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 53ms/step - loss: 1.8548 - val_loss: 1.9416
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8533
# Epoch 31: val_loss improved from 1.94165 to 1.94016, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 54ms/step - loss: 1.8533 - val_loss: 1.9402
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8518
# Epoch 32: val_loss improved from 1.94016 to 1.93867, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 1.8518 - val_loss: 1.9387
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8503
# Epoch 33: val_loss improved from 1.93867 to 1.93719, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 1.8503 - val_loss: 1.9372
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8489
# Epoch 34: val_loss improved from 1.93719 to 1.93571, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 1.8489 - val_loss: 1.9357
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8474
# Epoch 35: val_loss improved from 1.93571 to 1.93423, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 1.8474 - val_loss: 1.9342
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8460
# Epoch 36: val_loss improved from 1.93423 to 1.93276, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 54ms/step - loss: 1.8460 - val_loss: 1.9328
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8445
# Epoch 37: val_loss improved from 1.93276 to 1.93130, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 1.8445 - val_loss: 1.9313
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8431
# Epoch 38: val_loss improved from 1.93130 to 1.92984, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 75ms/step - loss: 1.8431 - val_loss: 1.9298
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8416
# Epoch 39: val_loss improved from 1.92984 to 1.92838, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 1.8416 - val_loss: 1.9284
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8402
# Epoch 40: val_loss improved from 1.92838 to 1.92693, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 47ms/step - loss: 1.8402 - val_loss: 1.9269
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8388
# Epoch 41: val_loss improved from 1.92693 to 1.92549, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 1.8388 - val_loss: 1.9255
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8374
# Epoch 42: val_loss improved from 1.92549 to 1.92405, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 1.8374 - val_loss: 1.9240
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8359
# Epoch 43: val_loss improved from 1.92405 to 1.92261, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 1.8359 - val_loss: 1.9226
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8345
# Epoch 44: val_loss improved from 1.92261 to 1.92117, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 1.8345 - val_loss: 1.9212
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8331
# Epoch 45: val_loss improved from 1.92117 to 1.91974, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 1.8331 - val_loss: 1.9197
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8317
# Epoch 46: val_loss improved from 1.91974 to 1.91832, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 1.8317 - val_loss: 1.9183
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8303
# Epoch 47: val_loss improved from 1.91832 to 1.91690, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 1.8303 - val_loss: 1.9169
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8289
# Epoch 48: val_loss improved from 1.91690 to 1.91548, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 1.8289 - val_loss: 1.9155
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8275
# Epoch 49: val_loss improved from 1.91548 to 1.91407, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 1.8275 - val_loss: 1.9141
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8261
# Epoch 50: val_loss improved from 1.91407 to 1.91266, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 1.8261 - val_loss: 1.9127
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8247
# Epoch 51: val_loss improved from 1.91266 to 1.91125, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 55ms/step - loss: 1.8247 - val_loss: 1.9113
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8233
# Epoch 52: val_loss improved from 1.91125 to 1.90985, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 1.8233 - val_loss: 1.9099
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8220
# Epoch 53: val_loss improved from 1.90985 to 1.90845, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 55ms/step - loss: 1.8220 - val_loss: 1.9085
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8206
# Epoch 54: val_loss improved from 1.90845 to 1.90706, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 56ms/step - loss: 1.8206 - val_loss: 1.9071
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8192
# Epoch 55: val_loss improved from 1.90706 to 1.90567, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 54ms/step - loss: 1.8192 - val_loss: 1.9057
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8178
# Epoch 56: val_loss improved from 1.90567 to 1.90428, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 1.8178 - val_loss: 1.9043
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8165
# Epoch 57: val_loss improved from 1.90428 to 1.90290, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 57ms/step - loss: 1.8165 - val_loss: 1.9029
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8151
# Epoch 58: val_loss improved from 1.90290 to 1.90152, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 55ms/step - loss: 1.8151 - val_loss: 1.9015
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8137
# Epoch 59: val_loss improved from 1.90152 to 1.90014, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 1.8137 - val_loss: 1.9001
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8124
# Epoch 60: val_loss improved from 1.90014 to 1.89877, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 59ms/step - loss: 1.8124 - val_loss: 1.8988
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8110
# Epoch 61: val_loss improved from 1.89877 to 1.89740, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 1.8110 - val_loss: 1.8974
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8097
# Epoch 62: val_loss improved from 1.89740 to 1.89604, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 1.8097 - val_loss: 1.8960
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8084
# Epoch 63: val_loss improved from 1.89604 to 1.89467, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 1.8084 - val_loss: 1.8947
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8070
# Epoch 64: val_loss improved from 1.89467 to 1.89332, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 1.8070 - val_loss: 1.8933
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8057
# Epoch 65: val_loss improved from 1.89332 to 1.89196, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 1.8057 - val_loss: 1.8920
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8043
# Epoch 66: val_loss improved from 1.89196 to 1.89061, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 1.8043 - val_loss: 1.8906
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8030
# Epoch 67: val_loss improved from 1.89061 to 1.88926, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 56ms/step - loss: 1.8030 - val_loss: 1.8893
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8017
# Epoch 68: val_loss improved from 1.88926 to 1.88791, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 1.8017 - val_loss: 1.8879
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8004
# Epoch 69: val_loss improved from 1.88791 to 1.88657, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 47ms/step - loss: 1.8004 - val_loss: 1.8866
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7990
# Epoch 70: val_loss improved from 1.88657 to 1.88523, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 53ms/step - loss: 1.7990 - val_loss: 1.8852
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7977
# Epoch 71: val_loss improved from 1.88523 to 1.88389, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 1.7977 - val_loss: 1.8839
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7964
# Epoch 72: val_loss improved from 1.88389 to 1.88256, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 1.7964 - val_loss: 1.8826
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7951
# Epoch 73: val_loss improved from 1.88256 to 1.88123, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 47ms/step - loss: 1.7951 - val_loss: 1.8812
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7938
# Epoch 74: val_loss improved from 1.88123 to 1.87990, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 1.7938 - val_loss: 1.8799
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7925
# Epoch 75: val_loss improved from 1.87990 to 1.87858, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 1.7925 - val_loss: 1.8786
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7912
# Epoch 76: val_loss improved from 1.87858 to 1.87726, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 1.7912 - val_loss: 1.8773
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7899
# Epoch 77: val_loss improved from 1.87726 to 1.87594, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 1.7899 - val_loss: 1.8759
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7886
# Epoch 78: val_loss improved from 1.87594 to 1.87462, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 47ms/step - loss: 1.7886 - val_loss: 1.8746
# Epoch 79/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7873
# Epoch 79: val_loss improved from 1.87462 to 1.87331, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 1.7873 - val_loss: 1.8733
# Epoch 80/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7860
# Epoch 80: val_loss improved from 1.87331 to 1.87200, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 1.7860 - val_loss: 1.8720
# Epoch 81/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7847
# Epoch 81: val_loss improved from 1.87200 to 1.87069, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 1.7847 - val_loss: 1.8707
# Epoch 82/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7834
# Epoch 82: val_loss improved from 1.87069 to 1.86939, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 1.7834 - val_loss: 1.8694
# Epoch 83/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7821
# Epoch 83: val_loss improved from 1.86939 to 1.86808, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 47ms/step - loss: 1.7821 - val_loss: 1.8681
# Epoch 84/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7808
# Epoch 84: val_loss improved from 1.86808 to 1.86678, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 1.7808 - val_loss: 1.8668
# Epoch 85/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7796
# Epoch 85: val_loss improved from 1.86678 to 1.86549, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 1.7796 - val_loss: 1.8655
# Epoch 86/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7783
# Epoch 86: val_loss improved from 1.86549 to 1.86419, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 57ms/step - loss: 1.7783 - val_loss: 1.8642
# Epoch 87/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7770
# Epoch 87: val_loss improved from 1.86419 to 1.86290, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 1.7770 - val_loss: 1.8629
# Epoch 88/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7758
# Epoch 88: val_loss improved from 1.86290 to 1.86161, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 1.7758 - val_loss: 1.8616
# Epoch 89/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7745
# Epoch 89: val_loss improved from 1.86161 to 1.86032, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 1.7745 - val_loss: 1.8603
# Epoch 90/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7732
# Epoch 90: val_loss improved from 1.86032 to 1.85904, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 1.7732 - val_loss: 1.8590
# Epoch 91/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7720
# Epoch 91: val_loss improved from 1.85904 to 1.85776, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 1.7720 - val_loss: 1.8578
# Epoch 92/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7707
# Epoch 92: val_loss improved from 1.85776 to 1.85648, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 1.7707 - val_loss: 1.8565
# Epoch 93/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7694
# Epoch 93: val_loss improved from 1.85648 to 1.85520, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 56ms/step - loss: 1.7694 - val_loss: 1.8552
# Epoch 94/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7682
# Epoch 94: val_loss improved from 1.85520 to 1.85393, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 1.7682 - val_loss: 1.8539
# Epoch 95/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7669
# Epoch 95: val_loss improved from 1.85393 to 1.85266, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 1.7669 - val_loss: 1.8527
# Epoch 96/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7657
# Epoch 96: val_loss improved from 1.85266 to 1.85139, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 1.7657 - val_loss: 1.8514
# Epoch 97/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7644
# Epoch 97: val_loss improved from 1.85139 to 1.85012, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 1.7644 - val_loss: 1.8501
# Epoch 98/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7632
# Epoch 98: val_loss improved from 1.85012 to 1.84885, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 1.7632 - val_loss: 1.8489
# Epoch 99/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7619
# Epoch 99: val_loss improved from 1.84885 to 1.84759, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 55ms/step - loss: 1.7619 - val_loss: 1.8476
# Epoch 100/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7607
# Epoch 100: val_loss improved from 1.84759 to 1.84633, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 1.7607 - val_loss: 1.8463
#
#  La media del mse, 0-fold es : 1.8270745086669922
#
#  La desviacion estandar del mse, 0-fold es : 0.040435061666981256
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 60)                15120
#
#  dense_1 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 2.0056
# Epoch 1: val_loss improved from inf to 1.51538, saving model to modelo-2.h5
# 2/2 [==============================] - 2s 409ms/step - loss: 1.9579 - val_loss: 1.5154
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 2.0031
# Epoch 2: val_loss improved from 1.51538 to 1.51248, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 1.9548 - val_loss: 1.5125
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8063
# Epoch 3: val_loss improved from 1.51248 to 1.50710, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.9517 - val_loss: 1.5071
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9808
# Epoch 4: val_loss improved from 1.50710 to 1.50366, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 1.9456 - val_loss: 1.5037
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9912
# Epoch 5: val_loss improved from 1.50366 to 1.50096, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.9421 - val_loss: 1.5010
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9741
# Epoch 6: val_loss improved from 1.50096 to 1.49760, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 1.9393 - val_loss: 1.4976
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9853
# Epoch 7: val_loss improved from 1.49760 to 1.49499, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 1.9358 - val_loss: 1.4950
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9804
# Epoch 8: val_loss improved from 1.49499 to 1.49229, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.9331 - val_loss: 1.4923
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9782
# Epoch 9: val_loss improved from 1.49229 to 1.48966, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 1.9303 - val_loss: 1.4897
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9636
# Epoch 10: val_loss improved from 1.48966 to 1.48650, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.9275 - val_loss: 1.4865
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9565
# Epoch 11: val_loss improved from 1.48650 to 1.48324, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.9242 - val_loss: 1.4832
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8078
# Epoch 12: val_loss improved from 1.48324 to 1.47841, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.9208 - val_loss: 1.4784
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9513
# Epoch 13: val_loss improved from 1.47841 to 1.47537, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.9153 - val_loss: 1.4754
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9591
# Epoch 14: val_loss improved from 1.47537 to 1.47287, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 1.9121 - val_loss: 1.4729
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9586
# Epoch 15: val_loss improved from 1.47287 to 1.47051, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.9095 - val_loss: 1.4705
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9561
# Epoch 16: val_loss improved from 1.47051 to 1.46818, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.9070 - val_loss: 1.4682
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9341
# Epoch 17: val_loss improved from 1.46818 to 1.46504, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 1.9046 - val_loss: 1.4650
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9373
# Epoch 18: val_loss improved from 1.46504 to 1.46216, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.9013 - val_loss: 1.4622
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8137
# Epoch 19: val_loss improved from 1.46216 to 1.45773, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.8982 - val_loss: 1.4577
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9227
# Epoch 20: val_loss improved from 1.45773 to 1.45470, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 1.8932 - val_loss: 1.4547
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8514
# Epoch 21: val_loss improved from 1.45470 to 1.45071, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.8900 - val_loss: 1.4507
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8072
# Epoch 22: val_loss improved from 1.45071 to 1.44643, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 1.8855 - val_loss: 1.4464
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8025
# Epoch 23: val_loss improved from 1.44643 to 1.44217, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.8806 - val_loss: 1.4422
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8021
# Epoch 24: val_loss improved from 1.44217 to 1.43800, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.8758 - val_loss: 1.4380
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9031
# Epoch 25: val_loss improved from 1.43800 to 1.43520, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.8710 - val_loss: 1.4352
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9000
# Epoch 26: val_loss improved from 1.43520 to 1.43241, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 1.8681 - val_loss: 1.4324
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9118
# Epoch 27: val_loss improved from 1.43241 to 1.43024, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 1.8652 - val_loss: 1.4302
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9089
# Epoch 28: val_loss improved from 1.43024 to 1.42807, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 1.8629 - val_loss: 1.4281
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8898
# Epoch 29: val_loss improved from 1.42807 to 1.42527, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 1.8606 - val_loss: 1.4253
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9055
# Epoch 30: val_loss improved from 1.42527 to 1.42326, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 1.8576 - val_loss: 1.4233
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8059
# Epoch 31: val_loss improved from 1.42326 to 1.41941, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.8554 - val_loss: 1.4194
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8133
# Epoch 32: val_loss improved from 1.41941 to 1.41571, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 1.8511 - val_loss: 1.4157
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8941
# Epoch 33: val_loss improved from 1.41571 to 1.41371, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.8469 - val_loss: 1.4137
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7719
# Epoch 34: val_loss improved from 1.41371 to 1.40975, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.8448 - val_loss: 1.4097
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7301
# Epoch 35: val_loss improved from 1.40975 to 1.40555, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 1.8402 - val_loss: 1.4056
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7474
# Epoch 36: val_loss improved from 1.40555 to 1.40152, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.8352 - val_loss: 1.4015
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8609
# Epoch 37: val_loss improved from 1.40152 to 1.39891, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 1.8306 - val_loss: 1.3989
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8629
# Epoch 38: val_loss improved from 1.39891 to 1.39646, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.8278 - val_loss: 1.3965
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7157
# Epoch 39: val_loss improved from 1.39646 to 1.39234, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.8252 - val_loss: 1.3923
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8650
# Epoch 40: val_loss improved from 1.39234 to 1.39031, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 1.8204 - val_loss: 1.3903
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8472
# Epoch 41: val_loss improved from 1.39031 to 1.38772, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 1.8182 - val_loss: 1.3877
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8600
# Epoch 42: val_loss improved from 1.38772 to 1.38572, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.8155 - val_loss: 1.3857
# Epoch 43/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8474
# Epoch 43: val_loss improved from 1.38572 to 1.38331, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.8134 - val_loss: 1.3833
# Epoch 44/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8577
# Epoch 44: val_loss improved from 1.38331 to 1.38146, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.8108 - val_loss: 1.3815
# Epoch 45/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8538
# Epoch 45: val_loss improved from 1.38146 to 1.37952, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 1.8088 - val_loss: 1.3795
# Epoch 46/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8382
# Epoch 46: val_loss improved from 1.37952 to 1.37708, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 1.8068 - val_loss: 1.3771
# Epoch 47/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8330
# Epoch 47: val_loss improved from 1.37708 to 1.37457, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 1.8042 - val_loss: 1.3746
# Epoch 48/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7532
# Epoch 48: val_loss improved from 1.37457 to 1.37100, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.8014 - val_loss: 1.3710
# Epoch 49/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8262
# Epoch 49: val_loss improved from 1.37100 to 1.36852, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.7974 - val_loss: 1.3685
# Epoch 50/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6552
# Epoch 50: val_loss improved from 1.36852 to 1.36432, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.7947 - val_loss: 1.3643
# Epoch 51/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8360
# Epoch 51: val_loss improved from 1.36432 to 1.36255, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 1.7897 - val_loss: 1.3626
# Epoch 52/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6802
# Epoch 52: val_loss improved from 1.36255 to 1.35857, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.7877 - val_loss: 1.3586
# Epoch 53/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8289
# Epoch 53: val_loss improved from 1.35857 to 1.35679, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 1.7831 - val_loss: 1.3568
# Epoch 54/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7826
# Epoch 54: val_loss improved from 1.35679 to 1.35385, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.7812 - val_loss: 1.3539
# Epoch 55/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8091
# Epoch 55: val_loss improved from 1.35385 to 1.35150, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 1.7779 - val_loss: 1.3515
# Epoch 56/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8191
# Epoch 56: val_loss improved from 1.35150 to 1.34963, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.7754 - val_loss: 1.3496
# Epoch 57/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7259
# Epoch 57: val_loss improved from 1.34963 to 1.34615, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 1.7734 - val_loss: 1.3461
# Epoch 58/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8149
# Epoch 58: val_loss improved from 1.34615 to 1.34441, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.7694 - val_loss: 1.3444
# Epoch 59/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8020
# Epoch 59: val_loss improved from 1.34441 to 1.34220, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.7675 - val_loss: 1.3422
# Epoch 60/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7178
# Epoch 60: val_loss improved from 1.34220 to 1.33874, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.7651 - val_loss: 1.3387
# Epoch 61/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8051
# Epoch 61: val_loss improved from 1.33874 to 1.33694, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 1.7612 - val_loss: 1.3369
# Epoch 62/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8050
# Epoch 62: val_loss improved from 1.33694 to 1.33523, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 1.7592 - val_loss: 1.3352
# Epoch 63/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7102
# Epoch 63: val_loss improved from 1.33523 to 1.33179, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 1.7573 - val_loss: 1.3318
# Epoch 64/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6466
# Epoch 64: val_loss improved from 1.33179 to 1.32790, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.7534 - val_loss: 1.3279
# Epoch 65/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6428
# Epoch 65: val_loss improved from 1.32790 to 1.32401, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.7487 - val_loss: 1.3240
# Epoch 66/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7782
# Epoch 66: val_loss improved from 1.32401 to 1.32185, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.7442 - val_loss: 1.3218
# Epoch 67/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7702
# Epoch 67: val_loss improved from 1.32185 to 1.31952, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 1.7418 - val_loss: 1.3195
# Epoch 68/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7837
# Epoch 68: val_loss improved from 1.31952 to 1.31781, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.7393 - val_loss: 1.3178
# Epoch 69/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7683
# Epoch 69: val_loss improved from 1.31781 to 1.31556, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.7375 - val_loss: 1.3156
# Epoch 70/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7658
# Epoch 70: val_loss improved from 1.31556 to 1.31333, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.7351 - val_loss: 1.3133
# Epoch 71/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7634
# Epoch 71: val_loss improved from 1.31333 to 1.31110, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 1.7326 - val_loss: 1.3111
# Epoch 72/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7610
# Epoch 72: val_loss improved from 1.31110 to 1.30888, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.7302 - val_loss: 1.3089
# Epoch 73/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6544
# Epoch 73: val_loss improved from 1.30888 to 1.30526, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 1.7278 - val_loss: 1.3053
# Epoch 74/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7254
# Epoch 74: val_loss improved from 1.30526 to 1.30248, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 1.7236 - val_loss: 1.3025
# Epoch 75/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7636
# Epoch 75: val_loss improved from 1.30248 to 1.30074, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.7205 - val_loss: 1.3007
# Epoch 76/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6131
# Epoch 76: val_loss improved from 1.30074 to 1.29690, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 1.7185 - val_loss: 1.2969
# Epoch 77/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7586
# Epoch 77: val_loss improved from 1.29690 to 1.29526, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 1.7140 - val_loss: 1.2953
# Epoch 78/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7142
# Epoch 78: val_loss improved from 1.29526 to 1.29249, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.7122 - val_loss: 1.2925
# Epoch 79/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7535
# Epoch 79: val_loss improved from 1.29249 to 1.29088, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.7091 - val_loss: 1.2909
# Epoch 80/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7502
# Epoch 80: val_loss improved from 1.29088 to 1.28917, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.7074 - val_loss: 1.2892
# Epoch 81/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6006
# Epoch 81: val_loss improved from 1.28917 to 1.28533, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.7054 - val_loss: 1.2853
# Epoch 82/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6122
# Epoch 82: val_loss improved from 1.28533 to 1.28162, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 1.7009 - val_loss: 1.2816
# Epoch 83/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7399
# Epoch 83: val_loss improved from 1.28162 to 1.27996, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 1.6965 - val_loss: 1.2800
# Epoch 84/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5903
# Epoch 84: val_loss improved from 1.27996 to 1.27613, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 1.6946 - val_loss: 1.2761
# Epoch 85/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7204
# Epoch 85: val_loss improved from 1.27613 to 1.27397, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 1.6901 - val_loss: 1.2740
# Epoch 86/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7181
# Epoch 86: val_loss improved from 1.27397 to 1.27181, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 1.6878 - val_loss: 1.2718
# Epoch 87/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7157
# Epoch 87: val_loss improved from 1.27181 to 1.26966, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 1.6854 - val_loss: 1.2697
# Epoch 88/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6112
# Epoch 88: val_loss improved from 1.26966 to 1.26608, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.6830 - val_loss: 1.2661
# Epoch 89/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7121
# Epoch 89: val_loss improved from 1.26608 to 1.26403, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.6789 - val_loss: 1.2640
# Epoch 90/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7187
# Epoch 90: val_loss improved from 1.26403 to 1.26234, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.6767 - val_loss: 1.2623
# Epoch 91/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7081
# Epoch 91: val_loss improved from 1.26234 to 1.26030, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 1.6748 - val_loss: 1.2603
# Epoch 92/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7142
# Epoch 92: val_loss improved from 1.26030 to 1.25859, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.6726 - val_loss: 1.2586
# Epoch 93/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7009
# ...
# 2/2 [==============================] - 0s 50ms/step - loss: 1.7139 - val_loss: 2.1565
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7526
# Epoch 36: val_loss improved from 2.15653 to 2.15461, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 1.7101 - val_loss: 2.1546
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7384
# Epoch 37: val_loss improved from 2.15461 to 2.15229, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.7083 - val_loss: 2.1523
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7506
# Epoch 38: val_loss improved from 2.15229 to 2.15048, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 1.7061 - val_loss: 2.1505
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5467
# Epoch 39: val_loss improved from 2.15048 to 2.14575, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.7043 - val_loss: 2.1457
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7275
# Epoch 40: val_loss improved from 2.14575 to 2.14335, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 1.7004 - val_loss: 2.1434
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7409
# Epoch 41: val_loss improved from 2.14335 to 2.14150, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.6982 - val_loss: 2.1415
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6866
# Epoch 42: val_loss improved from 2.14150 to 2.13814, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 1.6964 - val_loss: 2.1381
# Epoch 43/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7372
# Epoch 43: val_loss improved from 2.13814 to 2.13636, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 1.6934 - val_loss: 2.1364
# Epoch 44/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5679
# Epoch 44: val_loss improved from 2.13636 to 2.13183, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.6917 - val_loss: 2.1318
# Epoch 45/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7313
# Epoch 45: val_loss improved from 2.13183 to 2.13005, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.6880 - val_loss: 2.1300
# Epoch 46/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7296
# Epoch 46: val_loss improved from 2.13005 to 2.12827, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 1.6863 - val_loss: 2.1283
# Epoch 47/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7115
# Epoch 47: val_loss improved from 2.12827 to 2.12593, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.6846 - val_loss: 2.1259
# Epoch 48/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7132
# Epoch 48: val_loss improved from 2.12593 to 2.12373, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.6824 - val_loss: 2.1237
# Epoch 49/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5858
# Epoch 49: val_loss improved from 2.12373 to 2.11939, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 1.6802 - val_loss: 2.1194
# Epoch 50/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7036
# Epoch 50: val_loss improved from 2.11939 to 2.11708, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 1.6766 - val_loss: 2.1171
# Epoch 51/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5521
# Epoch 51: val_loss improved from 2.11708 to 2.11253, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 1.6744 - val_loss: 2.1125
# Epoch 52/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5146
# Epoch 52: val_loss improved from 2.11253 to 2.10779, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 1.6707 - val_loss: 2.1078
# Epoch 53/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6212
# Epoch 53: val_loss improved from 2.10779 to 2.10390, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.6668 - val_loss: 2.1039
# Epoch 54/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7071
# Epoch 54: val_loss improved from 2.10390 to 2.10218, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 1.6636 - val_loss: 2.1022
# Epoch 55/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6887
# Epoch 55: val_loss improved from 2.10218 to 2.09990, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.6619 - val_loss: 2.0999
# Epoch 56/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6927
# Epoch 56: val_loss improved from 2.09990 to 2.09782, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.6598 - val_loss: 2.0978
# Epoch 57/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7002
# Epoch 57: val_loss improved from 2.09782 to 2.09607, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.6578 - val_loss: 2.0961
# Epoch 58/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6855
# Epoch 58: val_loss improved from 2.09607 to 2.09388, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.6562 - val_loss: 2.0939
# Epoch 59/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6964
# Epoch 59: val_loss improved from 2.09388 to 2.09214, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 1.6541 - val_loss: 2.0921
# Epoch 60/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6944
# Epoch 60: val_loss improved from 2.09214 to 2.09039, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 1.6525 - val_loss: 2.0904
# Epoch 61/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6814
# Epoch 61: val_loss improved from 2.09039 to 2.08827, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.6508 - val_loss: 2.0883
# Epoch 62/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6757
# Epoch 62: val_loss improved from 2.08827 to 2.08603, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 1.6488 - val_loss: 2.0860
# Epoch 63/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6893
# Epoch 63: val_loss improved from 2.08603 to 2.08433, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 1.6467 - val_loss: 2.0843
# Epoch 64/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6747
# Epoch 64: val_loss improved from 2.08433 to 2.08219, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 1.6451 - val_loss: 2.0822
# Epoch 65/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6860
# Epoch 65: val_loss improved from 2.08219 to 2.08052, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.6432 - val_loss: 2.0805
# Epoch 66/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6699
# Epoch 66: val_loss improved from 2.08052 to 2.07835, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 1.6416 - val_loss: 2.0784
# Epoch 67/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6817
# Epoch 67: val_loss improved from 2.07835 to 2.07665, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.6396 - val_loss: 2.0767
# Epoch 68/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6707
# Epoch 68: val_loss improved from 2.07665 to 2.07462, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 1.6380 - val_loss: 2.0746
# Epoch 69/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5689
# Epoch 69: val_loss improved from 2.07462 to 2.07037, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 1.6360 - val_loss: 2.0704
# Epoch 70/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6752
# Epoch 70: val_loss improved from 2.07037 to 2.06871, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 1.6325 - val_loss: 2.0687
# Epoch 71/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6721
# Epoch 71: val_loss improved from 2.06871 to 2.06698, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.6310 - val_loss: 2.0670
# Epoch 72/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6608
# Epoch 72: val_loss improved from 2.06698 to 2.06490, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.6293 - val_loss: 2.0649
# Epoch 73/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5346
# Epoch 73: val_loss improved from 2.06490 to 2.06038, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 1.6274 - val_loss: 2.0604
# Epoch 74/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6550
# Epoch 74: val_loss improved from 2.06038 to 2.05830, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 1.6237 - val_loss: 2.0583
# Epoch 75/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6512
# Epoch 75: val_loss improved from 2.05830 to 2.05618, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.6218 - val_loss: 2.0562
# Epoch 76/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6465
# Epoch 76: val_loss improved from 2.05618 to 2.05397, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.6198 - val_loss: 2.0540
# Epoch 77/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6595
# Epoch 77: val_loss improved from 2.05397 to 2.05229, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 1.6178 - val_loss: 2.0523
# Epoch 78/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6428
# Epoch 78: val_loss improved from 2.05229 to 2.05007, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 1.6162 - val_loss: 2.0501
# Epoch 79/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5218
# Epoch 79: val_loss improved from 2.05007 to 2.04545, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 1.6141 - val_loss: 2.0455
# Epoch 80/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4565
# Epoch 80: val_loss improved from 2.04545 to 2.04039, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 1.6103 - val_loss: 2.0404
# Epoch 81/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5249
# Epoch 81: val_loss improved from 2.04039 to 2.03583, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 1.6063 - val_loss: 2.0358
# Epoch 82/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6443
# Epoch 82: val_loss improved from 2.03583 to 2.03415, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.6026 - val_loss: 2.0341
# Epoch 83/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4477
# Epoch 83: val_loss improved from 2.03415 to 2.02901, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 1.6010 - val_loss: 2.0290
# Epoch 84/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6385
# Epoch 84: val_loss improved from 2.02901 to 2.02732, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 1.5970 - val_loss: 2.0273
# Epoch 85/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4762
# Epoch 85: val_loss improved from 2.02732 to 2.02236, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 1.5953 - val_loss: 2.0224
# Epoch 86/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6320
# Epoch 86: val_loss improved from 2.02236 to 2.02064, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 1.5914 - val_loss: 2.0206
# Epoch 87/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6308
# Epoch 87: val_loss improved from 2.02064 to 2.01893, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.5898 - val_loss: 2.0189
# Epoch 88/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6191
# Epoch 88: val_loss improved from 2.01893 to 2.01683, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 1.5882 - val_loss: 2.0168
# Epoch 89/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4667
# Epoch 89: val_loss improved from 2.01683 to 2.01179, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.5863 - val_loss: 2.0118
# Epoch 90/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5171
# Epoch 90: val_loss improved from 2.01179 to 2.00721, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.5822 - val_loss: 2.0072
# Epoch 91/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6184
# Epoch 91: val_loss improved from 2.00721 to 2.00545, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 1.5785 - val_loss: 2.0055
# Epoch 92/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6031
# Epoch 92: val_loss improved from 2.00545 to 2.00321, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 1.5769 - val_loss: 2.0032
# Epoch 93/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6156
# Epoch 93: val_loss improved from 2.00321 to 2.00148, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 1.5749 - val_loss: 2.0015
# Epoch 94/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6146
# Epoch 94: val_loss improved from 2.00148 to 1.99980, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 1.5733 - val_loss: 1.9998
# Epoch 95/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4529
# Epoch 95: val_loss improved from 1.99980 to 1.99460, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.5717 - val_loss: 1.9946
# Epoch 96/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5126
# Epoch 96: val_loss improved from 1.99460 to 1.99005, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 1.5675 - val_loss: 1.9900
# Epoch 97/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4843
# Epoch 97: val_loss improved from 1.99005 to 1.98513, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.5638 - val_loss: 1.9851
# Epoch 98/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5906
# Epoch 98: val_loss improved from 1.98513 to 1.98301, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 1.5599 - val_loss: 1.9830
# Epoch 99/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5154
# Epoch 99: val_loss improved from 1.98301 to 1.97860, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 52ms/step - loss: 1.5580 - val_loss: 1.9786
# Epoch 100/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5826
# Epoch 100: val_loss improved from 1.97860 to 1.97638, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.5544 - val_loss: 1.9764
#
#  La media del mse, 4-fold es : 1.6784932112693787
#
#  La desviacion estandar del mse, 4-fold es : 0.0709723106177901

# %%
# rellenar de ceros los espacios vacios de la lista con loss y validation

df_train_losses = pd.DataFrame(train_losses)

df_filled_train_losses = df_train_losses.fillna(0)

train_losses_completa = df_filled_train_losses.values.tolist()

df_val_losses = pd.DataFrame(val_losses)

df_filled_val_losses = df_val_losses.fillna(0)

val_losses_completa = df_filled_val_losses.values.tolist()

# %%
# Calcular el promedio de "average loss" para todos los pliegues y épocas
avg_train_losses = np.mean(train_losses_completa, axis=0)
avg_val_losses = np.mean(val_losses_completa, axis=0)

# vamos a graficar
plt.plot(avg_train_losses, label='Perdida entrenamiento') # Grafico esta para ver si estoy sobre entrenando
plt.plot(avg_val_losses, label='Perdida Validacion') # Grafico esta para ver si estoy sobre entrenando
plt.title('avg loss train, avg loss val vs epoch ')
plt.xlabel('epoch')
plt.ylabel('Mean Square Error')
plt.legend()
plt.show()

# %%
# Cargar el mejor modelo
best_model = load_model(best_model_path)

# %%
# Seleccionar una secuencia específica
index = 0
input_sequence = X_test[index]

# Hacer la predicción
y_pred = best_model.predict(np.expand_dims(input_sequence, axis=0))
# usamos el np.expand_dims() para agregar una dimensión adicional al inicio de input_sequence
print(y_pred.shape)
# Out:
# 1/1 [==============================] - 1s 819ms/step
# (1, 210)

# %%
# Desenrollar X_test para convertirlo en un array bidimensional
X_test_flattened = X_test.reshape(-1, X_test.shape[-1])

# Aplicar la transformación inversa utilizando el objeto StandardScaler
X_test_desnormalizado = sc.inverse_transform(X_test_flattened)

# Volver a darle forma a X_test_desnormalizado a su forma original
X_test = X_test_desnormalizado.reshape(X_test.shape)

# Desnormalizar los datos
y_pred = sc_y.inverse_transform(y_pred)

y_test = sc_y.inverse_transform(y_test)

print(y_pred.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (1, 210)
# (17, 210)
# (17, 15, 2)

# %%
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
Curva=0

plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

print('')
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(X_test[Curva,:,0],color='orange', label='Valores actuales y anteriores de insulina')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_test[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 229.472625

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_pred[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 195.70194831848144

# %%
# Media MSE y desviacion estandar MSE de las prediciones con la escala normal
mse = mean_squared_error(y_test[0,:].flatten(), y_pred.flatten())
std = np.sqrt(mse)
mediamse = np.mean(mse)

print('La media MSE:',mediamse)
print('La desviacion standar MSE', std)

# calcular la MAE
mae = mean_absolute_error(y_test[0,:], y_pred[0,:])
print('MAE:', mae)

# calcular la RMSE
rmse = np.sqrt(mean_squared_error(y_test[0,:], y_pred[0,:]))
print('RMSE:', rmse)
# Out:
# La media MSE: 906.9869904413997
# La desviacion standar MSE 30.11622470432507
# MAE: 25.181951293945314
# RMSE: 30.11622470432507
