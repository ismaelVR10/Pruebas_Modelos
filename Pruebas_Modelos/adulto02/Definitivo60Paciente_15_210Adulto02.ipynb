# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Librerias
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split, KFold
from keras.callbacks import EarlyStopping

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import load_model

from keras.initializers import he_uniform

from tensorflow.keras.optimizers import RMSprop

# %%
#Dataset Adulto 02
data = pd.read_csv('/content/gdrive/MyDrive/Proyecto_de_grado/SUSTENTACION3.0/FinalX3/adulto02/my_adult02A2_data.csv')

print(f"El archivo se ha cargado correctamente. Tiene {data.shape[0]} filas y {data.shape[1]} columnas.")
# Out:
# El archivo se ha cargado correctamente. Tiene 29638 filas y 3 columnas.

# %%
train_size = int(len(data) * 0.7)

train_data = data.iloc[:train_size, :] # 70% entrenamiento
test_data = data.iloc[train_size:, :] # 30% prueba

test_data = test_data.reset_index(drop=True)

# %%
#los indices donde hay ingestas
posicionestrain = train_data.loc[train_data.iloc[:, 0] != 0].index
posicionestest = test_data.loc[test_data.iloc[:, 0] != 0].index

df_posiciones_train = pd.DataFrame(posicionestrain)
df_posiciones_test = pd.DataFrame(posicionestest)

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_train = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_train)):
    anterior = df_posiciones_train.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_train.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_train.append(anterior)

ultimo_elemento_train = df_posiciones_train.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_train.extend(ultimo_elemento_train.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_train)
print(len(cumplen_train))
# Out:
# [494, 862, 1358, 1974, 2353, 2840, 3461, 3846, 4334, 4956, 5324, 5820, 6438, 6815, 7301, 7917, 8283, 8781, 9398, 9781, 10268, 10880, 11255, 11750, 12363, 12742, 13230, 13845, 14212, 14699, 15311, 15686, 16183, 16795, 17162, 17650, 18266, 18653, 19140, 19757, 20125, 20614]
# 42

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_test = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_test)):
    anterior = df_posiciones_test.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_test.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_test.append(anterior)

ultimo_elemento_test = df_posiciones_test.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_test.extend(ultimo_elemento_test.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_test)
print(len(cumplen_test))
# Out:
# [487, 855, 1342, 1956, 2335, 2823, 3439, 3805, 4301, 4916, 5291, 5779, 6398, 6765, 7253, 7868, 8234, 8720]
# 18

# %%
# pasar la escala de los carbohidratos de las ingestas a gramos
data.iloc[:,0] = data.iloc[:,0].apply(lambda x: (x*15)/1000)

# Grafica con mayor detalle, el pico del comportamiento de la glucosa despues de la primera ingesta
print('')
print('Grafica de los datos del dataset')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
plt.title('Ingestas, Insulina y Glucosa')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')

print('Caso 1: Primera ingesta o Desayuno del primer dia:')
plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 700])
plt.ylim([-5, 250])
plt.show()
print('')

print('Caso 2: Primera y segunda ingesta del primer dia:')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1200])
plt.ylim([-5, 500])
plt.show()


print('Caso 3: las tres ingestas del primer dia:')

plt.plot(data.index, data.iloc[:,0], color='blue', label='Ingestas')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Ingestas de carbohidratos')
plt.xlabel('t [min]')
plt.ylabel('gramos')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Dosificación de insulina')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
#plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1800])
plt.ylim([-5, 500])
plt.show()
# Out:
# Grafica de los datos del dataset
# Caso 1: Primera ingesta o Desayuno del primer dia:
# Caso 2: Primera y segunda ingesta del primer dia:
# Caso 3: las tres ingestas del primer dia:

# %%
#Preprocesar los datos:
X_train = train_data.iloc[:, 1:3].values
y_train = train_data.iloc[:,2].values

X_test = test_data.iloc[:, 1:3].values
y_test = test_data.iloc[:, 2].values

print('Tamaño de los datos de entrada, de X_train: ',X_train.shape)
print(f'Tiene {X_train.shape[0]} filas y {X_train.shape[1]} columna')
print('La primera ingesta al minuto 300, ingesta: ',X_train[300])
print('La primera ingesta hasta el minuto 327, ingesta: ',X_train[327])

print('La entrada son los valores de la insulina y glucosa \n',X_train)
print('Tamaño de los datos de salia, de y_train',y_train.shape)
print(f'Tiene {y_train.shape[0]} filas y {y_train.shape[-1]} columnas')
print('La salida son los valores de glucosa \n',y_train)
# Out:
# Tamaño de los datos de entrada, de X_train:  (20746, 2)
# Tiene 20746 filas y 2 columna
# La primera ingesta al minuto 300, ingesta:  [  1.6789 123.44  ]
# La primera ingesta hasta el minuto 327, ingesta:  [  1.6789 123.44  ]
# La entrada son los valores de la insulina y glucosa
#  [[  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  [  1.6789 123.44  ]
#  ...
#  [  1.6789 198.03  ]
#  [  1.6789 197.1   ]
#  [  1.6789 196.18  ]]
# Tamaño de los datos de salia, de y_train (20746,)
# Tiene 20746 filas y 20746 columnas
# La salida son los valores de glucosa
#  [123.44 123.44 123.44 ... 198.03 197.1  196.18]

# %%
# Normalizar los datos
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Normalizar y_train
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.reshape(-1, 1))
y_test = sc_y.transform(y_test.reshape(-1, 1))

# %%
# Reorganizar los datos en forma de secuencia
def to_sequences(data,  seq_size_input, seq_size_output):
    X = []
    y = []

    for i in range(len(data)-seq_size_input-seq_size_output+1):
        X.append(data[i:(i+seq_size_input), 0:2])
        y.append(data[(i+seq_size_input):(i+seq_size_input+seq_size_output), 2])

    return np.array(X), np.array(y)

# %%
#CON LOS DATOS NORMALIZADOS
seq_size_input = 15
seq_size_output = 210
X_train, y_train = to_sequences(np.hstack((X_train, y_train)), seq_size_input, seq_size_output)
X_test, y_test = to_sequences(np.hstack((X_test, y_test)), seq_size_input, seq_size_output)
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (20522, 210)
# (20522, 15, 2)
# (8668, 210)
# (8668, 15, 2)

# %%
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
flattened_data = np.reshape(X_train, (X_train.shape[0], -1))

df_X_train = pd.DataFrame(flattened_data)

# %%
flattened_test = np.reshape(X_test, (X_test.shape[0], -1))

df_X_test = pd.DataFrame(flattened_test)

# %%
df_y_train = pd.DataFrame(y_train)
df_y_test = pd.DataFrame(y_test)

# %%
# Filtrar el dataframe para mantener solo las filas especificadas
df_X_train_seleccionado = df_X_train[df_X_train.index.isin(cumplen_train)]
df_y_train_seleccionado = df_y_train[df_y_train.index.isin(cumplen_train)]
df_X_test_seleccionado = df_X_test[df_X_test.index.isin(cumplen_test)]
df_y_test_seleccionado = df_y_test[df_y_test.index.isin(cumplen_test)]

# %%
print('Grafica de los datos del dataset')
#plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')

Numerocurva = 0

plt.plot(df_X_train_seleccionado.iloc[Numerocurva, 1::2],color='green',label='Entrada glucosa') #Para mostrar solo la glucosa
plt.plot(df_X_train_seleccionado.iloc[Numerocurva, ::2],color='orange',label='Entrada insulina') #Para mostrar solo la glucosa
plt.plot(range(seq_size_input*2, seq_size_output + seq_size_input*2),df_y_train_seleccionado.iloc[Numerocurva,:], color='red',label='Salida glucosa')
plt.title('Entradas y salidas, entrenamiento')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')
# Out:
# Grafica de los datos del dataset

# %%
X_train = df_X_train_seleccionado.values
y_train = df_y_train_seleccionado.values
X_test = df_X_test_seleccionado.values
y_test = df_y_test_seleccionado.values

print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 30)
# (17, 210)
# (17, 30)

# %%
print(len(X_test))
# Out:
# 17

# %%
X_train = np.reshape(X_train, (len(X_train), seq_size_input, 2))

X_test = np.reshape(X_test, (len(X_test), seq_size_input, 2))
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 15, 2)
# (17, 210)
# (17, 15, 2)

# %%
kf = KFold(n_splits=5)
kf.get_n_splits(X_train)
KFold(n_splits=5, random_state=None, shuffle=False)


# Crear listas para almacenar los valores del "average loss" de entrenamiento y validación en cada pliegue
train_losses = []
val_losses = []

#Para guardar el mejor modelo
best_loss = float('inf')
best_model_path = ""

for i, (train_index, test_index) in enumerate(kf.split(X_train,y_train)):
  model = Sequential()
  model.add(LSTM(60, activation='tanh', input_shape=(seq_size_input, 2), kernel_initializer=he_uniform()))
  model.add(Dense(seq_size_output, activation='linear', kernel_initializer=he_uniform()))


  model.compile(optimizer=RMSprop(), loss='mse')
  print(model.summary())

  filepath = f"modelo-{i+1}.h5"
  early_stop = EarlyStopping(monitor='val_loss', patience=3)
  checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

  X, y =  X_train[train_index], y_train[train_index]
  X_val, y_val = X_train[test_index], y_train[test_index]


  history = model.fit(X, y, epochs=100, batch_size=32,validation_data=(X_val, y_val),callbacks=[checkpoint, early_stop] )

  mediamse = np.mean( history.history['loss'] )
  stdmse = np.std(  history.history['loss'])
  print('')
  print(f" La media del mse, {i}-fold es : {mediamse}")
  print('')
  print(f" La desviacion estandar del mse, {i}-fold es : {stdmse}")

  # Obtener los valores de "average loss" para el pliegue actual
  fold_train_losses = model.history.history['loss']
  fold_val_losses = model.history.history['val_loss']

  # Almacenar los valores de "average loss" para el pliegue actual
  train_losses.append(fold_train_losses)
  val_losses.append(fold_val_losses)

  if min(fold_val_losses) < best_loss:
        best_loss = min(fold_val_losses)
        best_model_path = filepath

  history.history.keys() # aqui me muestra que esta guardando, con history me guarda todos los valores que calcula durante el proceso de entrenamiento

  # vamos a graficar
  plt.plot(history.history['loss'], label='Perdida') # Grafico esta para ver si estoy sobre entrenando
  plt.plot(history.history['val_loss'], label='Validacion') # Grafico esta para ver si estoy sobre entrenando
  plt.xlabel('epoch')
  plt.ylabel('Mean Square Error')
  plt.legend()
  plt.show()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 60)                15120
#
#  dense_10 (Dense)            (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8368
# Epoch 1: val_loss improved from inf to 1.83630, saving model to modelo-1.h5
# 1/1 [==============================] - 1s 1s/step - loss: 1.8368 - val_loss: 1.8363
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7477
# Epoch 2: val_loss improved from 1.83630 to 1.77363, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 1.7477 - val_loss: 1.7736
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6866
# Epoch 3: val_loss improved from 1.77363 to 1.71931, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 1.6866 - val_loss: 1.7193
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6337
# Epoch 4: val_loss improved from 1.71931 to 1.66763, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 47ms/step - loss: 1.6337 - val_loss: 1.6676
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5835
# Epoch 5: val_loss improved from 1.66763 to 1.61580, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 1.5835 - val_loss: 1.6158
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5331
# Epoch 6: val_loss improved from 1.61580 to 1.56215, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 1.5331 - val_loss: 1.5621
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4811
# Epoch 7: val_loss improved from 1.56215 to 1.50563, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 42ms/step - loss: 1.4811 - val_loss: 1.5056
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4264
# Epoch 8: val_loss improved from 1.50563 to 1.44576, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 1.4264 - val_loss: 1.4458
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3687
# Epoch 9: val_loss improved from 1.44576 to 1.38267, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 1.3687 - val_loss: 1.3827
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3080
# Epoch 10: val_loss improved from 1.38267 to 1.31706, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 1.3080 - val_loss: 1.3171
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2450
# Epoch 11: val_loss improved from 1.31706 to 1.25005, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 1.2450 - val_loss: 1.2501
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1808
# Epoch 12: val_loss improved from 1.25005 to 1.18290, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 1.1808 - val_loss: 1.1829
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1165
# Epoch 13: val_loss improved from 1.18290 to 1.11672, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 1.1165 - val_loss: 1.1167
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0533
# Epoch 14: val_loss improved from 1.11672 to 1.05236, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 53ms/step - loss: 1.0533 - val_loss: 1.0524
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9919
# Epoch 15: val_loss improved from 1.05236 to 0.99030, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 50ms/step - loss: 0.9919 - val_loss: 0.9903
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9327
# Epoch 16: val_loss improved from 0.99030 to 0.93079, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 50ms/step - loss: 0.9327 - val_loss: 0.9308
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8760
# Epoch 17: val_loss improved from 0.93079 to 0.87395, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 41ms/step - loss: 0.8760 - val_loss: 0.8740
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8219
# Epoch 18: val_loss improved from 0.87395 to 0.81980, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 0.8219 - val_loss: 0.8198
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7704
# Epoch 19: val_loss improved from 0.81980 to 0.76833, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 0.7704 - val_loss: 0.7683
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7215
# Epoch 20: val_loss improved from 0.76833 to 0.71953, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 0.7215 - val_loss: 0.7195
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6752
# Epoch 21: val_loss improved from 0.71953 to 0.67338, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6752 - val_loss: 0.6734
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6315
# Epoch 22: val_loss improved from 0.67338 to 0.62981, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6315 - val_loss: 0.6298
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5903
# Epoch 23: val_loss improved from 0.62981 to 0.58876, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 41ms/step - loss: 0.5903 - val_loss: 0.5888
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5515
# Epoch 24: val_loss improved from 0.58876 to 0.55012, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5515 - val_loss: 0.5501
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5151
# Epoch 25: val_loss improved from 0.55012 to 0.51379, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 0.5151 - val_loss: 0.5138
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4809
# Epoch 26: val_loss improved from 0.51379 to 0.47967, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 55ms/step - loss: 0.4809 - val_loss: 0.4797
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4489
# Epoch 27: val_loss improved from 0.47967 to 0.44769, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4489 - val_loss: 0.4477
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4190
# Epoch 28: val_loss improved from 0.44769 to 0.41775, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4190 - val_loss: 0.4177
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3910
# Epoch 29: val_loss improved from 0.41775 to 0.38978, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3910 - val_loss: 0.3898
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3650
# Epoch 30: val_loss improved from 0.38978 to 0.36374, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3650 - val_loss: 0.3637
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3408
# Epoch 31: val_loss improved from 0.36374 to 0.33949, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3408 - val_loss: 0.3395
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3183
# Epoch 32: val_loss improved from 0.33949 to 0.31875, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3183 - val_loss: 0.3188
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2989
# Epoch 33: val_loss improved from 0.31875 to 0.30779, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.2989 - val_loss: 0.3078
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2907
# Epoch 34: val_loss improved from 0.30779 to 0.29346, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.2907 - val_loss: 0.2935
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2756
# Epoch 35: val_loss improved from 0.29346 to 0.26689, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 0.2756 - val_loss: 0.2669
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2524
# Epoch 36: val_loss improved from 0.26689 to 0.24883, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2524 - val_loss: 0.2488
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2341
# Epoch 37: val_loss improved from 0.24883 to 0.23113, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2341 - val_loss: 0.2311
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2187
# Epoch 38: val_loss improved from 0.23113 to 0.21723, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2187 - val_loss: 0.2172
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2052
# Epoch 39: val_loss improved from 0.21723 to 0.20312, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2052 - val_loss: 0.2031
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1929
# Epoch 40: val_loss improved from 0.20312 to 0.19136, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1929 - val_loss: 0.1914
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1816
# Epoch 41: val_loss improved from 0.19136 to 0.17920, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1816 - val_loss: 0.1792
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1711
# Epoch 42: val_loss improved from 0.17920 to 0.16948, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 0.1711 - val_loss: 0.1695
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1615
# Epoch 43: val_loss improved from 0.16948 to 0.15886, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1615 - val_loss: 0.1589
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1527
# Epoch 44: val_loss improved from 0.15886 to 0.15187, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1527 - val_loss: 0.1519
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1451
# Epoch 45: val_loss improved from 0.15187 to 0.14261, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1451 - val_loss: 0.1426
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1384
# Epoch 46: val_loss improved from 0.14261 to 0.13854, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1384 - val_loss: 0.1385
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1326
# Epoch 47: val_loss improved from 0.13854 to 0.12818, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1326 - val_loss: 0.1282
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1256
# Epoch 48: val_loss improved from 0.12818 to 0.12361, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1256 - val_loss: 0.1236
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1187
# Epoch 49: val_loss improved from 0.12361 to 0.11248, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1187 - val_loss: 0.1125
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1108
# Epoch 50: val_loss improved from 0.11248 to 0.10780, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1108 - val_loss: 0.1078
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1042
# Epoch 51: val_loss improved from 0.10780 to 0.09886, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1042 - val_loss: 0.0989
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0979
# Epoch 52: val_loss improved from 0.09886 to 0.09491, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0979 - val_loss: 0.0949
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0924
# Epoch 53: val_loss improved from 0.09491 to 0.08760, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0924 - val_loss: 0.0876
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0873
# Epoch 54: val_loss improved from 0.08760 to 0.08448, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0873 - val_loss: 0.0845
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0827
# Epoch 55: val_loss improved from 0.08448 to 0.07806, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0827 - val_loss: 0.0781
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0784
# Epoch 56: val_loss improved from 0.07806 to 0.07602, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0784 - val_loss: 0.0760
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0747
# Epoch 57: val_loss improved from 0.07602 to 0.07009, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0747 - val_loss: 0.0701
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0712
# Epoch 58: val_loss improved from 0.07009 to 0.06947, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0712 - val_loss: 0.0695
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0683
# Epoch 59: val_loss improved from 0.06947 to 0.06363, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0683 - val_loss: 0.0636
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0655
# Epoch 60: val_loss did not improve from 0.06363
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0655 - val_loss: 0.0641
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0631
# Epoch 61: val_loss improved from 0.06363 to 0.05771, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0631 - val_loss: 0.0577
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0601
# Epoch 62: val_loss did not improve from 0.05771
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0601 - val_loss: 0.0580
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0573
# Epoch 63: val_loss improved from 0.05771 to 0.05141, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0573 - val_loss: 0.0514
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0539
# Epoch 64: val_loss improved from 0.05141 to 0.05132, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0539 - val_loss: 0.0513
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0510
# Epoch 65: val_loss improved from 0.05132 to 0.04561, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0510 - val_loss: 0.0456
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0481
# Epoch 66: val_loss improved from 0.04561 to 0.04555, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0481 - val_loss: 0.0456
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0456
# Epoch 67: val_loss improved from 0.04555 to 0.04081, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0456 - val_loss: 0.0408
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0433
# Epoch 68: val_loss did not improve from 0.04081
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0433 - val_loss: 0.0411
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0413
# Epoch 69: val_loss improved from 0.04081 to 0.03694, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0413 - val_loss: 0.0369
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0395
# Epoch 70: val_loss did not improve from 0.03694
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0395 - val_loss: 0.0377
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0381
# Epoch 71: val_loss improved from 0.03694 to 0.03392, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0381 - val_loss: 0.0339
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0367
# Epoch 72: val_loss did not improve from 0.03392
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0367 - val_loss: 0.0353
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0356
# Epoch 73: val_loss improved from 0.03392 to 0.03148, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0356 - val_loss: 0.0315
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0345
# Epoch 74: val_loss did not improve from 0.03148
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0345 - val_loss: 0.0331
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0334
# Epoch 75: val_loss improved from 0.03148 to 0.02898, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0334 - val_loss: 0.0290
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0321
# Epoch 76: val_loss did not improve from 0.02898
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0321 - val_loss: 0.0302
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0307
# Epoch 77: val_loss improved from 0.02898 to 0.02623, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0307 - val_loss: 0.0262
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0292
# Epoch 78: val_loss did not improve from 0.02623
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0292 - val_loss: 0.0272
# Epoch 79/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0278
# Epoch 79: val_loss improved from 0.02623 to 0.02371, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0278 - val_loss: 0.0237
# Epoch 80/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0265
# Epoch 80: val_loss did not improve from 0.02371
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0265 - val_loss: 0.0247
# Epoch 81/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0253
# Epoch 81: val_loss improved from 0.02371 to 0.02170, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0253 - val_loss: 0.0217
# Epoch 82/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0244
# Epoch 82: val_loss did not improve from 0.02170
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0244 - val_loss: 0.0228
# Epoch 83/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0235
# Epoch 83: val_loss improved from 0.02170 to 0.02023, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0235 - val_loss: 0.0202
# Epoch 84/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0229
# Epoch 84: val_loss did not improve from 0.02023
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0229 - val_loss: 0.0216
# Epoch 85/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0223
# Epoch 85: val_loss improved from 0.02023 to 0.01917, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0223 - val_loss: 0.0192
# Epoch 86/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0218
# Epoch 86: val_loss did not improve from 0.01917
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0218 - val_loss: 0.0206
# Epoch 87/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0213
# Epoch 87: val_loss improved from 0.01917 to 0.01822, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0213 - val_loss: 0.0182
# Epoch 88/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0209
# Epoch 88: val_loss did not improve from 0.01822
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0209 - val_loss: 0.0196
# Epoch 89/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0203
# Epoch 89: val_loss improved from 0.01822 to 0.01708, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0203 - val_loss: 0.0171
# Epoch 90/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0197
# Epoch 90: val_loss did not improve from 0.01708
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0197 - val_loss: 0.0182
# Epoch 91/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0189
# Epoch 91: val_loss improved from 0.01708 to 0.01582, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0189 - val_loss: 0.0158
# Epoch 92/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0183
# Epoch 92: val_loss did not improve from 0.01582
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0183 - val_loss: 0.0168
# Epoch 93/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0176
# Epoch 93: val_loss improved from 0.01582 to 0.01471, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0176 - val_loss: 0.0147
# Epoch 94/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0170
# Epoch 94: val_loss did not improve from 0.01471
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0170 - val_loss: 0.0157
# Epoch 95/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0165
# Epoch 95: val_loss improved from 0.01471 to 0.01389, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0165 - val_loss: 0.0139
# Epoch 96/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 96: val_loss did not improve from 0.01389
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0161 - val_loss: 0.0149
# Epoch 97/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0158
# Epoch 97: val_loss improved from 0.01389 to 0.01336, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0158 - val_loss: 0.0134
# Epoch 98/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0155
# Epoch 98: val_loss did not improve from 0.01336
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0155 - val_loss: 0.0145
# Epoch 99/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0153
# Epoch 99: val_loss improved from 0.01336 to 0.01298, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0153 - val_loss: 0.0130
# Epoch 100/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0151
# Epoch 100: val_loss did not improve from 0.01298
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0151 - val_loss: 0.0141
#
#  La media del mse, 0-fold es : 0.3648837613873184
#
#  La desviacion estandar del mse, 0-fold es : 0.4971378975761293
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_11 (LSTM)              (None, 60)                15120
#
#  dense_11 (Dense)            (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 1.9763
# Epoch 1: val_loss improved from inf to 1.37276, saving model to modelo-2.h5
# 2/2 [==============================] - 2s 813ms/step - loss: 1.9278 - val_loss: 1.3728
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8081
# Epoch 2: val_loss improved from 1.37276 to 1.27335, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 1.8050 - val_loss: 1.2733
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7391
# Epoch 3: val_loss improved from 1.27335 to 1.21880, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.6947 - val_loss: 1.2188
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6783
# Epoch 4: val_loss improved from 1.21880 to 1.16562, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 1.6351 - val_loss: 1.1656
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6068
# Epoch 5: val_loss improved from 1.16562 to 1.09239, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.5756 - val_loss: 1.0924
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5254
# Epoch 6: val_loss improved from 1.09239 to 1.01435, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 1.4947 - val_loss: 1.0144
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4393
# Epoch 7: val_loss improved from 1.01435 to 0.93780, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 1.4071 - val_loss: 0.9378
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2577
# Epoch 8: val_loss improved from 0.93780 to 0.80340, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 1.3153 - val_loss: 0.8034
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1795
# Epoch 9: val_loss improved from 0.80340 to 0.75927, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 37ms/step - loss: 1.1485 - val_loss: 0.7593
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0187
# Epoch 10: val_loss improved from 0.75927 to 0.65106, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 1.0930 - val_loss: 0.6511
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9746
# Epoch 11: val_loss improved from 0.65106 to 0.61504, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.9501 - val_loss: 0.6150
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9165
# Epoch 12: val_loss improved from 0.61504 to 0.55342, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.9090 - val_loss: 0.5534
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8552
# Epoch 13: val_loss improved from 0.55342 to 0.52236, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.8332 - val_loss: 0.5224
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8139
# Epoch 14: val_loss improved from 0.52236 to 0.47899, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.7959 - val_loss: 0.4790
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7639
# Epoch 15: val_loss improved from 0.47899 to 0.45026, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 38ms/step - loss: 0.7440 - val_loss: 0.4503
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7231
# Epoch 16: val_loss improved from 0.45026 to 0.40904, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 0.7065 - val_loss: 0.4090
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6724
# Epoch 17: val_loss improved from 0.40904 to 0.37583, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6556 - val_loss: 0.3758
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6289
# Epoch 18: val_loss improved from 0.37583 to 0.34185, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 0.6132 - val_loss: 0.3419
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5607
# Epoch 19: val_loss improved from 0.34185 to 0.28672, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.5666 - val_loss: 0.2867
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4945
# Epoch 20: val_loss improved from 0.28672 to 0.26229, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.4825 - val_loss: 0.2623
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4679
# Epoch 21: val_loss improved from 0.26229 to 0.24255, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.4559 - val_loss: 0.2426
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4396
# Epoch 22: val_loss improved from 0.24255 to 0.22282, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.4284 - val_loss: 0.2228
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3964
# Epoch 23: val_loss improved from 0.22282 to 0.18681, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.3984 - val_loss: 0.1868
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3438
# Epoch 24: val_loss improved from 0.18681 to 0.16704, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.3364 - val_loss: 0.1670
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2957
# Epoch 25: val_loss improved from 0.16704 to 0.16142, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.3095 - val_loss: 0.1614
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2753
# Epoch 26: val_loss improved from 0.16142 to 0.13041, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.2691 - val_loss: 0.1304
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2438
# Epoch 27: val_loss improved from 0.13041 to 0.12436, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 0.2378 - val_loss: 0.1244
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2187
# Epoch 28: val_loss improved from 0.12436 to 0.12407, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 0.2277 - val_loss: 0.1241
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2017
# Epoch 29: val_loss improved from 0.12407 to 0.10196, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1976 - val_loss: 0.1020
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1678
# Epoch 30: val_loss did not improve from 0.10196
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1753 - val_loss: 0.1106
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1605
# Epoch 31: val_loss improved from 0.10196 to 0.09323, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1569 - val_loss: 0.0932
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1560
# Epoch 32: val_loss improved from 0.09323 to 0.08821, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1525 - val_loss: 0.0882
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1394
# Epoch 33: val_loss did not improve from 0.08821
# 2/2 [==============================] - 0s 54ms/step - loss: 0.1439 - val_loss: 0.0900
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1185
# Epoch 34: val_loss improved from 0.08821 to 0.07866, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1171 - val_loss: 0.0787
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1095
# Epoch 35: val_loss improved from 0.07866 to 0.07460, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1077 - val_loss: 0.0746
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1047
# Epoch 36: val_loss improved from 0.07460 to 0.07018, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1028 - val_loss: 0.0702
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0911
# Epoch 37: val_loss did not improve from 0.07018
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0979 - val_loss: 0.1043
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0990
# Epoch 38: val_loss improved from 0.07018 to 0.06691, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0968 - val_loss: 0.0669
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0805
# Epoch 39: val_loss did not improve from 0.06691
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0793 - val_loss: 0.0727
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0724
# Epoch 40: val_loss did not improve from 0.06691
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0767 - val_loss: 0.0945
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0762
# Epoch 41: val_loss did not improve from 0.06691
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0752 - val_loss: 0.0687
#
#  La media del mse, 1-fold es : 0.6486915455358785
#
#  La desviacion estandar del mse, 1-fold es : 0.5593470643419379
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 60)                15120
#
#  dense_12 (Dense)            (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 1.7824
# Epoch 1: val_loss improved from inf to 1.61906, saving model to modelo-3.h5
# 2/2 [==============================] - 2s 360ms/step - loss: 1.8940 - val_loss: 1.6191
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7677
# Epoch 2: val_loss improved from 1.61906 to 1.54560, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 1.7383 - val_loss: 1.5456
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6909
# Epoch 3: val_loss improved from 1.54560 to 1.48489, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 1.6628 - val_loss: 1.4849
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6397
# Epoch 4: val_loss improved from 1.48489 to 1.43730, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 39ms/step - loss: 1.5973 - val_loss: 1.4373
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5887
# Epoch 5: val_loss improved from 1.43730 to 1.38875, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 1.5481 - val_loss: 1.3887
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5355
# Epoch 6: val_loss improved from 1.38875 to 1.33772, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.4956 - val_loss: 1.3377
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4793
# Epoch 7: val_loss improved from 1.33772 to 1.28612, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 1.4395 - val_loss: 1.2861
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4101
# Epoch 8: val_loss improved from 1.28612 to 1.20901, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 1.3813 - val_loss: 1.2090
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2110
# Epoch 9: val_loss improved from 1.20901 to 1.06688, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 1.2881 - val_loss: 1.0669
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0587
# Epoch 10: val_loss improved from 1.06688 to 0.94966, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.1223 - val_loss: 0.9497
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0120
# Epoch 11: val_loss improved from 0.94966 to 0.90552, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.9863 - val_loss: 0.9055
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9664
# Epoch 12: val_loss improved from 0.90552 to 0.86363, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.9413 - val_loss: 0.8636
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8402
# Epoch 13: val_loss improved from 0.86363 to 0.75300, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.8924 - val_loss: 0.7530
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7528
# Epoch 14: val_loss improved from 0.75300 to 0.68719, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.7615 - val_loss: 0.6872
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6978
# Epoch 15: val_loss improved from 0.68719 to 0.64230, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6825 - val_loss: 0.6423
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6528
# Epoch 16: val_loss improved from 0.64230 to 0.60576, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6379 - val_loss: 0.6058
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6136
# Epoch 17: val_loss improved from 0.60576 to 0.57244, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.5987 - val_loss: 0.5724
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5769
# Epoch 18: val_loss improved from 0.57244 to 0.54271, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 0.5632 - val_loss: 0.5427
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5472
# Epoch 19: val_loss improved from 0.54271 to 0.51068, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.5332 - val_loss: 0.5107
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5116
# Epoch 20: val_loss improved from 0.51068 to 0.48005, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 39ms/step - loss: 0.4984 - val_loss: 0.4800
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4710
# Epoch 21: val_loss improved from 0.48005 to 0.43232, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4643 - val_loss: 0.4323
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4156
# Epoch 22: val_loss improved from 0.43232 to 0.40638, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.4053 - val_loss: 0.4064
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3869
# Epoch 23: val_loss improved from 0.40638 to 0.36367, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.3812 - val_loss: 0.3637
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3256
# Epoch 24: val_loss improved from 0.36367 to 0.33081, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 39ms/step - loss: 0.3274 - val_loss: 0.3308
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2914
# Epoch 25: val_loss improved from 0.33081 to 0.28857, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.2848 - val_loss: 0.2886
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2560
# Epoch 26: val_loss improved from 0.28857 to 0.26887, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 0.2516 - val_loss: 0.2689
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2343
# Epoch 27: val_loss improved from 0.26887 to 0.24992, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.2294 - val_loss: 0.2499
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2106
# Epoch 28: val_loss improved from 0.24992 to 0.23172, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.2103 - val_loss: 0.2317
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1915
# Epoch 29: val_loss improved from 0.23172 to 0.20656, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1874 - val_loss: 0.2066
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1698
# Epoch 30: val_loss improved from 0.20656 to 0.19982, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1659 - val_loss: 0.1998
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1663
# Epoch 31: val_loss improved from 0.19982 to 0.18108, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1626 - val_loss: 0.1811
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1467
# Epoch 32: val_loss improved from 0.18108 to 0.16641, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1438 - val_loss: 0.1664
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1340
# Epoch 33: val_loss did not improve from 0.16641
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1308 - val_loss: 0.1691
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1325
# Epoch 34: val_loss improved from 0.16641 to 0.14368, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1331 - val_loss: 0.1437
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1110
# Epoch 35: val_loss improved from 0.14368 to 0.14184, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1085 - val_loss: 0.1418
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0969
# Epoch 36: val_loss improved from 0.14184 to 0.11809, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1056 - val_loss: 0.1181
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1000
# Epoch 37: val_loss improved from 0.11809 to 0.09570, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0986 - val_loss: 0.0957
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0705
# Epoch 38: val_loss did not improve from 0.09570
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0716 - val_loss: 0.1399
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1087
# Epoch 39: val_loss improved from 0.09570 to 0.09511, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1068 - val_loss: 0.0951
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0578
# Epoch 40: val_loss improved from 0.09511 to 0.08085, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0644 - val_loss: 0.0808
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0596
# Epoch 41: val_loss improved from 0.08085 to 0.07211, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0630 - val_loss: 0.0721
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0615
# Epoch 42: val_loss improved from 0.07211 to 0.06457, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0607 - val_loss: 0.0646
# Epoch 43/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0497
# Epoch 43: val_loss improved from 0.06457 to 0.06113, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0493 - val_loss: 0.0611
# Epoch 44/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0428
# Epoch 44: val_loss improved from 0.06113 to 0.05846, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0426 - val_loss: 0.0585
# Epoch 45/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0379
# Epoch 45: val_loss did not improve from 0.05846
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0395 - val_loss: 0.1108
# Epoch 46/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0861
# Epoch 46: val_loss did not improve from 0.05846
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0844 - val_loss: 0.0637
# Epoch 47/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0383
# Epoch 47: val_loss improved from 0.05846 to 0.05220, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0387 - val_loss: 0.0522
# Epoch 48/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0349
# Epoch 48: val_loss improved from 0.05220 to 0.04879, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0345 - val_loss: 0.0488
# Epoch 49/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0307
# Epoch 49: val_loss improved from 0.04879 to 0.04689, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0304 - val_loss: 0.0469
# Epoch 50/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0285
# Epoch 50: val_loss improved from 0.04689 to 0.04556, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0282 - val_loss: 0.0456
# Epoch 51/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0297
# Epoch 51: val_loss improved from 0.04556 to 0.04510, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0291 - val_loss: 0.0451
# Epoch 52/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0269
# Epoch 52: val_loss improved from 0.04510 to 0.04214, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0265 - val_loss: 0.0421
# ...
# Epoch 56/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0250
# Epoch 56: val_loss improved from 0.02070 to 0.01960, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0247 - val_loss: 0.0196
# Epoch 57/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0231
# Epoch 57: val_loss improved from 0.01960 to 0.01759, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0227 - val_loss: 0.0176
# Epoch 58/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0203
# Epoch 58: val_loss improved from 0.01759 to 0.01649, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0200 - val_loss: 0.0165
# Epoch 59/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0195
# Epoch 59: val_loss improved from 0.01649 to 0.01541, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0192 - val_loss: 0.0154
# Epoch 60/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0180
# Epoch 60: val_loss did not improve from 0.01541
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0176 - val_loss: 0.0156
# Epoch 61/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0179
# Epoch 61: val_loss improved from 0.01541 to 0.01499, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0176 - val_loss: 0.0150
# Epoch 62/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0167
# Epoch 62: val_loss did not improve from 0.01499
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0164 - val_loss: 0.0188
# Epoch 63/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0174
# Epoch 63: val_loss did not improve from 0.01499
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0220 - val_loss: 0.0498
# Epoch 64/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0497
# Epoch 64: val_loss did not improve from 0.01499
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0494 - val_loss: 0.0322
#
#  La media del mse, 3-fold es : 0.40951276320265606
#
#  La desviacion estandar del mse, 3-fold es : 0.518060681781544
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_14 (LSTM)              (None, 60)                15120
#
#  dense_14 (Dense)            (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 1.8567
# Epoch 1: val_loss improved from inf to 2.14088, saving model to modelo-5.h5
# 2/2 [==============================] - 2s 353ms/step - loss: 1.8229 - val_loss: 2.1409
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6045
# Epoch 2: val_loss improved from 2.14088 to 2.00628, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.6954 - val_loss: 2.0063
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6219
# Epoch 3: val_loss improved from 2.00628 to 1.94442, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 1.5915 - val_loss: 1.9444
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5702
# Epoch 4: val_loss improved from 1.94442 to 1.89024, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.5308 - val_loss: 1.8902
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3670
# Epoch 5: val_loss improved from 1.89024 to 1.74868, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 1.4771 - val_loss: 1.7487
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4025
# Epoch 6: val_loss improved from 1.74868 to 1.69095, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 1.3664 - val_loss: 1.6910
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3493
# Epoch 7: val_loss improved from 1.69095 to 1.62868, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 1.3138 - val_loss: 1.6287
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2818
# Epoch 8: val_loss improved from 1.62868 to 1.52449, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 1.2581 - val_loss: 1.5245
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2010
# Epoch 9: val_loss improved from 1.52449 to 1.44429, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 1.1693 - val_loss: 1.4443
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1326
# Epoch 10: val_loss improved from 1.44429 to 1.35727, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 1.1025 - val_loss: 1.3573
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0026
# Epoch 11: val_loss improved from 1.35727 to 1.13945, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 1.0269 - val_loss: 1.1394
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8097
# Epoch 12: val_loss improved from 1.13945 to 0.96816, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 0.8608 - val_loss: 0.9682
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7292
# Epoch 13: val_loss improved from 0.96816 to 0.86801, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.7394 - val_loss: 0.8680
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6249
# Epoch 14: val_loss improved from 0.86801 to 0.76495, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6626 - val_loss: 0.7650
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5986
# Epoch 15: val_loss improved from 0.76495 to 0.70315, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.5938 - val_loss: 0.7031
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5245
# Epoch 16: val_loss improved from 0.70315 to 0.63029, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.5373 - val_loss: 0.6303
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4739
# Epoch 17: val_loss improved from 0.63029 to 0.56296, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.4878 - val_loss: 0.5630
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4500
# Epoch 18: val_loss improved from 0.56296 to 0.53326, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4407 - val_loss: 0.5333
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4069
# Epoch 19: val_loss improved from 0.53326 to 0.50797, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 0.3978 - val_loss: 0.5080
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3846
# Epoch 20: val_loss improved from 0.50797 to 0.48878, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.3755 - val_loss: 0.4888
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3041
# Epoch 21: val_loss improved from 0.48878 to 0.39586, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.3554 - val_loss: 0.3959
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3157
# Epoch 22: val_loss improved from 0.39586 to 0.37927, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 49ms/step - loss: 0.3086 - val_loss: 0.3793
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2877
# Epoch 23: val_loss improved from 0.37927 to 0.35892, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 0.2818 - val_loss: 0.3589
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2720
# Epoch 24: val_loss improved from 0.35892 to 0.34300, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.2661 - val_loss: 0.3430
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2607
# Epoch 25: val_loss improved from 0.34300 to 0.33407, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2544 - val_loss: 0.3341
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2042
# Epoch 26: val_loss improved from 0.33407 to 0.26578, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2426 - val_loss: 0.2658
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2135
# Epoch 27: val_loss improved from 0.26578 to 0.23176, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2156 - val_loss: 0.2318
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1877
# Epoch 28: val_loss improved from 0.23176 to 0.22184, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1838 - val_loss: 0.2218
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1772
# Epoch 29: val_loss improved from 0.22184 to 0.21337, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1734 - val_loss: 0.2134
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1569
# Epoch 30: val_loss improved from 0.21337 to 0.18310, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1654 - val_loss: 0.1831
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1568
# Epoch 31: val_loss improved from 0.18310 to 0.17455, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1530 - val_loss: 0.1745
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1402
# Epoch 32: val_loss did not improve from 0.17455
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1370 - val_loss: 0.1852
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1437
# Epoch 33: val_loss improved from 0.17455 to 0.14471, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1441 - val_loss: 0.1447
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1200
# Epoch 34: val_loss improved from 0.14471 to 0.13915, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1178 - val_loss: 0.1391
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1177
# Epoch 35: val_loss did not improve from 0.13915
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1149 - val_loss: 0.1519
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1214
# Epoch 36: val_loss improved from 0.13915 to 0.12594, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1191 - val_loss: 0.1259
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0971
# Epoch 37: val_loss improved from 0.12594 to 0.10294, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1016 - val_loss: 0.1029
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1003
# Epoch 38: val_loss improved from 0.10294 to 0.09583, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0978 - val_loss: 0.0958
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0854
# Epoch 39: val_loss improved from 0.09583 to 0.09303, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0840 - val_loss: 0.0930
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0876
# Epoch 40: val_loss improved from 0.09303 to 0.08981, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0855 - val_loss: 0.0898
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0772
# Epoch 41: val_loss did not improve from 0.08981
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0771 - val_loss: 0.1038
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0854
# Epoch 42: val_loss did not improve from 0.08981
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0833 - val_loss: 0.0956
# Epoch 43/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0687
# Epoch 43: val_loss improved from 0.08981 to 0.06772, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0761 - val_loss: 0.0677
# Epoch 44/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0822
# Epoch 44: val_loss improved from 0.06772 to 0.05471, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0812 - val_loss: 0.0547
# Epoch 45/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0512
# Epoch 45: val_loss improved from 0.05471 to 0.04733, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0555 - val_loss: 0.0473
# Epoch 46/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0672
# Epoch 46: val_loss improved from 0.04733 to 0.04018, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0663 - val_loss: 0.0402
# Epoch 47/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0523
# Epoch 47: val_loss improved from 0.04018 to 0.03850, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0517 - val_loss: 0.0385
# Epoch 48/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0469
# Epoch 48: val_loss improved from 0.03850 to 0.03719, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0462 - val_loss: 0.0372
# Epoch 49/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0463
# Epoch 49: val_loss improved from 0.03719 to 0.03609, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0456 - val_loss: 0.0361
# Epoch 50/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0427
# Epoch 50: val_loss did not improve from 0.03609
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0419 - val_loss: 0.0397
# Epoch 51/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0412
# Epoch 51: val_loss improved from 0.03609 to 0.03323, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0405 - val_loss: 0.0332
# Epoch 52/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0391
# Epoch 52: val_loss improved from 0.03323 to 0.03275, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0386 - val_loss: 0.0327
# Epoch 53/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0361
# Epoch 53: val_loss did not improve from 0.03275
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0358 - val_loss: 0.0442
# Epoch 54/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0418
# Epoch 54: val_loss did not improve from 0.03275
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0422 - val_loss: 0.0854
# Epoch 55/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0745
# Epoch 55: val_loss did not improve from 0.03275
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0727 - val_loss: 0.0360
#
#  La media del mse, 4-fold es : 0.45285686735402453
#
#  La desviacion estandar del mse, 4-fold es : 0.5172149343277849

# %%
# rellenar de ceros los espacios vacios de la lista con loss y validation

df_train_losses = pd.DataFrame(train_losses)

df_filled_train_losses = df_train_losses.fillna(0)

train_losses_completa = df_filled_train_losses.values.tolist()

df_val_losses = pd.DataFrame(val_losses)

df_filled_val_losses = df_val_losses.fillna(0)

val_losses_completa = df_filled_val_losses.values.tolist()

# %%
# Calcular el promedio de "average loss" para todos los pliegues y épocas
avg_train_losses = np.mean(train_losses_completa, axis=0)
avg_val_losses = np.mean(val_losses_completa, axis=0)

# vamos a graficar
plt.plot(avg_train_losses, label='Perdida entrenamiento') # Grafico esta para ver si estoy sobre entrenando
plt.plot(avg_val_losses, label='Perdida Validacion') # Grafico esta para ver si estoy sobre entrenando
plt.title('avg loss train, avg loss val vs epoch ')
plt.xlabel('epoch')
plt.ylabel('Mean Square Error')
plt.legend()
plt.show()

# %%
# Cargar el mejor modelo
best_model = load_model(best_model_path)

# %%
# Seleccionar una secuencia específica
index = 0
input_sequence = X_test[index]

# Hacer la predicción
y_pred = best_model.predict(np.expand_dims(input_sequence, axis=0))
# usamos el np.expand_dims() para agregar una dimensión adicional al inicio de input_sequence
print(y_pred.shape)
# Out:
# 1/1 [==============================] - 0s 300ms/step
# (1, 210)

# %%
# Desenrollar X_test para convertirlo en un array bidimensional
X_test_flattened = X_test.reshape(-1, X_test.shape[-1])

# Aplicar la transformación inversa utilizando el objeto StandardScaler
X_test_desnormalizado = sc.inverse_transform(X_test_flattened)

# Volver a darle forma a X_test_desnormalizado a su forma original
X_test = X_test_desnormalizado.reshape(X_test.shape)

# Desnormalizar los datos
y_pred = sc_y.inverse_transform(y_pred)

y_test = sc_y.inverse_transform(y_test)

print(y_pred.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (1, 210)
# (17, 210)
# (17, 15, 2)

# %%
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
Curva=0

plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

print('')
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(X_test[Curva,:,0],color='orange', label='Valores actuales y anteriores de insulina')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_test[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 229.472625

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_pred[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 232.58954761505126

# %%
# Media MSE y desviacion estandar MSE de las prediciones con la escala normal
mse = mean_squared_error(y_test[0,:].flatten(), y_pred.flatten())
std = np.sqrt(mse)
mediamse = np.mean(mse)

print('La media MSE:',mediamse)
print('La desviacion standar MSE', std)

# calcular la MAE
mae = mean_absolute_error(y_test[0,:], y_pred[0,:])
print('MAE:', mae)

# calcular la RMSE
rmse = np.sqrt(mean_squared_error(y_test[0,:], y_pred[0,:]))
print('RMSE:', rmse)
# Out:
# La media MSE: 13.158599168820148
# La desviacion standar MSE 3.6274783484977755
# MAE: 2.6148879975818446
# RMSE: 3.6274783484977755
