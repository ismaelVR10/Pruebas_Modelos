# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Librerias
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split, KFold
from keras.callbacks import EarlyStopping

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import load_model

from keras.initializers import he_uniform

from tensorflow.keras.optimizers import RMSprop

# %%
#Dataset Adulto 01
data = pd.read_csv('/content/gdrive/MyDrive/Proyecto_de_grado/SUSTENTACION3.0/FinalX3/adulto03/my_adult03A2_data.csv')

print(f"El archivo se ha cargado correctamente. Tiene {data.shape[0]} filas y {data.shape[1]} columnas.")
# Out:
# El archivo se ha cargado correctamente. Tiene 28884 filas y 3 columnas.

# %%
train_size = int(len(data) * 0.7)

train_data = data.iloc[:train_size, :] # 70% entrenamiento
test_data = data.iloc[train_size:, :] # 30% prueba

test_data = test_data.reset_index(drop=True)

# %%
#los indices donde hay ingestas
posicionestrain = train_data.loc[train_data.iloc[:, 0] != 0].index
posicionestest = test_data.loc[test_data.iloc[:, 0] != 0].index

df_posiciones_train = pd.DataFrame(posicionestrain)
df_posiciones_test = pd.DataFrame(posicionestest)

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_train = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_train)):
    anterior = df_posiciones_train.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_train.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_train.append(anterior)

ultimo_elemento_train = df_posiciones_train.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_train.extend(ultimo_elemento_train.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_train)
print(len(cumplen_train))
# Out:
# [455, 820, 1301, 1902, 2263, 2744, 3345, 3706, 4187, 4788, 5149, 5630, 6231, 6592, 7073, 7674, 8035, 8516, 9117, 9478, 9959, 10560, 10921, 11402, 12003, 12364, 12845, 13446, 13807, 14288, 14889, 15250, 15731, 16332, 16693, 17174, 17775, 18136, 18617, 19218, 19579, 20060]
# 42

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_test = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_test)):
    anterior = df_posiciones_test.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_test.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_test.append(anterior)

ultimo_elemento_test = df_posiciones_test.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_test.extend(ultimo_elemento_test.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_test)
print(len(cumplen_test))
# Out:
# [443, 804, 1285, 1886, 2247, 2728, 3329, 3690, 4171, 4772, 5133, 5614, 6215, 6576, 7057, 7658, 8019, 8500]
# 18

# %%
# pasar la escala de los carbohidratos de las ingestas a gramos
data.iloc[:,0] = data.iloc[:,0].apply(lambda x: (x*15)/1000)

# Grafica con mayor detalle, el pico del comportamiento de la glucosa despues de la primera ingesta
print('')
print('Grafica de los datos del dataset')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
plt.title('Ingestas, Insulina y Glucosa')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')

print('Caso 1: Primera ingesta o Desayuno del primer dia:')
plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 700])
plt.ylim([-5, 250])
plt.show()
print('')

print('Caso 2: Primera y segunda ingesta del primer dia:')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1200])
plt.ylim([-5, 500])
plt.show()


print('Caso 3: las tres ingestas del primer dia:')

plt.plot(data.index, data.iloc[:,0], color='blue', label='Ingestas')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Ingestas de carbohidratos')
plt.xlabel('t [min]')
plt.ylabel('gramos')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Dosificación de insulina')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
#plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1800])
plt.ylim([-5, 500])
plt.show()
# Out:
# Grafica de los datos del dataset
# Caso 1: Primera ingesta o Desayuno del primer dia:
# Caso 2: Primera y segunda ingesta del primer dia:
# Caso 3: las tres ingestas del primer dia:

# %%
#Preprocesar los datos:
X_train = train_data.iloc[:, 1:3].values
y_train = train_data.iloc[:,2].values

X_test = test_data.iloc[:, 1:3].values
y_test = test_data.iloc[:, 2].values

print('Tamaño de los datos de entrada, de X_train: ',X_train.shape)
print(f'Tiene {X_train.shape[0]} filas y {X_train.shape[1]} columna')
print('La primera ingesta al minuto 300, ingesta: ',X_train[300])
print('La primera ingesta hasta el minuto 327, ingesta: ',X_train[327])

print('La entrada son los valores de la insulina y glucosa \n',X_train)
print('Tamaño de los datos de salia, de y_train',y_train.shape)
print(f'Tiene {y_train.shape[0]} filas y {y_train.shape[-1]} columnas')
print('La salida son los valores de glucosa \n',y_train)
# Out:
# Tamaño de los datos de entrada, de X_train:  (20218, 2)
# Tiene 20218 filas y 2 columna
# La primera ingesta al minuto 300, ingesta:  [  1.6789 147.08  ]
# La primera ingesta hasta el minuto 327, ingesta:  [  1.6789 150.68  ]
# La entrada son los valores de la insulina y glucosa
#  [[  1.6789 119.41  ]
#  [  1.6789 119.41  ]
#  [  1.6789 119.41  ]
#  ...
#  [  1.6789 385.77  ]
#  [  1.6789 385.3   ]
#  [  1.6789 384.83  ]]
# Tamaño de los datos de salia, de y_train (20218,)
# Tiene 20218 filas y 20218 columnas
# La salida son los valores de glucosa
#  [119.41 119.41 119.41 ... 385.77 385.3  384.83]

# %%
# Normalizar los datos
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Normalizar y_train
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.reshape(-1, 1))
y_test = sc_y.transform(y_test.reshape(-1, 1))

# %%
# Reorganizar los datos en forma de secuencia
def to_sequences(data,  seq_size_input, seq_size_output):
    X = []
    y = []

    for i in range(len(data)-seq_size_input-seq_size_output+1):
        X.append(data[i:(i+seq_size_input), 0:2])
        y.append(data[(i+seq_size_input):(i+seq_size_input+seq_size_output), 2])

    return np.array(X), np.array(y)

# %%
#CON LOS DATOS NORMALIZADOS
seq_size_input = 15
seq_size_output = 210
X_train, y_train = to_sequences(np.hstack((X_train, y_train)), seq_size_input, seq_size_output)
X_test, y_test = to_sequences(np.hstack((X_test, y_test)), seq_size_input, seq_size_output)
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (19994, 210)
# (19994, 15, 2)
# (8442, 210)
# (8442, 15, 2)

# %%
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
flattened_data = np.reshape(X_train, (X_train.shape[0], -1))

df_X_train = pd.DataFrame(flattened_data)

# %%
flattened_test = np.reshape(X_test, (X_test.shape[0], -1))

df_X_test = pd.DataFrame(flattened_test)

# %%
df_y_train = pd.DataFrame(y_train)
df_y_test = pd.DataFrame(y_test)

# %%
# Filtrar el dataframe para mantener solo las filas especificadas
df_X_train_seleccionado = df_X_train[df_X_train.index.isin(cumplen_train)]
df_y_train_seleccionado = df_y_train[df_y_train.index.isin(cumplen_train)]
df_X_test_seleccionado = df_X_test[df_X_test.index.isin(cumplen_test)]
df_y_test_seleccionado = df_y_test[df_y_test.index.isin(cumplen_test)]

# %%
print('Grafica de los datos del dataset')
#plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')

Numerocurva = 0

plt.plot(df_X_train_seleccionado.iloc[Numerocurva, 1::2],color='green',label='Entrada glucosa') #Para mostrar solo la glucosa
plt.plot(df_X_train_seleccionado.iloc[Numerocurva, ::2],color='orange',label='Entrada insulina') #Para mostrar solo la glucosa
plt.plot(range(seq_size_input*2, seq_size_output + seq_size_input*2),df_y_train_seleccionado.iloc[Numerocurva,:], color='red',label='Salida glucosa')
plt.title('Entradas y salidas, entrenamiento')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')
# Out:
# Grafica de los datos del dataset

# %%
X_train = df_X_train_seleccionado.values
y_train = df_y_train_seleccionado.values
X_test = df_X_test_seleccionado.values
y_test = df_y_test_seleccionado.values

print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 30)
# (17, 210)
# (17, 30)

# %%
print(len(X_test))
# Out:
# 17

# %%
X_train = np.reshape(X_train, (len(X_train), seq_size_input, 2))

X_test = np.reshape(X_test, (len(X_test), seq_size_input, 2))
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 15, 2)
# (17, 210)
# (17, 15, 2)

# %%
kf = KFold(n_splits=5)
kf.get_n_splits(X_train)
KFold(n_splits=5, random_state=None, shuffle=False)


# Crear listas para almacenar los valores del "average loss" de entrenamiento y validación en cada pliegue
train_losses = []
val_losses = []

#Para guardar el mejor modelo
best_loss = float('inf')
best_model_path = ""

for i, (train_index, test_index) in enumerate(kf.split(X_train,y_train)):
  model = Sequential()
  model.add(LSTM(60, activation='tanh', input_shape=(seq_size_input, 2), kernel_initializer=he_uniform()))
  model.add(Dense(seq_size_output, activation='linear', kernel_initializer=he_uniform()))


  model.compile(optimizer=RMSprop(), loss='mse')
  print(model.summary())

  filepath = f"modelo-{i+1}.h5"
  early_stop = EarlyStopping(monitor='val_loss', patience=3)
  checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

  X, y =  X_train[train_index], y_train[train_index]
  X_val, y_val = X_train[test_index], y_train[test_index]


  history = model.fit(X, y, epochs=100, batch_size=32,validation_data=(X_val, y_val),callbacks=[checkpoint, early_stop] )

  mediamse = np.mean( history.history['loss'] )
  stdmse = np.std(  history.history['loss'])
  print('')
  print(f" La media del mse, {i}-fold es : {mediamse}")
  print('')
  print(f" La desviacion estandar del mse, {i}-fold es : {stdmse}")

  # Obtener los valores de "average loss" para el pliegue actual
  fold_train_losses = model.history.history['loss']
  fold_val_losses = model.history.history['val_loss']

  # Almacenar los valores de "average loss" para el pliegue actual
  train_losses.append(fold_train_losses)
  val_losses.append(fold_val_losses)

  if min(fold_val_losses) < best_loss:
        best_loss = min(fold_val_losses)
        best_model_path = filepath

  history.history.keys() # aqui me muestra que esta guardando, con history me guarda todos los valores que calcula durante el proceso de entrenamiento

  # vamos a graficar
  plt.plot(history.history['loss'], label='Perdida') # Grafico esta para ver si estoy sobre entrenando
  plt.plot(history.history['val_loss'], label='Validacion') # Grafico esta para ver si estoy sobre entrenando
  plt.xlabel('epoch')
  plt.ylabel('Mean Square Error')
  plt.legend()
  plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60)                15120
#
#  dense (Dense)               (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4414
# Epoch 1: val_loss improved from inf to 1.41857, saving model to modelo-1.h5
# 1/1 [==============================] - 3s 3s/step - loss: 1.4414 - val_loss: 1.4186
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3118
# Epoch 2: val_loss improved from 1.41857 to 1.34019, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 1.3118 - val_loss: 1.3402
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2329
# Epoch 3: val_loss improved from 1.34019 to 1.27845, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 1.2329 - val_loss: 1.2785
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1714
# Epoch 4: val_loss improved from 1.27845 to 1.22556, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 1.1714 - val_loss: 1.2256
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1190
# Epoch 5: val_loss improved from 1.22556 to 1.17796, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 1.1190 - val_loss: 1.1780
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0722
# Epoch 6: val_loss improved from 1.17796 to 1.13411, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 1.0722 - val_loss: 1.1341
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0292
# Epoch 7: val_loss improved from 1.13411 to 1.09319, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 1.0292 - val_loss: 1.0932
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9893
# Epoch 8: val_loss improved from 1.09319 to 1.05475, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.9893 - val_loss: 1.0547
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9520
# Epoch 9: val_loss improved from 1.05475 to 1.01848, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.9520 - val_loss: 1.0185
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9168
# Epoch 10: val_loss improved from 1.01848 to 0.98410, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.9168 - val_loss: 0.9841
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8835
# Epoch 11: val_loss improved from 0.98410 to 0.95134, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.8835 - val_loss: 0.9513
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8518
# Epoch 12: val_loss improved from 0.95134 to 0.91990, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.8518 - val_loss: 0.9199
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8214
# Epoch 13: val_loss improved from 0.91990 to 0.88955, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.8214 - val_loss: 0.8895
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7922
# Epoch 14: val_loss improved from 0.88955 to 0.86012, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.7922 - val_loss: 0.8601
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7639
# Epoch 15: val_loss improved from 0.86012 to 0.83149, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.7639 - val_loss: 0.8315
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7365
# Epoch 16: val_loss improved from 0.83149 to 0.80369, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.7365 - val_loss: 0.8037
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7099
# Epoch 17: val_loss improved from 0.80369 to 0.77647, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.7099 - val_loss: 0.7765
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6842
# Epoch 18: val_loss improved from 0.77647 to 0.75064, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.6842 - val_loss: 0.7506
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6591
# Epoch 19: val_loss improved from 0.75064 to 0.72372, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.6591 - val_loss: 0.7237
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6352
# Epoch 20: val_loss improved from 0.72372 to 0.70523, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.6352 - val_loss: 0.7052
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6131
# Epoch 21: val_loss improved from 0.70523 to 0.67426, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 80ms/step - loss: 0.6131 - val_loss: 0.6743
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5912
# Epoch 22: val_loss improved from 0.67426 to 0.66088, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.5912 - val_loss: 0.6609
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5695
# Epoch 23: val_loss improved from 0.66088 to 0.62928, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.5695 - val_loss: 0.6293
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5472
# Epoch 24: val_loss improved from 0.62928 to 0.61336, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.5472 - val_loss: 0.6134
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5265
# Epoch 25: val_loss improved from 0.61336 to 0.58742, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.5265 - val_loss: 0.5874
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5064
# Epoch 26: val_loss improved from 0.58742 to 0.57082, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 84ms/step - loss: 0.5064 - val_loss: 0.5708
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4872
# Epoch 27: val_loss improved from 0.57082 to 0.54756, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4872 - val_loss: 0.5476
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4686
# Epoch 28: val_loss improved from 0.54756 to 0.53186, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4686 - val_loss: 0.5319
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4509
# Epoch 29: val_loss improved from 0.53186 to 0.50979, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4509 - val_loss: 0.5098
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4339
# Epoch 30: val_loss improved from 0.50979 to 0.49624, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4339 - val_loss: 0.4962
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4178
# Epoch 31: val_loss improved from 0.49624 to 0.47416, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.4178 - val_loss: 0.4742
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4023
# Epoch 32: val_loss improved from 0.47416 to 0.46360, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.4023 - val_loss: 0.4636
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3877
# Epoch 33: val_loss improved from 0.46360 to 0.44089, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 0.3877 - val_loss: 0.4409
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3735
# Epoch 34: val_loss improved from 0.44089 to 0.43311, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.3735 - val_loss: 0.4331
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3602
# Epoch 35: val_loss improved from 0.43311 to 0.41022, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 80ms/step - loss: 0.3602 - val_loss: 0.4102
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3472
# Epoch 36: val_loss improved from 0.41022 to 0.40365, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.3472 - val_loss: 0.4036
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3350
# Epoch 37: val_loss improved from 0.40365 to 0.38204, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.3350 - val_loss: 0.3820
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3229
# Epoch 38: val_loss improved from 0.38204 to 0.37483, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.3229 - val_loss: 0.3748
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3117
# Epoch 39: val_loss improved from 0.37483 to 0.35597, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.3117 - val_loss: 0.3560
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3006
# Epoch 40: val_loss improved from 0.35597 to 0.34777, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 80ms/step - loss: 0.3006 - val_loss: 0.3478
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2904
# Epoch 41: val_loss improved from 0.34777 to 0.33200, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.2904 - val_loss: 0.3320
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2805
# Epoch 42: val_loss improved from 0.33200 to 0.32344, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.2805 - val_loss: 0.3234
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2713
# Epoch 43: val_loss improved from 0.32344 to 0.31003, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.2713 - val_loss: 0.3100
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2625
# Epoch 44: val_loss improved from 0.31003 to 0.30167, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 0.2625 - val_loss: 0.3017
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2543
# Epoch 45: val_loss improved from 0.30167 to 0.28975, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.2543 - val_loss: 0.2898
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2464
# Epoch 46: val_loss improved from 0.28975 to 0.28203, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 79ms/step - loss: 0.2464 - val_loss: 0.2820
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2389
# Epoch 47: val_loss improved from 0.28203 to 0.27080, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.2389 - val_loss: 0.2708
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2318
# Epoch 48: val_loss improved from 0.27080 to 0.26433, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 0.2318 - val_loss: 0.2643
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2250
# Epoch 49: val_loss improved from 0.26433 to 0.25283, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 0.2250 - val_loss: 0.2528
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2184
# Epoch 50: val_loss improved from 0.25283 to 0.24901, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.2184 - val_loss: 0.2490
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2125
# Epoch 51: val_loss improved from 0.24901 to 0.23612, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 87ms/step - loss: 0.2125 - val_loss: 0.2361
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2066
# Epoch 52: val_loss did not improve from 0.23612
# 1/1 [==============================] - 0s 53ms/step - loss: 0.2066 - val_loss: 0.2391
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2020
# Epoch 53: val_loss improved from 0.23612 to 0.22177, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.2020 - val_loss: 0.2218
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1973
# Epoch 54: val_loss did not improve from 0.22177
# 1/1 [==============================] - 0s 73ms/step - loss: 0.1973 - val_loss: 0.2349
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1946
# Epoch 55: val_loss improved from 0.22177 to 0.20881, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 107ms/step - loss: 0.1946 - val_loss: 0.2088
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1878
# Epoch 56: val_loss did not improve from 0.20881
# 1/1 [==============================] - 0s 89ms/step - loss: 0.1878 - val_loss: 0.2104
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1833
# Epoch 57: val_loss improved from 0.20881 to 0.19609, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 98ms/step - loss: 0.1833 - val_loss: 0.1961
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1775
# Epoch 58: val_loss improved from 0.19609 to 0.19475, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 103ms/step - loss: 0.1775 - val_loss: 0.1948
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1733
# Epoch 59: val_loss improved from 0.19475 to 0.18443, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 106ms/step - loss: 0.1733 - val_loss: 0.1844
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1689
# Epoch 60: val_loss did not improve from 0.18443
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1689 - val_loss: 0.1866
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1654
# Epoch 61: val_loss improved from 0.18443 to 0.17360, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 83ms/step - loss: 0.1654 - val_loss: 0.1736
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1619
# Epoch 62: val_loss did not improve from 0.17360
# 1/1 [==============================] - 0s 87ms/step - loss: 0.1619 - val_loss: 0.1905
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1595
# Epoch 63: val_loss improved from 0.17360 to 0.16455, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 119ms/step - loss: 0.1595 - val_loss: 0.1646
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1571
# Epoch 64: val_loss did not improve from 0.16455
# 1/1 [==============================] - 0s 89ms/step - loss: 0.1571 - val_loss: 0.2110
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1559
# Epoch 65: val_loss improved from 0.16455 to 0.15646, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 95ms/step - loss: 0.1559 - val_loss: 0.1565
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1526
# Epoch 66: val_loss did not improve from 0.15646
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1526 - val_loss: 0.1889
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1491
# Epoch 67: val_loss improved from 0.15646 to 0.14605, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 110ms/step - loss: 0.1491 - val_loss: 0.1460
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1438
# Epoch 68: val_loss did not improve from 0.14605
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1438 - val_loss: 0.1682
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1406
# Epoch 69: val_loss improved from 0.14605 to 0.13925, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 87ms/step - loss: 0.1406 - val_loss: 0.1393
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1373
# Epoch 70: val_loss did not improve from 0.13925
# 1/1 [==============================] - 0s 83ms/step - loss: 0.1373 - val_loss: 0.1940
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1351
# Epoch 71: val_loss improved from 0.13925 to 0.13133, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 118ms/step - loss: 0.1351 - val_loss: 0.1313
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1349
# Epoch 72: val_loss did not improve from 0.13133
# 1/1 [==============================] - 0s 87ms/step - loss: 0.1349 - val_loss: 0.2680
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1380
# Epoch 73: val_loss did not improve from 0.13133
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1380 - val_loss: 0.1467
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1554
# Epoch 74: val_loss did not improve from 0.13133
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1554 - val_loss: 0.1439
#
#  La media del mse, 0-fold es : 0.45996098663355856
#
#  La desviacion estandar del mse, 0-fold es : 0.33480375257353917
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 60)                15120
#
#  dense_1 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.7267
# Epoch 1: val_loss improved from inf to 1.15311, saving model to modelo-2.h5
# 2/2 [==============================] - 3s 587ms/step - loss: 1.7841 - val_loss: 1.1531
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4178
# Epoch 2: val_loss improved from 1.15311 to 1.02931, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.4665 - val_loss: 1.0293
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3564
# Epoch 3: val_loss improved from 1.02931 to 0.97688, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.3332 - val_loss: 0.9769
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3145
# Epoch 4: val_loss improved from 0.97688 to 0.92176, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 1.2861 - val_loss: 0.9218
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2527
# Epoch 5: val_loss improved from 0.92176 to 0.88973, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 1.2287 - val_loss: 0.8897
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1437
# Epoch 6: val_loss improved from 0.88973 to 0.82059, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 1.1965 - val_loss: 0.8206
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1003
# Epoch 7: val_loss improved from 0.82059 to 0.77394, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 1.1124 - val_loss: 0.7739
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0814
# Epoch 8: val_loss improved from 0.77394 to 0.74536, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0550 - val_loss: 0.7454
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0496
# Epoch 9: val_loss improved from 0.74536 to 0.71862, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 1.0239 - val_loss: 0.7186
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9900
# Epoch 10: val_loss improved from 0.71862 to 0.70128, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.9938 - val_loss: 0.7013
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9237
# Epoch 11: val_loss improved from 0.70128 to 0.65553, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.9771 - val_loss: 0.6555
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9278
# Epoch 12: val_loss improved from 0.65553 to 0.63959, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 0.9129 - val_loss: 0.6396
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9212
# Epoch 13: val_loss improved from 0.63959 to 0.61849, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.9010 - val_loss: 0.6185
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8439
# Epoch 14: val_loss improved from 0.61849 to 0.58985, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.8719 - val_loss: 0.5898
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8346
# Epoch 15: val_loss improved from 0.58985 to 0.57240, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.8251 - val_loss: 0.5724
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8354
# Epoch 16: val_loss improved from 0.57240 to 0.55490, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.8150 - val_loss: 0.5549
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7990
# Epoch 17: val_loss improved from 0.55490 to 0.54555, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.7931 - val_loss: 0.5455
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7838
# Epoch 18: val_loss improved from 0.54555 to 0.53305, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.7903 - val_loss: 0.5331
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7892
# Epoch 19: val_loss improved from 0.53305 to 0.52612, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.7782 - val_loss: 0.5261
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7892
# Epoch 20: val_loss improved from 0.52612 to 0.51750, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.7744 - val_loss: 0.5175
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7793
# Epoch 21: val_loss improved from 0.51750 to 0.50819, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.7666 - val_loss: 0.5082
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7687
# Epoch 22: val_loss improved from 0.50819 to 0.49936, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.7575 - val_loss: 0.4994
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7686
# Epoch 23: val_loss improved from 0.49936 to 0.47522, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.7480 - val_loss: 0.4752
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6557
# Epoch 24: val_loss improved from 0.47522 to 0.43120, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.7131 - val_loss: 0.4312
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6165
# Epoch 25: val_loss improved from 0.43120 to 0.42346, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.6382 - val_loss: 0.4235
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6242
# Epoch 26: val_loss improved from 0.42346 to 0.39429, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.6090 - val_loss: 0.3943
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5557
# Epoch 27: val_loss did not improve from 0.39429
# 2/2 [==============================] - 0s 42ms/step - loss: 0.5839 - val_loss: 0.4037
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5823
# Epoch 28: val_loss improved from 0.39429 to 0.36467, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5681 - val_loss: 0.3647
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5518
# Epoch 29: val_loss improved from 0.36467 to 0.34994, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.5381 - val_loss: 0.3499
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5119
# Epoch 30: val_loss did not improve from 0.34994
# 2/2 [==============================] - 0s 42ms/step - loss: 0.5259 - val_loss: 0.3658
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5249
# Epoch 31: val_loss improved from 0.34994 to 0.32839, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 0.5159 - val_loss: 0.3284
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4926
# Epoch 32: val_loss improved from 0.32839 to 0.31157, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.4949 - val_loss: 0.3116
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5066
# Epoch 33: val_loss improved from 0.31157 to 0.30045, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.4934 - val_loss: 0.3004
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4727
# Epoch 34: val_loss did not improve from 0.30045
# 2/2 [==============================] - 0s 43ms/step - loss: 0.4747 - val_loss: 0.3111
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4697
# Epoch 35: val_loss improved from 0.30045 to 0.28549, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.4583 - val_loss: 0.2855
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4388
# Epoch 36: val_loss improved from 0.28549 to 0.26735, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.4406 - val_loss: 0.2673
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4440
# Epoch 37: val_loss improved from 0.26735 to 0.25294, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.4382 - val_loss: 0.2529
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4278
# Epoch 38: val_loss improved from 0.25294 to 0.24131, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.4222 - val_loss: 0.2413
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4175
# Epoch 39: val_loss improved from 0.24131 to 0.23976, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.4104 - val_loss: 0.2398
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4176
# Epoch 40: val_loss improved from 0.23976 to 0.22796, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.4115 - val_loss: 0.2280
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4040
# Epoch 41: val_loss improved from 0.22796 to 0.21805, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.3973 - val_loss: 0.2180
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3493
# Epoch 42: val_loss did not improve from 0.21805
# 2/2 [==============================] - 0s 47ms/step - loss: 0.3822 - val_loss: 0.2184
# Epoch 43/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3499
# Epoch 43: val_loss improved from 0.21805 to 0.19482, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.3446 - val_loss: 0.1948
# Epoch 44/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3157
# Epoch 44: val_loss did not improve from 0.19482
# 2/2 [==============================] - 0s 44ms/step - loss: 0.3319 - val_loss: 0.2131
# Epoch 45/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3281
# Epoch 45: val_loss improved from 0.19482 to 0.18415, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 91ms/step - loss: 0.3247 - val_loss: 0.1841
# Epoch 46/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2920
# Epoch 46: val_loss did not improve from 0.18415
# 2/2 [==============================] - 0s 49ms/step - loss: 0.3037 - val_loss: 0.2144
# Epoch 47/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3111
# Epoch 47: val_loss improved from 0.18415 to 0.18233, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.3087 - val_loss: 0.1823
# Epoch 48/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2791
# Epoch 48: val_loss did not improve from 0.18233
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2847 - val_loss: 0.2048
# Epoch 49/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2886
# Epoch 49: val_loss did not improve from 0.18233
# 2/2 [==============================] - 0s 51ms/step - loss: 0.2892 - val_loss: 0.2238
# Epoch 50/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2997
# Epoch 50: val_loss did not improve from 0.18233
# 2/2 [==============================] - 0s 48ms/step - loss: 0.2948 - val_loss: 0.1986
#
#  La media del mse, 1-fold es : 0.7037861061096191
#
#  La desviacion estandar del mse, 1-fold es : 0.3434521417475916
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 60)                15120
#
#  dense_2 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.5840
# Epoch 1: val_loss improved from inf to 1.27648, saving model to modelo-3.h5
# 2/2 [==============================] - 3s 557ms/step - loss: 1.5535 - val_loss: 1.2765
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3987
# Epoch 2: val_loss improved from 1.27648 to 1.21173, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.3699 - val_loss: 1.2117
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3308
# Epoch 3: val_loss improved from 1.21173 to 1.14614, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.3032 - val_loss: 1.1461
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2537
# Epoch 4: val_loss improved from 1.14614 to 1.11491, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 1.2296 - val_loss: 1.1149
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2247
# Epoch 5: val_loss improved from 1.11491 to 1.08846, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 1.1998 - val_loss: 1.0885
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1525
# Epoch 6: val_loss improved from 1.08846 to 1.02481, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.1705 - val_loss: 1.0248
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1115
# Epoch 7: val_loss improved from 1.02481 to 0.98577, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 1.0925 - val_loss: 0.9858
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0709
# Epoch 8: val_loss improved from 0.98577 to 0.95041, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 1.0477 - val_loss: 0.9504
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0246
# Epoch 9: val_loss improved from 0.95041 to 0.93630, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 1.0073 - val_loss: 0.9363
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9534
# Epoch 10: val_loss improved from 0.93630 to 0.88056, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 0.9940 - val_loss: 0.8806
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9414
# Epoch 11: val_loss improved from 0.88056 to 0.86398, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 87ms/step - loss: 0.9231 - val_loss: 0.8640
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9290
# Epoch 12: val_loss improved from 0.86398 to 0.85034, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 85ms/step - loss: 0.9097 - val_loss: 0.8503
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8583
# Epoch 13: val_loss improved from 0.85034 to 0.80145, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 0.8950 - val_loss: 0.8014
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7972
# Epoch 14: val_loss improved from 0.80145 to 0.77081, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 85ms/step - loss: 0.8287 - val_loss: 0.7708
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7885
# Epoch 15: val_loss improved from 0.77081 to 0.73860, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.7820 - val_loss: 0.7386
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7614
# Epoch 16: val_loss improved from 0.73860 to 0.71480, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 0.7426 - val_loss: 0.7148
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7301
# Epoch 17: val_loss improved from 0.71480 to 0.70260, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.7204 - val_loss: 0.7026
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6812
# Epoch 18: val_loss improved from 0.70260 to 0.67514, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 81ms/step - loss: 0.7144 - val_loss: 0.6751
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6616
# Epoch 19: val_loss improved from 0.67514 to 0.66919, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.6636 - val_loss: 0.6692
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6342
# Epoch 20: val_loss improved from 0.66919 to 0.66174, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.6432 - val_loss: 0.6617
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6364
# Epoch 21: val_loss improved from 0.66174 to 0.61405, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.6210 - val_loss: 0.6140
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5981
# Epoch 22: val_loss improved from 0.61405 to 0.59780, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 84ms/step - loss: 0.5834 - val_loss: 0.5978
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5429
# Epoch 23: val_loss did not improve from 0.59780
# 2/2 [==============================] - 0s 79ms/step - loss: 0.5720 - val_loss: 0.6233
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5537
# Epoch 24: val_loss did not improve from 0.59780
# 2/2 [==============================] - 0s 72ms/step - loss: 0.5698 - val_loss: 0.6202
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5468
# Epoch 25: val_loss did not improve from 0.59780
# 2/2 [==============================] - 0s 58ms/step - loss: 0.5559 - val_loss: 0.6177
#
#  La media del mse, 2-fold es : 0.9077156114578248
#
#  La desviacion estandar del mse, 2-fold es : 0.27610876652041644
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 60)                15120
#
#  dense_3 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.5564
# Epoch 1: val_loss improved from inf to 1.38071, saving model to modelo-4.h5
# 2/2 [==============================] - 3s 570ms/step - loss: 1.5247 - val_loss: 1.3807
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3963
# Epoch 2: val_loss improved from 1.38071 to 1.25607, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 1.3745 - val_loss: 1.2561
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2410
# Epoch 3: val_loss improved from 1.25607 to 1.13882, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 1.2606 - val_loss: 1.1388
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1251
# Epoch 4: val_loss improved from 1.13882 to 1.05073, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.1574 - val_loss: 1.0507
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1019
# Epoch 5: val_loss improved from 1.05073 to 1.00440, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0819 - val_loss: 1.0044
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9615
# Epoch 6: val_loss improved from 1.00440 to 0.92557, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 1.0386 - val_loss: 0.9256
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9864
# Epoch 7: val_loss improved from 0.92557 to 0.91031, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.9738 - val_loss: 0.9103
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9756
# Epoch 8: val_loss improved from 0.91031 to 0.87901, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.9524 - val_loss: 0.8790
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8997
# Epoch 9: val_loss improved from 0.87901 to 0.81940, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.9228 - val_loss: 0.8194
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8962
# Epoch 10: val_loss improved from 0.81940 to 0.79567, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.8738 - val_loss: 0.7957
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8426
# Epoch 11: val_loss improved from 0.79567 to 0.78643, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.8512 - val_loss: 0.7864
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8436
# Epoch 12: val_loss improved from 0.78643 to 0.78573, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.8355 - val_loss: 0.7857
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8518
# Epoch 13: val_loss improved from 0.78573 to 0.76105, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.8295 - val_loss: 0.7611
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7590
# Epoch 14: val_loss improved from 0.76105 to 0.69168, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.8052 - val_loss: 0.6917
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7399
# Epoch 15: val_loss improved from 0.69168 to 0.68360, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.7496 - val_loss: 0.6836
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7541
# Epoch 16: val_loss improved from 0.68360 to 0.66533, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.7352 - val_loss: 0.6653
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6819
# Epoch 17: val_loss improved from 0.66533 to 0.61699, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.7172 - val_loss: 0.6170
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6503
# Epoch 18: val_loss improved from 0.61699 to 0.59055, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.6789 - val_loss: 0.5906
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6746
# Epoch 19: val_loss improved from 0.59055 to 0.56653, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.6585 - val_loss: 0.5665
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6318
# Epoch 20: val_loss improved from 0.56653 to 0.56405, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.6330 - val_loss: 0.5640
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6305
# Epoch 21: val_loss improved from 0.56405 to 0.56338, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.6240 - val_loss: 0.5634
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6094
# Epoch 22: val_loss improved from 0.56338 to 0.52798, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6172 - val_loss: 0.5280
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6015
# Epoch 23: val_loss improved from 0.52798 to 0.52037, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.5879 - val_loss: 0.5204
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5542
# Epoch 24: val_loss improved from 0.52037 to 0.49711, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.5787 - val_loss: 0.4971
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5744
# Epoch 25: val_loss improved from 0.49711 to 0.48260, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 0.5603 - val_loss: 0.4826
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5582
# Epoch 26: val_loss improved from 0.48260 to 0.47971, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.5454 - val_loss: 0.4797
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5450
# Epoch 27: val_loss did not improve from 0.47971
# 2/2 [==============================] - 0s 54ms/step - loss: 0.5414 - val_loss: 0.4824
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5534
# Epoch 28: val_loss improved from 0.47971 to 0.47061, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.5388 - val_loss: 0.4706
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5149
# Epoch 29: val_loss improved from 0.47061 to 0.46399, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5270 - val_loss: 0.4640
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5278
# Epoch 30: val_loss improved from 0.46399 to 0.45400, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.5141 - val_loss: 0.4540
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5077
# Epoch 31: val_loss did not improve from 0.45400
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5049 - val_loss: 0.4590
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5077
# Epoch 32: val_loss did not improve from 0.45400
# 2/2 [==============================] - 0s 58ms/step - loss: 0.5062 - val_loss: 0.4639
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4970
# Epoch 33: val_loss improved from 0.45400 to 0.41396, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5036 - val_loss: 0.4140
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4233
# Epoch 34: val_loss improved from 0.41396 to 0.41011, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.4576 - val_loss: 0.4101
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4517
# Epoch 35: val_loss improved from 0.41011 to 0.38193, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.4506 - val_loss: 0.3819
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4151
# Epoch 36: val_loss did not improve from 0.38193
# 2/2 [==============================] - 0s 51ms/step - loss: 0.4178 - val_loss: 0.3824
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4020
# Epoch 37: val_loss did not improve from 0.38193
# 2/2 [==============================] - 0s 46ms/step - loss: 0.4159 - val_loss: 0.3984
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4111
# Epoch 38: val_loss did not improve from 0.38193
# 2/2 [==============================] - 0s 49ms/step - loss: 0.4291 - val_loss: 0.4147
#
#  La media del mse, 3-fold es : 0.7361709224550348
#
#  La desviacion estandar del mse, 3-fold es : 0.273162970492867
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 60)                15120
#
#  dense_4 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.3338
# Epoch 1: val_loss improved from inf to 1.45384, saving model to modelo-5.h5
# 2/2 [==============================] - 3s 861ms/step - loss: 1.3128 - val_loss: 1.4538
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1727
# Epoch 2: val_loss improved from 1.45384 to 1.33658, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 1.1675 - val_loss: 1.3366
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0517
# Epoch 3: val_loss improved from 1.33658 to 1.24441, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 94ms/step - loss: 1.0678 - val_loss: 1.2444
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0110
# Epoch 4: val_loss improved from 1.24441 to 1.21910, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 82ms/step - loss: 0.9947 - val_loss: 1.2191
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9830
# Epoch 5: val_loss improved from 1.21910 to 1.19775, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.9656 - val_loss: 1.1978
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8834
# Epoch 6: val_loss improved from 1.19775 to 1.11087, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 0.9410 - val_loss: 1.1109
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8881
# Epoch 7: val_loss improved from 1.11087 to 1.09951, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.8769 - val_loss: 1.0995
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8413
# Epoch 8: val_loss improved from 1.09951 to 1.03369, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8613 - val_loss: 1.0337
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8336
# Epoch 9: val_loss improved from 1.03369 to 1.00715, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 81ms/step - loss: 0.8129 - val_loss: 1.0072
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8008
# Epoch 10: val_loss improved from 1.00715 to 1.00003, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 89ms/step - loss: 0.7899 - val_loss: 1.0000
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7899
# Epoch 11: val_loss improved from 1.00003 to 0.99021, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 0.7800 - val_loss: 0.9902
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7776
# Epoch 12: val_loss improved from 0.99021 to 0.98279, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.7688 - val_loss: 0.9828
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7800
# Epoch 13: val_loss improved from 0.98279 to 0.95196, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 80ms/step - loss: 0.7596 - val_loss: 0.9520
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7240
# Epoch 14: val_loss improved from 0.95196 to 0.88396, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 94ms/step - loss: 0.7333 - val_loss: 0.8840
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6958
# Epoch 15: val_loss improved from 0.88396 to 0.83661, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 0.6862 - val_loss: 0.8366
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6415
# Epoch 16: val_loss improved from 0.83661 to 0.78341, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 112ms/step - loss: 0.6527 - val_loss: 0.7834
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6334
# Epoch 17: val_loss improved from 0.78341 to 0.74609, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.6219 - val_loss: 0.7461
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5993
# Epoch 18: val_loss improved from 0.74609 to 0.74248, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.5958 - val_loss: 0.7425
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5711
# Epoch 19: val_loss improved from 0.74248 to 0.69030, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 0.5833 - val_loss: 0.6903
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5678
# Epoch 20: val_loss improved from 0.69030 to 0.66166, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5580 - val_loss: 0.6617
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5360
# Epoch 21: val_loss improved from 0.66166 to 0.65997, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.5401 - val_loss: 0.6600
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5254
# Epoch 22: val_loss improved from 0.65997 to 0.62815, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 81ms/step - loss: 0.5264 - val_loss: 0.6281
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4797
# Epoch 23: val_loss improved from 0.62815 to 0.59824, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 87ms/step - loss: 0.5164 - val_loss: 0.5982
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4969
# Epoch 24: val_loss improved from 0.59824 to 0.57173, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 93ms/step - loss: 0.5151 - val_loss: 0.5717
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4925
# Epoch 25: val_loss improved from 0.57173 to 0.56627, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 81ms/step - loss: 0.4810 - val_loss: 0.5663
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4627
# Epoch 26: val_loss did not improve from 0.56627
# 2/2 [==============================] - 0s 67ms/step - loss: 0.4677 - val_loss: 0.5707
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4630
# Epoch 27: val_loss did not improve from 0.56627
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4625 - val_loss: 0.5699
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4676
# Epoch 28: val_loss did not improve from 0.56627
# 2/2 [==============================] - 0s 81ms/step - loss: 0.4577 - val_loss: 0.5786
#
#  La media del mse, 4-fold es : 0.7320363585438047
#
#  La desviacion estandar del mse, 4-fold es : 0.2239176010119407

# %%
# rellenar de ceros los espacios vacios de la lista con loss y validation

df_train_losses = pd.DataFrame(train_losses)

df_filled_train_losses = df_train_losses.fillna(0)

train_losses_completa = df_filled_train_losses.values.tolist()

df_val_losses = pd.DataFrame(val_losses)

df_filled_val_losses = df_val_losses.fillna(0)

val_losses_completa = df_filled_val_losses.values.tolist()

# %%
# Calcular el promedio de "average loss" para todos los pliegues y épocas
avg_train_losses = np.mean(train_losses_completa, axis=0)
avg_val_losses = np.mean(val_losses_completa, axis=0)

# vamos a graficar
plt.plot(avg_train_losses, label='Perdida entrenamiento') # Grafico esta para ver si estoy sobre entrenando
plt.plot(avg_val_losses, label='Perdida Validacion') # Grafico esta para ver si estoy sobre entrenando
plt.title('avg loss train, avg loss val vs epoch ')
plt.xlabel('epoch')
plt.ylabel('Mean Square Error')
plt.legend()
plt.show()

# %%
# Cargar el mejor modelo
best_model = load_model(best_model_path)

# %%
# Seleccionar una secuencia específica
index = 0
input_sequence = X_test[index]

# Hacer la predicción
y_pred = best_model.predict(np.expand_dims(input_sequence, axis=0))
# usamos el np.expand_dims() para agregar una dimensión adicional al inicio de input_sequence
print(y_pred.shape)
# Out:
# 1/1 [==============================] - 1s 534ms/step
# (1, 210)

# %%
# Desenrollar X_test para convertirlo en un array bidimensional
X_test_flattened = X_test.reshape(-1, X_test.shape[-1])

# Aplicar la transformación inversa utilizando el objeto StandardScaler
X_test_desnormalizado = sc.inverse_transform(X_test_flattened)

# Volver a darle forma a X_test_desnormalizado a su forma original
X_test = X_test_desnormalizado.reshape(X_test.shape)

# Desnormalizar los datos
y_pred = sc_y.inverse_transform(y_pred)

y_test = sc_y.inverse_transform(y_test)

print(y_pred.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (1, 210)
# (17, 210)
# (17, 15, 2)

# %%
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
Curva=0

plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

print('')
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(X_test[Curva,:,0],color='orange', label='Valores actuales y anteriores de insulina')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_test[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 610.31265

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_pred[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 622.4937963867187

# %%
# Media MSE y desviacion estandar MSE de las prediciones con la escala normal
mse = mean_squared_error(y_test[0,:].flatten(), y_pred.flatten())
std = np.sqrt(mse)
mediamse = np.mean(mse)

print('La media MSE:',mediamse)
print('La desviacion standar MSE', std)

# calcular la MAE
mae = mean_absolute_error(y_test[0,:], y_pred[0,:])
print('MAE:', mae)

# calcular la RMSE
rmse = np.sqrt(mean_squared_error(y_test[0,:], y_pred[0,:]))
print('RMSE:', rmse)
# Out:
# La media MSE: 186.4414478423557
# La desviacion standar MSE 13.654356368659627
# MAE: 9.440437587193081
# RMSE: 13.654356368659627
