# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Librerias
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split, KFold
from keras.callbacks import EarlyStopping

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import load_model

from keras.initializers import he_uniform

from tensorflow.keras.optimizers import RMSprop

# %%
#Dataset Adulto 01
data = pd.read_csv('/content/gdrive/MyDrive/Proyecto_de_grado/SUSTENTACION3.0/FinalX3/adulto08/my_adult08A2_data.csv')

print(f"El archivo se ha cargado correctamente. Tiene {data.shape[0]} filas y {data.shape[1]} columnas.")
# Out:
# El archivo se ha cargado correctamente. Tiene 29766 filas y 3 columnas.

# %%
train_size = int(len(data) * 0.7)

train_data = data.iloc[:train_size, :] # 70% entrenamiento
test_data = data.iloc[train_size:, :] # 30% prueba

test_data = test_data.reset_index(drop=True)

# %%
#los indices donde hay ingestas
posicionestrain = train_data.loc[train_data.iloc[:, 0] != 0].index
posicionestest = test_data.loc[test_data.iloc[:, 0] != 0].index

df_posiciones_train = pd.DataFrame(posicionestrain)
df_posiciones_test = pd.DataFrame(posicionestest)

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_train = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_train)):
    anterior = df_posiciones_train.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_train.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_train.append(anterior)

ultimo_elemento_train = df_posiciones_train.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_train.extend(ultimo_elemento_train.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_train)
print(len(cumplen_train))
# Out:
# [448, 818, 1319, 1934, 2306, 2803, 3415, 3788, 4285, 4901, 5278, 5778, 6392, 6767, 7263, 7877, 8252, 8750, 9366, 9746, 10245, 10862, 11242, 11738, 12360, 12735, 13235, 13854, 14230, 14725, 15337, 15711, 16212, 16840, 17214, 17710, 18325, 18701, 19194, 19809, 20186, 20676]
# 42

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_test = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_test)):
    anterior = df_posiciones_test.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_test.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_test.append(anterior)

ultimo_elemento_test = df_posiciones_test.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_test.extend(ultimo_elemento_test.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_test)
print(len(cumplen_test))
# Out:
# [455, 829, 1324, 1935, 2309, 2806, 3420, 3798, 4295, 4910, 5288, 5784, 6399, 6780, 7273, 7889, 8264, 8758]
# 18

# %%
# pasar la escala de los carbohidratos de las ingestas a gramos
data.iloc[:,0] = data.iloc[:,0].apply(lambda x: (x*15)/1000)

# Grafica con mayor detalle, el pico del comportamiento de la glucosa despues de la primera ingesta
print('')
print('Grafica de los datos del dataset')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
plt.title('Ingestas, Insulina y Glucosa')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')

print('Caso 1: Primera ingesta o Desayuno del primer dia:')
plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 700])
plt.ylim([-5, 250])
plt.show()
print('')

print('Caso 2: Primera y segunda ingesta del primer dia:')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1200])
plt.ylim([-5, 500])
plt.show()


print('Caso 3: las tres ingestas del primer dia:')

plt.plot(data.index, data.iloc[:,0], color='blue', label='Ingestas')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Ingestas de carbohidratos')
plt.xlabel('t [min]')
plt.ylabel('gramos')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Dosificación de insulina')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
#plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1800])
plt.ylim([-5, 500])
plt.show()
# Out:
# Grafica de los datos del dataset
# Caso 1: Primera ingesta o Desayuno del primer dia:
# Caso 2: Primera y segunda ingesta del primer dia:
# Caso 3: las tres ingestas del primer dia:

# %%
#Preprocesar los datos:
X_train = train_data.iloc[:, 1:3].values
y_train = train_data.iloc[:,2].values

X_test = test_data.iloc[:, 1:3].values
y_test = test_data.iloc[:, 2].values

print('Tamaño de los datos de entrada, de X_train: ',X_train.shape)
print(f'Tiene {X_train.shape[0]} filas y {X_train.shape[1]} columna')
print('La primera ingesta al minuto 300, ingesta: ',X_train[300])
print('La primera ingesta hasta el minuto 327, ingesta: ',X_train[327])

print('La entrada son los valores de la insulina y glucosa \n',X_train)
print('Tamaño de los datos de salia, de y_train',y_train.shape)
print(f'Tiene {y_train.shape[0]} filas y {y_train.shape[-1]} columnas')
print('La salida son los valores de glucosa \n',y_train)
# Out:
# Tamaño de los datos de entrada, de X_train:  (20836, 2)
# Tiene 20836 filas y 2 columna
# La primera ingesta al minuto 300, ingesta:  [  1.6789 101.11  ]
# La primera ingesta hasta el minuto 327, ingesta:  [ 1.6789 98.295 ]
# La entrada son los valores de la insulina y glucosa
#  [[  1.6789 130.02  ]
#  [  1.6789 130.02  ]
#  [  1.6789 130.02  ]
#  ...
#  [  1.6789 225.48  ]
#  [  1.6789 224.66  ]
#  [  1.6789 223.83  ]]
# Tamaño de los datos de salia, de y_train (20836,)
# Tiene 20836 filas y 20836 columnas
# La salida son los valores de glucosa
#  [130.02 130.02 130.02 ... 225.48 224.66 223.83]

# %%
# Normalizar los datos
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Normalizar y_train
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.reshape(-1, 1))
y_test = sc_y.transform(y_test.reshape(-1, 1))

# %%
# Reorganizar los datos en forma de secuencia
def to_sequences(data,  seq_size_input, seq_size_output):
    X = []
    y = []

    for i in range(len(data)-seq_size_input-seq_size_output+1):
        X.append(data[i:(i+seq_size_input), 0:2])
        y.append(data[(i+seq_size_input):(i+seq_size_input+seq_size_output), 2])

    return np.array(X), np.array(y)

# %%
#CON LOS DATOS NORMALIZADOS
seq_size_input = 15
seq_size_output = 210
X_train, y_train = to_sequences(np.hstack((X_train, y_train)), seq_size_input, seq_size_output)
X_test, y_test = to_sequences(np.hstack((X_test, y_test)), seq_size_input, seq_size_output)
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (20612, 210)
# (20612, 15, 2)
# (8706, 210)
# (8706, 15, 2)

# %%
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
flattened_data = np.reshape(X_train, (X_train.shape[0], -1))

df_X_train = pd.DataFrame(flattened_data)

# %%
flattened_test = np.reshape(X_test, (X_test.shape[0], -1))

df_X_test = pd.DataFrame(flattened_test)

# %%
df_y_train = pd.DataFrame(y_train)
df_y_test = pd.DataFrame(y_test)

# %%
# Filtrar el dataframe para mantener solo las filas especificadas
df_X_train_seleccionado = df_X_train[df_X_train.index.isin(cumplen_train)]
df_y_train_seleccionado = df_y_train[df_y_train.index.isin(cumplen_train)]
df_X_test_seleccionado = df_X_test[df_X_test.index.isin(cumplen_test)]
df_y_test_seleccionado = df_y_test[df_y_test.index.isin(cumplen_test)]

# %%
print('Grafica de los datos del dataset')
#plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')

Numerocurva = 0

plt.plot(df_X_train_seleccionado.iloc[Numerocurva, 1::2],color='green',label='Entrada glucosa') #Para mostrar solo la glucosa
plt.plot(df_X_train_seleccionado.iloc[Numerocurva, ::2],color='orange',label='Entrada insulina') #Para mostrar solo la glucosa
plt.plot(range(seq_size_input*2, seq_size_output + seq_size_input*2),df_y_train_seleccionado.iloc[Numerocurva,:], color='red',label='Salida glucosa')
plt.title('Entradas y salidas, entrenamiento')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')
# Out:
# Grafica de los datos del dataset

# %%
X_train = df_X_train_seleccionado.values
y_train = df_y_train_seleccionado.values
X_test = df_X_test_seleccionado.values
y_test = df_y_test_seleccionado.values

print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 30)
# (17, 210)
# (17, 30)

# %%
print(len(X_test))
# Out:
# 17

# %%
X_train = np.reshape(X_train, (len(X_train), seq_size_input, 2))

X_test = np.reshape(X_test, (len(X_test), seq_size_input, 2))
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 15, 2)
# (17, 210)
# (17, 15, 2)

# %%
kf = KFold(n_splits=5)
kf.get_n_splits(X_train)
KFold(n_splits=5, random_state=None, shuffle=False)


# Crear listas para almacenar los valores del "average loss" de entrenamiento y validación en cada pliegue
train_losses = []
val_losses = []

#Para guardar el mejor modelo
best_loss = float('inf')
best_model_path = ""

for i, (train_index, test_index) in enumerate(kf.split(X_train,y_train)):
  model = Sequential()
  model.add(LSTM(60, activation='tanh', input_shape=(seq_size_input, 2), kernel_initializer=he_uniform()))
  model.add(Dense(seq_size_output, activation='linear', kernel_initializer=he_uniform()))


  model.compile(optimizer=RMSprop(), loss='mse')
  print(model.summary())

  filepath = f"modelo-{i+1}.h5"
  early_stop = EarlyStopping(monitor='val_loss', patience=3)
  checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

  X, y =  X_train[train_index], y_train[train_index]
  X_val, y_val = X_train[test_index], y_train[test_index]


  history = model.fit(X, y, epochs=100, batch_size=32,validation_data=(X_val, y_val),callbacks=[checkpoint, early_stop] )

  mediamse = np.mean( history.history['loss'] )
  stdmse = np.std(  history.history['loss'])
  print('')
  print(f" La media del mse, {i}-fold es : {mediamse}")
  print('')
  print(f" La desviacion estandar del mse, {i}-fold es : {stdmse}")

  # Obtener los valores de "average loss" para el pliegue actual
  fold_train_losses = model.history.history['loss']
  fold_val_losses = model.history.history['val_loss']

  # Almacenar los valores de "average loss" para el pliegue actual
  train_losses.append(fold_train_losses)
  val_losses.append(fold_val_losses)

  if min(fold_val_losses) < best_loss:
        best_loss = min(fold_val_losses)
        best_model_path = filepath

  history.history.keys() # aqui me muestra que esta guardando, con history me guarda todos los valores que calcula durante el proceso de entrenamiento

  # vamos a graficar
  plt.plot(history.history['loss'], label='Perdida') # Grafico esta para ver si estoy sobre entrenando
  plt.plot(history.history['val_loss'], label='Validacion') # Grafico esta para ver si estoy sobre entrenando
  plt.xlabel('epoch')
  plt.ylabel('Mean Square Error')
  plt.legend()
  plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 60)                15120
#
#  dense_5 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8013
# Epoch 1: val_loss improved from inf to 1.73482, saving model to modelo-1.h5
# 1/1 [==============================] - 2s 2s/step - loss: 1.8013 - val_loss: 1.7348
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6557
# Epoch 2: val_loss improved from 1.73482 to 1.64147, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 78ms/step - loss: 1.6557 - val_loss: 1.6415
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5648
# Epoch 3: val_loss improved from 1.64147 to 1.56630, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 1.5648 - val_loss: 1.5663
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4917
# Epoch 4: val_loss improved from 1.56630 to 1.50009, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 77ms/step - loss: 1.4917 - val_loss: 1.5001
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4274
# Epoch 5: val_loss improved from 1.50009 to 1.43910, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 1.4274 - val_loss: 1.4391
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3684
# Epoch 6: val_loss improved from 1.43910 to 1.38157, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 79ms/step - loss: 1.3684 - val_loss: 1.3816
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3127
# Epoch 7: val_loss improved from 1.38157 to 1.32663, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 1.3127 - val_loss: 1.3266
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2597
# Epoch 8: val_loss improved from 1.32663 to 1.27393, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 1.2597 - val_loss: 1.2739
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2089
# Epoch 9: val_loss improved from 1.27393 to 1.22349, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 78ms/step - loss: 1.2089 - val_loss: 1.2235
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1604
# Epoch 10: val_loss improved from 1.22349 to 1.17545, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 1.1604 - val_loss: 1.1755
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1142
# Epoch 11: val_loss improved from 1.17545 to 1.12998, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 1.1142 - val_loss: 1.1300
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0706
# Epoch 12: val_loss improved from 1.12998 to 1.08716, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 1.0706 - val_loss: 1.0872
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0295
# Epoch 13: val_loss improved from 1.08716 to 1.04695, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 1.0295 - val_loss: 1.0469
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9909
# Epoch 14: val_loss improved from 1.04695 to 1.00922, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 79ms/step - loss: 0.9909 - val_loss: 1.0092
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9548
# Epoch 15: val_loss improved from 1.00922 to 0.97379, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 99ms/step - loss: 0.9548 - val_loss: 0.9738
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9208
# Epoch 16: val_loss improved from 0.97379 to 0.94045, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 97ms/step - loss: 0.9208 - val_loss: 0.9405
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8888
# Epoch 17: val_loss improved from 0.94045 to 0.90901, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 101ms/step - loss: 0.8888 - val_loss: 0.9090
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8587
# Epoch 18: val_loss improved from 0.90901 to 0.87929, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 91ms/step - loss: 0.8587 - val_loss: 0.8793
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8301
# Epoch 19: val_loss improved from 0.87929 to 0.85112, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.8301 - val_loss: 0.8511
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8031
# Epoch 20: val_loss improved from 0.85112 to 0.82437, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 78ms/step - loss: 0.8031 - val_loss: 0.8244
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7774
# Epoch 21: val_loss improved from 0.82437 to 0.79890, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 323ms/step - loss: 0.7774 - val_loss: 0.7989
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7529
# Epoch 22: val_loss improved from 0.79890 to 0.77461, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 175ms/step - loss: 0.7529 - val_loss: 0.7746
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7294
# Epoch 23: val_loss improved from 0.77461 to 0.75137, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 165ms/step - loss: 0.7294 - val_loss: 0.7514
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7070
# Epoch 24: val_loss improved from 0.75137 to 0.72908, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 98ms/step - loss: 0.7070 - val_loss: 0.7291
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6855
# Epoch 25: val_loss improved from 0.72908 to 0.70763, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.6855 - val_loss: 0.7076
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6648
# Epoch 26: val_loss improved from 0.70763 to 0.68689, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 77ms/step - loss: 0.6648 - val_loss: 0.6869
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6447
# Epoch 27: val_loss improved from 0.68689 to 0.66673, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 101ms/step - loss: 0.6447 - val_loss: 0.6667
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6252
# Epoch 28: val_loss improved from 0.66673 to 0.64705, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 0.6252 - val_loss: 0.6471
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6061
# Epoch 29: val_loss improved from 0.64705 to 0.62775, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 209ms/step - loss: 0.6061 - val_loss: 0.6277
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5874
# Epoch 30: val_loss improved from 0.62775 to 0.60874, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 261ms/step - loss: 0.5874 - val_loss: 0.6087
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5689
# Epoch 31: val_loss improved from 0.60874 to 0.59000, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 177ms/step - loss: 0.5689 - val_loss: 0.5900
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5507
# Epoch 32: val_loss improved from 0.59000 to 0.57152, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.5507 - val_loss: 0.5715
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5327
# Epoch 33: val_loss improved from 0.57152 to 0.55337, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.5327 - val_loss: 0.5534
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5151
# Epoch 34: val_loss improved from 0.55337 to 0.53562, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.5151 - val_loss: 0.5356
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4979
# Epoch 35: val_loss improved from 0.53562 to 0.51835, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 79ms/step - loss: 0.4979 - val_loss: 0.5184
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4812
# Epoch 36: val_loss improved from 0.51835 to 0.50164, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 0.4812 - val_loss: 0.5016
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4649
# Epoch 37: val_loss improved from 0.50164 to 0.48553, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4649 - val_loss: 0.4855
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4493
# Epoch 38: val_loss improved from 0.48553 to 0.47006, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 119ms/step - loss: 0.4493 - val_loss: 0.4701
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4343
# Epoch 39: val_loss improved from 0.47006 to 0.45529, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.4343 - val_loss: 0.4553
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4199
# Epoch 40: val_loss improved from 0.45529 to 0.44115, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4199 - val_loss: 0.4411
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4062
# Epoch 41: val_loss improved from 0.44115 to 0.42883, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4062 - val_loss: 0.4288
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3938
# Epoch 42: val_loss improved from 0.42883 to 0.42140, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.3938 - val_loss: 0.4214
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3878
# Epoch 43: val_loss improved from 0.42140 to 0.41945, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.3878 - val_loss: 0.4195
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3838
# Epoch 44: val_loss improved from 0.41945 to 0.40876, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 80ms/step - loss: 0.3838 - val_loss: 0.4088
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3759
# Epoch 45: val_loss improved from 0.40876 to 0.38736, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.3759 - val_loss: 0.3874
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3530
# Epoch 46: val_loss improved from 0.38736 to 0.37648, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 0.3530 - val_loss: 0.3765
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3431
# Epoch 47: val_loss improved from 0.37648 to 0.36819, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 95ms/step - loss: 0.3431 - val_loss: 0.3682
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3343
# Epoch 48: val_loss improved from 0.36819 to 0.35968, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.3343 - val_loss: 0.3597
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3260
# Epoch 49: val_loss improved from 0.35968 to 0.35235, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 92ms/step - loss: 0.3260 - val_loss: 0.3523
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3182
# Epoch 50: val_loss improved from 0.35235 to 0.34488, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 117ms/step - loss: 0.3182 - val_loss: 0.3449
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3109
# Epoch 51: val_loss improved from 0.34488 to 0.33864, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 102ms/step - loss: 0.3109 - val_loss: 0.3386
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3040
# Epoch 52: val_loss improved from 0.33864 to 0.33191, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 99ms/step - loss: 0.3040 - val_loss: 0.3319
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2977
# Epoch 53: val_loss improved from 0.33191 to 0.32815, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 117ms/step - loss: 0.2977 - val_loss: 0.3282
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2927
# Epoch 54: val_loss improved from 0.32815 to 0.32564, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 111ms/step - loss: 0.2927 - val_loss: 0.3256
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2935
# Epoch 55: val_loss did not improve from 0.32564
# 1/1 [==============================] - 0s 62ms/step - loss: 0.2935 - val_loss: 0.3284
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2933
# Epoch 56: val_loss did not improve from 0.32564
# 1/1 [==============================] - 0s 80ms/step - loss: 0.2933 - val_loss: 0.3325
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3029
# Epoch 57: val_loss improved from 0.32564 to 0.30864, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 110ms/step - loss: 0.3029 - val_loss: 0.3086
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2741
# Epoch 58: val_loss improved from 0.30864 to 0.30389, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 81ms/step - loss: 0.2741 - val_loss: 0.3039
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2692
# Epoch 59: val_loss improved from 0.30389 to 0.30039, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 100ms/step - loss: 0.2692 - val_loss: 0.3004
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2649
# Epoch 60: val_loss improved from 0.30039 to 0.29647, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 108ms/step - loss: 0.2649 - val_loss: 0.2965
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2608
# Epoch 61: val_loss improved from 0.29647 to 0.29364, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 121ms/step - loss: 0.2608 - val_loss: 0.2936
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2572
# Epoch 62: val_loss improved from 0.29364 to 0.29094, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 111ms/step - loss: 0.2572 - val_loss: 0.2909
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2551
# Epoch 63: val_loss did not improve from 0.29094
# 1/1 [==============================] - 0s 99ms/step - loss: 0.2551 - val_loss: 0.2935
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2576
# Epoch 64: val_loss did not improve from 0.29094
# 1/1 [==============================] - 0s 81ms/step - loss: 0.2576 - val_loss: 0.3053
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2754
# Epoch 65: val_loss improved from 0.29094 to 0.28358, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 114ms/step - loss: 0.2754 - val_loss: 0.2836
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2473
# Epoch 66: val_loss improved from 0.28358 to 0.28055, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 122ms/step - loss: 0.2473 - val_loss: 0.2805
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2449
# Epoch 67: val_loss improved from 0.28055 to 0.27968, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 121ms/step - loss: 0.2449 - val_loss: 0.2797
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2430
# Epoch 68: val_loss did not improve from 0.27968
# 1/1 [==============================] - 0s 88ms/step - loss: 0.2430 - val_loss: 0.2813
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2470
# Epoch 69: val_loss improved from 0.27968 to 0.27928, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 152ms/step - loss: 0.2470 - val_loss: 0.2793
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2432
# Epoch 70: val_loss did not improve from 0.27928
# 1/1 [==============================] - 0s 101ms/step - loss: 0.2432 - val_loss: 0.2848
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2530
# Epoch 71: val_loss improved from 0.27928 to 0.27096, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 156ms/step - loss: 0.2530 - val_loss: 0.2710
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2342
# Epoch 72: val_loss improved from 0.27096 to 0.26908, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 120ms/step - loss: 0.2342 - val_loss: 0.2691
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2327
# Epoch 73: val_loss improved from 0.26908 to 0.26832, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 118ms/step - loss: 0.2327 - val_loss: 0.2683
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2314
# Epoch 74: val_loss did not improve from 0.26832
# 1/1 [==============================] - 0s 99ms/step - loss: 0.2314 - val_loss: 0.2714
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2362
# Epoch 75: val_loss did not improve from 0.26832
# 1/1 [==============================] - 0s 78ms/step - loss: 0.2362 - val_loss: 0.2687
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2323
# Epoch 76: val_loss did not improve from 0.26832
# 1/1 [==============================] - 0s 97ms/step - loss: 0.2323 - val_loss: 0.2753
#
#  La media del mse, 0-fold es : 0.6037406650813002
#
#  La desviacion estandar del mse, 0-fold es : 0.401501978729621
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 60)                15120
#
#  dense_6 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.8761
# Epoch 1: val_loss improved from inf to 1.31351, saving model to modelo-2.h5
# 2/2 [==============================] - 3s 706ms/step - loss: 1.9410 - val_loss: 1.3135
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6712
# Epoch 2: val_loss improved from 1.31351 to 1.23378, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 1.6317 - val_loss: 1.2338
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5793
# Epoch 3: val_loss improved from 1.23378 to 1.15249, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 74ms/step - loss: 1.5519 - val_loss: 1.1525
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4893
# Epoch 4: val_loss improved from 1.15249 to 1.07991, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 1.4633 - val_loss: 1.0799
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4075
# Epoch 5: val_loss improved from 1.07991 to 1.01118, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 92ms/step - loss: 1.3829 - val_loss: 1.0112
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3299
# Epoch 6: val_loss improved from 1.01118 to 0.94558, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 1.3058 - val_loss: 0.9456
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2557
# Epoch 7: val_loss improved from 0.94558 to 0.88352, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 1.2312 - val_loss: 0.8835
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1117
# Epoch 8: val_loss improved from 0.88352 to 0.79732, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 1.1579 - val_loss: 0.7973
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0748
# Epoch 9: val_loss improved from 0.79732 to 0.75238, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 1.0523 - val_loss: 0.7524
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9496
# Epoch 10: val_loss improved from 0.75238 to 0.69135, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 1.0005 - val_loss: 0.6914
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8753
# Epoch 11: val_loss improved from 0.69135 to 0.65440, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 0.9188 - val_loss: 0.6544
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8836
# Epoch 12: val_loss improved from 0.65440 to 0.61549, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8638 - val_loss: 0.6155
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7893
# Epoch 13: val_loss improved from 0.61549 to 0.59308, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 91ms/step - loss: 0.8270 - val_loss: 0.5931
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7763
# Epoch 14: val_loss improved from 0.59308 to 0.57705, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 74ms/step - loss: 0.7864 - val_loss: 0.5770
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7620
# Epoch 15: val_loss improved from 0.57705 to 0.52136, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.7568 - val_loss: 0.5214
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6901
# Epoch 16: val_loss improved from 0.52136 to 0.51021, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 0.7156 - val_loss: 0.5102
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6911
# Epoch 17: val_loss improved from 0.51021 to 0.47004, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 84ms/step - loss: 0.6868 - val_loss: 0.4700
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6292
# Epoch 18: val_loss improved from 0.47004 to 0.46207, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 0.6577 - val_loss: 0.4621
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6356
# Epoch 19: val_loss improved from 0.46207 to 0.42251, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.6312 - val_loss: 0.4225
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6191
# Epoch 20: val_loss improved from 0.42251 to 0.40675, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 0.6040 - val_loss: 0.4068
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5946
# Epoch 21: val_loss improved from 0.40675 to 0.39364, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5896 - val_loss: 0.3936
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5911
# Epoch 22: val_loss improved from 0.39364 to 0.37991, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.5826 - val_loss: 0.3799
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5851
# Epoch 23: val_loss improved from 0.37991 to 0.36738, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 0.5703 - val_loss: 0.3674
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5048
# Epoch 24: val_loss improved from 0.36738 to 0.35157, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 89ms/step - loss: 0.5522 - val_loss: 0.3516
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4967
# Epoch 25: val_loss did not improve from 0.35157
# 2/2 [==============================] - 0s 76ms/step - loss: 0.5125 - val_loss: 0.3571
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5161
# Epoch 26: val_loss improved from 0.35157 to 0.32191, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 84ms/step - loss: 0.5037 - val_loss: 0.3219
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4688
# Epoch 27: val_loss improved from 0.32191 to 0.28014, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.4689 - val_loss: 0.2801
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4408
# Epoch 28: val_loss did not improve from 0.28014
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4402 - val_loss: 0.2853
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4368
# Epoch 29: val_loss improved from 0.28014 to 0.26231, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.4308 - val_loss: 0.2623
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4273
# Epoch 30: val_loss did not improve from 0.26231
# 2/2 [==============================] - 0s 51ms/step - loss: 0.4197 - val_loss: 0.2775
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4255
# Epoch 31: val_loss did not improve from 0.26231
# 2/2 [==============================] - 0s 49ms/step - loss: 0.4388 - val_loss: 0.2719
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4185
# Epoch 32: val_loss improved from 0.26231 to 0.24643, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.4130 - val_loss: 0.2464
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4035
# Epoch 33: val_loss did not improve from 0.24643
# 2/2 [==============================] - 0s 52ms/step - loss: 0.3984 - val_loss: 0.2478
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4172
# Epoch 34: val_loss did not improve from 0.24643
# 2/2 [==============================] - 0s 51ms/step - loss: 0.4091 - val_loss: 0.2625
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3873
# Epoch 35: val_loss did not improve from 0.24643
# 2/2 [==============================] - 0s 64ms/step - loss: 0.4247 - val_loss: 0.2475
#
#  La media del mse, 1-fold es : 0.8091748297214508
#
#  La desviacion estandar del mse, 1-fold es : 0.4059864638886005
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 60)                15120
#
#  dense_7 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.9821
# Epoch 1: val_loss improved from inf to 1.54230, saving model to modelo-3.h5
# 2/2 [==============================] - 3s 1s/step - loss: 1.9506 - val_loss: 1.5423
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7269
# Epoch 2: val_loss improved from 1.54230 to 1.42297, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 118ms/step - loss: 1.6996 - val_loss: 1.4230
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5932
# Epoch 3: val_loss improved from 1.42297 to 1.33014, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 141ms/step - loss: 1.5680 - val_loss: 1.3301
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4925
# Epoch 4: val_loss improved from 1.33014 to 1.25094, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 157ms/step - loss: 1.4640 - val_loss: 1.2509
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3163
# Epoch 5: val_loss improved from 1.25094 to 1.15215, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 135ms/step - loss: 1.3741 - val_loss: 1.1521
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2807
# Epoch 6: val_loss improved from 1.15215 to 1.09214, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 160ms/step - loss: 1.2560 - val_loss: 1.0921
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1591
# Epoch 7: val_loss improved from 1.09214 to 1.01067, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 128ms/step - loss: 1.1866 - val_loss: 1.0107
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0659
# Epoch 8: val_loss improved from 1.01067 to 0.94158, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 135ms/step - loss: 1.0845 - val_loss: 0.9416
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0000
# Epoch 9: val_loss improved from 0.94158 to 0.88720, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 138ms/step - loss: 0.9955 - val_loss: 0.8872
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8705
# Epoch 10: val_loss improved from 0.88720 to 0.84407, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 163ms/step - loss: 0.9252 - val_loss: 0.8441
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8638
# Epoch 11: val_loss improved from 0.84407 to 0.80565, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 146ms/step - loss: 0.8560 - val_loss: 0.8057
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8512
# Epoch 12: val_loss improved from 0.80565 to 0.77894, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 163ms/step - loss: 0.8307 - val_loss: 0.7789
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8172
# Epoch 13: val_loss improved from 0.77894 to 0.76061, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 173ms/step - loss: 0.8036 - val_loss: 0.7606
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7561
# Epoch 14: val_loss improved from 0.76061 to 0.71970, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 132ms/step - loss: 0.7888 - val_loss: 0.7197
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7412
# Epoch 15: val_loss improved from 0.71970 to 0.69699, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 117ms/step - loss: 0.7230 - val_loss: 0.6970
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6800
# Epoch 16: val_loss improved from 0.69699 to 0.68197, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 116ms/step - loss: 0.6985 - val_loss: 0.6820
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6363
# Epoch 17: val_loss did not improve from 0.68197
# 2/2 [==============================] - 0s 128ms/step - loss: 0.6609 - val_loss: 0.6855
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6272
# Epoch 18: val_loss did not improve from 0.68197
# 2/2 [==============================] - 0s 98ms/step - loss: 0.6433 - val_loss: 0.6958
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6336
# Epoch 19: val_loss improved from 0.68197 to 0.62842, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 109ms/step - loss: 0.6348 - val_loss: 0.6284
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6058
# Epoch 20: val_loss improved from 0.62842 to 0.61019, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5911 - val_loss: 0.6102
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5792
# Epoch 21: val_loss improved from 0.61019 to 0.59176, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 110ms/step - loss: 0.5795 - val_loss: 0.5918
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5916
# Epoch 22: val_loss improved from 0.59176 to 0.58255, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 130ms/step - loss: 0.5756 - val_loss: 0.5826
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5433
# Epoch 23: val_loss did not improve from 0.58255
# 2/2 [==============================] - 0s 121ms/step - loss: 0.5632 - val_loss: 0.5836
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5526
# Epoch 24: val_loss improved from 0.58255 to 0.56694, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 143ms/step - loss: 0.5382 - val_loss: 0.5669
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5300
# Epoch 25: val_loss improved from 0.56694 to 0.54797, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 152ms/step - loss: 0.5271 - val_loss: 0.5480
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4956
# Epoch 26: val_loss did not improve from 0.54797
# 2/2 [==============================] - 0s 89ms/step - loss: 0.5223 - val_loss: 0.5577
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4804
# Epoch 27: val_loss did not improve from 0.54797
# 2/2 [==============================] - 0s 55ms/step - loss: 0.5052 - val_loss: 0.5905
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5109
# Epoch 28: val_loss did not improve from 0.54797
# 2/2 [==============================] - 0s 77ms/step - loss: 0.5180 - val_loss: 0.6159
#
#  La media del mse, 2-fold es : 0.8951487179313388
#
#  La desviacion estandar del mse, 2-fold es : 0.39682622298930864
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 60)                15120
#
#  dense_8 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 3s - loss: 1.8906
# Epoch 1: val_loss improved from inf to 1.70425, saving model to modelo-4.h5
# 2/2 [==============================] - 4s 655ms/step - loss: 1.9397 - val_loss: 1.7042
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5803
# Epoch 2: val_loss improved from 1.70425 to 1.54007, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 84ms/step - loss: 1.6533 - val_loss: 1.5401
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5276
# Epoch 3: val_loss improved from 1.54007 to 1.44560, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 80ms/step - loss: 1.5031 - val_loss: 1.4456
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4044
# Epoch 4: val_loss improved from 1.44560 to 1.33109, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 1.4127 - val_loss: 1.3311
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2372
# Epoch 5: val_loss improved from 1.33109 to 1.20915, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 85ms/step - loss: 1.3066 - val_loss: 1.2092
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1581
# Epoch 6: val_loss improved from 1.20915 to 1.10741, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 74ms/step - loss: 1.1973 - val_loss: 1.1074
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1281
# Epoch 7: val_loss improved from 1.10741 to 1.04445, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 87ms/step - loss: 1.1068 - val_loss: 1.0444
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0679
# Epoch 8: val_loss improved from 1.04445 to 1.01538, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 1.0470 - val_loss: 1.0154
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9480
# Epoch 9: val_loss improved from 1.01538 to 0.90849, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 1.0118 - val_loss: 0.9085
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8966
# Epoch 10: val_loss improved from 0.90849 to 0.83644, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 0.9196 - val_loss: 0.8364
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8686
# Epoch 11: val_loss improved from 0.83644 to 0.81709, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 100ms/step - loss: 0.8581 - val_loss: 0.8171
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7861
# Epoch 12: val_loss improved from 0.81709 to 0.74519, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.8311 - val_loss: 0.7452
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7899
# Epoch 13: val_loss improved from 0.74519 to 0.71819, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 0.7716 - val_loss: 0.7182
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7619
# Epoch 14: val_loss improved from 0.71819 to 0.69633, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 81ms/step - loss: 0.7434 - val_loss: 0.6963
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7319
# Epoch 15: val_loss improved from 0.69633 to 0.69039, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.7213 - val_loss: 0.6904
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7214
# Epoch 16: val_loss improved from 0.69039 to 0.68640, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 118ms/step - loss: 0.7107 - val_loss: 0.6864
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6915
# Epoch 17: val_loss improved from 0.68640 to 0.60896, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 82ms/step - loss: 0.7006 - val_loss: 0.6090
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6057
# Epoch 18: val_loss improved from 0.60896 to 0.56820, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.6344 - val_loss: 0.5682
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6205
# Epoch 19: val_loss improved from 0.56820 to 0.54362, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.6053 - val_loss: 0.5436
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5922
# Epoch 20: val_loss improved from 0.54362 to 0.53034, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 0.5769 - val_loss: 0.5303
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5677
# Epoch 21: val_loss improved from 0.53034 to 0.50158, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5608 - val_loss: 0.5016
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4942
# Epoch 22: val_loss improved from 0.50158 to 0.50053, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 94ms/step - loss: 0.5385 - val_loss: 0.5005
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5514
# Epoch 23: val_loss improved from 0.50053 to 0.48401, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 91ms/step - loss: 0.5489 - val_loss: 0.4840
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5015
# Epoch 24: val_loss did not improve from 0.48401
# 2/2 [==============================] - 0s 80ms/step - loss: 0.5323 - val_loss: 0.5010
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5603
# Epoch 25: val_loss improved from 0.48401 to 0.46953, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 0.5510 - val_loss: 0.4695
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5054
# Epoch 26: val_loss improved from 0.46953 to 0.40287, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.5092 - val_loss: 0.4029
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4182
# Epoch 27: val_loss did not improve from 0.40287
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4340 - val_loss: 0.4190
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4441
# Epoch 28: val_loss did not improve from 0.40287
# 2/2 [==============================] - 0s 61ms/step - loss: 0.4488 - val_loss: 0.4395
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4792
# Epoch 29: val_loss did not improve from 0.40287
# 2/2 [==============================] - 0s 90ms/step - loss: 0.4666 - val_loss: 0.4045
#
#  La media del mse, 3-fold es : 0.8565997748539366
#
#  La desviacion estandar del mse, 3-fold es : 0.3875379717650306
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 60)                15120
#
#  dense_9 (Dense)             (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 3s - loss: 1.7511
# Epoch 1: val_loss improved from inf to 1.83272, saving model to modelo-5.h5
# 2/2 [==============================] - 5s 738ms/step - loss: 1.7210 - val_loss: 1.8327
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4035
# Epoch 2: val_loss improved from 1.83272 to 1.63324, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 72ms/step - loss: 1.4759 - val_loss: 1.6332
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2377
# Epoch 3: val_loss improved from 1.63324 to 1.49326, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 75ms/step - loss: 1.3045 - val_loss: 1.4933
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2096
# Epoch 4: val_loss improved from 1.49326 to 1.42188, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 1.1879 - val_loss: 1.4219
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1442
# Epoch 5: val_loss improved from 1.42188 to 1.34968, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 74ms/step - loss: 1.1236 - val_loss: 1.3497
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0539
# Epoch 6: val_loss improved from 1.34968 to 1.24638, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 1.0593 - val_loss: 1.2464
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9458
# Epoch 7: val_loss improved from 1.24638 to 1.14183, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.9759 - val_loss: 1.1418
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8396
# Epoch 8: val_loss improved from 1.14183 to 1.05189, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 0.8979 - val_loss: 1.0519
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8545
# Epoch 9: val_loss improved from 1.05189 to 1.01133, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 0.8367 - val_loss: 1.0113
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7430
# Epoch 10: val_loss improved from 1.01133 to 0.94084, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 88ms/step - loss: 0.7939 - val_loss: 0.9408
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7317
# Epoch 11: val_loss improved from 0.94084 to 0.89065, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 74ms/step - loss: 0.7512 - val_loss: 0.8906
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7046
# Epoch 12: val_loss improved from 0.89065 to 0.84836, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 0.7203 - val_loss: 0.8484
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6957
# Epoch 13: val_loss improved from 0.84836 to 0.81357, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 94ms/step - loss: 0.6938 - val_loss: 0.8136
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6176
# Epoch 14: val_loss improved from 0.81357 to 0.76698, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 0.6411 - val_loss: 0.7670
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5876
# Epoch 15: val_loss improved from 0.76698 to 0.73926, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.6206 - val_loss: 0.7393
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6050
# Epoch 16: val_loss improved from 0.73926 to 0.71094, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6180 - val_loss: 0.7109
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5994
# Epoch 17: val_loss improved from 0.71094 to 0.65950, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 85ms/step - loss: 0.6028 - val_loss: 0.6595
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5341
# Epoch 18: val_loss improved from 0.65950 to 0.65112, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5295 - val_loss: 0.6511
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4787
# Epoch 19: val_loss improved from 0.65112 to 0.60771, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 0.5107 - val_loss: 0.6077
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5047
# Epoch 20: val_loss improved from 0.60771 to 0.59098, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5039 - val_loss: 0.5910
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4752
# Epoch 21: val_loss improved from 0.59098 to 0.58481, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.4701 - val_loss: 0.5848
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4136
# Epoch 22: val_loss improved from 0.58481 to 0.54162, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4565 - val_loss: 0.5416
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4630
# Epoch 23: val_loss improved from 0.54162 to 0.52184, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.4590 - val_loss: 0.5218
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4315
# Epoch 24: val_loss improved from 0.52184 to 0.50349, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.4229 - val_loss: 0.5035
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4053
# Epoch 25: val_loss improved from 0.50349 to 0.48223, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 89ms/step - loss: 0.4117 - val_loss: 0.4822
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4180
# Epoch 26: val_loss improved from 0.48223 to 0.46679, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 87ms/step - loss: 0.4186 - val_loss: 0.4668
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3838
# Epoch 27: val_loss did not improve from 0.46679
# 2/2 [==============================] - 0s 78ms/step - loss: 0.3797 - val_loss: 0.4674
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3756
# Epoch 28: val_loss did not improve from 0.46679
# 2/2 [==============================] - 0s 75ms/step - loss: 0.3698 - val_loss: 0.5028
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3934
# Epoch 29: val_loss did not improve from 0.46679
# 2/2 [==============================] - 0s 56ms/step - loss: 0.3855 - val_loss: 0.5151
#
#  La media del mse, 4-fold es : 0.7359378337860107
#
#  La desviacion estandar del mse, 4-fold es : 0.3480983354196814

# %%
# rellenar de ceros los espacios vacios de la lista con loss y validation

df_train_losses = pd.DataFrame(train_losses)

df_filled_train_losses = df_train_losses.fillna(0)

train_losses_completa = df_filled_train_losses.values.tolist()

df_val_losses = pd.DataFrame(val_losses)

df_filled_val_losses = df_val_losses.fillna(0)

val_losses_completa = df_filled_val_losses.values.tolist()

# %%
# Calcular el promedio de "average loss" para todos los pliegues y épocas
avg_train_losses = np.mean(train_losses_completa, axis=0)
avg_val_losses = np.mean(val_losses_completa, axis=0)

# vamos a graficar
plt.plot(avg_train_losses, label='Perdida entrenamiento') # Grafico esta para ver si estoy sobre entrenando
plt.plot(avg_val_losses, label='Perdida Validacion') # Grafico esta para ver si estoy sobre entrenando
plt.title('avg loss train, avg loss val vs epoch ')
plt.xlabel('epoch')
plt.ylabel('Mean Square Error')
plt.legend()
plt.show()

# %%
# Cargar el mejor modelo
best_model = load_model(best_model_path)

# %%
# Seleccionar una secuencia específica
index = 0
input_sequence = X_test[index]

# Hacer la predicción
y_pred = best_model.predict(np.expand_dims(input_sequence, axis=0))
# usamos el np.expand_dims() para agregar una dimensión adicional al inicio de input_sequence
print(y_pred.shape)
# Out:
# 1/1 [==============================] - 1s 582ms/step
# (1, 210)

# %%
# Desenrollar X_test para convertirlo en un array bidimensional
X_test_flattened = X_test.reshape(-1, X_test.shape[-1])

# Aplicar la transformación inversa utilizando el objeto StandardScaler
X_test_desnormalizado = sc.inverse_transform(X_test_flattened)

# Volver a darle forma a X_test_desnormalizado a su forma original
X_test = X_test_desnormalizado.reshape(X_test.shape)

# Desnormalizar los datos
y_pred = sc_y.inverse_transform(y_pred)

y_test = sc_y.inverse_transform(y_test)

print(y_pred.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (1, 210)
# (17, 210)
# (17, 15, 2)

# %%
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
Curva=0

plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

print('')
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(X_test[Curva,:,0],color='orange', label='Valores actuales y anteriores de insulina')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_test[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 230.18977500000003

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_pred[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 319.2798983001709

# %%
# Media MSE y desviacion estandar MSE de las prediciones con la escala normal
mse = mean_squared_error(y_test[0,:].flatten(), y_pred.flatten())
std = np.sqrt(mse)
mediamse = np.mean(mse)

print('La media MSE:',mediamse)
print('La desviacion standar MSE', std)

# calcular la MAE
mae = mean_absolute_error(y_test[0,:], y_pred[0,:])
print('MAE:', mae)

# calcular la RMSE
rmse = np.sqrt(mean_squared_error(y_test[0,:], y_pred[0,:]))
print('RMSE:', rmse)
# Out:
# La media MSE: 1320.9209215344629
# La desviacion standar MSE 36.344475804920656
# MAE: 29.978245644705638
# RMSE: 36.344475804920656
