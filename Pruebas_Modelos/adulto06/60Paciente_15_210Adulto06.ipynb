# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Librerias
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split, KFold
from keras.callbacks import EarlyStopping

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import load_model

from keras.initializers import he_uniform

from tensorflow.keras.optimizers import RMSprop

# %%
#Dataset Adulto 01
data = pd.read_csv('/content/gdrive/MyDrive/Proyecto_de_grado/SUSTENTACION3.0/FinalX3/adulto06/my_adult06A2_data.csv')

print(f"El archivo se ha cargado correctamente. Tiene {data.shape[0]} filas y {data.shape[1]} columnas.")
# Out:
# El archivo se ha cargado correctamente. Tiene 28885 filas y 3 columnas.

# %%
train_size = int(len(data) * 0.7)

train_data = data.iloc[:train_size, :] # 70% entrenamiento
test_data = data.iloc[train_size:, :] # 30% prueba

test_data = test_data.reset_index(drop=True)

# %%
#los indices donde hay ingestas
posicionestrain = train_data.loc[train_data.iloc[:, 0] != 0].index
posicionestest = test_data.loc[test_data.iloc[:, 0] != 0].index

df_posiciones_train = pd.DataFrame(posicionestrain)
df_posiciones_test = pd.DataFrame(posicionestest)

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_train = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_train)):
    anterior = df_posiciones_train.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_train.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_train.append(anterior)

ultimo_elemento_train = df_posiciones_train.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_train.extend(ultimo_elemento_train.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_train)
print(len(cumplen_train))
# Out:
# [455, 821, 1302, 1903, 2264, 2745, 3346, 3707, 4188, 4789, 5150, 5631, 6232, 6593, 7074, 7675, 8036, 8517, 9118, 9479, 9960, 10561, 10922, 11403, 12004, 12365, 12846, 13447, 13808, 14289, 14890, 15251, 15732, 16333, 16694, 17175, 17776, 18137, 18618, 19219, 19580, 20061]
# 42

# %%
# Crear una lista para almacenar los valores anteriores que cumplen la condición
cumplen_test = []

# Comparar los elementos de la posición anterior con los elementos siguientes
for i in range(1, len(df_posiciones_test)):
    anterior = df_posiciones_test.iloc[i-1, 0]  # Obtener el elemento anterior de la segunda columna
    siguiente = df_posiciones_test.iloc[i, 0]  # Obtener el elemento actual de la segunda columna

    if siguiente >= 10 + anterior:
        cumplen_test.append(anterior)

ultimo_elemento_test = df_posiciones_test.iloc[-1]

# Unir el último elemento a la otra lista
cumplen_test.extend(ultimo_elemento_test.tolist())

# Imprimir la lista de valores anteriores que cumplen la condición
print(cumplen_test)
print(len(cumplen_test))
# Out:
# [443, 804, 1285, 1886, 2247, 2728, 3329, 3690, 4171, 4772, 5133, 5614, 6215, 6576, 7057, 7658, 8019, 8500]
# 18

# %%
# pasar la escala de los carbohidratos de las ingestas a gramos
data.iloc[:,0] = data.iloc[:,0].apply(lambda x: (x*15)/1000)

# Grafica con mayor detalle, el pico del comportamiento de la glucosa despues de la primera ingesta
print('')
print('Grafica de los datos del dataset')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
plt.title('Ingestas, Insulina y Glucosa')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')

print('Caso 1: Primera ingesta o Desayuno del primer dia:')
plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Caso 1: Desayuno del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 700])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 700])
plt.ylim([-5, 250])
plt.show()
print('')

print('Caso 2: Primera y segunda ingesta del primer dia:')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1200])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno y almuerzo del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1200])
plt.ylim([-5, 500])
plt.show()


print('Caso 3: las tres ingestas del primer dia:')

plt.plot(data.index, data.iloc[:,0], color='blue', label='Ingestas')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Ingestas de carbohidratos')
plt.xlabel('t [min]')
plt.ylabel('gramos')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')

plt.plot(data.index, data.iloc[:,1], color='orange', label='Insulina')
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Dosificación de insulina')
plt.xlabel('t [min]')
plt.ylabel('u [U/min]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')
#plt.plot(y_pred,color='orange', label='Valores predichos')
#plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.xlim([230, 1800])
#plt.ylim([185, 190])
plt.show()
print('')
plt.plot(data, label=['Ingestas', 'Insulina','Glucosa'])
#plt.plot(y_pred,color='orange', label='Valores predichos')
plt.title('Desayuno, almuerzo y cena del dia 1')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
plt.xlim([230, 1800])
plt.ylim([-5, 500])
plt.show()
# Out:
# Grafica de los datos del dataset
# Caso 1: Primera ingesta o Desayuno del primer dia:
# Caso 2: Primera y segunda ingesta del primer dia:
# Caso 3: las tres ingestas del primer dia:

# %%
#Preprocesar los datos:
X_train = train_data.iloc[:, 1:3].values
y_train = train_data.iloc[:,2].values

X_test = test_data.iloc[:, 1:3].values
y_test = test_data.iloc[:, 2].values

print('Tamaño de los datos de entrada, de X_train: ',X_train.shape)
print(f'Tiene {X_train.shape[0]} filas y {X_train.shape[1]} columna')
print('La primera ingesta al minuto 300, ingesta: ',X_train[300])
print('La primera ingesta hasta el minuto 327, ingesta: ',X_train[327])

print('La entrada son los valores de la insulina y glucosa \n',X_train)
print('Tamaño de los datos de salia, de y_train',y_train.shape)
print(f'Tiene {y_train.shape[0]} filas y {y_train.shape[-1]} columnas')
print('La salida son los valores de glucosa \n',y_train)
# Out:
# Tamaño de los datos de entrada, de X_train:  (20219, 2)
# Tiene 20219 filas y 2 columna
# La primera ingesta al minuto 300, ingesta:  [  1.6789 156.33  ]
# La primera ingesta hasta el minuto 327, ingesta:  [  1.6789 161.14  ]
# La entrada son los valores de la insulina y glucosa
#  [[  1.6789 115.57  ]
#  [  1.6789 115.57  ]
#  [  1.6789 115.57  ]
#  ...
#  [  1.6789 380.45  ]
#  [  1.6789 379.38  ]
#  [  1.6789 378.32  ]]
# Tamaño de los datos de salia, de y_train (20219,)
# Tiene 20219 filas y 20219 columnas
# La salida son los valores de glucosa
#  [115.57 115.57 115.57 ... 380.45 379.38 378.32]

# %%
# Normalizar los datos
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Normalizar y_train
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.reshape(-1, 1))
y_test = sc_y.transform(y_test.reshape(-1, 1))

# %%
# Reorganizar los datos en forma de secuencia
def to_sequences(data,  seq_size_input, seq_size_output):
    X = []
    y = []

    for i in range(len(data)-seq_size_input-seq_size_output+1):
        X.append(data[i:(i+seq_size_input), 0:2])
        y.append(data[(i+seq_size_input):(i+seq_size_input+seq_size_output), 2])

    return np.array(X), np.array(y)

# %%
#CON LOS DATOS NORMALIZADOS
seq_size_input = 15
seq_size_output = 210
X_train, y_train = to_sequences(np.hstack((X_train, y_train)), seq_size_input, seq_size_output)
X_test, y_test = to_sequences(np.hstack((X_test, y_test)), seq_size_input, seq_size_output)
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (19995, 210)
# (19995, 15, 2)
# (8442, 210)
# (8442, 15, 2)

# %%
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
flattened_data = np.reshape(X_train, (X_train.shape[0], -1))

df_X_train = pd.DataFrame(flattened_data)

# %%
flattened_test = np.reshape(X_test, (X_test.shape[0], -1))

df_X_test = pd.DataFrame(flattened_test)

# %%
df_y_train = pd.DataFrame(y_train)
df_y_test = pd.DataFrame(y_test)

# %%
# Filtrar el dataframe para mantener solo las filas especificadas
df_X_train_seleccionado = df_X_train[df_X_train.index.isin(cumplen_train)]
df_y_train_seleccionado = df_y_train[df_y_train.index.isin(cumplen_train)]
df_X_test_seleccionado = df_X_test[df_X_test.index.isin(cumplen_test)]
df_y_test_seleccionado = df_y_test[df_y_test.index.isin(cumplen_test)]

# %%
print('Grafica de los datos del dataset')
#plt.plot(data.index, data.iloc[:,2], color='green', label='Glucosa')

Numerocurva = 0

plt.plot(df_X_train_seleccionado.iloc[Numerocurva, 1::2],color='green',label='Entrada glucosa') #Para mostrar solo la glucosa
plt.plot(df_X_train_seleccionado.iloc[Numerocurva, ::2],color='orange',label='Entrada insulina') #Para mostrar solo la glucosa
plt.plot(range(seq_size_input*2, seq_size_output + seq_size_input*2),df_y_train_seleccionado.iloc[Numerocurva,:], color='red',label='Salida glucosa')
plt.title('Entradas y salidas, entrenamiento')
plt.xlabel('t [min]')
#plt.ylabel('Valor de la glucosa')
plt.legend()
#plt.xlim([209, 220])
#plt.ylim([185, 190])
plt.show()
print('')
# Out:
# Grafica de los datos del dataset

# %%
X_train = df_X_train_seleccionado.values
y_train = df_y_train_seleccionado.values
X_test = df_X_test_seleccionado.values
y_test = df_y_test_seleccionado.values

print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 30)
# (17, 210)
# (17, 30)

# %%
print(len(X_test))
# Out:
# 17

# %%
X_train = np.reshape(X_train, (len(X_train), seq_size_input, 2))

X_test = np.reshape(X_test, (len(X_test), seq_size_input, 2))
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (41, 210)
# (41, 15, 2)
# (17, 210)
# (17, 15, 2)

# %%
kf = KFold(n_splits=5)
kf.get_n_splits(X_train)
KFold(n_splits=5, random_state=None, shuffle=False)


# Crear listas para almacenar los valores del "average loss" de entrenamiento y validación en cada pliegue
train_losses = []
val_losses = []

#Para guardar el mejor modelo
best_loss = float('inf')
best_model_path = ""

for i, (train_index, test_index) in enumerate(kf.split(X_train,y_train)):
  model = Sequential()
  model.add(LSTM(60, activation='tanh', input_shape=(seq_size_input, 2), kernel_initializer=he_uniform()))
  model.add(Dense(seq_size_output, activation='linear', kernel_initializer=he_uniform()))


  model.compile(optimizer=RMSprop(), loss='mse')
  print(model.summary())

  filepath = f"modelo-{i+1}.h5"
  early_stop = EarlyStopping(monitor='val_loss', patience=3)
  checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

  X, y =  X_train[train_index], y_train[train_index]
  X_val, y_val = X_train[test_index], y_train[test_index]


  history = model.fit(X, y, epochs=100, batch_size=32,validation_data=(X_val, y_val),callbacks=[checkpoint, early_stop] )

  mediamse = np.mean( history.history['loss'] )
  stdmse = np.std(  history.history['loss'])
  print('')
  print(f" La media del mse, {i}-fold es : {mediamse}")
  print('')
  print(f" La desviacion estandar del mse, {i}-fold es : {stdmse}")

  # Obtener los valores de "average loss" para el pliegue actual
  fold_train_losses = model.history.history['loss']
  fold_val_losses = model.history.history['val_loss']

  # Almacenar los valores de "average loss" para el pliegue actual
  train_losses.append(fold_train_losses)
  val_losses.append(fold_val_losses)

  if min(fold_val_losses) < best_loss:
        best_loss = min(fold_val_losses)
        best_model_path = filepath

  history.history.keys() # aqui me muestra que esta guardando, con history me guarda todos los valores que calcula durante el proceso de entrenamiento

  # vamos a graficar
  plt.plot(history.history['loss'], label='Perdida') # Grafico esta para ver si estoy sobre entrenando
  plt.plot(history.history['val_loss'], label='Validacion') # Grafico esta para ver si estoy sobre entrenando
  plt.xlabel('epoch')
  plt.ylabel('Mean Square Error')
  plt.legend()
  plt.show()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 60)                15120
#
#  dense_10 (Dense)            (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5832
# Epoch 1: val_loss improved from inf to 1.55051, saving model to modelo-1.h5
# 1/1 [==============================] - 3s 3s/step - loss: 1.5832 - val_loss: 1.5505
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4671
# Epoch 2: val_loss improved from 1.55051 to 1.47554, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 1.4671 - val_loss: 1.4755
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3933
# Epoch 3: val_loss improved from 1.47554 to 1.41463, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 1.3933 - val_loss: 1.4146
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3338
# Epoch 4: val_loss improved from 1.41463 to 1.36157, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 1.3338 - val_loss: 1.3616
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2820
# Epoch 5: val_loss improved from 1.36157 to 1.31351, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 1.2820 - val_loss: 1.3135
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2352
# Epoch 6: val_loss improved from 1.31351 to 1.26915, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 1.2352 - val_loss: 1.2691
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1920
# Epoch 7: val_loss improved from 1.26915 to 1.22749, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 1.1920 - val_loss: 1.2275
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1516
# Epoch 8: val_loss improved from 1.22749 to 1.18792, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 1.1516 - val_loss: 1.1879
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1132
# Epoch 9: val_loss improved from 1.18792 to 1.15000, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 1.1132 - val_loss: 1.1500
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0766
# Epoch 10: val_loss improved from 1.15000 to 1.11346, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 1.0766 - val_loss: 1.1135
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0413
# Epoch 11: val_loss improved from 1.11346 to 1.07814, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 65ms/step - loss: 1.0413 - val_loss: 1.0781
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0073
# Epoch 12: val_loss improved from 1.07814 to 1.04395, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 79ms/step - loss: 1.0073 - val_loss: 1.0440
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9744
# Epoch 13: val_loss improved from 1.04395 to 1.01084, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 0.9744 - val_loss: 1.0108
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9426
# Epoch 14: val_loss improved from 1.01084 to 0.97876, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.9426 - val_loss: 0.9788
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9118
# Epoch 15: val_loss improved from 0.97876 to 0.94772, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 0.9118 - val_loss: 0.9477
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8822
# Epoch 16: val_loss improved from 0.94772 to 0.91772, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.8822 - val_loss: 0.9177
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8536
# Epoch 17: val_loss improved from 0.91772 to 0.88875, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.8536 - val_loss: 0.8888
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8261
# Epoch 18: val_loss improved from 0.88875 to 0.86084, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.8261 - val_loss: 0.8608
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7996
# Epoch 19: val_loss improved from 0.86084 to 0.83392, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.7996 - val_loss: 0.8339
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7742
# Epoch 20: val_loss improved from 0.83392 to 0.80821, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 87ms/step - loss: 0.7742 - val_loss: 0.8082
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7498
# Epoch 21: val_loss improved from 0.80821 to 0.78283, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 0.7498 - val_loss: 0.7828
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7266
# Epoch 22: val_loss improved from 0.78283 to 0.76184, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.7266 - val_loss: 0.7618
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7052
# Epoch 23: val_loss improved from 0.76184 to 0.73609, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.7052 - val_loss: 0.7361
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6837
# Epoch 24: val_loss improved from 0.73609 to 0.71660, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.6837 - val_loss: 0.7166
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6622
# Epoch 25: val_loss improved from 0.71660 to 0.69257, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.6622 - val_loss: 0.6926
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6413
# Epoch 26: val_loss improved from 0.69257 to 0.67375, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6413 - val_loss: 0.6738
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6214
# Epoch 27: val_loss improved from 0.67375 to 0.65198, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.6214 - val_loss: 0.6520
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6020
# Epoch 28: val_loss improved from 0.65198 to 0.63444, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6020 - val_loss: 0.6344
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5833
# Epoch 29: val_loss improved from 0.63444 to 0.61384, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.5833 - val_loss: 0.6138
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5652
# Epoch 30: val_loss improved from 0.61384 to 0.59859, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.5652 - val_loss: 0.5986
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5479
# Epoch 31: val_loss improved from 0.59859 to 0.57833, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.5479 - val_loss: 0.5783
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5313
# Epoch 32: val_loss improved from 0.57833 to 0.56698, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 97ms/step - loss: 0.5313 - val_loss: 0.5670
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5159
# Epoch 33: val_loss improved from 0.56698 to 0.54610, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 93ms/step - loss: 0.5159 - val_loss: 0.5461
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5010
# Epoch 34: val_loss improved from 0.54610 to 0.53883, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 98ms/step - loss: 0.5010 - val_loss: 0.5388
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4874
# Epoch 35: val_loss improved from 0.53883 to 0.51733, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 109ms/step - loss: 0.4874 - val_loss: 0.5173
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4733
# Epoch 36: val_loss improved from 0.51733 to 0.51071, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 100ms/step - loss: 0.4733 - val_loss: 0.5107
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4604
# Epoch 37: val_loss improved from 0.51071 to 0.49167, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 98ms/step - loss: 0.4604 - val_loss: 0.4917
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4477
# Epoch 38: val_loss improved from 0.49167 to 0.48458, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 97ms/step - loss: 0.4477 - val_loss: 0.4846
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4361
# Epoch 39: val_loss improved from 0.48458 to 0.46895, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 106ms/step - loss: 0.4361 - val_loss: 0.4690
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4252
# Epoch 40: val_loss improved from 0.46895 to 0.46199, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 84ms/step - loss: 0.4252 - val_loss: 0.4620
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4151
# Epoch 41: val_loss improved from 0.46199 to 0.44874, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 93ms/step - loss: 0.4151 - val_loss: 0.4487
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4056
# Epoch 42: val_loss improved from 0.44874 to 0.44241, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 107ms/step - loss: 0.4056 - val_loss: 0.4424
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3969
# Epoch 43: val_loss improved from 0.44241 to 0.43077, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 100ms/step - loss: 0.3969 - val_loss: 0.4308
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3886
# Epoch 44: val_loss improved from 0.43077 to 0.42533, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 83ms/step - loss: 0.3886 - val_loss: 0.4253
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3810
# Epoch 45: val_loss improved from 0.42533 to 0.41483, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 90ms/step - loss: 0.3810 - val_loss: 0.4148
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3738
# Epoch 46: val_loss improved from 0.41483 to 0.41038, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 84ms/step - loss: 0.3738 - val_loss: 0.4104
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3672
# Epoch 47: val_loss improved from 0.41038 to 0.40072, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 77ms/step - loss: 0.3672 - val_loss: 0.4007
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3609
# Epoch 48: val_loss improved from 0.40072 to 0.39729, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 111ms/step - loss: 0.3609 - val_loss: 0.3973
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3551
# Epoch 49: val_loss improved from 0.39729 to 0.38828, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 116ms/step - loss: 0.3551 - val_loss: 0.3883
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3496
# Epoch 50: val_loss improved from 0.38828 to 0.38580, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 105ms/step - loss: 0.3496 - val_loss: 0.3858
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3446
# Epoch 51: val_loss improved from 0.38580 to 0.37732, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 103ms/step - loss: 0.3446 - val_loss: 0.3773
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3397
# Epoch 52: val_loss improved from 0.37732 to 0.37564, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 90ms/step - loss: 0.3397 - val_loss: 0.3756
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3354
# Epoch 53: val_loss improved from 0.37564 to 0.36768, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 115ms/step - loss: 0.3354 - val_loss: 0.3677
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3310
# Epoch 54: val_loss improved from 0.36768 to 0.36653, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 109ms/step - loss: 0.3310 - val_loss: 0.3665
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3273
# Epoch 55: val_loss improved from 0.36653 to 0.35921, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 80ms/step - loss: 0.3273 - val_loss: 0.3592
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3234
# Epoch 56: val_loss improved from 0.35921 to 0.35836, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 78ms/step - loss: 0.3234 - val_loss: 0.3584
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3201
# Epoch 57: val_loss improved from 0.35836 to 0.35175, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 78ms/step - loss: 0.3201 - val_loss: 0.3517
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3167
# Epoch 58: val_loss improved from 0.35175 to 0.35113, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 0.3167 - val_loss: 0.3511
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3138
# Epoch 59: val_loss improved from 0.35113 to 0.34516, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 78ms/step - loss: 0.3138 - val_loss: 0.3452
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3108
# Epoch 60: val_loss improved from 0.34516 to 0.34485, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 96ms/step - loss: 0.3108 - val_loss: 0.3449
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3084
# Epoch 61: val_loss improved from 0.34485 to 0.33932, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 80ms/step - loss: 0.3084 - val_loss: 0.3393
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3057
# Epoch 62: val_loss did not improve from 0.33932
# 1/1 [==============================] - 0s 89ms/step - loss: 0.3057 - val_loss: 0.3394
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3036
# Epoch 63: val_loss improved from 0.33932 to 0.33415, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 94ms/step - loss: 0.3036 - val_loss: 0.3341
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3012
# Epoch 64: val_loss did not improve from 0.33415
# 1/1 [==============================] - 0s 82ms/step - loss: 0.3012 - val_loss: 0.3347
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2994
# Epoch 65: val_loss improved from 0.33415 to 0.32955, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 87ms/step - loss: 0.2994 - val_loss: 0.3295
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2971
# Epoch 66: val_loss did not improve from 0.32955
# 1/1 [==============================] - 0s 83ms/step - loss: 0.2971 - val_loss: 0.3303
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2957
# Epoch 67: val_loss improved from 0.32955 to 0.32546, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 0.2957 - val_loss: 0.3255
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2936
# Epoch 68: val_loss did not improve from 0.32546
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2936 - val_loss: 0.3262
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2923
# Epoch 69: val_loss improved from 0.32546 to 0.32180, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.2923 - val_loss: 0.3218
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2903
# Epoch 70: val_loss did not improve from 0.32180
# 1/1 [==============================] - 0s 81ms/step - loss: 0.2903 - val_loss: 0.3226
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2893
# Epoch 71: val_loss improved from 0.32180 to 0.31852, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 77ms/step - loss: 0.2893 - val_loss: 0.3185
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2875
# Epoch 72: val_loss did not improve from 0.31852
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2875 - val_loss: 0.3195
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2865
# Epoch 73: val_loss improved from 0.31852 to 0.31554, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 97ms/step - loss: 0.2865 - val_loss: 0.3155
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2848
# Epoch 74: val_loss did not improve from 0.31554
# 1/1 [==============================] - 0s 89ms/step - loss: 0.2848 - val_loss: 0.3166
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2841
# Epoch 75: val_loss improved from 0.31554 to 0.31284, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 84ms/step - loss: 0.2841 - val_loss: 0.3128
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2825
# Epoch 76: val_loss did not improve from 0.31284
# 1/1 [==============================] - 0s 89ms/step - loss: 0.2825 - val_loss: 0.3139
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2818
# Epoch 77: val_loss improved from 0.31284 to 0.31038, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 106ms/step - loss: 0.2818 - val_loss: 0.3104
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2803
# Epoch 78: val_loss did not improve from 0.31038
# 1/1 [==============================] - 0s 63ms/step - loss: 0.2803 - val_loss: 0.3115
# Epoch 79/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2797
# Epoch 79: val_loss improved from 0.31038 to 0.30814, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 81ms/step - loss: 0.2797 - val_loss: 0.3081
# Epoch 80/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2783
# Epoch 80: val_loss did not improve from 0.30814
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2783 - val_loss: 0.3093
# Epoch 81/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2778
# Epoch 81: val_loss improved from 0.30814 to 0.30609, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 106ms/step - loss: 0.2778 - val_loss: 0.3061
# Epoch 82/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2765
# Epoch 82: val_loss did not improve from 0.30609
# 1/1 [==============================] - 0s 64ms/step - loss: 0.2765 - val_loss: 0.3072
# Epoch 83/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2761
# Epoch 83: val_loss improved from 0.30609 to 0.30422, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 79ms/step - loss: 0.2761 - val_loss: 0.3042
# Epoch 84/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2748
# Epoch 84: val_loss did not improve from 0.30422
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2748 - val_loss: 0.3054
# Epoch 85/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2744
# Epoch 85: val_loss improved from 0.30422 to 0.30251, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.2744 - val_loss: 0.3025
# Epoch 86/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2732
# Epoch 86: val_loss did not improve from 0.30251
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2732 - val_loss: 0.3037
# Epoch 87/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2729
# Epoch 87: val_loss improved from 0.30251 to 0.30095, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.2729 - val_loss: 0.3009
# Epoch 88/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2718
# Epoch 88: val_loss did not improve from 0.30095
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2718 - val_loss: 0.3021
# Epoch 89/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2716
# Epoch 89: val_loss improved from 0.30095 to 0.29953, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.2716 - val_loss: 0.2995
# Epoch 90/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2705
# Epoch 90: val_loss did not improve from 0.29953
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2705 - val_loss: 0.3007
# Epoch 91/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2703
# Epoch 91: val_loss improved from 0.29953 to 0.29823, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.2703 - val_loss: 0.2982
# Epoch 92/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2693
# Epoch 92: val_loss did not improve from 0.29823
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2693 - val_loss: 0.2995
# Epoch 93/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2691
# Epoch 93: val_loss improved from 0.29823 to 0.29706, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.2691 - val_loss: 0.2971
# Epoch 94/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2682
# Epoch 94: val_loss did not improve from 0.29706
# 1/1 [==============================] - 0s 50ms/step - loss: 0.2682 - val_loss: 0.2983
# Epoch 95/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2681
# Epoch 95: val_loss improved from 0.29706 to 0.29601, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.2681 - val_loss: 0.2960
# Epoch 96/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2671
# Epoch 96: val_loss did not improve from 0.29601
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2671 - val_loss: 0.2973
# Epoch 97/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2671
# Epoch 97: val_loss improved from 0.29601 to 0.29505, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.2671 - val_loss: 0.2951
# Epoch 98/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2662
# Epoch 98: val_loss did not improve from 0.29505
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2662 - val_loss: 0.2964
# Epoch 99/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2662
# Epoch 99: val_loss improved from 0.29505 to 0.29420, saving model to modelo-1.h5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.2662 - val_loss: 0.2942
# Epoch 100/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2653
# Epoch 100: val_loss did not improve from 0.29420
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2653 - val_loss: 0.2956
#
#  La media del mse, 0-fold es : 0.5150287175178527
#
#  La desviacion estandar del mse, 0-fold es : 0.3270282785010433
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_11 (LSTM)              (None, 60)                15120
#
#  dense_11 (Dense)            (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.7277
# Epoch 1: val_loss improved from inf to 1.17659, saving model to modelo-2.h5
# 2/2 [==============================] - 3s 544ms/step - loss: 1.8007 - val_loss: 1.1766
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5979
# Epoch 2: val_loss improved from 1.17659 to 1.11115, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 1.5589 - val_loss: 1.1111
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5227
# Epoch 3: val_loss improved from 1.11115 to 1.04219, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 55ms/step - loss: 1.4931 - val_loss: 1.0422
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4529
# Epoch 4: val_loss improved from 1.04219 to 0.99625, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 1.4166 - val_loss: 0.9963
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3299
# Epoch 5: val_loss improved from 0.99625 to 0.89995, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 1.3660 - val_loss: 0.8999
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1990
# Epoch 6: val_loss improved from 0.89995 to 0.81512, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 1.2511 - val_loss: 0.8151
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1731
# Epoch 7: val_loss improved from 0.81512 to 0.78413, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 1.1466 - val_loss: 0.7841
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0563
# Epoch 8: val_loss improved from 0.78413 to 0.70769, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 1.1136 - val_loss: 0.7077
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0348
# Epoch 9: val_loss improved from 0.70769 to 0.68400, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 1.0149 - val_loss: 0.6840
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0178
# Epoch 10: val_loss improved from 0.68400 to 0.64783, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.9941 - val_loss: 0.6478
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9718
# Epoch 11: val_loss improved from 0.64783 to 0.62944, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.9520 - val_loss: 0.6294
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9539
# Epoch 12: val_loss improved from 0.62944 to 0.61237, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.9344 - val_loss: 0.6124
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9381
# Epoch 13: val_loss improved from 0.61237 to 0.59029, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.9165 - val_loss: 0.5903
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9148
# Epoch 14: val_loss improved from 0.59029 to 0.55152, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.8909 - val_loss: 0.5515
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8001
# Epoch 15: val_loss improved from 0.55152 to 0.48569, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.8403 - val_loss: 0.4857
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7034
# Epoch 16: val_loss improved from 0.48569 to 0.46844, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.7421 - val_loss: 0.4684
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7029
# Epoch 17: val_loss improved from 0.46844 to 0.42288, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.6964 - val_loss: 0.4229
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6801
# Epoch 18: val_loss improved from 0.42288 to 0.41171, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.6697 - val_loss: 0.4117
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6797
# Epoch 19: val_loss improved from 0.41171 to 0.39904, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 87ms/step - loss: 0.6633 - val_loss: 0.3990
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6177
# Epoch 20: val_loss improved from 0.39904 to 0.37557, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.6464 - val_loss: 0.3756
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6075
# Epoch 21: val_loss improved from 0.37557 to 0.35801, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.5949 - val_loss: 0.3580
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5966
# Epoch 22: val_loss improved from 0.35801 to 0.34938, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5839 - val_loss: 0.3494
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5953
# Epoch 23: val_loss improved from 0.34938 to 0.34389, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5811 - val_loss: 0.3439
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5846
# Epoch 24: val_loss improved from 0.34389 to 0.33994, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.5773 - val_loss: 0.3399
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5941
# Epoch 25: val_loss improved from 0.33994 to 0.33857, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.5796 - val_loss: 0.3386
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5947
# Epoch 26: val_loss improved from 0.33857 to 0.32742, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.5791 - val_loss: 0.3274
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5748
# Epoch 27: val_loss improved from 0.32742 to 0.32119, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.5648 - val_loss: 0.3212
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5536
# Epoch 28: val_loss improved from 0.32119 to 0.29580, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.5565 - val_loss: 0.2958
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5103
# Epoch 29: val_loss improved from 0.29580 to 0.27488, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.5020 - val_loss: 0.2749
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5049
# Epoch 30: val_loss improved from 0.27488 to 0.26620, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.4928 - val_loss: 0.2662
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4765
# Epoch 31: val_loss improved from 0.26620 to 0.25536, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.4706 - val_loss: 0.2554
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4705
# Epoch 32: val_loss improved from 0.25536 to 0.24693, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.4616 - val_loss: 0.2469
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4429
# Epoch 33: val_loss did not improve from 0.24693
# 2/2 [==============================] - 0s 53ms/step - loss: 0.4581 - val_loss: 0.2672
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4312
# Epoch 34: val_loss did not improve from 0.24693
# 2/2 [==============================] - 0s 44ms/step - loss: 0.4452 - val_loss: 0.2887
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4511
# Epoch 35: val_loss improved from 0.24693 to 0.22201, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.4465 - val_loss: 0.2220
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4084
# Epoch 36: val_loss improved from 0.22201 to 0.21539, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.4060 - val_loss: 0.2154
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3857
# Epoch 37: val_loss did not improve from 0.21539
# 2/2 [==============================] - 0s 45ms/step - loss: 0.4087 - val_loss: 0.2451
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4151
# Epoch 38: val_loss improved from 0.21539 to 0.21395, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.4084 - val_loss: 0.2139
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3866
# Epoch 39: val_loss did not improve from 0.21395
# 2/2 [==============================] - 0s 46ms/step - loss: 0.3905 - val_loss: 0.2400
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3973
# Epoch 40: val_loss improved from 0.21395 to 0.21024, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.3985 - val_loss: 0.2102
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3888
# Epoch 41: val_loss improved from 0.21024 to 0.19782, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.3839 - val_loss: 0.1978
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3828
# Epoch 42: val_loss improved from 0.19782 to 0.19756, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.3808 - val_loss: 0.1976
# Epoch 43/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3951
# Epoch 43: val_loss improved from 0.19756 to 0.19311, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.3881 - val_loss: 0.1931
# Epoch 44/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3911
# Epoch 44: val_loss improved from 0.19311 to 0.18944, saving model to modelo-2.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3838 - val_loss: 0.1894
# Epoch 45/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3839
# Epoch 45: val_loss did not improve from 0.18944
# 2/2 [==============================] - 0s 40ms/step - loss: 0.3802 - val_loss: 0.1937
# Epoch 46/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3864
# Epoch 46: val_loss did not improve from 0.18944
# 2/2 [==============================] - 0s 46ms/step - loss: 0.3878 - val_loss: 0.2023
# Epoch 47/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3753
# Epoch 47: val_loss did not improve from 0.18944
# 2/2 [==============================] - 0s 43ms/step - loss: 0.3725 - val_loss: 0.2166
#
#  La media del mse, 1-fold es : 0.7168263552036691
#
#  La desviacion estandar del mse, 1-fold es : 0.3649622018229349
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 60)                15120
#
#  dense_12 (Dense)            (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.6441
# Epoch 1: val_loss improved from inf to 1.33093, saving model to modelo-3.h5
# 2/2 [==============================] - 3s 787ms/step - loss: 1.6140 - val_loss: 1.3309
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4694
# Epoch 2: val_loss improved from 1.33093 to 1.24243, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 85ms/step - loss: 1.4386 - val_loss: 1.2424
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3699
# Epoch 3: val_loss improved from 1.24243 to 1.17227, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 92ms/step - loss: 1.3390 - val_loss: 1.1723
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2843
# Epoch 4: val_loss improved from 1.17227 to 1.10168, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 93ms/step - loss: 1.2586 - val_loss: 1.1017
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2035
# Epoch 5: val_loss improved from 1.10168 to 1.06821, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 72ms/step - loss: 1.1767 - val_loss: 1.0682
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1714
# Epoch 6: val_loss improved from 1.06821 to 1.03382, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 1.1423 - val_loss: 1.0338
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1332
# Epoch 7: val_loss improved from 1.03382 to 1.00169, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 81ms/step - loss: 1.1047 - val_loss: 1.0017
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0448
# Epoch 8: val_loss improved from 1.00169 to 0.91592, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 1.0661 - val_loss: 0.9159
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8887
# Epoch 9: val_loss improved from 0.91592 to 0.84823, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.9571 - val_loss: 0.8482
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8848
# Epoch 10: val_loss improved from 0.84823 to 0.82909, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 80ms/step - loss: 0.8668 - val_loss: 0.8291
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7972
# Epoch 11: val_loss improved from 0.82909 to 0.78364, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 113ms/step - loss: 0.8495 - val_loss: 0.7836
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7593
# Epoch 12: val_loss improved from 0.78364 to 0.75990, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 0.7814 - val_loss: 0.7599
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7574
# Epoch 13: val_loss improved from 0.75990 to 0.73430, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 85ms/step - loss: 0.7394 - val_loss: 0.7343
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7251
# Epoch 14: val_loss improved from 0.73430 to 0.71543, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 92ms/step - loss: 0.7165 - val_loss: 0.7154
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6570
# Epoch 15: val_loss improved from 0.71543 to 0.71439, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 0.6862 - val_loss: 0.7144
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6769
# Epoch 16: val_loss improved from 0.71439 to 0.67812, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 84ms/step - loss: 0.6615 - val_loss: 0.6781
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6516
# Epoch 17: val_loss improved from 0.67812 to 0.65979, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 0.6368 - val_loss: 0.6598
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6432
# Epoch 18: val_loss improved from 0.65979 to 0.64750, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 81ms/step - loss: 0.6267 - val_loss: 0.6475
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6212
# Epoch 19: val_loss improved from 0.64750 to 0.63649, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 85ms/step - loss: 0.6173 - val_loss: 0.6365
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6288
# Epoch 20: val_loss improved from 0.63649 to 0.62977, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.6188 - val_loss: 0.6298
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6271
# Epoch 21: val_loss improved from 0.62977 to 0.62352, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.6179 - val_loss: 0.6235
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6236
# Epoch 22: val_loss improved from 0.62352 to 0.61887, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6160 - val_loss: 0.6189
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6325
# Epoch 23: val_loss improved from 0.61887 to 0.60753, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.6152 - val_loss: 0.6075
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6131
# Epoch 24: val_loss improved from 0.60753 to 0.59811, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.6012 - val_loss: 0.5981
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6087
# Epoch 25: val_loss improved from 0.59811 to 0.58165, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5919 - val_loss: 0.5817
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5845
# Epoch 26: val_loss improved from 0.58165 to 0.57719, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 0.5694 - val_loss: 0.5772
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5289
# Epoch 27: val_loss improved from 0.57719 to 0.55201, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.5607 - val_loss: 0.5520
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4644
# Epoch 28: val_loss did not improve from 0.55201
# 2/2 [==============================] - 0s 46ms/step - loss: 0.4969 - val_loss: 0.5795
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5051
# Epoch 29: val_loss improved from 0.55201 to 0.53977, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.4954 - val_loss: 0.5398
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4756
# Epoch 30: val_loss improved from 0.53977 to 0.50996, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.4719 - val_loss: 0.5100
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4656
# Epoch 31: val_loss improved from 0.50996 to 0.50151, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.4605 - val_loss: 0.5015
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4749
# Epoch 32: val_loss improved from 0.50151 to 0.50103, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.4624 - val_loss: 0.5010
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4799
# Epoch 33: val_loss improved from 0.50103 to 0.49929, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.4669 - val_loss: 0.4993
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4756
# Epoch 34: val_loss improved from 0.49929 to 0.49121, saving model to modelo-3.h5
# 2/2 [==============================] - 0s 85ms/step - loss: 0.4675 - val_loss: 0.4912
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4703
# Epoch 35: val_loss did not improve from 0.49121
# 2/2 [==============================] - 0s 42ms/step - loss: 0.4614 - val_loss: 0.4983
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4852
# Epoch 36: val_loss did not improve from 0.49121
# 2/2 [==============================] - 0s 40ms/step - loss: 0.4748 - val_loss: 0.5022
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4944
# Epoch 37: val_loss did not improve from 0.49121
# 2/2 [==============================] - 0s 39ms/step - loss: 0.4812 - val_loss: 0.4957
#
#  La media del mse, 2-fold es : 0.7515992723606728
#
#  La desviacion estandar del mse, 2-fold es : 0.30599251252366105
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_13 (LSTM)              (None, 60)                15120
#
#  dense_13 (Dense)            (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 1s - loss: 1.7598
# Epoch 1: val_loss improved from inf to 1.62100, saving model to modelo-4.h5
# 2/2 [==============================] - 2s 536ms/step - loss: 1.7183 - val_loss: 1.6210
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5639
# Epoch 2: val_loss improved from 1.62100 to 1.46873, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 1.5698 - val_loss: 1.4687
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4621
# Epoch 3: val_loss improved from 1.46873 to 1.39120, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 1.4309 - val_loss: 1.3912
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3862
# Epoch 4: val_loss improved from 1.39120 to 1.31670, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 1.3584 - val_loss: 1.3167
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3201
# Epoch 5: val_loss improved from 1.31670 to 1.25217, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 1.2898 - val_loss: 1.2522
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2045
# Epoch 6: val_loss improved from 1.25217 to 1.14651, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 1.2281 - val_loss: 1.1465
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1617
# Epoch 7: val_loss improved from 1.14651 to 1.12238, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 1.1350 - val_loss: 1.1224
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1378
# Epoch 8: val_loss improved from 1.12238 to 1.09553, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 71ms/step - loss: 1.1096 - val_loss: 1.0955
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9755
# Epoch 9: val_loss improved from 1.09553 to 0.98183, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 1.0795 - val_loss: 0.9818
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9303
# Epoch 10: val_loss improved from 0.98183 to 0.90575, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.9784 - val_loss: 0.9058
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9349
# Epoch 11: val_loss improved from 0.90575 to 0.87875, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.9118 - val_loss: 0.8788
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9047
# Epoch 12: val_loss improved from 0.87875 to 0.86780, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.8862 - val_loss: 0.8678
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8283
# Epoch 13: val_loss improved from 0.86780 to 0.79199, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.8711 - val_loss: 0.7920
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8225
# Epoch 14: val_loss improved from 0.79199 to 0.77984, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.8055 - val_loss: 0.7798
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8112
# Epoch 15: val_loss improved from 0.77984 to 0.75425, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.7905 - val_loss: 0.7543
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7712
# Epoch 16: val_loss improved from 0.75425 to 0.70139, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.7656 - val_loss: 0.7014
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7361
# Epoch 17: val_loss improved from 0.70139 to 0.68434, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 57ms/step - loss: 0.7188 - val_loss: 0.6843
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6686
# Epoch 18: val_loss improved from 0.68434 to 0.63164, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.7004 - val_loss: 0.6316
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6734
# Epoch 19: val_loss improved from 0.63164 to 0.61054, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.6575 - val_loss: 0.6105
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5904
# Epoch 20: val_loss improved from 0.61054 to 0.58315, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.6339 - val_loss: 0.5832
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6181
# Epoch 21: val_loss improved from 0.58315 to 0.55712, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.6124 - val_loss: 0.5571
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5890
# Epoch 22: val_loss improved from 0.55712 to 0.55017, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5797 - val_loss: 0.5502
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5839
# Epoch 23: val_loss improved from 0.55017 to 0.54878, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.5702 - val_loss: 0.5488
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5253
# Epoch 24: val_loss improved from 0.54878 to 0.50886, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 74ms/step - loss: 0.5662 - val_loss: 0.5089
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5393
# Epoch 25: val_loss improved from 0.50886 to 0.49566, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5303 - val_loss: 0.4957
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5204
# Epoch 26: val_loss improved from 0.49566 to 0.49339, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5168 - val_loss: 0.4934
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5194
# Epoch 27: val_loss improved from 0.49339 to 0.48682, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.5116 - val_loss: 0.4868
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5113
# Epoch 28: val_loss improved from 0.48682 to 0.47871, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5023 - val_loss: 0.4787
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4987
# Epoch 29: val_loss improved from 0.47871 to 0.47555, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 56ms/step - loss: 0.4920 - val_loss: 0.4755
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4606
# Epoch 30: val_loss improved from 0.47555 to 0.43903, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.4836 - val_loss: 0.4390
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4294
# Epoch 31: val_loss did not improve from 0.43903
# 2/2 [==============================] - 0s 44ms/step - loss: 0.4442 - val_loss: 0.4406
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4424
# Epoch 32: val_loss improved from 0.43903 to 0.40496, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4368 - val_loss: 0.4050
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4151
# Epoch 33: val_loss improved from 0.40496 to 0.40065, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.4108 - val_loss: 0.4006
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3985
# Epoch 34: val_loss did not improve from 0.40065
# 2/2 [==============================] - 0s 49ms/step - loss: 0.4048 - val_loss: 0.4044
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3991
# Epoch 35: val_loss improved from 0.40065 to 0.38081, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 59ms/step - loss: 0.3948 - val_loss: 0.3808
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3829
# Epoch 36: val_loss improved from 0.38081 to 0.37507, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.3756 - val_loss: 0.3751
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3758
# Epoch 37: val_loss improved from 0.37507 to 0.37003, saving model to modelo-4.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.3694 - val_loss: 0.3700
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3293
# Epoch 38: val_loss did not improve from 0.37003
# 2/2 [==============================] - 0s 43ms/step - loss: 0.3639 - val_loss: 0.4044
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3784
# Epoch 39: val_loss did not improve from 0.37003
# 2/2 [==============================] - 0s 55ms/step - loss: 0.3717 - val_loss: 0.3742
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3549
# Epoch 40: val_loss did not improve from 0.37003
# 2/2 [==============================] - 0s 66ms/step - loss: 0.3495 - val_loss: 0.3895
#
#  La media del mse, 3-fold es : 0.7481468796730042
#
#  La desviacion estandar del mse, 3-fold es : 0.36240748878631
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_14 (LSTM)              (None, 60)                15120
#
#  dense_14 (Dense)            (None, 210)               12810
#
# =================================================================
# Total params: 27,930
# Trainable params: 27,930
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 2s - loss: 1.6549
# Epoch 1: val_loss improved from inf to 1.83821, saving model to modelo-5.h5
# 2/2 [==============================] - 4s 804ms/step - loss: 1.6164 - val_loss: 1.8382
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4757
# Epoch 2: val_loss improved from 1.83821 to 1.69680, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 73ms/step - loss: 1.4499 - val_loss: 1.6968
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3595
# Epoch 3: val_loss improved from 1.69680 to 1.63519, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 92ms/step - loss: 1.3268 - val_loss: 1.6352
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3017
# Epoch 4: val_loss improved from 1.63519 to 1.58074, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 110ms/step - loss: 1.2692 - val_loss: 1.5807
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1867
# Epoch 5: val_loss improved from 1.58074 to 1.44622, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 1.2168 - val_loss: 1.4462
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1337
# Epoch 6: val_loss improved from 1.44622 to 1.38256, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 1.1077 - val_loss: 1.3826
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0750
# Epoch 7: val_loss improved from 1.38256 to 1.30794, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 1.0532 - val_loss: 1.3079
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0166
# Epoch 8: val_loss improved from 1.30794 to 1.24664, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 84ms/step - loss: 0.9922 - val_loss: 1.2466
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9649
# Epoch 9: val_loss improved from 1.24664 to 1.18681, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 94ms/step - loss: 0.9412 - val_loss: 1.1868
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9106
# Epoch 10: val_loss improved from 1.18681 to 1.17694, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 89ms/step - loss: 0.8932 - val_loss: 1.1769
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9014
# Epoch 11: val_loss improved from 1.17694 to 1.10599, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.8800 - val_loss: 1.1060
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8446
# Epoch 12: val_loss improved from 1.10599 to 1.04041, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.8243 - val_loss: 1.0404
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7501
# Epoch 13: val_loss improved from 1.04041 to 0.93023, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.7722 - val_loss: 0.9302
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7122
# Epoch 14: val_loss did not improve from 0.93023
# 2/2 [==============================] - 0s 45ms/step - loss: 0.7036 - val_loss: 0.9329
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6166
# Epoch 15: val_loss improved from 0.93023 to 0.84655, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.6928 - val_loss: 0.8465
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6490
# Epoch 16: val_loss did not improve from 0.84655
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6471 - val_loss: 0.8472
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6270
# Epoch 17: val_loss improved from 0.84655 to 0.80292, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.6349 - val_loss: 0.8029
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6243
# Epoch 18: val_loss improved from 0.80292 to 0.77743, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 69ms/step - loss: 0.6127 - val_loss: 0.7774
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6119
# Epoch 19: val_loss improved from 0.77743 to 0.77245, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.5973 - val_loss: 0.7724
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5934
# Epoch 20: val_loss improved from 0.77245 to 0.74360, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 62ms/step - loss: 0.5843 - val_loss: 0.7436
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5861
# Epoch 21: val_loss improved from 0.74360 to 0.73999, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.5710 - val_loss: 0.7400
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5323
# Epoch 22: val_loss improved from 0.73999 to 0.71014, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.5588 - val_loss: 0.7101
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5774
# Epoch 23: val_loss improved from 0.71014 to 0.69516, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 58ms/step - loss: 0.5629 - val_loss: 0.6952
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5408
# Epoch 24: val_loss improved from 0.69516 to 0.67879, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.5388 - val_loss: 0.6788
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5451
# Epoch 25: val_loss improved from 0.67879 to 0.67335, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5426 - val_loss: 0.6734
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5643
# Epoch 26: val_loss improved from 0.67335 to 0.65467, saving model to modelo-5.h5
# 2/2 [==============================] - 0s 60ms/step - loss: 0.5522 - val_loss: 0.6547
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5135
# Epoch 27: val_loss did not improve from 0.65467
# 2/2 [==============================] - 0s 42ms/step - loss: 0.5138 - val_loss: 0.6657
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5103
# Epoch 28: val_loss did not improve from 0.65467
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5056 - val_loss: 0.6731
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5061
# Epoch 29: val_loss did not improve from 0.65467
# 2/2 [==============================] - 0s 49ms/step - loss: 0.5034 - val_loss: 0.6887
#
#  La media del mse, 4-fold es : 0.8160270678585974
#
#  La desviacion estandar del mse, 4-fold es : 0.3106319123683525

# %%
# rellenar de ceros los espacios vacios de la lista con loss y validation

df_train_losses = pd.DataFrame(train_losses)

df_filled_train_losses = df_train_losses.fillna(0)

train_losses_completa = df_filled_train_losses.values.tolist()

df_val_losses = pd.DataFrame(val_losses)

df_filled_val_losses = df_val_losses.fillna(0)

val_losses_completa = df_filled_val_losses.values.tolist()

# %%
# Calcular el promedio de "average loss" para todos los pliegues y épocas
avg_train_losses = np.mean(train_losses_completa, axis=0)
avg_val_losses = np.mean(val_losses_completa, axis=0)

# vamos a graficar
plt.plot(avg_train_losses, label='Perdida entrenamiento') # Grafico esta para ver si estoy sobre entrenando
plt.plot(avg_val_losses, label='Perdida Validacion') # Grafico esta para ver si estoy sobre entrenando
plt.title('avg loss train, avg loss val vs epoch ')
plt.xlabel('epoch')
plt.ylabel('Mean Square Error')
plt.legend()
plt.show()

# %%
# Cargar el mejor modelo
best_model = load_model(best_model_path)

# %%
# Seleccionar una secuencia específica
index = 0
input_sequence = X_test[index]

# Hacer la predicción
y_pred = best_model.predict(np.expand_dims(input_sequence, axis=0))
# usamos el np.expand_dims() para agregar una dimensión adicional al inicio de input_sequence
print(y_pred.shape)
# Out:
# 1/1 [==============================] - 0s 409ms/step
# (1, 210)

# %%
# Desenrollar X_test para convertirlo en un array bidimensional
X_test_flattened = X_test.reshape(-1, X_test.shape[-1])

# Aplicar la transformación inversa utilizando el objeto StandardScaler
X_test_desnormalizado = sc.inverse_transform(X_test_flattened)

# Volver a darle forma a X_test_desnormalizado a su forma original
X_test = X_test_desnormalizado.reshape(X_test.shape)

# Desnormalizar los datos
y_pred = sc_y.inverse_transform(y_pred)

y_test = sc_y.inverse_transform(y_test)

print(y_pred.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (1, 210)
# (17, 210)
# (17, 15, 2)

# %%
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
Curva=0

plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

print('')
# Grafica del comportamiento de la glucosa en el desayuno del dia 15
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_test[Curva,:],color='red', label='Valores reales de glucosa')
plt.plot(X_test[Curva,:,1],color='green', label='Valores actuales y anteriores de glucosa')
plt.plot(X_test[Curva,:,0],color='orange', label='Valores actuales y anteriores de insulina')
plt.plot(range(seq_size_input-1, seq_size_input-1+seq_size_output),y_pred[0,:],color='blue', label='Valores predichos de glucosa')
plt.title('Predicciones del comportamiento de la glucosa')
plt.xlabel('t [min]')
plt.ylabel('Gsc [mg/dL]')
plt.legend()
plt.show()

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_test[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 668.1403500000001

# %%
# Definir la matriz que contiene la curva
#fila_curva =  X_train[0,:,1] # Ejemplo de matriz con 3 filas

fila_curva =  y_pred[0,:] # Ejemplo de matriz con 3 filas

# Restarle la glucosa basal a cada elemento del array
for i in range(len(fila_curva)):
    fila_curva[i] -= 105

# Calcular el área bajo la curva usando la regla del trapecio
xx = np.arange(len(fila_curva))  # Valores x
yy = fila_curva  # Valores y
area = np.trapz(yy, xx)

arear = (area*15)/1000

print("El área bajo la curva es:", arear)
# Out:
# El área bajo la curva es: 716.3355670166015

# %%
# Media MSE y desviacion estandar MSE de las prediciones con la escala normal
mse = mean_squared_error(y_test[0,:].flatten(), y_pred.flatten())
std = np.sqrt(mse)
mediamse = np.mean(mse)

print('La media MSE:',mediamse)
print('La desviacion standar MSE', std)

# calcular la MAE
mae = mean_absolute_error(y_test[0,:], y_pred[0,:])
print('MAE:', mae)

# calcular la RMSE
rmse = np.sqrt(mean_squared_error(y_test[0,:], y_pred[0,:]))
print('RMSE:', rmse)
# Out:
# La media MSE: 1004.1135133008338
# La desviacion standar MSE 31.68775020888725
# MAE: 23.792619143531436
# RMSE: 31.68775020888725
